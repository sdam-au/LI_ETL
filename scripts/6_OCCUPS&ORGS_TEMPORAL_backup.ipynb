# %%
import pandas as pd
import numpy as np
import nltk
import requests
import re
import json
import random
import scipy

import geopandas

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.lines as mlines
from matplotlib.patches import Patch

import seaborn as sns
import geoplot as gplt

import warnings
warnings.filterwarnings('ignore')

from sklearn.feature_extraction.text import CountVectorizer
from gensim import corpora

import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe
from google.oauth2 import service_account # based on google-auth library

import sddk

# %%
# to access gsheet, you need Google Service Account key json file
# I have mine located in my personal space on sciencedata.dk, so I read it from there:
conf = sddk.configure()

# (1) read the file and parse its content
file_data = conf[0].get(conf[1] + "ServiceAccountsKey.json").json()
# (2) transform the content into crendentials object
credentials = service_account.Credentials.from_service_account_info(file_data)
# (3) specify your usage of the credentials
scoped_credentials = credentials.with_scopes(['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive'])
# (4) use the constrained credentials for authentication of gspread package
gc = gspread.Client(auth=scoped_credentials)
# (5) establish connection with spreadsheets specified by their url
occupations = gc.open_by_url("https://docs.google.com/spreadsheets/d/1nONTEwp42CVnq3iCiONrFbJedIcYtBV-l4Bil5mU7Eo/edit?usp=sharing")
# Out:
# sciencedata.dk username (format '123456@au.dk'): 648597@au.dk
# sciencedata.dk password: ········
# endpoint variable has been configured to: https://sciencedata.dk/files/

# %%
# login to our project folder
conf = sddk.configure("SDAM_root", "648597@au.dk")
# Out:
# sciencedata.dk username (format '123456@au.dk'): 648597@au.dk
# sciencedata.dk password: ········
# connection with shared folder established with you as its owner
# endpoint variable has been configured to: https://sciencedata.dk/files/SDAM_root/

# %%
# read the datasets
publicfolder = "e0f9cd400dd05584fe06fe1d804deff0"
EDH = sddk.read_file("EDH_urban_context.json", "df", publicfolder) # data with urban_context column
#EDH = sddk.read_file("EDH_occupsorgs_2021-02-26.json", "df", publicfolder)
EDCS = sddk.read_file("EDCS_urban_context.json", "df", publicfolder)
# Out:
# reading file located in a public folder
# reading file located in a public folder

# %%
len(EDCS)
# Out:
# 464483

# %%
len(EDCS[EDCS["language"].isnull()])
# Out:
# 464483

# %%
# focus on latin inscriptions only
EDH = EDH[EDH["language"].notnull()]
EDH = EDH[EDH["language"].str.contains("Latin")]
EDCS = EDCS[EDCS["language"].isnull()]

# %% [markdown]
# # Requirements

# %%
import pandas as pd
import numpy as np
import requests
import re
import json
import random
import scipy

import geopandas as gpd

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.lines as mlines
from matplotlib.patches import Patch

import seaborn as sns
import geoplot as gplt

import warnings
warnings.filterwarnings('ignore')

# %%
# read and execute our script for modelling dates - TEMPUN
script_url = "https://raw.githubusercontent.com/sdam-au/tempun/master/scripts/modelling_distributions.py"
# execute the script
exec(requests.get(script_url).content)

# %% [markdown]
# # Import the dataset

# %%
EDHCS = pd.read_csv("../data/large_data/EDHCS_occupsorgs.csv", low_memory=False, index_col=None)
EDHCS["geometry"] = EDHCS["geometry"].apply(eval)
EDHCSg = gpd.GeoDataFrame(EDHCS, geometry=gpd.points_from_xy(EDHCS["geometry"].apply(lambda x: x[0]), EDHCS["geometry"].apply(lambda x: x[1]))) #, crs={"init": "epsg:3857"})

# %% [markdown]
# # Exploring durations

# %%
def get_duration(start, stop):
  try:
    duration = abs(int(start) - int(stop)) + 1
    if 0 in range(int(start),  int(stop)):
      duration = duration - 1
  except:
    duration = np.nan
  return duration

EDHCSg["duration"] = EDHCSg.apply(lambda row: get_duration(row["not_before"], row["not_after"]), axis=1)

# %%
# %%time 
plt.style.use("seaborn-white")
plt.rcParams['figure.dpi'] = 300
plt.rcParams["font.family"] = "serif"
plt.rcParams['font.size'] = 8

fig, ax = plt.subplots(figsize=(5.2, 2.6), tight_layout=True)
sns.histplot(EDHCSg["duration"], kde=False, bins=range(-5, 305,10), color="tab:blue", ax=ax)
ax.set_xlim(-5, 305)
# Out:
# CPU times: user 192 ms, sys: 0 ns, total: 192 ms
# Wall time: 189 ms
# (-5.0, 305.0)

# %%
fig.savefig("../figures/durations_historgram.eps", format="eps", dpi=300)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
len(EDHCSg)
# Out:
# 136190

# %%
durations_df = pd.DataFrame(EDHCSg.groupby("duration").size().sort_values(ascending=False))
durations_df.reset_index(inplace=True)
durations_df = durations_df.astype(int)
durations_df.columns = ["duration", "count"]
durations_df["pct"] = np.round((durations_df["count"] / len(EDHCSg)) * 100, 2)
durations_df.head(20)
# Out:
#     duration  count    pct
# 0        100  33920  24.91
# 1        200  17658  12.97
# 2         50  15102  11.09
# 3        150   7542   5.54
# 4        300   5343   3.92
# 5         60   5176   3.80
# 6          1   4332   3.18
# 7         30   3471   2.55
# 8         40   2675   1.96
# 9        130   2652   1.95
# 10        80   2550   1.87
# 11         2   2046   1.50
# 12        70   2038   1.50
# 13        79   1725   1.27
# 14        28   1285   0.94
# 15         3   1150   0.84
# 16         6   1070   0.79
# 17        20    941   0.69
# 18         4    845   0.62
# 19        41    758   0.56

# %%
durations_df.to_csv("../data/durations_table.csv")

# %% [markdown]
# # Random dates and overall simulations

# %%
# %%time
# generate a list of 1000 random dates for each inscription in the dataset
# takes approx. 90 seconds in Google colab
EDHCSg["random_dates"] = EDHCSg.apply(lambda row: model_date(row["not_before"], row["not_after"], size=1000,), axis=1)
# Out:
# CPU times: user 1min 7s, sys: 1.43 s, total: 1min 9s
# Wall time: 1min 9s

# %%
# %%time
EDHCS_complete_simulations = timeblocks_from_randoms(EDHCS, "random_dates", [-50, 350, 50])
# Out:
# CPU times: user 8.03 s, sys: 39.9 ms, total: 8.07 s
# Wall time: 8.07 s

# %%
EDHCS_complete_simulations[0]
# Out:
# [((-50, -1), 5244),
#  ((1, 50), 20155),
#  ((51, 100), 20063),
#  ((101, 150), 22289),
#  ((151, 200), 21972),
#  ((201, 250), 17702),
#  ((251, 300), 9806),
#  ((301, 350), 7974)]

# %%
def simulations_merged(simulation_data):
    merged_data = []
    for n in range(len(simulation_data[0])): # choose the first simulation to get the length 
        merged_data.append((simulation_data[0][n][0], [sim[n][1] for sim in simulation_data]))
    return merged_data

# %%
EDHCS_complete_merged = simulations_merged(EDHCS_complete_simulations)

# %%
len(EDHCS_complete_merged)
# Out:
# 8

# %% [markdown]
# # Comparing distributions by means of KDE

# %%
# periods definitions

periods = { # to avoid overlaps, startdates are postponed by one year, when needed
    "Julio-Claudian" : {"startdate": -27, "enddate" : 68},
    "Flavian" : {"startdate": 69, "enddate": 96},
    "Nerva-Antonine" : {"startdate" : 97, "enddate" : 192},
    "Severan" : {"startdate": 193, "enddate": 235},
    "Barracks emperors" : {"startdate" : 236, "enddate" : 284},
    "Tetrarchy\n& Constantine I" : {"startdate" : 285, "enddate" : 337}
    }
tab_colors_list = list(mcolors.TABLEAU_COLORS.keys())

timeblocks_periods = [(periods[period]["startdate"], periods[period]["enddate"]) for period in periods]
timeblocks_periods
# Out:
# [(-27, 68), (69, 96), (97, 192), (193, 235), (236, 284), (285, 337)]

# %%
periods_duration = [abs(tup[1] - tup[0]) for tup in timeblocks_periods]
periods_duration
# Out:
# [95, 27, 95, 42, 48, 52]

# %%
var_data_edhcs = []
for var_n in range(1000):
    var_data_edhcs.append([var[var_n] for var in EDHCS["random_dates"] if var !=None])

# %%
# %%time 
plt.style.use("fast")
plt.rcParams['figure.dpi'] = 300
plt.rcParams["font.family"] = "serif"
plt.rcParams['font.size'] = 8

# timeconsuming, because of the KDE involved
labels=[key for key in periods.keys()]
positions = [np.mean(tup) for tup in timeblocks_periods]

fig, ax = plt.subplots(figsize=[5.2,3])

for data in var_data_edhcs[:100]:
    sns.kdeplot(data, ax=ax, color="black")
for period, color in zip(periods.keys(), tab_colors_list):
    ax.axvspan(periods[period]["startdate"], periods[period]["enddate"], color=color, alpha=0.5)#, linestyles="dashed", color="red")
ax.set_xlim(-50,350)
ax.set_ylabel("KDE")


# period labels
ax.set_xticks(positions)
ax.set_xticklabels(labels)
ax.xaxis.set_tick_params(rotation=90)
ax.xaxis.tick_top()

# time ticks
ax.secondary_xaxis("bottom")
# Out:
# CPU times: user 1min 48s, sys: 1min 39s, total: 3min 27s
# Wall time: 52.2 s

# %%
fig.savefig("../figures/temporal_kde_all.eps", format="eps", dpi=300)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# %%time
sim_big = timeblocks_from_randoms(EDHCS[EDHCS["urban_context"]=="big"], "random_dates", [-50, 350, 50])
sim_middle = timeblocks_from_randoms(EDHCS[EDHCS["urban_context"]=="middle"], "random_dates", [-50, 350, 50])
sim_rest = timeblocks_from_randoms(EDHCS[EDHCS["urban_context"]=="rest"], "random_dates", [-50, 350, 50])
# Out:
# CPU times: user 5.81 s, sys: 119 ms, total: 5.93 s
# Wall time: 5.93 s

# %%
# %%time 
plt.style.use("fast")
plt.rcParams['figure.dpi'] = 300
plt.rcParams["font.family"] = "serif"
plt.rcParams['font.size'] = 8

labels=[key for key in periods.keys()]
positions = [np.mean(tup) for tup in timeblocks_periods]

fig, [ax1, ax2] = plt.subplots(2,1, figsize=[5.2,4.5], tight_layout=True)

# ax1 - EDH KDE plot
for data in var_data_edhcs[:100]:
    sns.kdeplot(data, ax=ax1, color="black")   

for period, color in zip(periods.keys(), tab_colors_list):
    ax1.axvspan(periods[period]["startdate"], periods[period]["enddate"], color=color, alpha=0.5)#, linestyles="dashed", color="red")
ax1.set_xlim(-50,350)
# period labels
ax1.set_xticks(positions)
ax1.set_xticklabels(labels)
ax1.xaxis.set_tick_params(rotation=90)
ax1.xaxis.tick_top()
ax1.set_ylabel("KDE")

# ax2 - timeblocks
plot_timeblocks_data(sim_big, color="darkblue", ax=ax2)
plot_timeblocks_data(sim_middle, color="darkred", ax=ax2)
plot_timeblocks_data(sim_rest, color="darkgreen", ax=ax2)
ax2.set_ylabel("count")
ax2.set_xlim(-50,350)

legend_labels=[
    "cities\n(pop.≥30K)",
    "cities\n(pop.>1K)",
    "rural areas\nor minor\ncities"]

colors=["darkblue", "darkred", "darkgreen"]
markers = [plt.Line2D([0,0],[0,0],color=color, lw=2) for color in colors]
ax2.legend(markers, legend_labels, numpoints=1,  title="Urban context", bbox_to_anchor=(1, 1), loc='upper left')
# Out:
# CPU times: user 1min 47s, sys: 1min 38s, total: 3min 25s
# Wall time: 53.2 s

# %%
fig.savefig("../figures/temporal_distribution_by_context.eps", format="eps", dpi=300)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Spatial dissemination of inscriptions

# %%
def get_date_var(randoms):
    try: return randoms[0]
    except: return None
EDHCSg["date_var_1"] = EDHCSg["random_dates"].apply(get_date_var)

# %%
def date_to_str(date):
    if date < 0:
        date = str(abs(date)) + "BC"
    else: 
        date = str(date) + "AD"
    return date

periods_labels = []
for period in periods.keys():
    start = date_to_str(periods[period]["startdate"])
    end = date_to_str(periods[period]["enddate"])
    periods_labels.append(period + " ({0}-{1})".format(start, end))
periods_labels
# Out:
# ['Julio-Claudian (27BC-68AD)',
#  'Flavian (69AD-96AD)',
#  'Nerva-Antonine (97AD-192AD)',
#  'Severan (193AD-235AD)',
#  'Barracks emperors (236AD-284AD)',
#  'Tetrarchy\n& Constantine I (285AD-337AD)']

# %%
### # pelagios provinces - only for plotting purposes
pleiades_regions = gpd.read_file('../data/pleiades_regions.geojson', driver='GeoJSON')

# %%
edhcs_df_by_periods = []

for period in timeblocks_periods:
    edhcs_sample = EDHCSg[EDHCSg["date_var_1"].between(period[0], period[1])]
    edhcs_df_by_periods.append(edhcs_sample)

# %%
plt.style.use("seaborn-white")
plt.rcParams['figure.dpi'] = 300
plt.rcParams["font.family"] = "serif"
plt.rcParams['font.size'] = 8

fig, axs  = plt.subplots(3, 2, figsize=(5.2, 5.2), tight_layout=True)

contexts_pct = {}

for df, ax, period in zip(edhcs_df_by_periods, axs.ravel(), periods_labels):
    pleiades_regions.plot(ax=ax, color="lightgray")
    #gplt.kdeplot(df, cmap='Reds', shade=True, thresh=0.05, alpha=0.5, ax=ax)
    for context, color in [("rest", "orange"), ("middle", "red"), ("big", "darkred")]:
        df_context = df[df["urban_context"]==context]
        contexts_pct[context] = str(np.round(((len(df_context) / len(df)) * 100), 2)) + "%"
        df_context.plot(markersize=0.1, color=color, ax=ax)
    ax.set_title(period, fontsize=8)
    ax.set_axis_off()
    markers = [plt.Line2D([0,0],[0,0],color=color, marker=".", linestyle="") for color in ["darkred", "red", "orange"]]
    legend_labels = ["Big cities ({0})".format(contexts_pct["big"]), "Middle cities ({0})".format(contexts_pct["middle"]), "Rural areas ({0})".format(contexts_pct["rest"])]
    ax.legend(markers, legend_labels, numpoints=1, bbox_to_anchor=(0.65, 1.05), loc='upper left', fontsize=6)

plt.subplots_adjust(wspace=0, hspace=0)

# %%
fig.savefig("../figures/spatial_distribution_tempo.eps", format="eps", dpi=300)

# %% [markdown]
# # Occupations and organizations over time

# %%
var_data_occups, var_data_orgs = [], []
for var_n in range(1000):
    var_data_occups.append([var[var_n] for var in EDH[EDH["occups_N"] > 0]["random_dates"] if var !=None])
    var_data_orgs.append([var[var_n] for var in EDH[EDH["organizations_N"] > 0]["random_dates"] if var !=None])

# %%
len(EDH[(EDH["occups_N"] > 0) & (EDH["random_dates"].notnull())])
# Out:
# 1224

# %%
print(len(var_data_occups[0]))
print(len(var_data_orgs[0]))
# Out:
# 1224
# 529

# %%
sample_size = len(var_data_occups[0]) + len(var_data_orgs[0])
sample_size
# Out:
# 1753

# %%
# %%time 
# timeconsuming, because of the KDE involved
labels=[key for key in periods.keys()]
positions = [np.mean(tup[0]) for tup in occups_ratios_merged]

fig, ax = plt.subplots(figsize=[6,4])

for period, color in zip(periods.keys(), tab_colors_list):
    ax.axvspan(periods[period]["startdate"], periods[period]["enddate"], color=color, alpha=0.2)#, linestyles="dashed", color="red")


for data in var_data[:100]:
    # to be based on sample or not... 
    data = random.sample(data, k=sample_size)
    sns.kdeplot(data, ax=ax, color="darkgrey", alpha=0.5)   
    
for data in var_data_occups[:100]:
    sns.kdeplot(data, ax=ax, color="green", alpha=0.5)
    
for data in var_data_orgs[:100]:
    sns.kdeplot(data, ax=ax, color="blue", alpha=0.5)
 

    
ax.set_xlim(-50,350)



ax.set_ylabel("KDE")

# period labels
ax.set_xticks(positions)
ax.set_xticklabels(labels)
ax.xaxis.set_tick_params(rotation=90)
ax.xaxis.tick_top()

# time ticks
ax.secondary_xaxis("bottom")


markers = [plt.Line2D([0,0],[0,0],color=color, lw=4) for color in ["darkgrey", "green", "blue"]]
plt.legend(markers, ["Ins. total", "Ins. mentioning\noccupations", "Ins. mentioning\norganizations"], bbox_to_anchor=(1, 1), loc='upper left')
# Out:
# CPU times: user 3.32 s, sys: 81.8 ms, total: 3.4 s
# Wall time: 3.23 s

# %% [markdown]
# # Statistical comparison
#
#
# We use two-sample Kolmogorov-Smirnov test, which checks whether  two data samples come from the same distribution. This does not specify what that common distribution is (e.g. whether it's normal or not normal).
#
# We employ it to compare distribution of all iscriptions mentioning an occupation/organization against a distribution based on a random sample of inscriptions of the same length. We repeat this procedure for all dating simulations and evaluate the consinstency of the findings.

# %%
# one variant example
scipy.stats.kstest(var_data_orgs[0], random.sample(var_data[0], k=len(var_data_orgs[0])))
# Out:
# KstestResult(statistic=0.1833648393194707, pvalue=3.4677011823818415e-08)

# %%
random.seed(0)

p_values, KS_stats = [], []
for var_n in range(len(var_data)):
    ks, p = scipy.stats.ks_2samp(var_data_orgs[var_n], random.sample(var_data[var_n], k=len(var_data_orgs[var_n])))
    KS_stats.append(ks)
    p_values.append(p)
len([p for p in p_values if p < 0.001])
# Out:
# 998

# %% [markdown]
# In the case of organizations, there is a robust difference in the distributions, with p < 0.001 in more than 99% of cases.

# %%
random.seed(0)

p_values, KS_stats = [], []
for var_n in range(len(var_data)):
    ks, p = scipy.stats.ks_2samp(var_data_occups[var_n], random.sample(var_data[var_n], k=len(var_data_occups[var_n])))
    KS_stats.append(ks)
    p_values.append(p)
len([p for p in p_values if p < 0.001])
# Out:
# 35

# %%
len([p for p in p_values if p < 0.05])
# Out:
# 619

# %% [markdown]
# In the case of occuptions, the difference is much smaller, with p<0.05 in only about 62% of cases.

# %%
# counts on the basis of periods
EDH_complete_periods = timeblocks_from_randoms(EDH, "random_dates", timeblocks_periods)
EDH_complete_periods[0]
# Out:
# [((-27, 67), 7690),
#  ((69, 96), 4137),
#  ((97, 193), 22235),
#  ((194, 235), 10351),
#  ((236, 284), 7446),
#  ((285, 337), 3074)]

# %% [markdown]
# # Inscriptions over time: Word counts & character counts

# %%
# functions to be used to extract interesting information from timeblocks simulation data

def wordcount(timeblock_df, column="clean_text_interpretive_word"):
    """number of words in inscriptions within timeblock"""
    return timeblock_df[column].astype(str).apply(lambda x: len(x.split())).sum()

def wordcount_avg(timeblock_df, column="clean_text_interpretive_word"):
    """average number of words in inscriptions within timeblock"""
    return timeblock_df[column].astype(str).apply(lambda x: len(x.split())).sum() / len(timeblock_df)

def charcount(timeblock_df, column="clean_text_interpretive_word"):
    """number of characters in inscriptions within timeblock"""
    return timeblock_df[column].astype(str).apply(lambda x: len(x)).sum()

def charcount_avg(timeblock_df, column="clean_text_interpretive_word"):
    """average number of characters in inscriptions within timeblock"""
    return timeblock_df[column].astype(str).apply(lambda x: len(x)).sum() / len(timeblock_df)

def unique_words(timeblock_df, column="clean_text_interpretive_word"):
    """number of unique words in inscriptions within timeblock"""
    inscriptions_list = timeblock_df[column].astype(str).tolist()
    unique_words = len(set(" ".join(inscriptions_list).split()))
    return unique_words

def unique_words_weighted(timeblock_df, column="clean_text_interpretive_word"):
    """number of unique words in inscriptions within timeblock
    in proportion to total number of words"""
    wordcount = timeblock_df[column].astype(str).apply(lambda x: len(x.split())).sum()
    inscriptions_list = timeblock_df[column].astype(str).tolist()
    unique_words = len(set(" ".join(inscriptions_list).split()))
    return unique_words / wordcount

def extract_ngrams(text, width=4):
    """extracts character ngrams from a string of given width
    returns: list of ngrams"""
    char_ngrams = ["".join(ngram) for ngram in list(ngrams(str(text), width))]
    return char_ngrams

def unique_ngrams(timeblock_df, column="clean_text_interpretive_word"):
    """number of unique ngrams in inscriptions within timeblock"""
    ngrams_series = timeblock_df[column].astype(str).apply(extract_ngrams)
    all_ngrams = [el for sublist in ngrams_series for el in sublist]
    all_ngrams_unique = list(set(all_ngrams))
    charcount = timeblock_df[column].astype(str).apply(lambda x: len(x)).sum()
    return len(all_ngrams_unique)

def unique_ngrams_weighted(timeblock_df, column="clean_text_interpretive_word"):
    """number of unique ngrams in inscriptions within timeblock
    in proportion to total number of characters"""
    ngrams_series = timeblock_df[column].astype(str).apply(extract_ngrams)
    all_ngrams = [el for sublist in ngrams_series for el in sublist]
    all_ngrams_unique = list(set(all_ngrams))
    charcount = timeblock_df[column].astype(str).apply(lambda x: len(x)).sum()
    return len(all_ngrams_unique) / charcount

# %%
# %%time
wordcounts_data = sim_data_by_function(EDH, 100, [-200, 600, 50], wordcount) 
wordcounts_avg_data = sim_data_by_function(EDH, 100, [-200, 600, 50], wordcount_avg) 
charcounts_data = sim_data_by_function(EDH, 100, [-200, 600, 50], charcount) 
charcounts_avg_data = sim_data_by_function(EDH, 100, [-200, 600, 50], charcount_avg) 
unique_words_data = sim_data_by_function(EDH, 100, [-200, 600, 50], unique_words)
unique_ngrams_data = sim_data_by_function(EDH, 100, [-200, 600, 50], unique_ngrams)
# Out:
# CPU times: user 6min 57s, sys: 7.72 s, total: 7min 4s
# Wall time: 6min 54s

# %%
sim_data_list = [
    (EDH_complete_simulations, "(A) EDH - inscription counts", "count"),
    (wordcounts_data, "(B) EDH - wordcounts", "wordcount"),
    (charcounts_data,  "(C) EDH - character counts", "character count"),
    (unique_words_data, "(D) EDH - unique words counts", "count"),
    (unique_ngrams_data, "(E) EDH - unique character four-grams", "count"),
    (charcounts_avg_data, "(F) EDH - average character counts per inscription", "avr. char. count")]
    #(wordcounts_avg_data, "(E) EDH - average wordcounts per inscription", "avr. wordcount"),

# %%
tab_colors_list = list(mcolors.TABLEAU_COLORS.keys())
tab_colors_list
# Out:
# ['tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:purple',
#  'tab:brown',
#  'tab:pink',
#  'tab:gray',
#  'tab:olive',
#  'tab:cyan']

# %%
plt.style.use("seaborn-white")

mpl.rcParams["axes.formatter.limits"] = [-5, 10]

fig, axs  = plt.subplots(3, 2, figsize=(10, 7), tight_layout=True)

for sim_data, ax, color in zip(sim_data_list, axs.ravel(), tab_colors_list[:len(sim_data_list)]):
    plot_timeblocks_data(sim_data[0], ax, color)
    ax.set_title(sim_data[1])
    ax.set_ylabel(sim_data[2])
    if max([el[1] for el in sim_data[0][0]]) > 5000:
        ticks = list(ax.get_yticks())
        print(ticks)
        ticks_K = [str(int(int(tick) / 1000)) + "K" if tick != 0 else tick for tick in ticks]
        #ax.set_yticklabels(ticks_K)
# to hide an axis:
#axs[3,1].set_axis_off()
# Out:
# [-5000.0, 0.0, 5000.0, 10000.0, 15000.0]
# [-50000.0, 0.0, 50000.0, 100000.0, 150000.0, 200000.0]
# [-500000.0, 0.0, 500000.0, 1000000.0, 1500000.0]
# [-10000.0, 0.0, 10000.0, 20000.0, 30000.0]
# [0.0, 20000.0, 40000.0, 60000.0]

# %%
sddk.write_file("SDAM_data/social_diversity/EDH_word+char_counts_temporal.png", fig, conf)
# Out:
# A file with the same name ("EDH_word+char_counts_temporal.png") already exists in this location.
# Press Enter to overwrite it or choose different path and filename:
# Your <class 'matplotlib.figure.Figure'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/social_diversity/EDH_word+char_counts_temporal.png"

# %%
EDH["language"].unique()
# Out:
# array(['Latin', 'Greek-Latin', 'Greek', 'Phonician-Punic-Latin',
#        'Italic-Latin', 'Hebrew-Latin', 'PyGL', 'Celtic-Latin',
#        'Iberian-Latin', 'Greek-Hebrew-Latin', 'Hebrew-Iberian-Latin',
#        'Palmyrenic-Latin', None, 'Numidian', 'LG', 'Celtic'], dtype=object)

# %%
EDH[EDH["language"].str.contains("Latin", na=False)]
# Out:
#       responsible_individual    type_of_inscription letter_size not_after  \
# 0                    Feraudi                epitaph    3.2-2 cm      0130
# 1                    Feraudi                epitaph        4 cm      0200
# 2                    Feraudi  honorific inscription    4.5-3 cm      0170
# 3                       Gräf     votive inscription      2.5 cm      0200
# 4                    Feraudi                epitaph        None      0200
# ...                      ...                    ...         ...       ...
# 81471                Feraudi                   None        None      0200
# 81472                Feraudi                   None        None      0300
# 81473                Feraudi     votive inscription        None      0300
# 81474                   Gräf    votive inscription?        None      0222
# 81475                   Gräf     votive inscription        None      0222
#
#                                               literature  \
# 0      AE 1983, 0192.; M. Annecchino, Puteoli 4/5, 19...
# 1      AE 1983, 0080. (A); A. Ferrua, RAL 36, 1981, 1...
# 2      AE 1983, 0518. (B); J. González, ZPE 52, 1983,...
# 3      AE 1983, 0533. (B); A.U. Stylow, Gerión 1, 198...
# 4      AE 1983, 0078. (B); A. Ferrua, RAL 36, 1981, 1...
# ...                                                  ...
# 81471  H. Lehner, Die antiken Steindenkmäler des Prov...
# 81472  H. Lehner, Die antiken Steindenkmäler des Prov...
# 81473  CIL 13, 07788; Zeichnung.; H. Lehner, Die anti...
# 81474  AE 2006, 0854.; CIL 13, 05940.; A. Daguet-Gage...
# 81475  AE 1982, 0714. (B); AE 1983, 0716.; A. Daguet-...
#
#                 work_status   height  \
# 0               provisional    33 cm
# 1                  no image    28 cm
# 2               provisional  (37) cm
# 3        checked with photo  (39) cm
# 4                  no image     None
# ...                     ...      ...
# 81471  checked with drawing  (23) cm
# 81472  checked with drawing  (17) cm
# 81473    checked with photo  (21) cm
# 81474           provisional     None
# 81475           provisional  (45) cm
#
#                                          diplomatic_text  \
# 0      D M / NONIAE P F OPTATAE / ET C IVLIO ARTEMONI...
# 1                C SEXTIVS PARIS / QVI VIXIT / ANNIS LXX
# 2      [ ]VMMIO [ ] / [ ]ISENNA[ ] / [ ] XV[ ] / [ ] / [
# 3      [ ]AVS[ ]LLA / M PORCI NIGRI SER / DOMINAE VEN...
# 4      [ ] L SVCCESSVS / [ ] L L IRENAEVS / [ ] C L T...
# ...                                                  ...
# 81471                     ] AEL[ ] / [ ]PRI[ ] / [ ]MAT[
# 81472                           ]ON SE[ ] / [ ]IL FRV[ ]
# 81473  [ ] / [ ]ABVS / [ ]VS L / [ ]NIVS IV / [ ] COS...
# 81474                                               None
# 81475                                               None
#
#                                                   people    depth  ...  \
# 0      [{'name': 'Noniae P.f. Optatae', 'cognomen': '...   2.7 cm  ...
# 1      [{'nomen': 'Sextius', 'praenomen': 'C.', 'pers...     None  ...
# 2      [{'nomen': 'Mummius+', 'gender': 'male', 'prae...  (12) cm  ...
# 3      [{'name': '[---?]AV(?)S(?)[---]L(?)L(?)A M. Po...    18 cm  ...
# 4      [{'person_id': '1', 'name': '[---]l. Successus...     None  ...
# ...                                                  ...      ...  ...
# 81471                                                 {}    11 cm  ...
# 81472                                                 {}   5.5 cm  ...
# 81473  [{'person_id': '1', 'cognomen': 'Iucundus+?', ...  (11) cm  ...
# 81474                                                 {}     None  ...
# 81475  [{'nomen': '[---]', 'praenomen': '[-]', 'cogno...    33 cm  ...
#
#       geography social_economic_legal_history military occups occups_N  \
# 0          None                          None     None     []        0
# 1          None                          None     None     []        0
# 2          None                          None     None     []        0
# 3          None                          None     None     []        0
# 4          None                          None     None     []        0
# ...         ...                           ...      ...    ...      ...
# 81471      None                          None     None     []        0
# 81472      None                          None     None     []        0
# 81473      None                          None     None     []        0
# 81474      None                          None     None     []        0
# 81475      None                          None     None     []        0
#
#       organizations organizations_N  \
# 0                []               0
# 1                []               0
# 2                []               0
# 3                []               0
# 4                []               0
# ...             ...             ...
# 81471            []               0
# 81472            []               0
# 81473            []               0
# 81474            []               0
# 81475            []               0
#
#                                             random_dates occupsorgs  \
# 0      [124, 74, 106, 77, 72, 106, 96, 74, 100, 102, ...         []
# 1      [165, 173, 130, 98, 177, 83, 136, 166, 151, 14...         []
# 2      [163, 142, 169, 158, 137, 136, 164, 134, 147, ...         []
# 3      [153, 198, 163, 176, 158, 195, 157, 166, 165, ...         []
# 4      [13, 160, 13, 184, 171, 104, 197, 140, 163, 2,...         []
# ...                                                  ...        ...
# 81471  [171, 145, 200, 134, 184, 169, 139, 164, 197, ...         []
# 81472  [256, 241, 235, 164, 67, 65, 235, 278, 154, 22...         []
# 81473  [233, 181, 206, 265, 276, 160, 222, 198, 229, ...         []
# 81474  [185, 216, 215, 212, 193, 217, 208, 206, 184, ...         []
# 81475  [213, 213, 196, 210, 195, 200, 191, 162, 180, ...         []
#
#       occupsorgs_N
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 81471            0
# 81472            0
# 81473            0
# 81474            0
# 81475            0
#
# [80177 rows x 81 columns]

# %%
def filter_by_first(random_dates):
    try:
        return random_dates[0]
    except:
        None

EDH_100bc = EDH[EDH["random_dates"].apply(filter_by_first) < -100]
EDH_100bc
# Out:
#       responsible_individual        type_of_inscription letter_size not_after  \
# 556                  Feraudi   owner/artist inscription  1.6-2.3 cm     -0101
# 701                     Gräf         votive inscription        None     -0201
# 704                     Gräf         votive inscription        None     -0201
# 707                  Feraudi         votive inscription        None     -0211
# 865                     Gräf                       list  1.2-0.8 cm     -0031
# ...                      ...                        ...         ...       ...
# 64708              Cimarosti         votive inscription    4-3.5 cm      None
# 67256                   Gräf   owner/artist inscription        None      None
# 67351                  Cowey  private legal inscription        5 cm     -0171
# 67388                   Gräf                      list?        None     -0051
# 67410                   Gräf                       list      2-3 cm     -0051
#
#                                               literature  \
# 556    AE 1983, 0145.; Z. Mari, Tibur, Forma Italiae,...
# 701    AE 1983, 0405.; A.M. Sgubini Moretti, in: Nuov...
# 704    AE 1983, 0408.; A.M. Sgubini Moretti, in: Nuov...
# 707    AE 1983, 0406.; A.M. Sgubini Moretti, in: Nuov...
# 865    AE 1983, 0389.; M.G. Angeli Bertinelli, QuadSt...
# ...                                                  ...
# 64708  CIL 05, 07213.; ILS 1853.; P. Wuilleumier, L’a...
# 67256  AE 2006, 0814.; L. Benquet, Aquitania 22, 2006...
# 67351                  IG 11, 04, 00712.; AE 2009, 1308.
# 67388  CIL 03, 00714.; CIL 01 (2. Aufl.) 02, 00664.; ...
# 67410  CIL 03, 12318. (B); CIL 03, 13709.; CIL 02 (2....
#
#                    work_status    height  \
# 556                provisional      None
# 701                   no image      9 cm
# 704         checked with photo  (4.9) cm
# 707                provisional      9 cm
# 865         checked with photo    7.5 cm
# ...                        ...       ...
# 64708  checked through autopsy   63.3 cm
# 67256              provisional      None
# 67351                 no image     54 cm
# 67388                 no image      None
# 67410       checked with photo   (25) cm
#
#                                          diplomatic_text  \
# 556                                         Q PANDVSINVS
# 701                        [ ]RCIVS L L / [ ]ONEAE / [ ]
# 704              ] / FERONEA DONO / LVBENS MERTO / DEDIT
# 707                  L CALPVRNIVS / [ ]RONEA DONO MERITE
# 865    P [ ]IRTIVS T F / P CVRFIDIVS [ ] / M FVFICIVS...
# ...                                                  ...
# 64708  PVDENS SOC / PVBL XL SER / SCR FINIB / COTTI V...
# 67256                F / M / M AEMILIO / L AVRELIO / COS
# 67351  ΕΔΟΞΕΝ ΤΕΙ ΒΟΥΛΕΙ ΚΑΙ ΤΩΙ ΔΗΜΩΙ· Α[ ] / ΤΙΛΑΚΟ...
# 67388         ] / C L LVCCI C F EQ / C MISPIVS MVSTE / [
# 67410  MVSTAE PIEIS / EPOPTAE / L FOVRIVS L F OV[ ] /...
#
#                                                   people   depth  ...  \
# 556    [{'name': 'Q. Pandusinus', 'nomen': 'Pandusinu...  3.4 cm  ...
# 701    [{'person_id': '1', 'name': '[---]rcius l.l.',...    None  ...
# 704    [{'name': 'Feronea', 'nomen': 'Feronea', 'pers...  3.8 cm  ...
# 707    [{'nomen': 'Calpurnius', 'name': 'L. Calpurniu...   20 cm  ...
# 865    [{'name': 'P. [H]irtius T.f.', 'nomen': 'Hirti...   10 cm  ...
# ...                                                  ...     ...  ...
# 64708  [{'name': 'Pudens', 'person_id': '1', 'status'...   39 cm  ...
# 67256  [{'praenomen': 'M.', 'person_id': '1', 'name':...    None  ...
# 67351  [{'person_id': '1', 'cognomen': 'á¼Î½Ïá½·Î»Î...    9 cm  ...
# 67388  [{'person_id': '1', 'praenomen': 'C.', 'nomen'...    None  ...
# 67410                                                 {}    8 cm  ...
#
#             geography social_economic_legal_history military  \
# 556              None                          None     None
# 701              None                          None     None
# 704              None                          None     None
# 707              None                          None     None
# 865              None                          None     None
# ...               ...                           ...      ...
# 64708  data available                data available     None
# 67256            None                          None     None
# 67351            None                          None     None
# 67388            None                          None     None
# 67410            None                          None     None
#
#                      occups occups_N organizations organizations_N  \
# 556                      []        0            []               0
# 701                      []        0            []               0
# 704                      []        0            []               0
# 707                      []        0            []               0
# 865                      []        0            []               0
# ...                     ...      ...           ...             ...
# 64708  [arcarius, arcarius]        2            []               0
# 67256                    []        0            []               0
# 67351                    []        0            []               0
# 67388                    []        0            []               0
# 67410                    []        0            []               0
#
#                                             random_dates  \
# 556    [-118, -117, -105, -121, -104, -130, -101, -12...
# 701    [-241, -233, -237, -234, -228, -220, -242, -23...
# 704    [-274, -209, -243, -231, -225, -298, -299, -21...
# 707    [-237, -282, -220, -223, -240, -226, -222, -24...
# 865    [-142, -82, -132, -67, -128, -117, -61, -80, -...
# ...                                                  ...
# 64708  [-177, -170, -167, -165, -151, -169, -176, -15...
# 67256  [-123, -100, -73, -87, -111, -105, -73, -118, ...
# 67351  [-184, -182, -197, -178, -196, -175, -188, -17...
# 67388  [-150, -61, -190, -156, -134, -73, -74, -88, -...
# 67410  [-195, -151, -168, -69, -161, -131, -92, -124,...
#
#                  occupsorgs occupsorgs_N
# 556                      []            0
# 701                      []            0
# 704                      []            0
# 707                      []            0
# 865                      []            0
# ...                     ...          ...
# 64708  [arcarius, arcarius]            2
# 67256                    []            0
# 67351                    []            0
# 67388                    []            0
# 67410                    []            0
#
# [138 rows x 81 columns]

# %%
EDH_100bc["length"] = EDH_100bc["clean_text_interpretive_word"].apply(len)
EDH_100bc.sort_values("length", ascending=False)
# Out:
# /home/kasev/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       responsible_individual       type_of_inscription letter_size not_after  \
# 42924                  Cowey  public legal inscription        None     -0190
# 53168                  Cowey     honorific inscription        None     -0130
# 64381                  Cowey  public legal inscription        None     -0167
# 64370                  Cowey                      list    1.5-1 cm     -0001
# 64338                  Cowey     honorific inscription    0.7-2 cm     -0150
# ...                      ...                       ...         ...       ...
# 13842                   Gräf                   epitaph  1.8-2.2 cm     -0051
# 48723                   Gräf  owner/artist inscription        None     -0101
# 48728                   Gräf  owner/artist inscription        None     -0101
# 50047                  Platz  owner/artist inscription        None     -0071
# 28920                Feraudi                      None        None     -0071
#
#                                               literature         work_status  \
# 42924  SIG (3. Aufl.) 609-610.; R.K. Shark, Roman Doc...            no image
# 53168  AE 1995, 1377.; K. Gallis, AD 31 B, 1976, 262-...  checked with photo
# 64381  AE 2006, 1260.; A. Tziaphalias - J.L. GarcÃ­a ...  checked with photo
# 64370  AE 2005, 1357.; L.D. Loukopoulou - A. Zournatz...  checked with photo
# 64338  IG 09, 02, 01292.; IG 09, 02, 01293a.; IG 09, ...  checked with photo
# ...                                                  ...                 ...
# 13842  AE 1968, 0181a.; M. Cristofani, SE 35, 1967, 5...  checked with photo
# 48723  AE 1998, 1224e.; B. Dautaj, Iliria 24, 1994, 1...  checked with photo
# 48728  AE 1998, 1224j.; B. Dautaj, Iliria 24, 1994, 1...  checked with photo
# 50047                                     AE 1996, 1635.         provisional
# 28920                       CIL 02 (2. Aufl.) 07, 00630.            no image
#
#          height                                    diplomatic_text  \
# 42924      None  [ ]ΤΑ ΥΠΑΡΧ[ ]Ν [ ]ΑΛΥΜΑ ΤΟΙΣ ΗΜΕΤΕΡΟΙ[ ]ΙΤΑ[ ...
# 53168  (130) cm  [ ] / [ ]ΙΑΙ[ ] / [ ]ΣΠΕΠΟ[ ] / [ ]ΗΣ ΑΥΤΟΙΣ[ ...
# 64381   93.5 cm  ΤΑΓΕΥΟΝΤΟΥΝ ΤΙΜΟΣΘΕΝΕΟΣ ΑΛΕΞΙΑΙΟΙ ΙΠ / ΠΟΛΟΧΟΙ...
# 64370    123 cm  ΕΠΙ ΑΡΧΙΕΡΕΩΣ ΤΟΥ ΣΕΡΑΠΙΔΟΣ ΚΑΙ ΤΗΣ / ΕΙΣΙΔΟΣ ...
# 64338   (39) cm  [ ]ΓΟΥΝΤΟΣ ΦΙΛΟΞΕΝΟΥ ΤΟΥ ΕΥΑΡΧ[ ]Υ ΜΟΝΔΑΙΕΩΣ /...
# ...         ...                                                ...
# 13842     21 cm                                      [ ] GREBO [ ]
# 48723      None                                               CAAC
# 48728      None                                               OMIT
# 50047      None                                                  L
# 28920      None                                           [ ]AL[ ]
#
#                                                   people  depth  ...  \
# 42924                                                 {}   None  ...
# 53168  [{'nomen': 'ÎÎ±Î¹Îºá½³Î»Î¹Î¿Ï', 'gender': 'm...  10 cm  ...
# 64381                                                 {}  12 cm  ...
# 64370  [{'name': 'ÎÎµÎ½Î¿ÎºÏá½·ÏÎ¿Ï
#  ÏÎ¿á¿¦ ÎÎ·Î...  18 cm  ...
# 64338  [{'origo': 'ÎÎ¿Î½Î´Î±Î¹á½³ÏÏ', 'person_id':...  22 cm  ...
# ...                                                  ...    ...  ...
# 13842  [{'cognomen': '[---]', 'name': '[---] Grebo [-...   None  ...
# 48723                                                 {}   None  ...
# 48728                                                 {}   None  ...
# 50047                                                 {}   None  ...
# 28920                                                 {}   None  ...
#
#       social_economic_legal_history military occups occups_N organizations  \
# 42924                          None     None     []        0            []
# 53168                          None     None     []        0            []
# 64381                          None     None     []        0            []
# 64370                          None     None     []        0            []
# 64338                          None     None     []        0            []
# ...                             ...      ...    ...      ...           ...
# 13842                          None     None     []        0            []
# 48723                          None     None     []        0            []
# 48728                          None     None     []        0            []
# 50047                          None     None     []        0            []
# 28920                          None     None     []        0            []
#
#       organizations_N                                       random_dates  \
# 42924               0  [-190, -190, -190, -191, -190, -190, -191, -19...
# 53168               0  [-147, -135, -135, -149, -139, -142, -146, -14...
# 64381               0  [-167, -167, -167, -167, -167, -167, -168, -16...
# 64370               0  [-102, -150, -117, -95, -141, -21, -22, -105, ...
# 64338               0  [-151, -161, -150, -171, -155, -150, -163, -16...
# ...               ...                                                ...
# 13842               0  [-277, -81, -259, -144, -295, -151, -166, -205...
# 48723               0  [-183, -102, -122, -131, -115, -155, -159, -15...
# 48728               0  [-198, -184, -163, -184, -189, -185, -119, -15...
# 50047               0  [-120, -99, -86, -125, -73, -73, -72, -100, -9...
# 28920               0  [-129, -107, -102, -102, -73, -105, -105, -109...
#
#       occupsorgs occupsorgs_N length
# 42924         []            0   4095
# 53168         []            0   3651
# 64381         []            0   2413
# 64370         []            0   1505
# 64338         []            0   1406
# ...          ...          ...    ...
# 13842         []            0      5
# 48723         []            0      4
# 48728         []            0      4
# 50047         []            0      4
# 28920         []            0      2
#
# [138 rows x 82 columns]

# %%
EDH_100bc.columns
# Out:
# Index(['responsible_individual', 'type_of_inscription', 'letter_size',
#        'not_after', 'literature', 'work_status', 'height', 'diplomatic_text',
#        'people', 'depth', 'material', 'type_of_monument', 'province_label',
#        'width', 'transcription', 'country', 'uri', 'findspot_ancient',
#        'last_update', 'modern_region', 'findspot_modern', 'language', 'id',
#        'edh_geography_uri', 'commentary', 'trismegistos_uri', 'not_before',
#        'external_image_uris', 'fotos', 'coordinates', 'idno_tm',
#        'placenames_refs', 'text_edition', 'origdate_text', 'layout_execution',
#        'layout_execution_text', 'support_objecttype',
#        'support_objecttype_text', 'support_material', 'support_material_text',
#        'support_decoration', 'keywords_term', 'keywords_term_text',
#        'type_of_inscription_clean', 'type_of_inscription_certainty',
#        'height_cm', 'width_cm', 'depth_cm', 'material_clean',
#        'type_of_monument_clean', 'type_of_monument_certainty',
#        'province_label_clean', 'province_label_certainty', 'country_clean',
#        'country_certainty', 'findspot_ancient_clean',
#        'findspot_ancient_certainty', 'modern_region_clean',
#        'modern_region_certainty', 'findspot_modern_clean',
#        'findspot_modern_certainty', 'findspot_clean', 'findspot_certainty',
#        'origdate_text_clean', 'clean_text_conservative',
#        'clean_text_interpretive_word', 'clean_text_interpretive_sentence',
#        'findspot', 'year_of_find', 'present_location', 'religion', 'geography',
#        'social_economic_legal_history', 'military', 'occups', 'occups_N',
#        'organizations', 'organizations_N', 'random_dates', 'occupsorgs',
#        'occupsorgs_N', 'length'],
#       dtype='object')

# %%
EDH_100bc.sort_values("length", ascending=False)["id"].tolist()
# Out:
# ['HD043295',
#  'HD053580',
#  'HD065228',
#  'HD065217',
#  'HD065185',
#  'HD044444',
#  'HD065235',
#  'HD037104',
#  'HD065234',
#  'HD053732',
#  'HD021778',
#  'HD022400',
#  'HD065233',
#  'HD068210',
#  'HD065187',
#  'HD044493',
#  'HD065236',
#  'HD056666',
#  'HD065230',
#  'HD056977',
#  'HD056638',
#  'HD065232',
#  'HD020426',
#  'HD056788',
#  'HD017681',
#  'HD056785',
#  'HD065201',
#  'HD004004',
#  'HD002003',
#  'HD065139',
#  'HD065555',
#  'HD002680',
#  'HD056798',
#  'HD022784',
#  'HD043660',
#  'HD036894',
#  'HD003965',
#  'HD020429',
#  'HD029508',
#  'HD028716',
#  'HD003815',
#  'HD023606',
#  'HD068269',
#  'HD004469',
#  'HD000869',
#  'HD036967',
#  'HD051027',
#  'HD001118',
#  'HD003556',
#  'HD000884',
#  'HD037876',
#  'HD055621',
#  'HD011513',
#  'HD015667',
#  'HD046201',
#  'HD004234',
#  'HD016038',
#  'HD001109',
#  'HD003562',
#  'HD002650',
#  'HD013960',
#  'HD018347',
#  'HD014984',
#  'HD068247',
#  'HD068115',
#  'HD013963',
#  'HD008472',
#  'HD001651',
#  'HD002893',
#  'HD004064',
#  'HD000881',
#  'HD040884',
#  'HD001877',
#  'HD043625',
#  'HD003362',
#  'HD002950',
#  'HD003365',
#  'HD056796',
#  'HD004871',
#  'HD003462',
#  'HD053401',
#  'HD044421',
#  'HD044413',
#  'HD018358',
#  'HD040882',
#  'HD040881',
#  'HD044412',
#  'HD001172',
#  'HD041892',
#  'HD000710',
#  'HD013991',
#  'HD040883',
#  'HD003380',
#  'HD036011',
#  'HD001486',
#  'HD000704',
#  'HD036971',
#  'HD000707',
#  'HD002641',
#  'HD003315',
#  'HD013964',
#  'HD056658',
#  'HD064636',
#  'HD013988',
#  'HD062224',
#  'HD000971',
#  'HD013967',
#  'HD018334',
#  'HD000974',
#  'HD013961',
#  'HD045174',
#  'HD013976',
#  'HD000938',
#  'HD003151',
#  'HD020390',
#  'HD000559',
#  'HD001895',
#  'HD013979',
#  'HD018683',
#  'HD050777',
#  'HD004126',
#  'HD013970',
#  'HD013973',
#  'HD021388',
#  'HD001004',
#  'HD049115',
#  'HD049112',
#  'HD042313',
#  'HD061166',
#  'HD065395',
#  'HD040880',
#  'HD049123',
#  'HD003162',
#  'HD013958',
#  'HD049116',
#  'HD049121',
#  'HD050446',
#  'HD029195']

# %%
EDH_100bc.sort_values("length", ascending=False)["language"].tolist()
# Out:
# ['Greek',
#  'Greek',
#  'Greek',
#  'Latin',
#  'Greek',
#  'Latin',
#  'Greek',
#  'Greek',
#  'Greek',
#  'Greek',
#  'Latin',
#  'Greek-Latin',
#  'Greek',
#  'Greek',
#  'Greek',
#  'Greek-Latin',
#  'Greek',
#  'Latin',
#  'Greek',
#  'Greek-Latin',
#  'Greek-Latin',
#  'Greek',
#  'Greek-Latin',
#  'Greek-Latin',
#  'Greek-Latin',
#  'Greek-Latin',
#  'Greek',
#  'Latin',
#  'Greek-Latin',
#  'Greek',
#  'Latin',
#  'Latin',
#  'Greek-Latin',
#  'Greek-Latin',
#  'Greek',
#  'Greek',
#  'Latin',
#  'Latin',
#  'Greek-Latin',
#  'Greek-Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Greek',
#  'Greek-Latin',
#  'Latin',
#  'Latin',
#  'Italic-Latin',
#  'Latin',
#  'Greek-Latin',
#  'Greek-Latin',
#  'Latin',
#  'Greek-Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Greek',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Greek',
#  'Latin',
#  'Latin',
#  'Greek',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Greek',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin']

# %% [markdown]
# # Inscription types over time

# %%
simulations_by_type_len = []

for ins_type in EDH["type_of_inscription_clean"].unique():
    if ins_type != "NULL":
        subset_df = EDH[EDH["type_of_inscription_clean"]==ins_type]
        simulations_by_type_len.append((ins_type, len(subset_df)))
simulations_by_type_len = sorted(simulations_by_type_len, key = lambda x: x[1], reverse=True)
simulations_by_type_len
# Out:
# [('epitaph', 27953),
#  ('votive inscription', 14044),
#  ('owner/artist inscription', 5185),
#  ('honorific inscription', 3999),
#  ('building/dedicatory inscription', 3307),
#  ('mile-/leaguestone', 1730),
#  ('identification inscription', 1574),
#  ('acclamation', 533),
#  ('military diploma', 500),
#  ('list', 360),
#  ('defixio', 309),
#  ('label', 289),
#  ('public legal inscription', 248),
#  ('boundary inscription', 246),
#  ('elogium', 143),
#  ('letter', 121),
#  ('seat inscription', 87),
#  ('prayer', 56),
#  ('private legal inscription', 45),
#  ('assignation inscription', 16),
#  ('calendar', 14),
#  ('adnuntiatio', 3)]

# %%
simulations_by_type = []

for ins_type_tup in simulations_by_type_len[:10]:
    subset_df = EDH[EDH["type_of_inscription_clean"]==ins_type_tup[0]]
    simulations = timeblocks_from_randoms(subset_df, "random_dates", [-200, 600, 100])
    ins_type_N =len(subset_df)
    simulations_by_type.append([ins_type_tup[0],ins_type_N, simulations]) 
simulations_by_type = sorted(simulations_by_type, key=lambda x: x[1], reverse=True)

# %%
simulations_by_type = sorted(simulations_by_type, key=lambda x: x[1], reverse=True)

# %%
simulations_by_type[4][1]
# Out:
# 3307

# %%
date_vars_by_instypes = []
for ins_type_tup in simulations_by_type_len[:10]:
    subset_df = EDH[EDH["type_of_inscription_clean"]==ins_type_tup[0]]
    date_vars = []
    for n in range(100):
        date_vars.append([date_var[n] for date_var in subset_df["random_dates"] if date_var != None])
    date_vars_by_instypes.append(date_vars)

# %%
# %%time 
# timeconsuming, because of the KDE involved
labels=[key for key in periods.keys()]
positions = [np.mean(tup[0]) for tup in occups_ratios_merged]

fig, ax = plt.subplots(figsize=[6,4])

labels_ins = [tup[0] for tup in simulations_by_type_len]

for period, color in zip(periods.keys(), tab_colors_list):
    ax.axvspan(periods[period]["startdate"], periods[period]["enddate"], color=color, alpha=0.2)#, linestyles="dashed", color="red")

for instype_data, color in zip(date_vars_by_instypes[:5], tab_colors_list[:5]):
    for sim_var in instype_data:
        sns.kdeplot(sim_var, ax=ax, color=color)
        

ax.set_xlim(-50,350)
ax.set_ylabel("KDE")

# period labels
ax.set_xticks(positions)
ax.set_xticklabels(labels)
ax.xaxis.set_tick_params(rotation=90)
ax.xaxis.tick_top()

# time ticks
ax.secondary_xaxis("bottom")

markers = [plt.Line2D([0,0],[0,0],color=color, lw=4) for color in tab_colors_list[:len(simulations_by_type)]]
plt.legend(markers, labels_ins[:5], bbox_to_anchor=(1, 1), loc='upper left')
# Out:
# CPU times: user 2min 22s, sys: 3min 18s, total: 5min 41s
# Wall time: 33.5 s

# %%
tab_colors_list = list(mcolors.TABLEAU_COLORS.keys())
plt.style.use("seaborn-white")

fig, ax  = plt.subplots(figsize=(10, 4), tight_layout=True)

for ins_type_sims, color in zip(simulations_by_type, tab_colors_list[:len(simulations_by_type)]):
    plot_timeblocks_data(ins_type_sims[2], ax=ax, color=color)
    
ax.set_xlabel("date")
ax.set_ylabel("count")
#ax.set_title("EDH - 10 most common inscription types over time")
 
markers = [plt.Line2D([0,0],[0,0],color=color, lw=4) for color in tab_colors_list[:len(simulations_by_type)]]
plt.legend(markers, [tup[0] for tup in simulations_by_type], numpoints=1,  title="Inscription types", bbox_to_anchor=(1, 1), loc='upper right')

# %%
sddk.write_file("SDAM_data/social_diversity/EDH_inscription_types_temporal.png", fig, conf)
# Out:
# A file with the same name ("EDH_inscription_types_temporal.png") already exists in this location.
# Press Enter to overwrite it or choose different path and filename:
# Your <class 'matplotlib.figure.Figure'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/social_diversity/EDH_inscription_types_temporal.png"

# %% [markdown]
# # Occupations & organizations over inscription types

# %%
# N of occuptions and N of organization per inscription category
ins_types_occs_orgs = []
for ins_type_tup in simulations_by_type_len:
    subset_df = EDH[EDH["type_of_inscription_clean"]==ins_type_tup[0]]
    occ_N = subset_df["occups_N"].sum()
    orgs_N = subset_df["organizations_N"].sum()
    ins_types_occs_orgs.append([ins_type_tup[0] + " (N={0})".format(len(subset_df)), occ_N, orgs_N])
    print("inscription type: {0}, N of occupations: {1}, N of organizations: {2}".format(ins_type_tup[0], str(occ_N), str(orgs_N)))
# Out:
# inscription type: epitaph, N of occupations: 565, N of organizations: 282
# inscription type: votive inscription, N of occupations: 345, N of organizations: 150
# inscription type: owner/artist inscription, N of occupations: 24, N of organizations: 0
# inscription type: honorific inscription, N of occupations: 218, N of organizations: 87
# inscription type: building/dedicatory inscription, N of occupations: 103, N of organizations: 48
# inscription type: mile-/leaguestone, N of occupations: 0, N of organizations: 0
# inscription type: identification inscription, N of occupations: 12, N of organizations: 0
# inscription type: acclamation, N of occupations: 5, N of organizations: 0
# inscription type: military diploma, N of occupations: 77, N of organizations: 0
# inscription type: list, N of occupations: 47, N of organizations: 16
# inscription type: defixio, N of occupations: 5, N of organizations: 5
# inscription type: label, N of occupations: 0, N of organizations: 0
# inscription type: public legal inscription, N of occupations: 34, N of organizations: 36
# inscription type: boundary inscription, N of occupations: 7, N of organizations: 2
# inscription type: elogium, N of occupations: 2, N of organizations: 2
# inscription type: letter, N of occupations: 10, N of organizations: 1
# inscription type: seat inscription, N of occupations: 0, N of organizations: 0
# inscription type: prayer, N of occupations: 1, N of organizations: 0
# inscription type: private legal inscription, N of occupations: 11, N of organizations: 4
# inscription type: assignation inscription, N of occupations: 0, N of organizations: 0
# inscription type: calendar, N of occupations: 0, N of organizations: 0
# inscription type: adnuntiatio, N of occupations: 0, N of organizations: 0

# %%
pd.DataFrame(ins_types_occs_orgs, columns=["inscription type", "occupations", "organisations"])
# Out:
#                             inscription type  occupations  organisations
# 0                          epitaph (N=27953)          565            282
# 1               votive inscription (N=14044)          345            150
# 2          owner/artist inscription (N=5185)           24              0
# 3             honorific inscription (N=3999)          218             87
# 4   building/dedicatory inscription (N=3307)          103             48
# 5                 mile-/leaguestone (N=1730)            0              0
# 6        identification inscription (N=1574)           12              0
# 7                        acclamation (N=533)            5              0
# 8                   military diploma (N=500)           77              0
# 9                               list (N=360)           47             16
# 10                           defixio (N=309)            5              5
# 11                             label (N=289)            0              0
# 12          public legal inscription (N=248)           34             36
# 13              boundary inscription (N=246)            7              2
# 14                           elogium (N=143)            2              2
# 15                            letter (N=121)           10              1
# 16                   seat inscription (N=87)            0              0
# 17                             prayer (N=56)            1              0
# 18          private legal inscription (N=45)           11              4
# 19            assignation inscription (N=16)            0              0
# 20                           calendar (N=14)            0              0
# 21                         adnuntiatio (N=3)            0              0

# %%
types, occups_freqs, orgs_freqs = [], [], [] 

for ins_type_tup in simulations_by_type_len[:10][::-1]: # for horizontal bar below, we need the list in reverse order, therefore: [::-1]
    subset_df = EDH[EDH["type_of_inscription_clean"]==ins_type_tup[0]]
    subset_wordcount = wordcount(subset_df).sum()
    types.append(ins_type_tup[0])
    occups_freqs.append(subset_df["occups_N"].sum() / subset_wordcount * 1000)
    orgs_freqs.append(subset_df["organizations_N"].sum() / subset_wordcount * 1000)

# %%
fig, ax  = plt.subplots(figsize=(10, 4), tight_layout=True)

y = np.arange(len(types))
height = 0.4

ax.barh(y + height/2, occups_freqs, height, label="occupations", color="tab:blue") #, color=tab_colors_list[:len(simulations_by_type)])
ax.barh(y - height/2, orgs_freqs, height, label="organizations", color="tab:orange") #, color=tab_colors_list[:len(simulations_by_type)])

ax.set_yticks(y) #y_pos, types)
ax.set_yticklabels(types) #, rotation="vertical")
ax.set_xlabel("occupations/orgnazation mentioned per 1,000 words")
ax.set_ylabel("inscription type")
ax.legend()

# %%
sddk.write_file("SDAM_data/social_diversity/EDH_occupsorgs_by_instypes.png", fig, conf)
# Out:
# A file with the same name ("EDH_occupsorgs_by_instypes.png") already exists in this location.
# Press Enter to overwrite it or choose different path and filename:
# Your <class 'matplotlib.figure.Figure'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/social_diversity/EDH_occupsorgs_by_instypes.png"

# %% [markdown]
# # Occupations & organizations together

# %%
len(EDH[EDH["organizations_N"]>0])
# Out:
# 727

# %%
len(EDH[EDH["occups_N"]>0])
# Out:
# 1913

# %%
len(EDH[(EDH["occups_N"]>0) & (EDH["organizations_N"]>0)])
# Out:
# 231

# %%
EDH["occupsorgs"] = EDH.apply(lambda row: row["occups"] + row["organizations"], axis=1)

# %%
EDH["occupsorgs_N"] = EDH["occupsorgs"].apply(len)

# %%
EDH["occupsorgs_N"].sum()
# Out:
# 3136

# %%
occupsorgs_list = [el for el in EDH["occupsorgs"].tolist() if len(el) > 0]
occupsorgs_list
# Out:
# [['corpus'],
#  ['negotiator'],
#  ['fullo'],
#  ['dendrophorus'],
#  ['aerarius', 'corpus'],
#  ['mulionus'],
#  ['mulionus'],
#  ['collegium'],
#  ['corpus'],
#  ['faber'],
#  ['navalis', 'faber', 'corpus'],
#  ['subaedianus',
#   'subaedianus',
#   'faber',
#   'faber',
#   'collegium',
#   'corpus',
#   'corpus'],
#  ['faber'],
#  ['argentarius', 'coactor'],
#  ['negotiator'],
#  ['negotiator'],
#  ['scriba', 'corpus', 'corpus'],
#  ['curator'],
#  ['corpus'],
#  ['pomarius'],
#  ['sagittarius', 'sagittarius'],
#  ['aerarius'],
#  ['curator'],
#  ['arcarius'],
#  ['curator', 'faber'],
#  ['sagittarius', 'faber'],
#  ['copo'],
#  ['collegium', 'collegium'],
#  ['faber', 'collegium'],
#  ['sagittarius', 'sagittarius'],
#  ['sagittarius', 'sagittarius'],
#  ['sagittarius', 'sagittarius'],
#  ['sagittarius', 'sagittarius'],
#  ['faber'],
#  ['imaginarius',
#   'scriba',
#   'collegium',
#   'collegium',
#   'collegium',
#   'collegium',
#   'collegium',
#   'collegium',
#   'collegium',
#   'collegium',
#   'collegium',
#   'collegium',
#   'collegium',
#   'collegium',
#   'corpus',
#   'corpus',
#   'corpus'],
#  ['collegium',
#   'collegium',
#   'collegium',
#   'collegium',
#   'collegium',
#   'collegium',
#   'collegium',
#   'collegium',
#   'collegium',
#   'collegium',
#   'collegium'],
#  ['vestiarius', 'curator', 'medicus', 'medicus', 'cocus'],
#  ['scriba', 'scriba'],
#  ['faber'],
#  ['gladiator'],
#  ['corpus'],
#  ['curator'],
#  ['tignarius', 'faber', 'collegium'],
#  ['collegium'],
#  ['architectus', 'faber'],
#  ['mensor'],
#  ['ephippiarius'],
#  ['agricola', 'pomarius'],
#  ['sagittarius', 'curator'],
#  ['scriba'],
#  ['sagittarius'],
#  ['faber', 'collegium', 'collegium'],
#  ['argentarius'],
#  ['collega', 'collega', 'collega'],
#  ['corpus'],
#  ['collegium'],
#  ['conlegium'],
#  ['centonarius', 'nauta', 'corporatus'],
#  ['anabolicarius'],
#  ['navigans', 'nauta'],
#  ['architectus', 'sagarius'],
#  ['sagittarius'],
#  ['aerarius'],
#  ['tonsor'],
#  ['faber', 'collegium'],
#  ['negotiator', 'vinarius'],
#  ['armamentarius'],
#  ['purpurarius'],
#  ['lintiarius'],
#  ['gladiator', 'gladiator'],
#  ['soliarius'],
#  ['faber', 'collegium'],
#  ['corpus'],
#  ['cuparius'],
#  ['aerarius'],
#  ['curator'],
#  ['aerarius'],
#  ['vexillarius', 'faber'],
#  ['corpus'],
#  ['dissignator'],
#  ['dissignator'],
#  ['collegium'],
#  ['collegium'],
#  ['collega'],
#  ['vinariarius', 'negotians'],
#  ['officinator', 'officinator'],
#  ['medicus'],
#  ['negotiator'],
#  ['curator'],
#  ['arcarius'],
#  ['dendrophorus', 'collegium'],
#  ['curator'],
#  ['possessor'],
#  ['scaenicus', 'corpus'],
#  ['corpus'],
#  ['sagarius'],
#  ['clibanarius', 'collegium'],
#  ['collega'],
#  ['circitor'],
#  ['medicus'],
#  ['dendrophorus'],
#  ['sagittarius'],
#  ['salarius'],
#  ['lupinarius'],
#  ['dendrophorus'],
#  ['cocus'],
#  ['medicus', 'collega'],
#  ['mulionus', 'collegium'],
#  ['statuarius', 'scalptor'],
#  ['curator'],
#  ['sodalicium'],
#  ['collega'],
#  ['armamentarius'],
#  ['lintiarius'],
#  ['sagittarius', 'sagittarius'],
#  ['curator'],
#  ['curator'],
#  ['possessor', 'possessor'],
#  ['pistor'],
#  ['scriba'],
#  ['propola'],
#  ['sarcinatrix'],
#  ['corpus'],
#  ['curator'],
#  ['faber'],
#  ['fullo'],
#  ['aerarius', 'aerarius', 'collegium', 'collega'],
#  ['aurufex'],
#  ['curator'],
#  ['machinator'],
#  ['faber'],
#  ['collegiatus'],
#  ['carbonarus'],
#  ['aerarius', 'sutor'],
#  ['vexillarius'],
#  ['mercator'],
#  ['faber'],
#  ['faber'],
#  ['faber'],
#  ['arcarius'],
#  ['faber', 'faber'],
#  ['ustor', 'ustor'],
#  ['collegium', 'collegium'],
#  ['olearius'],
#  ['faber'],
#  ['conlegium'],
#  ['faber'],
#  ['faber'],
#  ['corpus'],
#  ['aerarius'],
#  ['collegium'],
#  ['coactor'],
#  ['medicus'],
#  ['medicus'],
#  ['olearius'],
#  ['aerarius'],
#  ['faber'],
#  ['curator'],
#  ['curator', 'faber'],
#  ['possessor'],
#  ['unctor', 'unctor'],
#  ['cocus'],
#  ['medicus'],
#  ['plumbarius'],
#  ['corpus'],
#  ['specularius'],
#  ['medicus'],
#  ['faber'],
#  ['faber', 'collegium'],
#  ['suarius', 'corpus'],
#  ['collegium'],
#  ['collegium'],
#  ['vestiarius'],
#  ['pantomimus'],
#  ['armamentarius'],
#  ['faber'],
#  ['aerarius'],
#  ['figulus'],
#  ['faber'],
#  ['negotiator'],
#  ['faber', 'collegium'],
#  ['faber', 'collegium'],
#  ['medicus'],
#  ['faber', 'collegium'],
#  ['collegium'],
#  ['sagittarius'],
#  ['possessor'],
#  ['mercator', 'mercator', 'mercator'],
#  ['structor'],
#  ['ornatrix'],
#  ['aerarius'],
#  ['collegium'],
#  ['pictor'],
#  ['collegium'],
#  ['aerarius', 'curator', 'corpus'],
#  ['faber'],
#  ['sagittarius', 'faber'],
#  ['scriba'],
#  ['fontanus', 'fullo'],
#  ['curator'],
#  ['mensor'],
#  ['corpus'],
#  ['corpus'],
#  ['curator'],
#  ['collegius'],
#  ['aerarius'],
#  ['aerarius', 'corpus'],
#  ['curator'],
#  ['argentarius'],
#  ['curator'],
#  ['scriba', 'scriba', 'faber', 'faber'],
#  ['aurifex'],
#  ['aerarius'],
#  ['venator'],
#  ['artifex'],
#  ['sagittarius'],
#  ['faber'],
#  ['vexillarius', 'faber'],
#  ['arcarius'],
#  ['collegium'],
#  ['structor'],
#  ['calcarius'],
#  ['aerarius'],
#  ['corpus'],
#  ['sagittarius'],
#  ['scriba'],
#  ['scriba', 'scriba', 'scriba'],
#  ['nauta'],
#  ['extructor'],
#  ['medicus'],
#  ['corpus'],
#  ['scriba', 'faber'],
#  ['collegium'],
#  ['dendrophorus'],
#  ['faber', 'collegium'],
#  ['scriba'],
#  ['scriba'],
#  ['officinator'],
#  ['faber', 'collegium'],
#  ['collegium'],
#  ['curator'],
#  ['collega'],
#  ['aerarius'],
#  ['scriba'],
#  ['curator'],
#  ['collegium'],
#  ['faber'],
#  ['collegium'],
#  ['aerarius'],
#  ['collegiarius'],
#  ['aerarius'],
#  ['curator'],
#  ['medicus'],
#  ['aerarius'],
#  ['margaritarius'],
#  ['curator'],
#  ['anularius', 'faber'],
#  ['venator'],
#  ['collegium'],
#  ['retiarius'],
#  ['collegium'],
#  ['sagittarius', 'sagittarius'],
#  ['lanarius'],
#  ['faber', 'collegium'],
#  ['colorator'],
#  ['aerarius', 'aerarius'],
#  ['aerarius', 'corpus'],
#  ['aerarius'],
#  ['curator'],
#  ['dendrophorus', 'faber'],
#  ['dendrophorus', 'faber'],
#  ['curator'],
#  ['curator'],
#  ['collega'],
#  ['societas'],
#  ['retiarius'],
#  ['curator'],
#  ['collegium'],
#  ['ornatrix'],
#  ['collegium'],
#  ['curator'],
#  ['curator', 'corpus'],
#  ['argentarius', 'coactor'],
#  ['cerarius', 'scriba'],
#  ['faber'],
#  ['argentarius', 'coactor', 'faber', 'collegium'],
#  ['mensor', 'corpus'],
#  ['conditor'],
#  ['conditor'],
#  ['faber'],
#  ['corpus'],
#  ['corpus'],
#  ['arcarius'],
#  ['faber'],
#  ['faber'],
#  ['sutor', 'sutor'],
#  ['corpus'],
#  ['collegium'],
#  ['collegium'],
#  ['curator'],
#  ['corpus'],
#  ['curator'],
#  ['corpus'],
#  ['corpus'],
#  ['stuppator', 'corpus'],
#  ['corpus'],
#  ['dendrophorus', 'faber', 'collegium', 'collegium'],
#  ['faber', 'collegium'],
#  ['sagittarius'],
#  ['sagittarius'],
#  ['gladiator', 'scaenicus'],
#  ['sagittarius'],
#  ['medicus'],
#  ['curator'],
#  ['structor'],
#  ['faber', 'collegium'],
#  ['medicus'],
#  ['corpus'],
#  ['redemptor'],
#  ['medicus'],
#  ['collegium'],
#  ['purpurarius', 'mercator'],
#  ['collegium'],
#  ['medicus'],
#  ['topiarius'],
#  ['venator', 'collegium'],
#  ['negotiator'],
#  ['faber'],
#  ['sarcinator'],
#  ['faber'],
#  ['pellio'],
#  ['faber'],
#  ['faber'],
#  ['curator'],
#  ['mesor'],
#  ['faber', 'collegium'],
#  ['corporatus'],
#  ['pectinarius'],
#  ['collegium'],
#  ['scriba'],
#  ['scriba'],
#  ['collegium'],
#  ['faber'],
#  ['collegium'],
#  ['curator'],
#  ['collegium', 'collegium'],
#  ['pellio'],
#  ['tignarius', 'faber', 'collegium'],
#  ['medicus'],
#  ['vexillarius'],
#  ['curator'],
#  ['gladiator'],
#  ['gladiator', 'faber'],
#  ['tibicinus'],
#  ['architectus'],
#  ['corpus'],
#  ['curator', 'curator'],
#  ['sutor'],
#  ['negotiator'],
#  ['collegium'],
#  ['medicus'],
#  ['sarsor'],
#  ['collega'],
#  ['naupegus'],
#  ['mesor'],
#  ['sagittarius', 'sagittarius'],
#  ['corpus'],
#  ['corpus', 'corpus'],
#  ['corpus'],
#  ['aerarius'],
#  ['collegium'],
#  ['tibicinus', 'collegium'],
#  ['vestiarius'],
#  ['tignarius', 'faber', 'collegium'],
#  ['navicularius',
#   'nummularius',
#   'lyntrarius',
#   'faber',
#   'corporatus',
#   'collegium',
#   'corpus'],
#  ['archimagirus'],
#  ['aurifex'],
#  ['aurifex'],
#  ['lanarius'],
#  ['ornatrix'],
#  ['architectus', 'faber'],
#  ['faber', 'collegium'],
#  ['curator'],
#  ['corpus'],
#  ['libitinarius', 'redemptor', 'aerarius', 'aerarius', 'ustor'],
#  ['dendrophorus'],
#  ['medicus'],
#  ['arcarius', 'arcarius'],
#  ['artifex'],
#  ['scriba'],
#  ['scriba'],
#  ['scaenicus'],
#  ['cunarius'],
#  ['copo'],
#  ['faber'],
#  ['medicus'],
#  ['faber'],
#  ['structor'],
#  ['tinctor'],
#  ['redemptor'],
#  ['collegium', 'corpus'],
#  ['abietarius'],
#  ['faber', 'collegium'],
#  ['curator'],
#  ['curator'],
#  ['sagittarius'],
#  ['collegium'],
#  ['curator'],
#  ['curator'],
#  ['negotiator', 'salarius'],
#  ['negotiator', 'salarius'],
#  ['negotiator'],
#  ['nauta'],
#  ['negotiator'],
#  ['negotiator', 'salarius'],
#  ['medicus'],
#  ['sagittarius'],
#  ['curator'],
#  ['mensor'],
#  ['scriba'],
#  ['lapidarius'],
#  ['faber'],
#  ['sagittarius'],
#  ['aquarius'],
#  ['curator'],
#  ['corpus'],
#  ['corpus'],
#  ['collegium'],
#  ['vexillarius'],
#  ['librator'],
#  ['corpus'],
#  ['aerarius', 'aerarius'],
#  ['faber'],
#  ['cellarius'],
#  ['scriba'],
#  ['curator'],
#  ['faber'],
#  ['dendrophorus', 'collegium'],
#  ['medicus'],
#  ['corpus'],
#  ['vexillarius'],
#  ['conditor'],
#  ['sagittarius'],
#  ['sagittarius'],
#  ['concilium', 'concilium', 'concilium', 'concilium', 'corpus'],
#  ['intestinus'],
#  ['sagittarius'],
#  ['curator'],
#  ['sagittarius'],
#  ['collega'],
#  ['collega'],
#  ['corpus'],
#  ['faber', 'collegium'],
#  ['exceptor'],
#  ['sagittarius', 'sagittarius'],
#  ['sagittarius'],
#  ['argentarius'],
#  ['caelator'],
#  ['corpus'],
#  ['faber', 'collegium'],
#  ['lanipendia'],
#  ['conditor'],
#  ['copo'],
#  ['curator'],
#  ['collega'],
#  ['faber'],
#  ['corpus'],
#  ['curator'],
#  ['faber'],
#  ['collegium'],
#  ['medicus'],
#  ['faber'],
#  ['arcarius'],
#  ['arcarius'],
#  ['sarcinatrix'],
#  ['sagarius'],
#  ['faber'],
#  ['curator'],
#  ['curator', 'collegium', 'corpus'],
#  ['eborarius'],
#  ['collegium', 'collegium'],
#  ['faber'],
#  ['negotians', 'vinarius', 'faber', 'collegium'],
#  ['collegiatus'],
#  ['collegium'],
#  ['collegium'],
#  ['faber'],
#  ['negotiator'],
#  ['aeneator', 'collegius'],
#  ['lecticarius'],
#  ['corpus'],
#  ['corpus'],
#  ['faber'],
#  ['collegium'],
#  ['copo'],
#  ['tignarius', 'faber', 'collegium'],
#  ['collegium'],
#  ['collegium'],
#  ['collegium'],
#  ['dolator'],
#  ['sagittarius', 'faber'],
#  ['medicus'],
#  ['faber navales', 'faber', 'corporatus', 'collegium'],
#  ['corpus'],
#  ['collegium'],
#  ['corpus'],
#  ['faber', 'collegium'],
#  ['scriptor'],
#  ['faber'],
#  ['navicularius', 'corpus', 'corpus'],
#  ['collegium', 'collega'],
#  ['collegium'],
#  ['corpus'],
#  ['sagittarius', 'sagittarius'],
#  ['lapidarius'],
#  ['collegium'],
#  ['medicus'],
#  ['corpus', 'corpus'],
#  ['cerarius'],
#  ['medicus'],
#  ['corpus', 'corpus'],
#  ['architectus'],
#  ['circitor'],
#  ['faber'],
#  ['faber'],
#  ['armamentarius'],
#  ['aedifex'],
#  ['collegium'],
#  ['faber'],
#  ['aerarius'],
#  ['scriba'],
#  ['aerarius', 'aerarius'],
#  ['faber'],
#  ['faber'],
#  ['aerarius'],
#  ['scriba'],
#  ['aerarius'],
#  ['conditor'],
#  ['corpus'],
#  ['scaenicus'],
#  ['circitor'],
#  ['conlegium'],
#  ['coactor', 'coactor'],
#  ['eborarius'],
#  ['lanius'],
#  ['collegius'],
#  ['lanionus'],
#  ['aquarius'],
#  ['mimus'],
#  ['scriba'],
#  ['collegium'],
#  ['intestinus', 'corpus'],
#  ['parasitus'],
#  ['curator'],
#  ['curator'],
#  ['scriba'],
#  ['collegium'],
#  ['collegium'],
#  ['faber'],
#  ['vexillarius'],
#  ['vexillarius'],
#  ['scriba'],
#  ['scriba'],
#  ['faber'],
#  ['negotiator'],
#  ['faber'],
#  ['curator', 'faber'],
#  ['faber'],
#  ['scriba'],
#  ['corpus'],
#  ['corpus'],
#  ['scriba'],
#  ['gladiator'],
#  ['corpus'],
#  ['curator'],
#  ['faber', 'collegium'],
#  ['aerarius'],
#  ['scriba'],
#  ['faber', 'collegium'],
#  ['dendrophorus'],
#  ['aerarius'],
#  ['faber', 'collegium', 'collegium'],
#  ['faber'],
#  ['vestiarius'],
#  ['lapidarius', 'faber'],
#  ['aerarius'],
#  ['sagittarius'],
#  ['negotiator'],
#  ['faber'],
#  ['unguentarius'],
#  ['collegium'],
#  ['lecticarius'],
#  ['navalis'],
#  ['curator'],
#  ['dendrophorus', 'faber'],
#  ['factor'],
#  ['vexillarius'],
#  ['cornicen', 'cornicen', 'cornicen'],
#  ['conlegium'],
#  ['faber', 'collegium', 'collegium'],
#  ['structor'],
#  ['collegium'],
#  ['dendrophorus',
#   'dendrophorus',
#   'dendrophorus',
#   'faber',
#   'collegium',
#   'collegium'],
#  ['scriba'],
#  ['scriba', 'scriba', 'scriba', 'scriba'],
#  ['collegius'],
#  ['lanius'],
#  ['utriclarius', 'faber', 'collegium'],
#  ['vexillarius'],
#  ['corpus'],
#  ['scaenicus'],
#  ['curator'],
#  ['scaenicus'],
#  ['scriba'],
#  ['medicus'],
#  ['corpus', 'corpus'],
#  ['dendrophorus'],
#  ['curator'],
#  ['faber'],
#  ['faber'],
#  ['figulus'],
#  ['scutarius'],
#  ['pictor'],
#  ['sodalicium'],
#  ['collegium'],
#  ['aerarius'],
#  ['aerarius'],
#  ['faber'],
#  ['vexillarius'],
#  ['dendrophorus'],
#  ['scabillarius'],
#  ['aerarius', 'scriba'],
#  ['curator'],
#  ['negotiator'],
#  ['curator'],
#  ['curator'],
#  ['faber', 'collegium'],
#  ['curator'],
#  ['faber', 'faber'],
#  ['architectus'],
#  ['forensis'],
#  ['medicus'],
#  ['aurificus'],
#  ['collega'],
#  ['scholasticus'],
#  ['sagittarius', 'sagittarius'],
#  ['faber'],
#  ['faber'],
#  ['collegium'],
#  ['scriptor'],
#  ['oleareus'],
#  ['vexillarius'],
#  ['collegius'],
#  ['collegium'],
#  ['materiarius'],
#  ['pantomimus'],
#  ['negotiator', 'moritex'],
#  ['retiarius', 'retiarius'],
#  ['architectus'],
#  ['mensor'],
#  ['collegiatus'],
#  ['medicus'],
#  ['curator', 'collegium'],
#  ['curator'],
#  ['retiarius'],
#  ['collegium'],
#  ['medicus'],
#  ['vinarius'],
#  ['sagittarius'],
#  ['infector'],
#  ['medicus'],
#  ['collegium', 'corpus'],
#  ['collegium', 'corpus'],
#  ['collegium', 'corpus'],
#  ['collegium', 'corpus'],
#  ['collegium', 'corpus'],
#  ['aerarius', 'salarius'],
#  ['corpus'],
#  ['aerarius', 'faber'],
#  ['curator'],
#  ['curator'],
#  ['faber'],
#  ['signator'],
#  ['faber', 'collegium'],
#  ['faber'],
#  ['faber'],
#  ['faber'],
#  ['sodalicium'],
#  ['medicus'],
#  ['corpus'],
#  ['collega'],
#  ['caelator'],
#  ['corpus'],
#  ['sagarius'],
#  ['aerarius', 'faber', 'collegium'],
#  ['curator'],
#  ['aerarius'],
#  ['armamentarius'],
#  ['aerarius'],
#  ['mensor', 'corpus'],
#  ['aerarius', 'navalis', 'navalis', 'faber', 'faber', 'corpus'],
#  ['statuarius'],
#  ['aerarius', 'faber'],
#  ['faber'],
#  ['negotians'],
#  ['corpus'],
#  ['sagittarius'],
#  ['gladiator'],
#  ['sagittarius', 'sagittarius'],
#  ['collegium'],
#  ['sagittarius'],
#  ['curator'],
#  ['vestiarius'],
#  ['lanarius'],
#  ['faber', 'collegium'],
#  ['medicus'],
#  ['medicus'],
#  ['argentarius', 'coactor'],
#  ['scriba'],
#  ['officinator'],
#  ['curator', 'collegium'],
#  ['possessor', 'possessor', 'curator'],
#  ['opifex', 'collega'],
#  ['collegium'],
#  ['collega', 'corpus'],
#  ['conlegium'],
#  ['mulionus'],
#  ['collegium'],
#  ['collegium'],
#  ['parasitus'],
#  ['scriptor'],
#  ['pernarius'],
#  ['scaenicus'],
#  ['scaenicus'],
#  ['medicus'],
#  ['collegium'],
#  ['gladiator', 'curator'],
#  ['arcarius', 'collegius'],
#  ['scriba'],
#  ['corporatus'],
#  ['corpus'],
#  ['collegium'],
#  ['corpus'],
#  ['pictor'],
#  ['lanifica'],
#  ['curator'],
#  ['sagittarius'],
#  ['sagittarius', 'sagittarius', 'sagittarius', 'sagittarius'],
#  ['faber', 'collegium'],
#  ['navalis'],
#  ['ornatrix', 'tonsor'],
#  ['aurufex'],
#  ['curator'],
#  ['curator'],
#  ['negotians'],
#  ['collegium'],
#  ['collegium'],
#  ['faber', 'collegium', 'collegium'],
#  ['faber', 'collegium'],
#  ['dolabrarius', 'faber', 'collegium'],
#  ['sagittarius'],
#  ['aedifex'],
#  ['corpus', 'corpus'],
#  ['architectus', 'coriarius'],
#  ['vitor'],
#  ['pistor'],
#  ['corpus'],
#  ['sagittarius'],
#  ['curator'],
#  ['curator', 'corpus'],
#  ['collega'],
#  ['collegium', 'collegium'],
#  ['corporatus'],
#  ['corporatus'],
#  ['collegium'],
#  ['collegium'],
#  ['inaurator'],
#  ['tabernarius'],
#  ['scholasticus'],
#  ['gladiator'],
#  ['gladiator'],
#  ['decanus'],
#  ['faber', 'collegium'],
#  ['concilium'],
#  ['argentarius'],
#  ['curator'],
#  ['conditor'],
#  ['ornatrix'],
#  ['scaenicus'],
#  ['sagittarius'],
#  ['collegium'],
#  ['medicus'],
#  ['vexillarius'],
#  ['collegium'],
#  ['scaenicus'],
#  ['pistor'],
#  ['ornatrix'],
#  ['curator'],
#  ['gladiator'],
#  ['medicus'],
#  ['scriptor'],
#  ['collegium', 'collegium'],
#  ['tignarius', 'scriba', 'faber', 'collegium', 'collegium'],
#  ['tignarius', 'faber', 'collegium'],
#  ['tignarius', 'faber', 'collegium'],
#  ['faber', 'faber'],
#  ['aerarius'],
#  ['medicus'],
#  ['faber'],
#  ['vexillarius'],
#  ['librator'],
#  ['medicus'],
#  ['scaenicus'],
#  ['marmorarius'],
#  ['pecuarius'],
#  ['aerarius'],
#  ['corpus'],
#  ['corporatus'],
#  ['cerarius', 'scriba', 'collegium'],
#  ['hastifer', 'corpus'],
#  ['cerarius', 'scriba'],
#  ['faber'],
#  ['gladiator'],
#  ['curator navium'],
#  ['gladiator'],
#  ['curator'],
#  ['tonsor'],
#  ['collegium'],
#  ['corpus'],
#  ['scaenicus'],
#  ['marmorarius'],
#  ['corpus'],
#  ['aerarius'],
#  ['curator'],
#  ['curator'],
#  ['aerarius', 'aerarius'],
#  ['sarcinatrix'],
#  ['sarcinatrix'],
#  ['curator'],
#  ['societas', 'societas'],
#  ['manticularius'],
#  ['negotiator'],
#  ['argentarius'],
#  ['cornicen'],
#  ['collega'],
#  ['sagittarius'],
#  ['vexillarius'],
#  ['curator'],
#  ['olarius'],
#  ['dendrophorus'],
#  ['collegium'],
#  ['ornator'],
#  ['curator'],
#  ['vexillarius', 'capsarius'],
#  ['vexillarius'],
#  ['figulus'],
#  ['conditor'],
#  ['asinarius', 'asinarius'],
#  ['negotiator'],
#  ['faber'],
#  ['collegium'],
#  ['faber'],
#  ['ballistarius'],
#  ['conditor'],
#  ['mensor'],
#  ['collegium'],
#  ['faber'],
#  ['faber', 'collegium'],
#  ['faber'],
#  ['faber', 'collegium'],
#  ['curator'],
#  ['capsarius'],
#  ['sagittarius'],
#  ['negotiator'],
#  ['conditor'],
#  ['scriba'],
#  ['nauta'],
#  ['cerarius', 'collegium', 'collega', 'collega', 'collega'],
#  ['faber'],
#  ['curator'],
#  ['scriba'],
#  ['faber'],
#  ['sagarius'],
#  ['faber'],
#  ['institor'],
#  ['curator'],
#  ['corpus'],
#  ['pectenarius', 'clavarius', 'fullo', 'fullo', 'sutor'],
#  ['capsarius'],
#  ['faber'],
#  ['plombarius'],
#  ['corpus'],
#  ['pomarius', 'pomarius'],
#  ['collegium'],
#  ['pistor'],
#  ['embaenitarius'],
#  ['mensor'],
#  ['aurufex'],
#  ['medicus'],
#  ['sagittarius'],
#  ['curator'],
#  ['infector'],
#  ['curator', 'curator'],
#  ['pectinarius', 'vestiarius'],
#  ['nauta'],
#  ['faber'],
#  ['curator'],
#  ['nauta'],
#  ['fullo'],
#  ['collegium'],
#  ['negotiator'],
#  ['corpus'],
#  ['lapidarius'],
#  ['faber', 'collegium'],
#  ['curator'],
#  ['nauta'],
#  ['curator'],
#  ['sagittarius', 'faber'],
#  ['cornicen'],
#  ['tignarius', 'faber', 'collegium'],
#  ['sagittarius'],
#  ['aerarius'],
#  ['collegius'],
#  ['lotor'],
#  ['medicus'],
#  ['corpus'],
#  ['curator'],
#  ['medicus'],
#  ['negotians'],
#  ['furnarius', 'furnaria'],
#  ['faber'],
#  ['pecuarius'],
#  ['seplasiarius'],
#  ['faber'],
#  ['gladiator', 'gladiator'],
#  ['vestiarius'],
#  ['caligarius', 'lapidarius'],
#  ['collegium'],
#  ['faber'],
#  ['archimagirus'],
#  ['structor', 'collegium'],
#  ['medicus'],
#  ['signator', 'scriba', 'scriba'],
#  ['medicus'],
#  ['scriba'],
#  ['albarius'],
#  ['medicus'],
#  ['curator'],
#  ['corpus'],
#  ['cellarius'],
#  ['mensor'],
#  ['mulionus'],
#  ['cornicen'],
#  ['cocus'],
#  ['sagittarius', 'sagittarius'],
#  ['vexillarius', 'collegium'],
#  ['faber', 'collegium'],
#  ['gladiator'],
#  ['scriba'],
#  ['annonarius'],
#  ['argentarius', 'faber'],
#  ['pictor'],
#  ['collega'],
#  ['margaritarius'],
#  ['scriba'],
#  ['argentarius'],
#  ['cellarius'],
#  ['curator'],
#  ['scriba'],
#  ['medicus'],
#  ['faber'],
#  ['gladiator', 'gladiator'],
#  ['mulionus', 'collegium'],
#  ['medicus'],
#  ['corpus'],
#  ['faber', 'faber'],
#  ['faber'],
#  ['structor'],
#  ['scriba'],
#  ['albarius'],
#  ['collegium'],
#  ['conditor'],
#  ['cervesarius', 'negotiator'],
#  ['copo'],
#  ['curator'],
#  ['curator'],
#  ['faber', 'collegium'],
#  ['corpus'],
#  ['nauta'],
#  ['arcarius'],
#  ['scutarius'],
#  ['salarius'],
#  ['argentarius', 'coactor'],
#  ['curator'],
#  ['curator'],
#  ['glutinarius'],
#  ['scriba'],
#  ['tector'],
#  ['arcarius', 'olearius'],
#  ['argentarius', 'vasclarius'],
#  ...]

# %%
len(occupsorgs_list)
# Out:
# 2409

# %%
dictionary = corpora.Dictionary(occupsorgs_list)

# %%
dictionary = corpora.Dictionary(occupsorgs_list)
vocabulary = [el[1] for el in dictionary.items()]
vocabulary[:10]
# Out:
# ['corpus',
#  'negotiator',
#  'fullo',
#  'dendrophorus',
#  'aerarius',
#  'mulionus',
#  'collegium',
#  'faber',
#  'navalis',
#  'subaedianus']

# %%
orgs = ["colegium", "collegium", "collegiatus", "collegius", "collega", "concilium", "conlegium", "collegatarius", "collegiarius", "corpus", "corporatus", "sociatio", "societas", "sodalitas", "sodalicium"]

# %%
for org in orgs:
    try:
        org_id = dictionary.token2id[org]
        org_freq = dictionary.cfs[org_id]
        print("'{0}' count: {1}".format(org, org_freq))
    except:
        print("'{0}' not found".format(org))
# Out:
# 'colegium' count: 1
# 'collegium' count: 452
# 'collegiatus' count: 11
# 'collegius' count: 10
# 'collega' count: 60
# 'concilium' count: 12
# 'conlegium' count: 13
# 'collegatarius' not found
# 'collegiarius' count: 1
# 'corpus' count: 288
# 'corporatus' count: 11
# 'sociatio' not found
# 'societas' count: 5
# 'sodalitas' not found
# 'sodalicium' count: 4

# %%
terms_dfs = [dictionary.dfs[n] for n in range(len(dictionary))]

# %%
vec_bow = CountVectorizer(vocabulary=vocabulary)
bow = vec_bow.fit_transform([" ".join(list(set(el))) for el in occupsorgs_list]) ### run the model
vec_bow.get_feature_names()
cooc  = bow.T * bow

cooc.setdiag(terms_dfs) 

cooc_df = pd.DataFrame(cooc.todense(), columns=vocabulary, index=vocabulary) # / len(docs)
cooc_df
# Out:
# /home/kasev/.local/lib/python3.6/site-packages/scipy/sparse/_index.py:125: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#                 corpus  negotiator  fullo  dendrophorus  aerarius  mulionus  \
# corpus             251           0      0             0         6         0
# negotiator           0          51      0             0         0         0
# fullo                0           0      9             0         0         0
# dendrophorus         0           0      0            26         0         0
# aerarius             6           0      0             0        95         0
# ...                ...         ...    ...           ...       ...       ...
# saccarius            0           0      0             0         0         0
# caupo                0           0      0             0         0         0
# macellarius          0           0      0             0         0         0
# faber ferrarii       0           0      0             0         0         0
# quadratarius         0           0      0             0         0         0
#
#                 collegium  faber  navalis  subaedianus  ...  lignarius  \
# corpus                 13      6        2            1  ...          0
# negotiator              0      0        0            0  ...          0
# fullo                   0      0        0            0  ...          0
# dendrophorus            9      7        0            0  ...          0
# aerarius                4      8        2            0  ...          0
# ...                   ...    ...      ...          ...  ...        ...
# saccarius               0      0        0            0  ...          0
# caupo                   0      0        0            0  ...          0
# macellarius             0      0        0            0  ...          0
# faber ferrarii          0      0        0            0  ...          0
# quadratarius            0      0        0            0  ...          0
#
#                 arenarius  uctor  metator  sculptor  saccarius  caupo  \
# corpus                  0      0        1         0          0      0
# negotiator              0      0        0         0          0      0
# fullo                   0      0        0         0          0      0
# dendrophorus            0      0        0         0          0      0
# aerarius                0      0        0         0          0      0
# ...                   ...    ...      ...       ...        ...    ...
# saccarius               0      0        0         0          1      0
# caupo                   0      0        0         0          0      1
# macellarius             0      0        0         0          0      1
# faber ferrarii          0      0        0         0          0      0
# quadratarius            0      0        0         0          0      0
#
#                 macellarius  faber ferrarii  quadratarius
# corpus                    0               0             0
# negotiator                0               0             0
# fullo                     0               0             0
# dendrophorus              0               0             0
# aerarius                  0               0             0
# ...                     ...             ...           ...
# saccarius                 0               0             0
# caupo                     1               0             0
# macellarius               1               0             0
# faber ferrarii            0               1             0
# quadratarius              0               0             1
#
# [272 rows x 272 columns]

# %%
cooc_df[cooc_df["collegium"]>0].sort_values("collegium", ascending=False)["collegium"][1:]
# Out:
# faber           149
# corpus           13
# tignarius        12
# dendrophorus      9
# scriba            7
# collega           5
# curator           5
# aerarius          4
# cerarius          3
# vexillarius       3
# lapidarius        2
# utricularius      2
# scaenicus         2
# medicus           2
# mulionus          2
# collegiatus       2
# corporatus        2
# scriptor          1
# lanionus          1
# lotorus           1
# unguentarius      1
# utriclarius       1
# dolabrarius       1
# navicularius      1
# nauclerus         1
# tegularius        1
# fabriciensis      1
# nummularius       1
# clibanarius       1
# lyntrarius        1
# tibicinus         1
# anularius         1
# venator           1
# structor          1
# negotians         1
# vinarius          1
# conlegium         1
# mensor            1
# imaginarius       1
# coactor           1
# argentarius       1
# subaedianus       1
# focarius          1
# Name: collegium, dtype: int64

# %%
cooc_df[cooc_df["corpus"]>0].sort_values("corpus", ascending=False)["corpus"][1:]
# Out:
# collegium        13
# faber             6
# curator           6
# aerarius          6
# mensor            3
# navalis           2
# scriba            2
# navicularius      2
# concilium         1
# lyntrarius        1
# nummularius       1
# parasitus         1
# intestinus        1
# conditor          1
# hastifer          1
# conquiliarius     1
# stuppator         1
# scaenicus         1
# aurifex           1
# suarius           1
# collegiatus       1
# negotians         1
# corporatus        1
# collega           1
# imaginarius       1
# sagittarius       1
# subaedianus       1
# metator           1
# Name: corpus, dtype: int64

# %% [markdown]
# # Occupations by industry types

# %%
occupations_df = get_as_dataframe(occupations.worksheet("Occupation"))
occupations_df = occupations_df[['Term', 'gen_sg', 'Vocab_nom_sg', 'Source', 'Category', 'Subcategory','Translation_eng']]
occupations_df = occupations_df.dropna(thresh=5)
occups_cats_dict = dict(zip(occupations_df["Term"], occupations_df["Category"]))

# %%
def cat_for_occup(list_of_occups):
    try:
        return [occups_cats_dict[occup] for occup in list_of_occups]
    except:
        return []
    
EDH["occups_cats"] = EDH["occups"].apply(cat_for_occup)

# %%
occups_cats_list = [el for sublist in EDH["occups_cats"].tolist() for el in sublist]
print(len(occups_cats_list))
print(nltk.FreqDist(occups_cats_list).most_common(30))
# Out:
# 2268
# [('Metal-Working', 741), ('Miscellaneous Services', 357), ('Managerial', 283), ('Building', 151), ('Retail', 132), ('Education', 118), ('Performing Arts', 113), ('Food-Production', 93), ('Clothing', 83), ('Transport', 70), ('Finance', 41), ('Plastic Arts', 30), ('Household Goods', 20), ('Food-Retail', 19), ('Water-Management', 7), ('Death-care sector', 4), ('Glass-Working', 3), ('Unclear meaning', 2), ('Fuel / Raw material', 1)]

# %% [markdown]
# # Occupations & Organizations over centuries

# %%
# various metrics on the level of timeblocks
def occups_count(timeblock_df):
    return timeblock_df["occups_N"].sum()

def orgs_count(timeblock_df):
    return timeblock_df["organizations_N"].sum()

def occups_inscriptions_ratio(timeblock_df):
    occups_N_sum = len(timeblock_df[timeblock_df["occups_N"] > 0])
    return (occups_N_sum / len(timeblock_df)) * 100

def orgs_inscriptions_ratio(timeblock_df):
    occups_N_sum = len(timeblock_df[timeblock_df["organizations_N"] > 0])
    return (occups_N_sum / len(timeblock_df)) * 100

# various metrics on the level of timeblocks
def occups_cumulTF(timeblock_df):
    occups_N_sum = timeblock_df["occups_N"].sum()
    wordcount = timeblock_df["clean_text_interpretive_word"].apply(lambda x: len(str(x).split())).sum()
    return (occups_N_sum / wordcount) * 1000

def orgs_cumulTF(timeblock_df):
    occups_N_sum = timeblock_df["organizations_N"].sum()
    wordcount = timeblock_df["clean_text_interpretive_word"].apply(lambda x: len(str(x).split())).sum()
    return (occups_N_sum / wordcount) * 1000

# various metrics on the level of timeblocks
def unique_occups(timeblock_df):
    unique_occups = len(set([el for sublist in timeblock_df["occups"].tolist() for el in sublist]))
    inscriptions_list = timeblock_df["clean_text_interpretive_word"].astype(str).tolist()
    return unique_occups

# unique occups / inscriptions
def unique_occups_ins_ratio(timeblock_df):
    unique_occups = len(set([el for sublist in timeblock_df["occups"].tolist() for el in sublist]))
    return unique_occups / len(timeblock_df)


# various metrics on the level of timeblocks
def unique_occups_ratio(timeblock_df):
    unique_occups = len(set([el for sublist in timeblock_df["occups"].tolist() for el in sublist]))
    inscriptions_list = timeblock_df["clean_text_interpretive_word"].astype(str).tolist()
    unique_words = len(set(" ".join(inscriptions_list).split()))
    return unique_occups / unique_words

# %%
occups_counts = sim_data_by_function(EDH, 100, [-200, 600, 100], occups_count) 
occups_ins_ratio = sim_data_by_function(EDH, 100, [-200, 600, 100], occups_inscriptions_ratio)
occups_TF_data = sim_data_by_function(EDH, 100, [-200, 600, 100], occups_cumulTF) 
unique_occups_data = sim_data_by_function(EDH, 100, [-200, 600, 100], unique_occups) 
unique_occups_ratio_data = sim_data_by_function(EDH, 100, [-200, 600, 100], unique_occups_ratio) 
unique_occups_ins_ratio_data = sim_data_by_function(EDH, 100, [-200, 600, 100], unique_occups_ins_ratio)

# %%
orgs_counts = sim_data_by_function(EDH, 100, [-200, 600, 100], orgs_count) 
orgs_ins_ratio = sim_data_by_function(EDH, 100, [-200, 600, 100], orgs_inscriptions_ratio)
orgs_TF_data = sim_data_by_function(EDH, 100, [-200, 600, 100], orgs_cumulTF)

# %%
sim_data_list = [
    ([occups_counts, orgs_counts], "(A) EDH - occupations/organizations count", "occupation mentions count"),
    ([occups_ins_ratio, orgs_ins_ratio], "(B) EDH - occupations/organizations per 100 inscriptions", "inscriptions/organizations"),
    ([occups_TF_data, orgs_TF_data], "(C) EDH - occupations/organizations per 1000 words", "occupations/organizatations"),
    ([unique_occups_data], "(D) EDH - unique occupations", "unique occupations"),
    ([unique_occups_ratio_data], "(E) EDH - unique occupations per 1000 unique words", "unique occupations"),
    ([unique_occups_ins_ratio_data], "(F) EDH - unique occupations per 100 inscriptions", "unique occupations")     
]

# %%
unique_occups_data[0]
# Out:
# [((-200, -101), 2),
#  ((-100, -1), 20),
#  ((1, 100), 86),
#  ((101, 200), 94),
#  ((201, 300), 102),
#  ((301, 400), 31),
#  ((401, 500), 13),
#  ((501, 600), 5)]

# %%
tab_colors_list = [col for col in tab_colors_list if col != "tab:gray"]

# %%
plt.style.use("seaborn-white")

fig, axs  = plt.subplots(3, 2, figsize=(10, 8), tight_layout=True)
n = 0
for sim_data, ax in zip(sim_data_list, axs.ravel()):
        for plot_data, color, label in zip(sim_data[0], ["tab:blue", "tab:orange"], ["occupations", "organizations"]):
            plot_timeblocks_data(plot_data, ax, color, label=label, alpha=0.8)
            n += 1
        ax.set_title(sim_data[1])
        ax.set_ylabel(sim_data[2])
        ax.legend()

# %%
sddk.write_file("SDAM_data/social_diversity/EDH_occupsorgs_temporal.png", fig, conf)
# Out:
# A file with the same name ("EDH_occupsorgs_temporal.png") already exists in this location.
# Press Enter to overwrite it or choose different path and filename:
# Your <class 'matplotlib.figure.Figure'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/social_diversity/EDH_occupsorgs_temporal.png"

# %% [markdown]
# # Occupations & organizations by periods

# %%
# periods definitions

periods = { # to avoid overlaps, startdates are postponed by one year, when needed
    "Julio-Claudians" : {"startdate": -27, "enddate" : 67},
    "Flavians" : {"startdate": 69, "enddate": 96},
    "Nerva-Antonine" : {"startdate" : 97, "enddate" : 193},
    # or:
    #"5 good emperors" : {"startdate": 97, "enddate": 180},
    #"Commodus" : {"startdate" : 181, "enddate" : 193},
    "Severan dynasty" : {"startdate": 194, "enddate": 235},
    "Crisis of the 3rd\nCentury" : {"startdate" : 236, "enddate" : 284},
    "Diocetian\n& Constantine" : {"startdate" : 285, "enddate" : 337}
    }
tab_colors_list = list(mcolors.TABLEAU_COLORS.keys())

timeblocks_periods = [(periods[period]["startdate"], periods[period]["enddate"]) for period in periods]
timeblocks_periods
# Out:
# [(-27, 67), (69, 96), (97, 193), (194, 235), (236, 284), (285, 337)]

# %%
# various metrics on the level of timeblocks
def occups_count(timeblock_df):
    return timeblock_df["occups_N"].sum()

def orgs_count(timeblock_df):
    return timeblock_df["organizations_N"].sum()

def occups_per_1K_ins(timeblock_df):
    timeblock_sample = timeblock_df.sample(1000, replace=True)
    occups_N_sum = timeblock_sample["occups_N"].sum()
    return occups_N_sum

def orgs_per_1K_ins(timeblock_df):
    timeblock_sample = timeblock_df.sample(1000, replace=True)
    occups_N_sum = timeblock_sample["organizations_N"].sum()
    return occups_N_sum

# %%
# %%time

# time consuming, apply carefully
#occups_counts = sim_data_by_function(EDH, 1000, timeblocks_periods, occups_count) 
occups_ins_ratio = sim_data_by_function(EDH, 1000, timeblocks_periods, occups_per_1K_ins)
#orgs_counts = sim_data_by_function(EDH, 1000, timeblocks_periods, orgs_count) 
orgs_ins_ratio = sim_data_by_function(EDH, 1000, timeblocks_periods, orgs_per_1K_ins)
# Out:
# CPU times: user 8min 41s, sys: 6.2 s, total: 8min 47s
# Wall time: 8min 34s

# %%
occups_ins_ratio[2]
# Out:
# [((-27, 67), 19),
#  ((69, 96), 21),
#  ((97, 193), 34),
#  ((194, 235), 14),
#  ((236, 284), 29),
#  ((285, 337), 28)]

# %%
def simulations_merged(simulation_data):
    merged_data = []
    for n in range(len(simulation_data[0])): # choose the first simulation to get the length 
        merged_data.append((simulation_data[0][n][0], [sim[n][1] for sim in simulation_data]))
    return merged_data

occups_ratios_merged = simulations_merged(occups_ins_ratio)
orgs_ratios_merged = simulations_merged(orgs_ins_ratio)

# %%
occups_ratios_merged = simulations_merged(occups_ins_ratio)
orgs_ratios_merged = simulations_merged(orgs_ins_ratio)

# %%
[key for key in periods.keys()]
# Out:
# ['Julio-Claudians',
#  'Flavians',
#  'Nerva-Antonine',
#  'Severan dynasty',
#  'Crisis of the 3rd\nCentury',
#  'Diocetian\n& Constantine']

# %%
[abs(tup[0][1] - tup[0][0]) for tup in occups_ratios_merged]
# Out:
# [94, 27, 96, 41, 48, 52]

# %%
# number of occupations/organizizations per 1,000 randomly sampled inscriptions. The samples are with replacement. Each sample is based on different dating simulation. 

plt.style.use("seaborn-white")#-white")

labels=[key for key in periods.keys()]
widths = [abs(tup[0][1] - tup[0][0]) for tup in occups_ratios_merged]
positions = [np.mean(tup[0]) for tup in occups_ratios_merged]


fig, [ax1, ax2] = plt.subplots(1,2, figsize=[12,4])

data1 = [tup[1] for tup in occups_ratios_merged]
means1 = [np.mean(tup[1]) for tup in occups_ratios_merged]

bplot1 = ax1.boxplot(data1, positions=positions, widths=widths, whis=[2.5, 97.5], labels=labels, patch_artist=True)
ax1.plot(positions, means1, color="black", linestyle="dashed", zorder=10)


ax1.set_title("A")
ax1.set_ylabel("Number of occupations\nper 1,000 inscriptions")
ax1.set_ylim(0, 60)
ax1.xaxis.set_tick_params(rotation=90)
ax1.xaxis.tick_top()
ax1.secondary_xaxis("bottom")
ax1.set_xlim(-50, 350)



data2 = [tup[1] for tup in orgs_ratios_merged]
means2 = [np.mean(tup[1]) for tup in orgs_ratios_merged]

bplot2 = ax2.boxplot(data2, positions=positions, widths=widths, whis=[2.5, 97.5], labels=labels, patch_artist=True)
ax2.plot(positions, means2, color="black", linestyle="dashed", zorder=10)

ax2.set_title("B")
ax2.set_ylabel("Number of organizations\nper 1,000 inscriptions")
ax2.set_ylim(0, 60)
ax2.xaxis.set_tick_params(rotation=90)
ax2.xaxis.tick_top()
ax2.secondary_xaxis("bottom")

# fill with colors
colors =tab_colors_list[:len(labels)]
for bplot in (bplot1, bplot2):
    for patch, color in zip(bplot['boxes'], colors):
        patch.set_facecolor(color)
