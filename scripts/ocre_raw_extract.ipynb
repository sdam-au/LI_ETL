# %%
import requests
import pandas as pd
import pickle


import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe
from google.oauth2 import service_account # based on google-auth library

import sddk

# %%
conf = sddk.configure("SDAM_root", "648597@au.dk")
# Out:
# sciencedata.dk username (format '123456@au.dk'): 648597@au.dk
# sciencedata.dk password: ········
# connection with shared folder established with you as its owner
# endpoint variable has been configured to: https://sciencedata.dk/files/SDAM_root/

# %%
# to access gsheet, you need Google Service Account key json file
# I have mine located in my personal space on sciencedata.dk, so I read it from there:

# (1) read the file and parse its content
file_data = sddk.read_file("https://sciencedata.dk/files/ServiceAccountsKey.json", "dict", conf)# conf[0].get(conf[1] + "ServiceAccountsKey.json").json()
# (2) transform the content into crendentials object
credentials = service_account.Credentials.from_service_account_info(file_data)
# (3) specify your usage of the credentials
scoped_credentials = credentials.with_scopes(['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive'])
# (4) use the constrained credentials for authentication of gspread package
gc = gspread.Client(auth=scoped_credentials)
# (5) establish connection with spreadsheets specified by their url
coins_gsheet = gc.open_by_url("https://docs.google.com/spreadsheets/d/1T5krnx1fzu_MrJTmfu3hS1Jpx_PC79D2J7cnkoJFi4s/edit?usp=sharing")

# %%
url = "http://nomisma.org/nomisma.org.jsonld"
nomisma = pd.read_json(url)

# %%
nomisma.head(5)
# Out:
#                                    @id  \
# 0  http://nomisma.org/id/ric.2.ves.194
# 1  http://nomisma.org/id/ric.2.ves.195
# 2  http://nomisma.org/id/ric.2.ves.196
# 3  http://nomisma.org/id/ric.2.ves.197
# 4   http://nomisma.org/id/johannes_vii
#
#                                                @type  \
# 0  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 1  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 2  [http://www.w3.org/2004/02/skos/core#Concept, ...
# 3  [http://nomisma.org/ontology#TypeSeriesItem, h...
# 4  [http://www.w3.org/2004/02/skos/core#Concept, ...
#
#                http://purl.org/dc/terms/isReplacedBy  \
# 0  [{'@id': 'http://numismatics.org/ocre/id/ric.2...
# 1  [{'@id': 'http://numismatics.org/ocre/id/ric.2...
# 2  [{'@id': 'http://numismatics.org/ocre/id/ric.2...
# 3  [{'@id': 'http://numismatics.org/ocre/id/ric.2...
# 4                                                NaN
#
#       http://www.w3.org/2004/02/skos/core#changeNote  \
# 0  [{'@id': 'http://nomisma.org/id/ric.2.ves.194#...
# 1  [{'@id': 'http://nomisma.org/id/ric.2.ves.195#...
# 2  [{'@id': 'http://nomisma.org/id/ric.2.ves.196#...
# 3  [{'@id': 'http://nomisma.org/id/ric.2.ves.197#...
# 4  [{'@id': 'http://nomisma.org/id/johannes_vii#p...
#
#   http://www.w3.org/2004/02/skos/core#inScheme  \
# 0          [{'@id': 'http://nomisma.org/id/'}]
# 1          [{'@id': 'http://nomisma.org/id/'}]
# 2          [{'@id': 'http://nomisma.org/id/'}]
# 3          [{'@id': 'http://nomisma.org/id/'}]
# 4          [{'@id': 'http://nomisma.org/id/'}]
#
#        http://www.w3.org/2004/02/skos/core#prefLabel  \
# 0   [{'@language': 'en', '@value': 'ric.2.ves.194'}]
# 1   [{'@language': 'en', '@value': 'ric.2.ves.195'}]
# 2   [{'@language': 'en', '@value': 'ric.2.ves.196'}]
# 3   [{'@language': 'en', '@value': 'ric.2.ves.197'}]
# 4  [{'@language': 'nl', '@value': 'Johannes VII P...
#
#                    http://purl.org/dc/terms/isPartOf  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [{'@id': 'http://nomisma.org/id/byzantine_numi...
#
#       http://www.w3.org/2004/02/skos/core#definition  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [{'@language': 'en', '@value': 'The Byzantine ...
#
#       http://www.w3.org/2004/02/skos/core#exactMatch  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [{'@id': 'https://www.freebase.com/m/0jtv8'}, ...
#
#   http://www.w3.org/ns/prov#wasGeneratedBy  ...  \
# 0                                      NaN  ...
# 1                                      NaN  ...
# 2                                      NaN  ...
# 3                                      NaN  ...
# 4                                      NaN  ...
#
#   http://xmlns.com/foaf/0.1/depiction  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   http://www.w3.org/2000/01/rdf-schema#domain  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   http://www.w3.org/2000/01/rdf-schema#range  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   http://www.w3.org/2004/02/skos/core#notation  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   http://www.w3.org/2004/02/skos/core#defintion  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   http://nomisma.org/ontology#hasClosingDate  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   http://www.w3.org/2002/07/owl#deprecated  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   http://www.w3.org/2002/07/owl#inverseOf  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   http://www.w3.org/2004/02/skos/core#seeAlso  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   http://www.w3.org/2004/02/skos/core#definitition
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
# [5 rows x 70 columns]

# %%
nomisma_ids = nomisma["@id"].tolist()

# %%
ocre_urls = []
for nom_url in nomisma_ids:
    try:
        nom_id = nom_url.rpartition("/")[2]
        ocre_url = "http://numismatics.org/ocre/id/{0}.jsonld".format(nom_id)
        ocre_urls.append(ocre_url)
    except:
        pass

# %%
len(ocre_urls)
# Out:
# 78689

# %%
ns = range(0, len(ocre_urls), 100)
ocre_data = []
for url, n in zip(ocre_urls, range(len(ocre_urls))):
    try:
        resp = requests.get(url)
        if resp.ok:
            ocre_data.append(resp.json())
        if n in ns:
            print("url processed: {0}, success: {1}".format(n, len(ocre_data)))
    except:
        pass
# Out:
# url processed: 0, success: 0
# url processed: 100, success: 3
# url processed: 200, success: 4
# url processed: 300, success: 9
# url processed: 400, success: 15
# url processed: 500, success: 23
# url processed: 600, success: 23
# url processed: 700, success: 27
# url processed: 800, success: 30
# url processed: 900, success: 36
# url processed: 1000, success: 39
# url processed: 1100, success: 55
# url processed: 1200, success: 63
# url processed: 1300, success: 64
# url processed: 1500, success: 77
# url processed: 1600, success: 77
# url processed: 1700, success: 79
# url processed: 1800, success: 92
# url processed: 1900, success: 98
# url processed: 2000, success: 98
# url processed: 2100, success: 104

# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-23bd34261907> in <module>
# ----> 1 with open('../coins_etl/data/ocre_data_raw_test.pkl', 'rb') as f:
#       2     ocre_data = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../coins_etl/data/ocre_data_raw_test.pkl'

# %%
ocre_data[:10]
# Out:
# [{'@context': {'crmarchaeo': 'http://www.cidoc-crm.org/cidoc-crm/CRMarchaeo/',
#    'dcterms': 'http://purl.org/dc/terms/',
#    'relations': 'http://pelagios.github.io/vocab/relations#',
#    'edm': 'http://www.europeana.eu/schemas/edm/',
#    'nm': 'http://nomisma.org/id/',
#    'svcs': 'http://rdfs.org/sioc/services#',
#    'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#',
#    'doap': 'http://usefulinc.com/ns/doap#',
#    'rdfs': 'http://www.w3.org/2000/01/rdf-schema#',
#    'crm': 'http://www.cidoc-crm.org/cidoc-crm/',
#    'oa': 'http://www.w3.org/ns/oa#',
#    'skos': 'http://www.w3.org/2004/02/skos/core#',
#    'xsd': 'http://www.w3.org/2001/XMLSchema#',
#    'pelagios': 'http://pelagios.github.io/vocab/terms#',
#    'foaf': 'http://xmlns.com/foaf/0.1/',
#    'un': 'http://www.owl-ontologies.com/Ontology1181490123.owl#',
#    'void': 'http://rdfs.org/ns/void#',
#    'dcmitype': 'http://purl.org/dc/dcmitype/',
#    'nmo': 'http://nomisma.org/ontology#',
#    'crmsci': 'http://www.ics.forth.gr/isl/CRMsci/',
#    'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#    'crmgeo': 'http://www.ics.forth.gr/isl/CRMgeo/'},
#   '@graph': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.747h',
#     '@type': ['nmo:TypeSeriesItem',
#      'http://www.w3.org/2004/02/skos/core#Concept'],
#     'rdf:type': ['http://www.w3.org/2004/02/skos/core#Concept'],
#     'skos:prefLabel': [{'@value': 'RIC II Hadrian 747h', '@language': 'en'}],
#     'skos:definition': [{'@value': 'RIC II Hadrian 747h', '@language': 'en'}],
#     'dcterms:source': [{'@id': 'http://nomisma.org/id/ric'}],
#     'dcterms:isReplacedBy': [{'@id': 'http://numismatics.org/ocre/id/ric.2_3(2).hdn.1914'}],
#     'skos:exactMatch': [{'@id': 'http://numismatics.org/ocre/id/ric.2_3(2).hdn.1914'}],
#     'nmo:representsObjectType': [{'@id': 'http://nomisma.org/id/coin'}],
#     'nmo:hasManufacture': [{'@id': 'http://nomisma.org/id/struck'}],
#     'nmo:hasDenomination': [{'@id': 'http://nomisma.org/id/sestertius'}],
#     'nmo:hasMaterial': [{'@id': 'http://nomisma.org/id/ae'}],
#     'nmo:hasAuthority': [{'@id': 'http://nomisma.org/id/hadrian'}],
#     'nmo:hasMint': [{'@id': 'http://nomisma.org/id/rome'}],
#     'nmo:hasRegion': [{'@id': 'http://nomisma.org/id/italy'}],
#     'nmo:hasStartDate': [{'@value': '0134',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasEndDate': [{'@value': '0138',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasObverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.747h#obverse'}],
#     'nmo:hasReverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.747h#reverse'}],
#     'void:inDataset': [{'@id': 'http://numismatics.org/ocre/'}]}]},
#  {'@context': {'crmarchaeo': 'http://www.cidoc-crm.org/cidoc-crm/CRMarchaeo/',
#    'dcterms': 'http://purl.org/dc/terms/',
#    'relations': 'http://pelagios.github.io/vocab/relations#',
#    'edm': 'http://www.europeana.eu/schemas/edm/',
#    'nm': 'http://nomisma.org/id/',
#    'svcs': 'http://rdfs.org/sioc/services#',
#    'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#',
#    'doap': 'http://usefulinc.com/ns/doap#',
#    'rdfs': 'http://www.w3.org/2000/01/rdf-schema#',
#    'crm': 'http://www.cidoc-crm.org/cidoc-crm/',
#    'oa': 'http://www.w3.org/ns/oa#',
#    'skos': 'http://www.w3.org/2004/02/skos/core#',
#    'xsd': 'http://www.w3.org/2001/XMLSchema#',
#    'pelagios': 'http://pelagios.github.io/vocab/terms#',
#    'foaf': 'http://xmlns.com/foaf/0.1/',
#    'un': 'http://www.owl-ontologies.com/Ontology1181490123.owl#',
#    'void': 'http://rdfs.org/ns/void#',
#    'dcmitype': 'http://purl.org/dc/dcmitype/',
#    'nmo': 'http://nomisma.org/ontology#',
#    'crmsci': 'http://www.ics.forth.gr/isl/CRMsci/',
#    'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#    'crmgeo': 'http://www.ics.forth.gr/isl/CRMgeo/'},
#   '@graph': [{'@id': 'http://numismatics.org/ocre/id/ric.2.tr.85',
#     '@type': ['nmo:TypeSeriesItem',
#      'http://www.w3.org/2004/02/skos/core#Concept'],
#     'rdf:type': ['http://www.w3.org/2004/02/skos/core#Concept'],
#     'skos:prefLabel': [{'@value': 'RIC II Trajan 85', '@language': 'en'}],
#     'skos:definition': [{'@value': 'RIC II Trajan 85', '@language': 'en'}],
#     'dcterms:source': [{'@id': 'http://nomisma.org/id/ric'}],
#     'nmo:representsObjectType': [{'@id': 'http://nomisma.org/id/coin'}],
#     'nmo:hasManufacture': [{'@id': 'http://nomisma.org/id/struck'}],
#     'nmo:hasDenomination': [{'@id': 'http://nomisma.org/id/denarius'}],
#     'nmo:hasMaterial': [{'@id': 'http://nomisma.org/id/ar'}],
#     'nmo:hasAuthority': [{'@id': 'http://nomisma.org/id/trajan'}],
#     'nmo:hasMint': [{'@id': 'http://nomisma.org/id/rome'}],
#     'nmo:hasRegion': [{'@id': 'http://nomisma.org/id/italy'}],
#     'nmo:hasStartDate': [{'@value': '0103',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasEndDate': [{'@value': '0111',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasObverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.tr.85#obverse'}],
#     'nmo:hasReverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.tr.85#reverse'}],
#     'void:inDataset': [{'@id': 'http://numismatics.org/ocre/'}]},
#    {'@id': 'http://numismatics.org/ocre/id/ric.2.tr.85#obverse',
#     'nmo:hasLegend': [{'@value': 'IMP NERVA TRAIANVS AVG GER DACICVS'}],
#     'dcterms:description': [{'@value': 'Bust of Trajan, laureate, right',
#       '@language': 'en'}],
#     'nmo:hasPortrait': [{'@id': 'http://nomisma.org/id/trajan'}]},
#    {'@id': 'http://numismatics.org/ocre/id/ric.2.tr.85#reverse',
#     'nmo:hasLegend': [{'@value': 'P M TR P COS V P P'}],
#     'dcterms:description': [{'@value': 'Trajan, standing front, holding vertical spear in right hand and parazonium in in left, crowned by Victory , draped on right, standing left, holding palm in left',
#       '@language': 'en'}],
#     'nmo:hasPortrait': [{'@id': 'http://nomisma.org/id/trajan'},
#      {'@id': 'http://collection.britishmuseum.org/id/person-institution/60915'}]}]},
#  {'@context': {'crmarchaeo': 'http://www.cidoc-crm.org/cidoc-crm/CRMarchaeo/',
#    'dcterms': 'http://purl.org/dc/terms/',
#    'relations': 'http://pelagios.github.io/vocab/relations#',
#    'edm': 'http://www.europeana.eu/schemas/edm/',
#    'nm': 'http://nomisma.org/id/',
#    'svcs': 'http://rdfs.org/sioc/services#',
#    'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#',
#    'doap': 'http://usefulinc.com/ns/doap#',
#    'rdfs': 'http://www.w3.org/2000/01/rdf-schema#',
#    'crm': 'http://www.cidoc-crm.org/cidoc-crm/',
#    'oa': 'http://www.w3.org/ns/oa#',
#    'skos': 'http://www.w3.org/2004/02/skos/core#',
#    'xsd': 'http://www.w3.org/2001/XMLSchema#',
#    'pelagios': 'http://pelagios.github.io/vocab/terms#',
#    'foaf': 'http://xmlns.com/foaf/0.1/',
#    'un': 'http://www.owl-ontologies.com/Ontology1181490123.owl#',
#    'void': 'http://rdfs.org/ns/void#',
#    'dcmitype': 'http://purl.org/dc/dcmitype/',
#    'nmo': 'http://nomisma.org/ontology#',
#    'crmsci': 'http://www.ics.forth.gr/isl/CRMsci/',
#    'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#    'crmgeo': 'http://www.ics.forth.gr/isl/CRMgeo/'},
#   '@graph': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.142',
#     '@type': ['nmo:TypeSeriesItem',
#      'http://www.w3.org/2004/02/skos/core#Concept'],
#     'rdf:type': ['http://www.w3.org/2004/02/skos/core#Concept'],
#     'skos:prefLabel': [{'@value': 'RIC II Hadrian 142', '@language': 'en'}],
#     'skos:definition': [{'@value': 'RIC II Hadrian 142', '@language': 'en'}],
#     'dcterms:source': [{'@id': 'http://nomisma.org/id/ric'}],
#     'dcterms:isReplacedBy': [{'@id': 'http://numismatics.org/ocre/id/ric.2_3(2).hdn.2791'}],
#     'skos:exactMatch': [{'@id': 'http://numismatics.org/ocre/id/ric.2_3(2).hdn.2791'}],
#     'nmo:representsObjectType': [{'@id': 'http://nomisma.org/id/coin'}],
#     'nmo:hasManufacture': [{'@id': 'http://nomisma.org/id/struck'}],
#     'nmo:hasDenomination': [{'@id': 'http://nomisma.org/id/denarius'}],
#     'nmo:hasMaterial': [{'@id': 'http://nomisma.org/id/ar'}],
#     'nmo:hasAuthority': [{'@id': 'http://nomisma.org/id/hadrian'}],
#     'nmo:hasMint': [{'@id': 'http://nomisma.org/id/rome'}],
#     'nmo:hasRegion': [{'@id': 'http://nomisma.org/id/italy'}],
#     'nmo:hasStartDate': [{'@value': '0119',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasEndDate': [{'@value': '0122',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasObverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.142#obverse'}],
#     'nmo:hasReverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.142#reverse'}],
#     'void:inDataset': [{'@id': 'http://numismatics.org/ocre/'}]}]},
#  {'@context': {'crmarchaeo': 'http://www.cidoc-crm.org/cidoc-crm/CRMarchaeo/',
#    'dcterms': 'http://purl.org/dc/terms/',
#    'relations': 'http://pelagios.github.io/vocab/relations#',
#    'edm': 'http://www.europeana.eu/schemas/edm/',
#    'nm': 'http://nomisma.org/id/',
#    'svcs': 'http://rdfs.org/sioc/services#',
#    'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#',
#    'doap': 'http://usefulinc.com/ns/doap#',
#    'rdfs': 'http://www.w3.org/2000/01/rdf-schema#',
#    'crm': 'http://www.cidoc-crm.org/cidoc-crm/',
#    'oa': 'http://www.w3.org/ns/oa#',
#    'skos': 'http://www.w3.org/2004/02/skos/core#',
#    'xsd': 'http://www.w3.org/2001/XMLSchema#',
#    'pelagios': 'http://pelagios.github.io/vocab/terms#',
#    'foaf': 'http://xmlns.com/foaf/0.1/',
#    'un': 'http://www.owl-ontologies.com/Ontology1181490123.owl#',
#    'void': 'http://rdfs.org/ns/void#',
#    'dcmitype': 'http://purl.org/dc/dcmitype/',
#    'nmo': 'http://nomisma.org/ontology#',
#    'crmsci': 'http://www.ics.forth.gr/isl/CRMsci/',
#    'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#    'crmgeo': 'http://www.ics.forth.gr/isl/CRMgeo/'},
#   '@graph': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.988',
#     '@type': ['nmo:TypeSeriesItem',
#      'http://www.w3.org/2004/02/skos/core#Concept'],
#     'rdf:type': ['http://www.w3.org/2004/02/skos/core#Concept'],
#     'skos:prefLabel': [{'@value': 'RIC II Hadrian 988'}],
#     'skos:definition': [{'@value': 'RIC II Hadrian 988'}],
#     'dcterms:source': [{'@id': 'http://nomisma.org/id/ric'}],
#     'dcterms:isReplacedBy': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.988_as'},
#      {'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.988_dupondius'}],
#     'nmo:representsObjectType': [{'@id': 'http://nomisma.org/id/coin'}],
#     'nmo:hasManufacture': [{'@id': 'http://nomisma.org/id/struck'}],
#     'nmo:hasDenomination': [{'@id': 'http://nomisma.org/id/dupondius'},
#      {'@id': 'http://nomisma.org/id/as'}],
#     'nmo:hasMaterial': [{'@id': 'http://nomisma.org/id/orichalcum'}],
#     'nmo:hasMint': [{'@id': 'http://nomisma.org/id/rome'}],
#     'nmo:hasRegion': [{'@id': 'http://nomisma.org/id/italy'}],
#     'nmo:hasAuthority': [{'@id': 'http://nomisma.org/id/hadrian'}],
#     'nmo:hasStartDate': [{'@value': '0132',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasEndDate': [{'@value': '0134',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasObverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.988#obverse'}],
#     'nmo:hasReverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.988#reverse'}],
#     'void:inDataset': [{'@id': 'http://numismatics.org/ocre/'}]}]},
#  {'@context': {'crmarchaeo': 'http://www.cidoc-crm.org/cidoc-crm/CRMarchaeo/',
#    'dcterms': 'http://purl.org/dc/terms/',
#    'relations': 'http://pelagios.github.io/vocab/relations#',
#    'edm': 'http://www.europeana.eu/schemas/edm/',
#    'nm': 'http://nomisma.org/id/',
#    'svcs': 'http://rdfs.org/sioc/services#',
#    'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#',
#    'doap': 'http://usefulinc.com/ns/doap#',
#    'rdfs': 'http://www.w3.org/2000/01/rdf-schema#',
#    'crm': 'http://www.cidoc-crm.org/cidoc-crm/',
#    'oa': 'http://www.w3.org/ns/oa#',
#    'skos': 'http://www.w3.org/2004/02/skos/core#',
#    'xsd': 'http://www.w3.org/2001/XMLSchema#',
#    'pelagios': 'http://pelagios.github.io/vocab/terms#',
#    'foaf': 'http://xmlns.com/foaf/0.1/',
#    'un': 'http://www.owl-ontologies.com/Ontology1181490123.owl#',
#    'void': 'http://rdfs.org/ns/void#',
#    'dcmitype': 'http://purl.org/dc/dcmitype/',
#    'nmo': 'http://nomisma.org/ontology#',
#    'crmsci': 'http://www.ics.forth.gr/isl/CRMsci/',
#    'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#    'crmgeo': 'http://www.ics.forth.gr/isl/CRMgeo/'},
#   '@graph': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.640a',
#     '@type': ['nmo:TypeSeriesItem',
#      'http://www.w3.org/2004/02/skos/core#Concept'],
#     'rdf:type': ['http://www.w3.org/2004/02/skos/core#Concept'],
#     'skos:prefLabel': [{'@value': 'RIC II Hadrian 640a', '@language': 'en'}],
#     'skos:definition': [{'@value': 'RIC II Hadrian 640a', '@language': 'en'}],
#     'dcterms:source': [{'@id': 'http://nomisma.org/id/ric'}],
#     'dcterms:isReplacedBy': [{'@id': 'http://numismatics.org/ocre/id/ric.2_3(2).hdn.827'}],
#     'skos:exactMatch': [{'@id': 'http://numismatics.org/ocre/id/ric.2_3(2).hdn.827'}],
#     'nmo:representsObjectType': [{'@id': 'http://nomisma.org/id/coin'}],
#     'nmo:hasManufacture': [{'@id': 'http://nomisma.org/id/struck'}],
#     'nmo:hasDenomination': [{'@id': 'http://nomisma.org/id/sestertius'}],
#     'nmo:hasMaterial': [{'@id': 'http://nomisma.org/id/ae'}],
#     'nmo:hasAuthority': [{'@id': 'http://nomisma.org/id/hadrian'}],
#     'nmo:hasMint': [{'@id': 'http://nomisma.org/id/rome'}],
#     'nmo:hasRegion': [{'@id': 'http://nomisma.org/id/italy'}],
#     'nmo:hasStartDate': [{'@value': '0125',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasEndDate': [{'@value': '0128',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasObverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.640a#obverse'}],
#     'nmo:hasReverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.640a#reverse'}],
#     'void:inDataset': [{'@id': 'http://numismatics.org/ocre/'}]}]},
#  {'@context': {'crmarchaeo': 'http://www.cidoc-crm.org/cidoc-crm/CRMarchaeo/',
#    'dcterms': 'http://purl.org/dc/terms/',
#    'relations': 'http://pelagios.github.io/vocab/relations#',
#    'edm': 'http://www.europeana.eu/schemas/edm/',
#    'nm': 'http://nomisma.org/id/',
#    'svcs': 'http://rdfs.org/sioc/services#',
#    'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#',
#    'doap': 'http://usefulinc.com/ns/doap#',
#    'rdfs': 'http://www.w3.org/2000/01/rdf-schema#',
#    'crm': 'http://www.cidoc-crm.org/cidoc-crm/',
#    'oa': 'http://www.w3.org/ns/oa#',
#    'skos': 'http://www.w3.org/2004/02/skos/core#',
#    'xsd': 'http://www.w3.org/2001/XMLSchema#',
#    'pelagios': 'http://pelagios.github.io/vocab/terms#',
#    'foaf': 'http://xmlns.com/foaf/0.1/',
#    'un': 'http://www.owl-ontologies.com/Ontology1181490123.owl#',
#    'void': 'http://rdfs.org/ns/void#',
#    'dcmitype': 'http://purl.org/dc/dcmitype/',
#    'nmo': 'http://nomisma.org/ontology#',
#    'crmsci': 'http://www.ics.forth.gr/isl/CRMsci/',
#    'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#    'crmgeo': 'http://www.ics.forth.gr/isl/CRMgeo/'},
#   '@graph': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.640d',
#     '@type': ['nmo:TypeSeriesItem',
#      'http://www.w3.org/2004/02/skos/core#Concept'],
#     'rdf:type': ['http://www.w3.org/2004/02/skos/core#Concept'],
#     'skos:prefLabel': [{'@value': 'RIC II Hadrian 640d', '@language': 'en'}],
#     'skos:definition': [{'@value': 'RIC II Hadrian 640d', '@language': 'en'}],
#     'dcterms:source': [{'@id': 'http://nomisma.org/id/ric'}],
#     'dcterms:isReplacedBy': [{'@id': 'http://numismatics.org/ocre/id/ric.2_3(2).hdn.826'}],
#     'skos:exactMatch': [{'@id': 'http://numismatics.org/ocre/id/ric.2_3(2).hdn.826'}],
#     'nmo:representsObjectType': [{'@id': 'http://nomisma.org/id/coin'}],
#     'nmo:hasManufacture': [{'@id': 'http://nomisma.org/id/struck'}],
#     'nmo:hasDenomination': [{'@id': 'http://nomisma.org/id/sestertius'}],
#     'nmo:hasMaterial': [{'@id': 'http://nomisma.org/id/ae'}],
#     'nmo:hasAuthority': [{'@id': 'http://nomisma.org/id/hadrian'}],
#     'nmo:hasMint': [{'@id': 'http://nomisma.org/id/rome'}],
#     'nmo:hasRegion': [{'@id': 'http://nomisma.org/id/italy'}],
#     'nmo:hasStartDate': [{'@value': '0125',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasEndDate': [{'@value': '0128',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasObverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.640d#obverse'}],
#     'nmo:hasReverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.640d#reverse'}],
#     'void:inDataset': [{'@id': 'http://numismatics.org/ocre/'}]}]},
#  {'@context': {'crmarchaeo': 'http://www.cidoc-crm.org/cidoc-crm/CRMarchaeo/',
#    'dcterms': 'http://purl.org/dc/terms/',
#    'relations': 'http://pelagios.github.io/vocab/relations#',
#    'edm': 'http://www.europeana.eu/schemas/edm/',
#    'nm': 'http://nomisma.org/id/',
#    'svcs': 'http://rdfs.org/sioc/services#',
#    'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#',
#    'doap': 'http://usefulinc.com/ns/doap#',
#    'rdfs': 'http://www.w3.org/2000/01/rdf-schema#',
#    'crm': 'http://www.cidoc-crm.org/cidoc-crm/',
#    'oa': 'http://www.w3.org/ns/oa#',
#    'skos': 'http://www.w3.org/2004/02/skos/core#',
#    'xsd': 'http://www.w3.org/2001/XMLSchema#',
#    'pelagios': 'http://pelagios.github.io/vocab/terms#',
#    'foaf': 'http://xmlns.com/foaf/0.1/',
#    'un': 'http://www.owl-ontologies.com/Ontology1181490123.owl#',
#    'void': 'http://rdfs.org/ns/void#',
#    'dcmitype': 'http://purl.org/dc/dcmitype/',
#    'nmo': 'http://nomisma.org/ontology#',
#    'crmsci': 'http://www.ics.forth.gr/isl/CRMsci/',
#    'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#    'crmgeo': 'http://www.ics.forth.gr/isl/CRMgeo/'},
#   '@graph': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.640f',
#     '@type': ['nmo:TypeSeriesItem',
#      'http://www.w3.org/2004/02/skos/core#Concept'],
#     'rdf:type': ['http://www.w3.org/2004/02/skos/core#Concept'],
#     'skos:prefLabel': [{'@value': 'RIC II Hadrian 640f', '@language': 'en'}],
#     'skos:definition': [{'@value': 'RIC II Hadrian 640f', '@language': 'en'}],
#     'dcterms:source': [{'@id': 'http://nomisma.org/id/ric'}],
#     'nmo:representsObjectType': [{'@id': 'http://nomisma.org/id/coin'}],
#     'nmo:hasManufacture': [{'@id': 'http://nomisma.org/id/struck'}],
#     'nmo:hasDenomination': [{'@id': 'http://nomisma.org/id/sestertius'}],
#     'nmo:hasMaterial': [{'@id': 'http://nomisma.org/id/ae'}],
#     'nmo:hasAuthority': [{'@id': 'http://nomisma.org/id/hadrian'}],
#     'nmo:hasMint': [{'@id': 'http://nomisma.org/id/rome'}],
#     'nmo:hasRegion': [{'@id': 'http://nomisma.org/id/italy'}],
#     'nmo:hasStartDate': [{'@value': '0125',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasEndDate': [{'@value': '0128',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasObverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.640f#obverse'}],
#     'nmo:hasReverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.640f#reverse'}],
#     'void:inDataset': [{'@id': 'http://numismatics.org/ocre/'}]}]},
#  {'@context': {'crmarchaeo': 'http://www.cidoc-crm.org/cidoc-crm/CRMarchaeo/',
#    'dcterms': 'http://purl.org/dc/terms/',
#    'relations': 'http://pelagios.github.io/vocab/relations#',
#    'edm': 'http://www.europeana.eu/schemas/edm/',
#    'nm': 'http://nomisma.org/id/',
#    'svcs': 'http://rdfs.org/sioc/services#',
#    'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#',
#    'doap': 'http://usefulinc.com/ns/doap#',
#    'rdfs': 'http://www.w3.org/2000/01/rdf-schema#',
#    'crm': 'http://www.cidoc-crm.org/cidoc-crm/',
#    'oa': 'http://www.w3.org/ns/oa#',
#    'skos': 'http://www.w3.org/2004/02/skos/core#',
#    'xsd': 'http://www.w3.org/2001/XMLSchema#',
#    'pelagios': 'http://pelagios.github.io/vocab/terms#',
#    'foaf': 'http://xmlns.com/foaf/0.1/',
#    'un': 'http://www.owl-ontologies.com/Ontology1181490123.owl#',
#    'void': 'http://rdfs.org/ns/void#',
#    'dcmitype': 'http://purl.org/dc/dcmitype/',
#    'nmo': 'http://nomisma.org/ontology#',
#    'crmsci': 'http://www.ics.forth.gr/isl/CRMsci/',
#    'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#    'crmgeo': 'http://www.ics.forth.gr/isl/CRMgeo/'},
#   '@graph': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.129c',
#     '@type': ['nmo:TypeSeriesItem',
#      'http://www.w3.org/2004/02/skos/core#Concept'],
#     'rdf:type': ['http://www.w3.org/2004/02/skos/core#Concept'],
#     'skos:prefLabel': [{'@value': 'RIC II Hadrian 129c', '@language': 'en'}],
#     'skos:definition': [{'@value': 'RIC II Hadrian 129c', '@language': 'en'}],
#     'dcterms:source': [{'@id': 'http://nomisma.org/id/ric'}],
#     'nmo:representsObjectType': [{'@id': 'http://nomisma.org/id/coin'}],
#     'nmo:hasManufacture': [{'@id': 'http://nomisma.org/id/struck'}],
#     'nmo:hasDenomination': [{'@id': 'http://nomisma.org/id/denarius'}],
#     'nmo:hasMaterial': [{'@id': 'http://nomisma.org/id/ar'}],
#     'nmo:hasAuthority': [{'@id': 'http://nomisma.org/id/hadrian'}],
#     'nmo:hasMint': [{'@id': 'http://nomisma.org/id/rome'}],
#     'nmo:hasRegion': [{'@id': 'http://nomisma.org/id/italy'}],
#     'nmo:hasStartDate': [{'@value': '0119',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasEndDate': [{'@value': '0122',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasObverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.129c#obverse'}],
#     'nmo:hasReverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.129c#reverse'}],
#     'void:inDataset': [{'@id': 'http://numismatics.org/ocre/'}]}]},
#  {'@context': {'crmarchaeo': 'http://www.cidoc-crm.org/cidoc-crm/CRMarchaeo/',
#    'dcterms': 'http://purl.org/dc/terms/',
#    'relations': 'http://pelagios.github.io/vocab/relations#',
#    'edm': 'http://www.europeana.eu/schemas/edm/',
#    'nm': 'http://nomisma.org/id/',
#    'svcs': 'http://rdfs.org/sioc/services#',
#    'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#',
#    'doap': 'http://usefulinc.com/ns/doap#',
#    'rdfs': 'http://www.w3.org/2000/01/rdf-schema#',
#    'crm': 'http://www.cidoc-crm.org/cidoc-crm/',
#    'oa': 'http://www.w3.org/ns/oa#',
#    'skos': 'http://www.w3.org/2004/02/skos/core#',
#    'xsd': 'http://www.w3.org/2001/XMLSchema#',
#    'pelagios': 'http://pelagios.github.io/vocab/terms#',
#    'foaf': 'http://xmlns.com/foaf/0.1/',
#    'un': 'http://www.owl-ontologies.com/Ontology1181490123.owl#',
#    'void': 'http://rdfs.org/ns/void#',
#    'dcmitype': 'http://purl.org/dc/dcmitype/',
#    'nmo': 'http://nomisma.org/ontology#',
#    'crmsci': 'http://www.ics.forth.gr/isl/CRMsci/',
#    'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#    'crmgeo': 'http://www.ics.forth.gr/isl/CRMgeo/'},
#   '@graph': [{'@id': 'http://numismatics.org/ocre/id/ric.2.tr.246',
#     '@type': ['nmo:TypeSeriesItem',
#      'http://www.w3.org/2004/02/skos/core#Concept'],
#     'rdf:type': ['http://www.w3.org/2004/02/skos/core#Concept'],
#     'skos:prefLabel': [{'@value': 'RIC II Trajan 246', '@language': 'en'}],
#     'skos:definition': [{'@value': 'RIC II Trajan 246', '@language': 'en'}],
#     'dcterms:source': [{'@id': 'http://nomisma.org/id/ric'}],
#     'nmo:representsObjectType': [{'@id': 'http://nomisma.org/id/coin'}],
#     'nmo:hasManufacture': [{'@id': 'http://nomisma.org/id/struck'}],
#     'nmo:hasDenomination': [{'@id': 'http://nomisma.org/id/aureus'}],
#     'nmo:hasMaterial': [{'@id': 'http://nomisma.org/id/av'}],
#     'nmo:hasAuthority': [{'@id': 'http://nomisma.org/id/trajan'}],
#     'nmo:hasMint': [{'@id': 'http://nomisma.org/id/rome'}],
#     'nmo:hasRegion': [{'@id': 'http://nomisma.org/id/italy'}],
#     'nmo:hasStartDate': [{'@value': '0112',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasEndDate': [{'@value': '0114',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasObverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.tr.246#obverse'}],
#     'nmo:hasReverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.tr.246#reverse'}],
#     'void:inDataset': [{'@id': 'http://numismatics.org/ocre/'}]},
#    {'@id': 'http://numismatics.org/ocre/id/ric.2.tr.246#obverse',
#     'nmo:hasLegend': [{'@value': 'IMP TRAIANO AVG GER DAC P M TR P COS VI P P'}],
#     'dcterms:description': [{'@value': 'Bust of Trajan, laureate, draped, right with aegis',
#       '@language': 'en'}],
#     'nmo:hasPortrait': [{'@id': 'http://nomisma.org/id/trajan'}]},
#    {'@id': 'http://numismatics.org/ocre/id/ric.2.tr.246#reverse',
#     'nmo:hasLegend': [{'@value': 'BASILICA VLPIA'}],
#     'dcterms:description': [{'@value': 'Basilica of Trajan',
#       '@language': 'en'}]}]},
#  {'@context': {'crmarchaeo': 'http://www.cidoc-crm.org/cidoc-crm/CRMarchaeo/',
#    'dcterms': 'http://purl.org/dc/terms/',
#    'relations': 'http://pelagios.github.io/vocab/relations#',
#    'edm': 'http://www.europeana.eu/schemas/edm/',
#    'nm': 'http://nomisma.org/id/',
#    'svcs': 'http://rdfs.org/sioc/services#',
#    'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#',
#    'doap': 'http://usefulinc.com/ns/doap#',
#    'rdfs': 'http://www.w3.org/2000/01/rdf-schema#',
#    'crm': 'http://www.cidoc-crm.org/cidoc-crm/',
#    'oa': 'http://www.w3.org/ns/oa#',
#    'skos': 'http://www.w3.org/2004/02/skos/core#',
#    'xsd': 'http://www.w3.org/2001/XMLSchema#',
#    'pelagios': 'http://pelagios.github.io/vocab/terms#',
#    'foaf': 'http://xmlns.com/foaf/0.1/',
#    'un': 'http://www.owl-ontologies.com/Ontology1181490123.owl#',
#    'void': 'http://rdfs.org/ns/void#',
#    'dcmitype': 'http://purl.org/dc/dcmitype/',
#    'nmo': 'http://nomisma.org/ontology#',
#    'crmsci': 'http://www.ics.forth.gr/isl/CRMsci/',
#    'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#    'crmgeo': 'http://www.ics.forth.gr/isl/CRMgeo/'},
#   '@graph': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.980',
#     '@type': ['nmo:TypeSeriesItem',
#      'http://www.w3.org/2004/02/skos/core#Concept'],
#     'rdf:type': ['http://www.w3.org/2004/02/skos/core#Concept'],
#     'skos:prefLabel': [{'@value': 'RIC II Hadrian 980'}],
#     'skos:definition': [{'@value': 'RIC II Hadrian 980'}],
#     'dcterms:source': [{'@id': 'http://nomisma.org/id/ric'}],
#     'dcterms:isReplacedBy': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.980_as'},
#      {'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.980_dupondius'}],
#     'nmo:representsObjectType': [{'@id': 'http://nomisma.org/id/coin'}],
#     'nmo:hasManufacture': [{'@id': 'http://nomisma.org/id/struck'}],
#     'nmo:hasDenomination': [{'@id': 'http://nomisma.org/id/dupondius'},
#      {'@id': 'http://nomisma.org/id/as'}],
#     'nmo:hasMaterial': [{'@id': 'http://nomisma.org/id/orichalcum'}],
#     'nmo:hasMint': [{'@id': 'http://nomisma.org/id/rome'}],
#     'nmo:hasRegion': [{'@id': 'http://nomisma.org/id/italy'}],
#     'nmo:hasAuthority': [{'@id': 'http://nomisma.org/id/hadrian'}],
#     'nmo:hasStartDate': [{'@value': '0128',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasEndDate': [{'@value': '0132',
#       '@type': 'http://www.w3.org/2001/XMLSchema#gYear'}],
#     'nmo:hasObverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.980#obverse'}],
#     'nmo:hasReverse': [{'@id': 'http://numismatics.org/ocre/id/ric.2.hdn.980#reverse'}],
#     'void:inDataset': [{'@id': 'http://numismatics.org/ocre/'}]}]}]

# %%
keys = list(ocre_data[0]["@graph"][0].keys())
keys
# Out:
# ['@id',
#  '@type',
#  'rdf:type',
#  'skos:prefLabel',
#  'skos:definition',
#  'dcterms:source',
#  'dcterms:isReplacedBy',
#  'skos:exactMatch',
#  'nmo:representsObjectType',
#  'nmo:hasManufacture',
#  'nmo:hasDenomination',
#  'nmo:hasMaterial',
#  'nmo:hasAuthority',
#  'nmo:hasMint',
#  'nmo:hasRegion',
#  'nmo:hasStartDate',
#  'nmo:hasEndDate',
#  'nmo:hasObverse',
#  'nmo:hasReverse',
#  'void:inDataset']

# %%
data_values = []
for el in ocre_data:
    el_data_values = []
    
    el_data = el["@graph"][0]
    for key in keys:
        try:
            new_data = el_data[key][0]["@id"]
        except:
            try:
                new_data = el_data[key][0]["@value"]
            except:
                try:
                    new_data = el_data[key]
                except:
                    new_data = None
        if isinstance(new_data, str):
            new_data = new_data.rpartition("/")[2]
        el_data_values.append(new_data)
    data_values.append(el_data_values)

# %%
ocre_data_df = pd.DataFrame(data_values, columns=keys)
ocre_data_df.head(5)
# Out:
#               @id                                              @type  \
# 0  ric.2.hdn.747h  [nmo:TypeSeriesItem, http://www.w3.org/2004/02...
# 1     ric.2.tr.85  [nmo:TypeSeriesItem, http://www.w3.org/2004/02...
# 2   ric.2.hdn.142  [nmo:TypeSeriesItem, http://www.w3.org/2004/02...
# 3   ric.2.hdn.988  [nmo:TypeSeriesItem, http://www.w3.org/2004/02...
# 4  ric.2.hdn.640a  [nmo:TypeSeriesItem, http://www.w3.org/2004/02...
#
#                                         rdf:type       skos:prefLabel  \
# 0  [http://www.w3.org/2004/02/skos/core#Concept]  RIC II Hadrian 747h
# 1  [http://www.w3.org/2004/02/skos/core#Concept]     RIC II Trajan 85
# 2  [http://www.w3.org/2004/02/skos/core#Concept]   RIC II Hadrian 142
# 3  [http://www.w3.org/2004/02/skos/core#Concept]   RIC II Hadrian 988
# 4  [http://www.w3.org/2004/02/skos/core#Concept]  RIC II Hadrian 640a
#
#        skos:definition dcterms:source dcterms:isReplacedBy  \
# 0  RIC II Hadrian 747h            ric  ric.2_3(2).hdn.1914
# 1     RIC II Trajan 85            ric                 None
# 2   RIC II Hadrian 142            ric  ric.2_3(2).hdn.2791
# 3   RIC II Hadrian 988            ric     ric.2.hdn.988_as
# 4  RIC II Hadrian 640a            ric   ric.2_3(2).hdn.827
#
#        skos:exactMatch nmo:representsObjectType nmo:hasManufacture  \
# 0  ric.2_3(2).hdn.1914                     coin             struck
# 1                 None                     coin             struck
# 2  ric.2_3(2).hdn.2791                     coin             struck
# 3                 None                     coin             struck
# 4   ric.2_3(2).hdn.827                     coin             struck
#
#   nmo:hasDenomination nmo:hasMaterial nmo:hasAuthority nmo:hasMint  \
# 0          sestertius              ae          hadrian        rome
# 1            denarius              ar           trajan        rome
# 2            denarius              ar          hadrian        rome
# 3           dupondius      orichalcum          hadrian        rome
# 4          sestertius              ae          hadrian        rome
#
#   nmo:hasRegion nmo:hasStartDate nmo:hasEndDate          nmo:hasObverse  \
# 0         italy             0134           0138  ric.2.hdn.747h#obverse
# 1         italy             0103           0111     ric.2.tr.85#obverse
# 2         italy             0119           0122   ric.2.hdn.142#obverse
# 3         italy             0132           0134   ric.2.hdn.988#obverse
# 4         italy             0125           0128  ric.2.hdn.640a#obverse
#
#            nmo:hasReverse void:inDataset
# 0  ric.2.hdn.747h#reverse
# 1     ric.2.tr.85#reverse
# 2   ric.2.hdn.142#reverse
# 3   ric.2.hdn.988#reverse
# 4  ric.2.hdn.640a#reverse

# %%
ocre_data_df.groupby("nmo:hasAuthority").size()
# Out:
# nmo:hasAuthority
# anonymous      37
# hadrian      1854
# nerva         141
# trajan        754
# dtype: int64

# %%
set_with_dataframe(coins_gsheet.add_worksheet("ocre_data_test1", 1,1), ocre_data_df)
