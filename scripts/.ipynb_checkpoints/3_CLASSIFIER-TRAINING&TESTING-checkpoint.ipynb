# %%
import sddk
import pandas as pd
import tabulate
pd.options.display.max_columns = 1000 # to see all columns
import json
import re
import geopandas as gpd
from shapely.geometry import Point
from functools import partial
from shapely.ops import transform
import pyproj
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from scipy.spatial import cKDTree
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix

from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score, make_scorer


from sklearn.dummy import DummyClassifier

# Create decision tree classifier object 
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

import pickle

import nltk
from nltk.util import bigrams

# %%
EDHCSg = sddk.read_file("EDHCSg.geojson", "gdf", "a9237c5ea642d4714bcdefb03f70a1f4")
# Out:
# reading file located in a public folder
# The history saving thread hit an unexpected error (OperationalError('database or disk is full',)).History will not be written to the database.

# %%
# to train the model, we will work with a subset of the for which we have both the EDH and EDCS attributes
# we will call it EDHg
EDH_overlap_all = EDHCSg[(EDHCSg["EDH-ID"].notnull()) & (EDHCSg["EDCS-ID"].notnull())] 
EDH_overlap_all.groupby("type_of_inscription_clean").size().sort_values(ascending=False)
# Out:
# type_of_inscription_clean
# epitaph                            21520
# votive inscription                 11728
# NULL                                3745
# owner/artist inscription            3340
# honorific inscription               3003
# building/dedicatory inscription     2561
# mile-/leaguestone                   1307
# identification inscription           850
# acclamation                          287
# defixio                              269
# list                                 246
# military diploma                     209
# label                                194
# boundary inscription                 175
# elogium                              132
# letter                               119
# public legal inscription             109
# seat inscription                      42
# private legal inscription             36
# prayer                                18
# assignation inscription               15
# calendar                              10
# adnuntiatio                            1
# dtype: int64

# %%
EDH_overlap = EDH_overlap_all[~EDH_overlap_all["type_of_inscription_clean"].str.contains("NULL")]

# %% [markdown]
# Now we can focus on some EDCS attributes (i.e. firt 28 columns) which might be good predictors of `type_of_inscription_clean` in EDH. First, look at `status_list`:

# %%
EDH_overlap.groupby("type_of_inscription_clean").size().sort_values(ascending=False)
# Out:
# type_of_inscription_clean
# epitaph                            21520
# votive inscription                 11728
# owner/artist inscription            3340
# honorific inscription               3003
# building/dedicatory inscription     2561
# mile-/leaguestone                   1307
# identification inscription           850
# acclamation                          287
# defixio                              269
# list                                 246
# military diploma                     209
# label                                194
# boundary inscription                 175
# elogium                              132
# letter                               119
# public legal inscription             109
# seat inscription                      42
# private legal inscription             36
# prayer                                18
# assignation inscription               15
# calendar                              10
# adnuntiatio                            1
# dtype: int64

# %%
classes_sorted = [key for key in dict(EDH_overlap.groupby("type_of_inscription_clean").size().sort_values(ascending=False))]

# %%
# alternative, treat whole dataset as a sample
EDH_sampled = EDH_overlap

# %%
y = EDH_sampled["type_of_inscription_clean"].tolist()

# %% [markdown]
# # Build a SVM model combining `status_list` & `clean_text_interpretive_word`

# %% [markdown]
# next step would be to build a model combining the information from the `status_list` with an informatation from the text of the inscription (i.e. `clean_text_interpretive_word`).

# %%
EDH_sampled.head(5)
# Out:
#          EDCS-ID                                        publication province  \
# 0  EDCS-03700724  ZPE-108-159 = Thesprotia 00001 = AE 1993, 0140...   Achaia
# 1  EDCS-03300852                                     AE 1995, 01409   Achaia
# 2  EDCS-28500283  CIL 03, 07251 = D 00214 = NDIEC-07, p 81 = AE ...   Achaia
# 3  EDCS-09400671  CIMRM-02, 02350 = IG-12, 00274 = Andros 00124 ...   Achaia
# 4  EDCS-24600769                    AE 1995, 01407 = AE 2001, 01812   Achaia
#
#   province_list                                       place  \
# 0        Achaia                  Agios Athanasios / Photike
# 1        Achaia                                Alea / Tegea
# 2        Achaia                                Alea / Tegea
# 3        Achaia                                      Andros
# 4        Achaia  Archea Olimpia / Archaia Olympia / Olympia
#
#                                          place_list end_yr_list  \
# 0                   ['Agios Athanasios', 'Photike']         313
# 1                                 ['Alea', 'Tegea']         276
# 2                                 ['Alea', 'Tegea']          50
# 3                                            Andros         209
# 4  ['Archea Olimpia', 'Archaia Olympia', 'Olympia']          96
#
#                              notes_dating  \
# 0
# 1  to 276;   b:  276 to 282         \n\n
# 2
# 3
# 4
#
#                                          status_list        inscr_type  \
# 0  ['Augusti/Augustae', 'litterae erasae', 'ordo ...  tituli honorarii
# 1           ['Augusti/Augustae', 'miliaria', 'viri']          miliaria
# 2              ['Augusti/Augustae', 'leges', 'viri']             leges
# 3                ['litterae erasae', 'tituli sacri']      tituli sacri
# 4                                                 {}                {}
#
#                                      status_notation    inscr_process  \
# 0  ['Augusti/Augustae', 'ordo equester', 'tria no...  litterae erasae
# 1                       ['Augusti/Augustae', 'viri']               {}
# 2                       ['Augusti/Augustae', 'viri']               {}
# 3                                                 {}  litterae erasae
# 4                                                 {}               {}
#
#   notes_references notes_comments  \
# 0
# 1
# 2
# 3
# 4
#
#                                          inscription  \
# 0  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 1  to 276;   b:  276 to 282         \n\n \n \nImp...
# 2  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 3  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 4                             Octa(vius) Sa(lutaris)
#
#                           inscription_stripped_final  \
# 0  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 1  Imp(eratori) / Floriano / P(io) F(elici) Aug(u...
# 2  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 3  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 4                             Octa(vius) Sa(lutaris)
#
#                                                Links  dating from dating to  \
# 0  http://db.edcs.eu/epigr/partner.php?s_language...        309.0       313
# 1  http://db.edcs.eu/epigr/partner.php?s_language...          NaN       276
# 2  http://db.edcs.eu/epigr/partner.php?s_language...         49.0        50
# 3  http://db.edcs.eu/epigr/partner.php?s_language...        198.0       209
# 4  http://db.edcs.eu/epigr/partner.php?s_language...         81.0        96
#
#                                               status   Latitude  Longitude  \
# 0  Augusti/Augustae; litterae erasae; ordo equest...  39.451218  20.766767
# 1                   Augusti/Augustae; miliaria; viri  37.454501  22.420877
# 2                      Augusti/Augustae; leges; viri  37.454501  22.420877
# 3                      litterae erasae; tituli sacri  37.837612  24.937637
# 4                                               None  37.643870  21.625513
#
#                                                photo Material Comment  \
# 0  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None    None
# 1                                               None    lapis    None
# 2                                               None     None    None
# 3  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None    None
# 4                                               None     None    None
#
#      EDH-ID language_EDCS                  clean_text_interpretive_word_EDCS  \
# 0  HD052964          None  Fortissimo et Piissimo Caesari domino nostro G...
# 1  HD051000          None  Imperatori Floriano Pio Felici Augusto patri p...
# 2  HD021396          None  Tiberius Claudius Caesar Augustus Germanicus p...
# 3  HD011892          None  Pro salute Imperatoris Caesaris Luci Septimi S...
# 4  HD050999          None                                 Octavius Salutaris
#
#   responsible_individual       type_of_inscription letter_size  \
# 0                  Cowey     honorific inscription    3-5.3 cm
# 1                  Cowey         mile-/leaguestone    3.3-6 cm
# 2                  Cowey  public legal inscription        None
# 3                  Cowey        votive inscription  5.5-5.7 cm
# 4                  Cowey  owner/artist inscription        None
#
#                                           literature         work_status  \
# 0  AE 1993, 1406.; V. Papadopoulou, AD 43 B, 1988...  checked with photo
# 1  AE 1995, 1409.; M. Iozzer - M. Pangano, ASAA 6...  checked with photo
# 2  CIL 03, 07251.; ILS 0214.; AE 1941, 0119.; MAI...  checked with photo
# 3  AE 1911, 0056. (B); T. Sauciuc, MDAI(R) 25, 19...  checked with photo
# 4  AE 1995, 1407.; U. Sinn u. a., Nikephoros 8, 1...  checked with photo
#
#     height                                    diplomatic_text  \
# 0    99 cm  FORTISSIMO ET PIIS / SIMO CAESARI D N / GAL VA...
# 1  (44) cm  [ ] / AN[ ] FLORIANO / P F AVG / P P / M P III...
# 2   160 cm  T[ ] CLAVDIVS CAESAR AVG / G[ ]ANICVS PONTIF M...
# 3    48 cm  PRO SALVTE IMP CAESARI / L SEPTIMI SEVERI ET M...
# 4     None                                           OCTA SAL
#
#                                               people  depth material  \
# 0  [{'name': 'Gal. Val. [[Maximiano]]', 'nomen': ...  67 cm     None
# 1  [{'person_id': '1', 'nomen': 'Annius+', 'name'...   None     None
# 2  [{'gender': 'male', 'cognomen': 'Caesar August...  17 cm     None
# 3  [{'gender': 'male', 'praenomen': 'L.', 'name':...   None     None
# 4  [{'person_id': '1', 'nomen': 'Octavius*', 'nam...   None     None
#
#           type_of_monument province_label   width  \
# 0              statue base         Epirus   67 cm
# 1        mile-/leaguestone         Achaia   24 cm
# 2                   tabula         Achaia   58 cm
# 3                     None         Achaia  126 cm
# 4  instrumentum domesticum         Achaia    None
#
#                                        transcription country  \
# 0  Fortissimo et piis/simo Caesari d(omino) n(ost...  Greece
# 1  [Imp(eratori) Caes(ari) M(arco)] / An[nio] Flo...  Greece
# 2  T[i(berius)] Claudius Caesar Aug(ustus) / G[er...  Greece
# 3  Pro salute Imp(eratorum) Caesari(s) / L(uci) S...  Greece
# 4                             Octa(vius) Sal(utaris)  Greece
#
#                                                  uri findspot_ancient  \
# 0  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Photike
# 1  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 2  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 3  https://edh-www.adw.uni-heidelberg.de/edh/insc...      Palaeopolis
# 4  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Olympia
#
#   last_update  modern_region findspot_modern  \
# 0  2014-09-16        Ípeiros      Paramythía
# 1  2011-05-24   Pelopónissos            Alea
# 2  2011-05-10   Pelopónissos            Alea
# 3  2017-05-30   Nótio Aigaío     Palaiópolis
# 4  2012-04-16  Stereá Elláda         Olympia
#
#                                    edh_geography_uri  \
# 0  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 1  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 2  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 3  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 4  https://edh-www.adw.uni-heidelberg.de/edh/geog...
#
#                                           commentary  \
# 0                                               None
# 1   Die erste Inschrift ist auf 276, die zweite a...
# 2                                               None
# 3   Auf dem Foto sind die Buchstaben oft kaum erk...
# 4       (B): Sa(lutaris) fehlerhaft für Sal(utaris).
#
#                            trismegistos_uri external_image_uris fotos idno_tm  \
# 0  https://www.trismegistos.org/text/121715                  {}    {}  121715
# 1  https://www.trismegistos.org/text/177273                  {}    {}  177273
# 2  https://www.trismegistos.org/text/177131                  {}    {}  177131
# 3  https://www.trismegistos.org/text/177087                  {}    {}  177087
# 4  https://www.trismegistos.org/text/177272                  {}    {}  177272
#
#                                      placenames_refs  \
# 0  ['http://www.trismegistos.org/place/000655', '...
# 1  ['http://www.trismegistos.org/place/000078', '...
# 2  ['http://www.trismegistos.org/place/000078', '...
# 3                                                 []
# 4  ['http://www.trismegistos.org/place/000078', '...
#
#                                         text_edition  \
# 0                  Fortissimo et piissimo Caesari...
# 1  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 2                  Tiberius Claudius Caesar Augus...
# 3                  Pro salute Imperatorum Caesari...
# 4                                 Octavius Salutaris
#
#                                  origdate_text layout_execution  \
# 0  309 AD – 313 AD                                           21
# 1           276 AD                                           21
# 2    49 AD – 50 AD                                           21
# 3  198 AD – 209 AD                                           21
# 4    81 AD – 96 AD                                           21
#
#   layout_execution_text  support_objecttype  support_objecttype_text  \
# 0            unbestimmt                57.0             Statuenbasis
# 1            unbestimmt                89.0      Meilen-/Leugenstein
# 2            unbestimmt               257.0                    Tafel
# 3            unbestimmt                 2.0               unbestimmt
# 4            unbestimmt               140.0  Instrumentum domesticum
#
#   support_material support_material_text  support_decoration keywords_term  \
# 0              138            unbestimmt              1000.0            69
# 1              138            unbestimmt              1000.0           102
# 2              138            unbestimmt              1000.0
# 3              138            unbestimmt              1000.0            80
# 4              138            unbestimmt              1000.0           311
#
#                  keywords_term_text type_of_inscription_clean  \
# 0                    Ehreninschrift     honorific inscription
# 1               Meilen-/Leugenstein         mile-/leaguestone
# 2  Rechtliche Verfügung, öffentlich  public legal inscription
# 3                     Weihinschrift        votive inscription
# 4     Besitzer-/Herstellerinschrift  owner/artist inscription
#
#   type_of_inscription_certainty  height_cm  width_cm  depth_cm material_clean  \
# 0                       Certain       99.0      67.0      67.0           NULL
# 1                       Certain       44.0      24.0       NaN           NULL
# 2                       Certain      160.0      58.0      17.0           NULL
# 3                       Certain       48.0     126.0       NaN           NULL
# 4                       Certain        NaN       NaN       NaN           NULL
#
#     type_of_monument_clean type_of_monument_certainty province_label_clean  \
# 0              statue base                    Certain               Epirus
# 1        mile-/leaguestone                    Certain               Achaia
# 2                   tabula                    Certain               Achaia
# 3                     NULL                       NULL               Achaia
# 4  instrumentum domesticum                    Certain               Achaia
#
#   province_label_certainty country_clean country_certainty  \
# 0                  Certain        Greece           Certain
# 1                  Certain        Greece           Certain
# 2                  Certain        Greece           Certain
# 3                  Certain        Greece           Certain
# 4                  Certain        Greece           Certain
#
#   findspot_ancient_clean findspot_ancient_certainty modern_region_clean  \
# 0                Photike                    Certain             Ípeiros
# 1                  Tegea                    Certain        Pelopónissos
# 2                  Tegea                    Certain        Pelopónissos
# 3            Palaeopolis                    Certain        Nótio Aigaío
# 4                Olympia                    Certain       Stereá Elláda
#
#   modern_region_certainty findspot_modern_clean findspot_modern_certainty  \
# 0                 Certain            Paramythía                   Certain
# 1                 Certain                  Alea                   Certain
# 2                 Certain                  Alea                   Certain
# 3                 Certain           Palaiópolis                   Certain
# 4                 Certain               Olympia                   Certain
#
#                           findspot_clean findspot_certainty  \
# 0                       Agios Athanasios            Certain
# 1                           Stringu, bei            Certain
# 2                                   NULL               NULL
# 3  to Elleniko Mauer, sekundär verwendet            Certain
# 4                      Haus der Athleten            Certain
#
#   origdate_text_clean                            clean_text_conservative  \
# 0     309 AD – 313 AD  Fortissimo et piissimo Caesari d n Gal Val P F...
# 1              276 AD  An Floriano P F Aug p p m p III Imp Caes M Aur...
# 2       49 AD – 50 AD  T Claudius Caesar Aug Ganicus pontif max trib ...
# 3     198 AD – 209 AD  Pro salute Imp Caesari L Septimi Severi et M A...
# 4       81 AD – 96 AD                                           Octa Sal
#
#                     clean_text_interpretive_sentence  \
# 0  Fortissimo et piissimo Caesari domino nostro G...
# 1  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 2  Tiberius Claudius Caesar Augustus Germanicus p...
# 3  Pro salute Imperatorum Caesaris Luci Septimi S...
# 4                                 Octavius Salutaris
#
#                                 findspot year_of_find  \
# 0                       Agios Athanasios         None
# 1                           Stringu, bei         None
# 2                                   None         None
# 3  to Elleniko Mauer, sekundär verwendet         None
# 4                      Haus der Athleten         None
#
#                present_location                religion       geography  \
# 0                 Fragma Kalama                    None  data available
# 1                   Tegea, Mus.                    None            None
# 2                          None                    None            None
# 3  to Elleniko Mauer, vermauert  names of pagan deities            None
# 4                          None                    None            None
#
#   social_economic_legal_history        military  not_after language  \
# 0                          None            None      313.0    Latin
# 1                data available            None        NaN    Latin
# 2                          None            None       50.0    Latin
# 3                          None  data available      209.0    Latin
# 4                          None            None       96.0    Latin
#
#    not_before         coordinates  \
# 0       309.0  [20.7668, 39.4512]
# 1       276.0  [22.4171, 37.4319]
# 2        49.0  [22.4171, 37.4319]
# 3       198.0  [24.8323, 37.8188]
# 4        81.0  [21.6271, 37.6479]
#
#                         clean_text_interpretive_word urban_context  \
# 0  Fortissimo et piissimo Caesari domino nostro G...          rest
# 1  Imperatori Caesari Marco Annio Floriano Pio Fe...           big
# 2  Tiberius Claudius Caesar Augustus Germanicus p...           big
# 3  Pro salute Imperatorum Caesaris Luci Septimi S...          rest
# 4                                 Octavius Salutaris           big
#
#    within_rome nearest_city city_id_hanson  city_pop_est  \
# 0        False       Dodona             31        1000.0
# 1        False        Tegea             97       46362.0
# 2        False        Tegea             97       46362.0
# 3        False       Ioulis             47        1000.0
# 4        False         Elis             35        1000.0
#
#             city_geometry nearest_city_type  nearest_city_dist  \
# 0  [20.787767, 39.546432]             minor           0.097513
# 1  [22.417226, 37.427653]               big           0.004249
# 2  [22.417226, 37.427653]               big           0.004249
# 3   [24.34625, 37.633122]             minor           0.520308
# 4  [21.435443, 37.827452]             minor           0.262624
#
#    type_of_inscription_auto  type_of_inscription_auto_prob  \
# 0     honorific inscription                            1.0
# 1         mile-/leaguestone                            1.0
# 2  public legal inscription                            1.0
# 3        votive inscription                            1.0
# 4  owner/artist inscription                            1.0
#
#                     geometry
# 0  POINT (20.76680 39.45120)
# 1  POINT (22.41710 37.43190)
# 2  POINT (22.41710 37.43190)
# 3  POINT (24.83230 37.81880)
# 4  POINT (21.62710 37.64790)

# %%
inscr_texts = EDH_sampled["clean_text_interpretive_word"].tolist()

# %% [markdown]
# The language of inscriptions is characterized by a number of standardized phrases, which often determine the type of insription. Treated separately, "Dis" and "Manibus" might be confusing, but treated as a bigram, they bear a crucial information about the type of inscription.

# %%
def get_bigrams_underscore(inscr_text):
    try:
        inscr_bigrams = [" ".join(el) for el in list(bigrams(inscr_text.split()))]
        inscr_bigrams_ = [bigram.replace(" ", "_") for bigram in inscr_bigrams]
    except:
        inscr_bigrams_ = []
    return inscr_bigrams_

# %%
EDH_bigrams_ = [get_bigrams_underscore(inscr_text) for inscr_text in inscr_texts]
EDH_bigrams_[:5]
# Out:
# [['Fortissimo_et',
#   'et_piissimo',
#   'piissimo_Caesari',
#   'Caesari_domino',
#   'domino_nostro',
#   'nostro_Galerio',
#   'Galerio_Valerio',
#   'Valerio_Maximiano',
#   'Maximiano_Pio',
#   'Pio_Felici',
#   'Felici_Invicto',
#   'Invicto_Coranius',
#   'Coranius_Titianus',
#   'Titianus_vir',
#   'vir_perfectissimus',
#   'perfectissimus_praeses',
#   'praeses_provinciae',
#   'provinciae_veteris',
#   'veteris_Epiri',
#   'Epiri_numini',
#   'numini_eorum',
#   'eorum_dicatissimus'],
#  ['Imperatori_Caesari',
#   'Caesari_Marco',
#   'Marco_Annio',
#   'Annio_Floriano',
#   'Floriano_Pio',
#   'Pio_Felici',
#   'Felici_Augusto',
#   'Augusto_patri',
#   'patri_patriae',
#   'patriae_milia',
#   'milia_passuum',
#   'passuum_III',
#   'III_Imperatori',
#   'Imperatori_Caesari',
#   'Caesari_Marco',
#   'Marco_Aurelio',
#   'Aurelio_Probo',
#   'Probo_Pio',
#   'Pio_Felici',
#   'Felici_Augusto',
#   'Augusto_milia',
#   'milia_passuum',
#   'passuum_II'],
#  ['Tiberius_Claudius',
#   'Claudius_Caesar',
#   'Caesar_Augustus',
#   'Augustus_Germanicus',
#   'Germanicus_pontifex',
#   'pontifex_maximus',
#   'maximus_tribunicia',
#   'tribunicia_potestate',
#   'potestate_VIIII',
#   'VIIII_imperator',
#   'imperator_XVI',
#   'XVI_pater',
#   'pater_patriae',
#   'patriae_dicit',
#   'dicit_cum',
#   'cum_et',
#   'et_colonias',
#   'colonias_et',
#   'et_municipia',
#   'municipia_non',
#   'non_solum',
#   'solum_Italiae',
#   'Italiae_verum',
#   'verum_etiam',
#   'etiam_provinciarum',
#   'provinciarum_item',
#   'item_civitatium',
#   'civitatium_cuius',
#   'cuius_que',
#   'que_provinciae',
#   'provinciae_lebare',
#   'lebare_oneribus',
#   'oneribus_vehiculorum',
#   'vehiculorum_praebendorum',
#   'praebendorum_saepe',
#   'saepe_temptavissem',
#   'temptavissem_et',
#   'et_cum',
#   'cum_satis',
#   'satis_multa',
#   'multa_remedia',
#   'remedia_invenisse',
#   'invenisse_mihi',
#   'mihi_viderer',
#   'viderer_potuit',
#   'potuit_tamen',
#   'tamen_nequitiae',
#   'nequitiae_hominum',
#   'hominum_C',
#   'C_RAS',
#   'RAS_RVM',
#   'RVM_aut',
#   'aut_falsa',
#   'falsa_nomina',
#   'nomina_ius',
#   'ius_dedit',
#   'dedit_turo',
#   'turo_ante',
#   'ante_diem'],
#  ['Pro_salute',
#   'salute_Imperatorum',
#   'Imperatorum_Caesaris',
#   'Caesaris_Luci',
#   'Luci_Septimi',
#   'Septimi_Severi',
#   'Severi_et',
#   'et_Marci',
#   'Marci_Aureli',
#   'Aureli_Antonini',
#   'Antonini_Auggustorum',
#   'Auggustorum_et',
#   'et_Publi',
#   'Publi_Septimi',
#   'Septimi_Gaetae',
#   'Gaetae_Caesaris',
#   'Caesaris_Marcus',
#   'Marcus_Aurelius',
#   'Aurelius_Rufinus',
#   'Rufinus_evocatus',
#   'evocatus_Auggustorum',
#   'Auggustorum_nnostrorum',
#   'nnostrorum_Sancto',
#   'Sancto_Deo',
#   'Deo_Invicto',
#   'Invicto_speleum',
#   'speleum_constituit',
#   'constituit_cum',
#   'cum_militibus',
#   'militibus_praetorianis',
#   'praetorianis_Flavio',
#   'Flavio_Clarino',
#   'Clarino_Aelio',
#   'Aelio_Messio',
#   'Messio_Aurelio',
#   'Aurelio_Iuliano'],
#  ['Octavius_Salutaris']]

# %%
# flat list of all bigrams
bigrams_list = [el for sublist in EDH_bigrams_ for el in sublist]
bigrams_list[:10]
# Out:
# ['Fortissimo_et',
#  'et_piissimo',
#  'piissimo_Caesari',
#  'Caesari_domino',
#  'domino_nostro',
#  'nostro_Galerio',
#  'Galerio_Valerio',
#  'Valerio_Maximiano',
#  'Maximiano_Pio',
#  'Pio_Felici']

# %%
# ok, let's list only N of the most common
bigrams_mostfreq = nltk.FreqDist(bigrams_list).most_common()
bigrams_mostfreq = [tup[0] for tup in bigrams_mostfreq]
bigrams_mostfreq[:10]
# Out:
# ['Dis_Manibus',
#  'vixit_annos',
#  'votum_solvit',
#  'solvit_libens',
#  'libens_merito',
#  'Iovi_Optimo',
#  'Optimo_Maximo',
#  'hic_situs',
#  'situs_est',
#  'tribunicia_potestate']

# %%
all_bigrams_freq_dict = dict(nltk.FreqDist(bigrams_list).most_common())

# %%
EDH_sampled["bigrams"] = EDH_bigrams_

# %%
len(EDH_sampled["type_of_inscription_clean"].unique())
# Out:
# 22

# %%
all_bigrams_freq_dict
# Out:
# {'Dis_Manibus': 7844,
#  'vixit_annos': 4084,
#  'votum_solvit': 3335,
#  'solvit_libens': 2982,
#  'libens_merito': 2710,
#  'Iovi_Optimo': 2413,
#  'Optimo_Maximo': 2399,
#  'hic_situs': 2338,
#  'situs_est': 2228,
#  'tribunicia_potestate': 1990,
#  'Manibus_sacrum': 1865,
#  'bene_merenti': 1585,
#  'sibi_et': 1476,
#  'Imperatori_Caesari': 1256,
#  'hic_sita': 1216,
#  'sita_est': 1155,
#  'faciendum_curavit': 1118,
#  'pro_salute': 1117,
#  'terra_levis': 1111,
#  'Imperator_Caesar': 1099,
#  'tibi_terra': 1029,
#  'sit_tibi': 999,
#  'vixit_annis': 996,
#  'pro_praetore': 932,
#  'pontifex_maximus': 837,
#  'miles_legionis': 783,
#  'pontifici_maximo': 780,
#  'est_sit': 749,
#  'maximus_tribunicia': 708,
#  'maximo_tribunicia': 706,
#  'ex_voto': 701,
#  'Pio_Felici': 698,
#  'pater_patriae': 698,
#  'patri_patriae': 687,
#  'divi_Nervae': 670,
#  'et_suis': 664,
#  'et_I': 663,
#  'Marcus_Aurelius': 656,
#  'qui_vixit': 634,
#  'piae_fidelis': 611,
#  'Caius_Iulius': 608,
#  'Marco_Aurelio': 600,
#  'libens_laetus': 588,
#  'decreto_decurionum': 585,
#  'divi_Traiani': 559,
#  'et_sibi': 558,
#  'laetus_merito': 548,
#  'legionis_II': 544,
#  'fecit_sibi': 530,
#  'vivus_fecit': 522,
#  'Augusti_pro': 521,
#  'Traiani_Parthici': 504,
#  'legionis_I': 500,
#  'quae_vixit': 462,
#  'civium_Romanorum': 459,
#  'Cai_filius': 451,
#  'Imperatoris_Caesaris': 448,
#  'beneficiarius_consularis': 445,
#  'domus_divinae': 429,
#  'pro_se': 424,
#  'milia_passuum': 420,
#  'Luci_filius': 420,
#  'Augusto_pontifici': 410,
#  'Caesari_Marco': 406,
#  'merenti_posuit': 406,
#  'annorum_XXX': 396,
#  'veteranus_legionis': 390,
#  'Antonini_Pii': 390,
#  'honorem_domus': 390,
#  'In_honorem': 387,
#  'se_et': 386,
#  'II_adiutricis': 381,
#  'Caesar_divi': 380,
#  'de_suo': 376,
#  'divi_Hadriani': 374,
#  'cohortis_I': 372,
#  'Maximo_et': 372,
#  'Marci_Aureli': 365,
#  'legato_Augusti': 355,
#  'Augustus_pontifex': 355,
#  'centurio_legionis': 354,
#  'in_suis': 345,
#  'coniugi_bene': 343,
#  'Felici_Augusto': 341,
#  'Publius_Aelius': 335,
#  'faciendum_curaverunt': 322,
#  'Caesar_Marcus': 319,
#  'Aurelio_Antonino': 315,
#  'annorum_L': 311,
#  'votum_solverunt': 305,
#  'fronte_pedes': 303,
#  'Pius_Felix': 302,
#  'in_fronte': 301,
#  'Antonino_Augusto': 300,
#  'posteris_que': 300,
#  'que_eorum': 299,
#  'Marci_filius': 297,
#  'Titus_Flavius': 296,
#  'II_vir': 296,
#  'Luci_filio': 295,
#  'ex_testamento': 293,
#  'filio_divi': 288,
#  'annorum_XX': 288,
#  'annorum_LX': 286,
#  'votum_libens': 280,
#  'suis_hic': 280,
#  'in_agro': 278,
#  'fieri_iussit': 278,
#  'annorum_XXV': 277,
#  'sua_pecunia': 276,
#  'libentes_merito': 275,
#  'Iunoni_Reginae': 274,
#  'II_viro': 269,
#  'heres_faciendum': 262,
#  'Invicto_Augusto': 261,
#  'et_II': 261,
#  'Caesari_divi': 260,
#  'solverunt_libentes': 260,
#  'Romanorum_et': 257,
#  'agro_pedes': 256,
#  'divi_Antonini': 255,
#  'viva_fecit': 255,
#  'divi_Augusti': 252,
#  'Cai_filio': 251,
#  'filio_annorum': 251,
#  'Septimi_Severi': 248,
#  'voto_posuit': 248,
#  'consul_III': 247,
#  'legionis_VII': 246,
#  'et_Genio': 245,
#  'Felici_Invicto': 244,
#  'filius_divi': 244,
#  'legionis_XIIII': 242,
#  'Pii_Felicis': 241,
#  'salute_Imperatoris': 241,
#  'Marcus_Ulpius': 239,
#  'coniugi_et': 237,
#  'testamento_fieri': 236,
#  'Tiberius_Claudius': 234,
#  'sacrum_Caius': 233,
#  'Augusti_et': 228,
#  'et_Iuliae': 228,
#  'Augusto_sacrum': 226,
#  'Luci_Septimi': 225,
#  'salute_sua': 225,
#  'legionis_XIII': 222,
#  'vivi_fecerunt': 222,
#  'XIII_geminae': 221,
#  'Invicto_Mithrae': 221,
#  'Augustus_Germanicus': 219,
#  'XIIII_geminae': 219,
#  'suis_votum': 218,
#  'Caio_Iulio': 217,
#  'Aureli_Antonini': 215,
#  'annos_LX': 214,
#  'Severi_Pii': 214,
#  'honesta_missione': 213,
#  'sacrum_Lucius': 213,
#  'consuli_II': 211,
#  'Aurelius_Antoninus': 211,
#  'consuli_III': 210,
#  'defuncto_annorum': 209,
#  'II_et': 208,
#  'iure_dicundo': 202,
#  'fecit_et': 201,
#  'annos_L': 200,
#  'miles_cohortis': 200,
#  'Silvano_Domestico': 200,
#  'maiestati_que': 199,
#  'rei_publicae': 199,
#  'Augusti_nostri': 199,
#  'filio_et': 199,
#  'numini_maiestati': 197,
#  'annos_XXX': 197,
#  'decurio_coloniae': 197,
#  'cui_praeest': 197,
#  'annorum_XXXV': 196,
#  'Caesaris_Augusti': 195,
#  'Marci_filio': 195,
#  'quorum_nomina': 194,
#  'legionis_XV': 193,
#  'Felix_Augustus': 193,
#  'I_adiutricis': 193,
#  'militavit_annos': 192,
#  'filius_annorum': 192,
#  'nobilissimo_Caesari': 191,
#  'annorum_XL': 191,
#  'Quinti_filius': 189,
#  'nepoti_divi': 189,
#  'legionis_III': 188,
#  'que_eius': 187,
#  'militum_legionis': 187,
#  'Felicis_Augusti': 187,
#  'domini_nostri': 187,
#  'Deo_Invicto': 186,
#  'defunctae_annorum': 186,
#  'legionis_X': 185,
#  'patriae_proconsuli': 185,
#  'hoc_monumentum': 185,
#  'pius_in': 185,
#  'legionis_XI': 184,
#  'merenti_fecit': 184,
#  'filio_Galeria': 184,
#  'annorum_LXX': 184,
#  'Lucius_Septimius': 183,
#  'Pro_salute': 182,
#  'Publi_filius': 182,
#  'XV_Apollinaris': 181,
#  'consul_II': 180,
#  'nomina_subscripta': 179,
#  'subscripta_sunt': 178,
#  'heredem_non': 178,
#  'non_sequetur': 178,
#  'Parthico_maximo': 177,
#  'Antoninus_Augustus': 176,
#  'filia_annorum': 176,
#  'bene_merentibus': 175,
#  'legionis_IIII': 175,
#  'sacrum_Marcus': 174,
#  'annos_XXV': 173,
#  'annos_XX': 173,
#  'Augusti_filio': 172,
#  'praetore_provinciae': 172,
#  'Lucio_Septimio': 172,
#  'pia_in': 172,
#  'legionis_XXII': 171,
#  'Genio_loci': 169,
#  'V_Macedonicae': 168,
#  'annos_XXXV': 165,
#  'locus_datus': 165,
#  'Pertinacis_Augusti': 165,
#  'tribuno_militum': 164,
#  'Caesaris_Marci': 164,
#  'Antonini_Augusti': 164,
#  'legatus_Augusti': 163,
#  'Maximo_Dolicheno': 163,
#  'veteranus_ex': 163,
#  'consularis_votum': 163,
#  'adiutricis_piae': 162,
#  'libertis_libertabus': 162,
#  'Parthici_maximi': 162,
#  'et_conubium': 162,
#  'conubium_cum': 162,
#  'Claudiae_piae': 161,
#  'Tiberio_Claudio': 161,
#  'cum_uxoribus': 161,
#  'Caius_Valerius': 161,
#  'hic_siti': 161,
#  'Augusto_et': 160,
#  'dedit_et': 160,
#  'donum_dedit': 160,
#  'libens_posuit': 160,
#  'militi_legionis': 160,
#  'et_III': 160,
#  'Antonino_Pio': 159,
#  'sua_et': 159,
#  'et_Imperator': 158,
#  'Luci_filia': 158,
#  'Pii_Pertinacis': 158,
#  'tribuniciae_potestatis': 158,
#  'Libero_Patri': 158,
#  'legionis_V': 156,
#  'XI_Claudiae': 156,
#  'filius_Quirina': 156,
#  'Flavio_Valerio': 155,
#  'VII_Claudiae': 155,
#  'Augustae_sacrum': 155,
#  'datus_decreto': 155,
#  'Maximo_Iunoni': 155,
#  'de_sua': 154,
#  'siti_sunt': 154,
#  'Augusto_Germanico': 153,
#  'quas_postea': 153,
#  'cohortis_II': 153,
#  'Septimio_Severo': 153,
#  'qui_militaverunt': 151,
#  'potestate_consuli': 151,
#  'I_Thracum': 151,
#  'uxoribus_quas': 150,
#  'sunt_in': 150,
#  'et_Marco': 149,
#  'ponendum_curavit': 149,
#  'L_hic': 149,
#  'dimissis_honesta': 148,
#  'libens_solvit': 147,
#  'monumentum_heredem': 147,
#  'potestate_II': 146,
#  'et_coniugi': 146,
#  'Antoninus_Pius': 146,
#  'III_et': 146,
#  'patris_patriae': 146,
#  'pecunia_publica': 146,
#  'Septimius_Severus': 146,
#  'Parthicus_maximus': 146,
#  'postea_duxissent': 145,
#  'I_Italicae': 145,
#  'Arabici_Adiabenici': 145,
#  'Caesar_Lucius': 145,
#  'XXII_Primigeniae': 144,
#  'quas_tunc': 144,
#  'tunc_habuissent': 144,
#  'Caesari_Lucio': 144,
#  'deabus_que': 144,
#  'Titi_filius': 143,
#  'duxissent_dumtaxat': 143,
#  'filius_et': 143,
#  'est_civitas': 143,
#  'I_Minerviae': 142,
#  'libertabus_que': 142,
#  'habuissent_cum': 142,
#  'cum_est': 142,
#  'patriae_et': 142,
#  'Augusto_Pio': 142,
#  'militaverunt_in': 142,
#  'pia_fidelis': 142,
#  'Titus_Aelius': 141,
#  'data_aut': 141,
#  'domino_nostro': 139,
#  'alae_I': 139,
#  'consularis_legionis': 139,
#  'ante_diem': 138,
#  'filius_Galeria': 138,
#  'divi_Marci': 138,
#  'plus_minus': 137,
#  'maximus_pontifex': 137,
#  'dono_dedit': 137,
#  'fecerunt_sibi': 137,
#  'III_pater': 136,
#  'si_quis': 136,
#  'X_geminae': 135,
#  'sacrum_Quintus': 135,
#  'LX_hic': 135,
#  'et_Iunoni': 135,
#  'Luci_filiae': 134,
#  'Imperatore_Caesare': 133,
#  'annorum_X': 133,
#  'emeritis_dimissis': 133,
#  'cohors_I': 133,
#  'potestate_IIII': 132,
#  'et_Caio': 132,
#  'a_solo': 132,
#  'Marci_Antonini': 132,
#  'Adiabenici_Parthici': 132,
#  'Manibus_Marcus': 131,
#  'pronepoti_divi': 131,
#  'eius_et': 131,
#  'et_Marcus': 131,
#  'XXV_hic': 131,
#  'filiae_annorum': 131,
#  'Germanicus_pontifex': 130,
#  'Marcus_Iulius': 130,
#  'Manibus_Marco': 130,
#  'Severo_Pio': 130,
#  'Tito_Aelio': 130,
#  'Soli_Invicto': 130,
#  'proconsul_et': 129,
#  'missione_quorum': 129,
#  'stipendiis_emeritis': 129,
#  'Lucius_Valerius': 128,
#  'patriae_proconsul': 128,
#  'Maximo_pro': 128,
#  'praefectus_cohortis': 127,
#  'Manibus_Lucio': 126,
#  'et_recognitum': 126,
#  'Cai_filia': 126,
#  'cum_iis': 126,
#  'IIII_Flaviae': 126,
#  'ex_imperio': 125,
#  'Severus_Pius': 125,
#  'descriptum_et': 124,
#  'Manibus_Caio': 124,
#  'Cai_Iuli': 124,
#  'recognitum_ex': 124,
#  'Augusti_Arabici': 124,
#  'Manibus_Caius': 123,
#  'ob_honorem': 123,
#  'Iuliae_Augustae': 123,
#  'Germanici_Sarmatici': 123,
#  'Pertinax_Augustus': 123,
#  'et_suorum': 123,
#  'et_sunt': 123,
#  'pecunia_sua': 122,
#  'sub_cura': 122,
#  'consul_IIII': 122,
#  'Manibus_Aurelius': 122,
#  'Caesar_Augustus': 121,
#  'res_publica': 121,
#  'annos_LXX': 121,
#  'XX_hic': 121,
#  'III_patri': 120,
#  'ex_tabula': 120,
#  'cum_suis': 120,
#  'iis_quas': 120,
#  'et_Aurelia': 120,
#  'et_peditibus': 120,
#  'iis_data': 119,
#  'Pertinaci_Augusto': 119,
#  'Auggustorum_pro': 119,
#  'Pius_Pertinax': 119,
#  'equitibus_et': 118,
#  'potestate_III': 117,
#  'Augustus_Pius': 117,
#  'nepos_divi': 117,
#  'quae_fixa': 117,
#  'fixa_est': 117,
#  'Pio_Pertinaci': 117,
#  'merenti_posuerunt': 117,
#  'peditibus_qui': 117,
#  'civitas_iis': 116,
#  'nobilissimus_Caesar': 116,
#  'Legio_XIII': 116,
#  'legato_pro': 115,
#  'Marcus_Valerius': 115,
#  'Tito_Flavio': 115,
#  'Quinti_filio': 115,
#  'est_Romae': 115,
#  'XXX_hic': 115,
#  'Luci_libertus': 114,
#  'et_heres': 114,
#  'sacrum_Iulia': 114,
#  'Titus_Aurelius': 114,
#  'Traianus_Hadrianus': 113,
#  'filio_Quirina': 112,
#  'et_Flavio': 112,
#  'liberis_posteris': 112,
#  'coniugi_pientissimae': 112,
#  'in_alis': 112,
#  'et_cohortibus': 112,
#  'Hadriano_Augusto': 111,
#  'Hadrianus_Augustus': 111,
#  'et_Publius': 111,
#  'quae_appellantur': 111,
#  'XIII_gemina': 111,
#  'annos_LXXX': 110,
#  'Manibus_et': 110,
#  'Publi_filio': 109,
#  'Nerva_Traianus': 109,
#  'sacrum_Publius': 109,
#  'Arabico_Adiabenico': 109,
#  'maximo_pontifici': 109,
#  'filio_pientissimo': 109,
#  'Caesari_Caio': 108,
#  'annos_XL': 108,
#  'Romae_in': 108,
#  'suo_posuit': 108,
#  'annorum_V': 108,
#  'III_Augustae': 107,
#  'Aelio_Hadriano': 107,
#  'Hadriano_Antonino': 107,
#  'et_Lucio': 106,
#  'Traiano_Hadriano': 106,
#  'et_Caius': 106,
#  'II_consul': 106,
#  'Augustus_Arabicus': 106,
#  'annorum_XXXX': 106,
#  'et_Marci': 105,
#  'tribunus_militum': 105,
#  'ex_decreto': 105,
#  'Arabicus_Adiabenicus': 105,
#  'Manibus_Lucius': 105,
#  'hic_sit': 105,
#  'et_Aureliae': 105,
#  'potestate_VIIII': 104,
#  'ipsis_liberis': 104,
#  'clarissimo_viro': 104,
#  'in_pace': 104,
#  'coniugi_carissimae': 104,
#  'et_filio': 104,
#  'legionis_VI': 104,
#  'patriae_consuli': 103,
#  'annos_X': 102,
#  'veterano_legionis': 102,
#  'Marci_filiae': 102,
#  'sunt_ipsis': 102,
#  'et_Imperatori': 102,
#  'Pii_Germanici': 102,
#  'Caesaris_Luci': 101,
#  'annos_LV': 101,
#  'Maximo_sacrum': 101,
#  'et_Iulia': 100,
#  'Marcus_Antonius': 100,
#  'IIIIII_vir': 100,
#  'civitatem_dedit': 100,
#  'Augusto_Arabico': 100,
#  'XXXV_hic': 100,
#  'VIII_Augustae': 100,
#  'Augustalis_coloniae': 100,
#  'quin_que': 99,
#  'Augustus_tribunicia': 99,
#  'et_Aurelius': 99,
#  'titulum_posuit': 99,
#  'Nervae_nepos': 98,
#  'nepos_Traianus': 98,
#  'eorum_civitatem': 98,
#  'sacrum_pro': 98,
#  'pontificis_maximi': 98,
#  'cohortis_III': 98,
#  'IIII_pater': 98,
#  'legionis_XXX': 98,
#  'eques_alae': 98,
#  'Valerio_Maximiano': 97,
#  'potestate_XVI': 97,
#  'Parthici_filius': 97,
#  'et_V': 97,
#  'Gaius_Iulius': 97,
#  'Cai_libertus': 96,
#  'Luci_liberta': 96,
#  'Adiabenicus_Parthicus': 96,
#  'annorum_LXXX': 96,
#  'annorum_XVIII': 96,
#  'Manibus_Aurelio': 96,
#  'Augusti_Germanici': 95,
#  'filius_Voltinia': 95,
#  'Titi_filio': 95,
#  'potestate_consul': 95,
#  'Augusti_ad': 95,
#  'II_consulibus': 95,
#  'decurionum_pecunia': 95,
#  'equo_publico': 95,
#  'Domino_nostro': 95,
#  'annos_LXV': 95,
#  'legionis_VIII': 95,
#  'dis_deabus': 95,
#  'patriae_equitibus': 95,
#  'tribuno_plebis': 94,
#  'Lucius_Iulius': 94,
#  'Pius_Augustus': 94,
#  'legato_Auggustorum': 94,
#  'consuli_proconsuli': 94,
#  'ddominorum_nnostrorum': 94,
#  'consuli_IIII': 93,
#  'decurio_municipii': 93,
#  'votum_posuit': 93,
#  'pedes_XII': 92,
#  'Cai_filiae': 92,
#  'imperio_ipsarum': 92,
#  'Adiabenico_Parthico': 92,
#  'Augusti_Pii': 92,
#  'Iulius_Verus': 92,
#  'vivus_sibi': 92,
#  'que_omnibus': 92,
#  'pro_pietate': 92,
#  'Publio_Aelio': 91,
#  'Primigeniae_piae': 91,
#  'Marco_Iulio': 91,
#  'annos_XXXX': 91,
#  'annorum_XV': 91,
#  'Maximo_Marcus': 91,
#  'I_Flavia': 91,
#  'II_patri': 90,
#  'Marci_filia': 90,
#  'sit_est': 90,
#  'annorum_LV': 90,
#  'vir_perfectissimus': 89,
#  'patriae_consul': 89,
#  'Caesari_Augusto': 89,
#  'dumtaxat_singuli': 89,
#  'posuit_et': 89,
#  'Aelius_Hadrianus': 88,
#  'Hadrianus_Antoninus': 88,
#  'IIII_viro': 88,
#  'aedili_II': 88,
#  'que_et': 88,
#  'Nervae_filius': 88,
#  'Augusti_libertus': 88,
#  'singuli_singulas': 88,
#  'vir_Augustalis': 88,
#  'II_consuli': 88,
#  'II_Augustae': 88,
#  'legati_Augusti': 88,
#  'filius_Nerva': 87,
#  'coniugi_suae': 87,
#  'Maximo_Caius': 87,
#  'legato_legionis': 86,
#  'salute_et': 86,
#  'abnepoti_divi': 86,
#  'filiae_et': 86,
#  'imperator_II': 86,
#  'coniugi_annorum': 86,
#  'obito_annorum': 86,
#  'devotus_numini': 85,
#  'et_Lucius': 85,
#  'Quintus_Iulius': 85,
#  'Valerio_Constantino': 85,
#  'legionis_XX': 85,
#  'caelibes_essent': 85,
#  'Tiberi_Caesaris': 85,
#  'LXX_hic': 85,
#  'Deo_Soli': 85,
#  'Germanici_Caesaris': 85,
#  'heres_posuit': 84,
#  'filio_dulcissimo': 84,
#  'provinciae_Africae': 83,
#  'praefecto_cohortis': 83,
#  'uxori_et': 83,
#  'Germanico_maximo': 83,
#  'essent_cum': 83,
#  'et_castrorum': 83,
#  'annos_LXXV': 83,
#  'ad_que': 82,
#  'in_muro': 82,
#  'ad_Minervam': 82,
#  'Quinti_filia': 82,
#  'militi_cohortis': 82,
#  'merenti_et': 82,
#  'II_pater': 81,
#  'Manibus_Tito': 81,
#  'mulieris_liberta': 81,
#  'que_suis': 81,
#  'Traianus_Augustus': 81,
#  'muro_post': 81,
#  'post_templum': 81,
#  'templum_divi': 81,
#  'Augusto_tribunicia': 81,
#  'LXXX_hic': 81,
#  'filiae_coniugi': 81,
#  'XXX_Ulpiae': 81,
#  'ab_Aquinco': 81,
#  'civitatem_Romanam': 80,
#  'idem_que': 80,
#  'consuli_patri': 80,
#  'et_Publio': 80,
#  'posuit_libens': 80,
#  'Marco_Antonio': 79,
#  'Deo_Mercurio': 79,
#  'heres_ex': 79,
#  'annorum_XXII': 79,
#  'Manibus_Publius': 79,
#  'Aquinco_milia': 79,
#  'II_viri': 78,
#  'Marci_libertus': 78,
#  'Aurelio_Valerio': 78,
#  'annos_V': 78,
#  'potestate_VI': 78,
#  'Nervae_adnepoti': 78,
#  'est_heres': 78,
#  'ne_que': 77,
#  'et_in': 77,
#  'Invictus_Augustus': 77,
#  'legionis_eiusdem': 77,
#  'pedes_XX': 77,
#  'qui_et': 77,
#  'patri_et': 77,
#  'filius_Claudia': 77,
#  'suorum_que': 77,
#  'Tiberi_Claudi': 76,
#  'Manibus_Iuliae': 76,
#  'sibi_viva': 76,
#  'pater_et': 76,
#  'XX_Valeriae': 76,
#  'LV_hic': 76,
#  'XXX_stipendiorum': 76,
#  'filius_vivus': 75,
#  'vir_iure': 75,
#  'et_divi': 75,
#  'potestate_patri': 75,
#  'viro_iure': 75,
#  'I_Hispanorum': 75,
#  'supra_scriptae': 75,
#  'LX_et': 75,
#  'stlitibus_iudicandis': 74,
#  'Germanicus_maximus': 74,
#  'potestate_V': 74,
#  'Manibus_Publio': 74,
#  'maximi_tribunicia': 74,
#  'dedit_dedicavit': 74,
#  'Augustae_matri': 74,
#  'L_et': 74,
#  'ex_beneficiario': 74,
#  'Deo_Marti': 74,
#  'testamento_faciendum': 74,
#  'et_Aurelio': 74,
#  'I_I': 74,
#  'et_Hygiae': 74,
#  'divi_Vespasiani': 73,
#  'Manibus_Titus': 73,
#  'Felix_Invictus': 73,
#  'suo_fecit': 73,
#  'et_libertis': 73,
#  'coniugi_karissimae': 73,
#  'filiae_uxori': 73,
#  'decurioni_coloniae': 73,
#  'proconsuli_et': 73,
#  'hic_est': 73,
#  'Augusti_filius': 73,
#  'et_Flavia': 73,
#  'Domestico_sacrum': 73,
#  'que_posteris': 73,
#  'Severi_et': 72,
#  'menses_V': 72,
#  'patri_bene': 72,
#  'pontifice_maximo': 72,
#  'filio_piissimo': 72,
#  'annorum_XVI': 72,
#  'sibi_fecit': 72,
#  'annorum_III': 72,
#  'II_Italicae': 72,
#  'Parthici_filio': 71,
#  'ob_merita': 71,
#  'tabula_aenea': 71,
#  'Septimius_Geta': 71,
#  'annos_LXXXV': 71,
#  'LXXV_hic': 71,
#  'annorum_LXV': 71,
#  'Iulio_Philippo': 71,
#  'Hadriani_filius': 71,
#  'Galerio_Valerio': 70,
#  'Iulius_Cai': 70,
#  'aut_si': 70,
#  'Iulio_Vero': 70,
#  'Augusto_Parthico': 70,
#  'mater_filio': 70,
#  'Caesar_Caius': 70,
#  'patri_pientissimo': 70,
#  'annorum_XLV': 70,
#  'annorum_XII': 70,
#  'appellantur_I': 70,
#  'annos_XXXXV': 70,
#  'fidelis_et': 70,
#  'curam_agente': 69,
#  'matri_et': 69,
#  'Nervae_pronepos': 69,
#  'centurioni_legionis': 69,
#  'annorum_et': 69,
#  'Apollinaris_annorum': 69,
#  'sibi_vivus': 68,
#  'III_consuli': 68,
#  'Parthici_et': 68,
#  'Severi_Alexandri': 68,
#  'coniugi_incomparabili': 68,
#  'filius_Sergia': 68,
#  'Pius_pontifex': 68,
#  'et_vicenis': 68,
#  'et_Aelia': 68,
#  'pluribusve_stipendiis': 68,
#  'sacris_faciundis': 67,
#  'praefecto_fabrum': 67,
#  'aenea_quae': 67,
#  'suo_et': 67,
#  'filius_Augustus': 67,
#  'filius_Papiria': 67,
#  'menses_VI': 67,
#  'III_consul': 67,
#  'libentes_laeti': 67,
#  'Lucius_Cornelius': 67,
#  'Gallorum_et': 67,
#  'si_qui': 66,
#  'patre_patriae': 66,
#  'coniugi_eius': 66,
#  'LXV_hic': 66,
#  'matri_pientissimae': 66,
#  'qui_eorum': 66,
#  'Valeriae_victricis': 66,
#  'salute_domini': 66,
#  'sunt_civitatem': 66,
#  'Auggustorum_et': 65,
#  'quo_que': 65,
#  'Hadriani_Augusti': 65,
#  'filio_suo': 65,
#  'XXX_et': 65,
#  'consul_pater': 65,
#  'Publi_libertus': 65,
#  'in_honorem': 65,
#  'X_hic': 65,
#  'Ulpiae_victricis': 65,
#  'et_et': 65,
#  'consularis_pro': 65,
#  'et_Aeliae': 65,
#  'Caio_Valerio': 64,
#  'vir_clarissimus': 64,
#  'Germanicus_Dacicus': 64,
#  'annos_XV': 64,
#  'V_et': 64,
#  'est_Caius': 64,
#  'annos_III': 64,
#  'solvit_merito': 64,
#  'VI_victricis': 64,
#  'annorum_II': 64,
#  'annorum_XXVI': 64,
#  'obitae_annorum': 64,
#  'filius_Pollia': 63,
#  'IIIIII_viro': 63,
#  'ex_HS': 63,
#  'pedes_X': 63,
#  'libens_animo': 63,
#  'consul_proconsul': 63,
#  'centurio_cohortis': 63,
#  'Publio_Licinio': 63,
#  'filia_vixit': 63,
#  'beneficiario_consularis': 63,
#  'pientissimo_et': 63,
#  'viva_sibi': 63,
#  'et_pontes': 63,
#  'et_filiae': 63,
#  'pronepos_Titus': 63,
#  'consulibus_cohortis': 63,
#  'Herculi_Augusto': 63,
#  'Parthici_nepos': 63,
#  'praeses_provinciae': 62,
#  'Publius_Septimius': 62,
#  'I_et': 62,
#  'Tiberius_Iulius': 62,
#  'Silvano_sacrum': 62,
#  'et_filiis': 62,
#  'divinae_Iovi': 62,
#  'stipendiorum_X': 62,
#  'Romanam_qui': 62,
#  'eorum_non': 62,
#  'non_haberent': 62,
#  'sua_suorum': 62,
#  'Marco_Ulpio': 61,
#  'qui_caelibes': 61,
#  'VI_vir': 61,
#  'est_testamento': 61,
#  'filiae_dulcissimae': 61,
#  'filiae_pientissimae': 61,
#  'Titi_Aeli': 61,
#  'semper_Augusto': 61,
#  'Severo_Alexandro': 61,
#  'Silvano_Augusto': 61,
#  'voto_suscepto': 61,
#  'at_que': 61,
#  'Lucius_Aemilius': 61,
#  'geminae_votum': 61,
#  'XXXX_hic': 61,
#  'vias_et': 61,
#  'dumtaxat_singulis': 61,
#  'quinis_et': 61,
#  'VIIII_imperator': 60,
#  'poni_iussit': 60,
#  'XII_in': 60,
#  'IIII_vir': 60,
#  'coniux_et': 60,
#  'Constantio_et': 60,
#  'et_Valeria': 60,
#  'Augustae_matris': 60,
#  'LXXXV_hic': 60,
#  'se_vivo': 60,
#  'laeti_merito': 60,
#  'geminae_Martiae': 60,
#  'primus_pilus': 60,
#  'III_Thracum': 60,
#  'maximus_tribuniciae': 59,
#  'annos_XLV': 59,
#  'filio_Papiria': 59,
#  'Maximo_Lucius': 59,
#  'voto_libens': 59,
#  'nostro_Flavio': 58,
#  'proconsuli_provinciae': 58,
#  'procuratoris_Augusti': 58,
#  'Lucio_Aurelio': 58,
#  'pronepos_divi': 58,
#  'Septimio_Getae': 58,
#  'divi_Severi': 58,
#  'Sexti_filius': 58,
#  'potestate_XV': 58,
#  'IIII_patri': 58,
#  'Britannico_maximo': 58,
#  'et_heredes': 58,
#  'Lucius_Aurelius': 58,
#  'annorum_LXXV': 58,
#  'aut_cum': 58,
#  'vicenis_pluribusve': 58,
#  'coloniae_Sarmizegetusae': 58,
#  'Nervae_nepoti': 57,
#  'nepoti_Traiano': 57,
#  'annos_XVIII': 57,
#  'annos_XXVI': 57,
#  'cohortis_IIII': 57,
#  'marito_bene': 57,
#  'principi_iuventutis': 57,
#  'Valerio_Constantio': 57,
#  'IIII_et': 57,
#  'Caesari_Flavio': 57,
#  'Martiae_victricis': 57,
#  'coniugi_pientissimo': 57,
#  'suorum_votum': 57,
#  'annorum_XXIII': 57,
#  'filio_eius': 57,
#  'perpetuae_securitati': 57,
#  'I_Aelia': 57,
#  'et_IIII': 57,
#  'veterano_ex': 57,
#  'II_Flavia': 57,
#  'militavit_annis': 56,
#  'imperatori_II': 56,
#  'viro_Augustali': 56,
#  'annos_XVI': 56,
#  'in_suo': 56,
#  'voto_posuerunt': 56,
#  'maximo_Britannico': 56,
#  'Augusti_legionis': 56,
#  'annos_VII': 56,
#  'vir_egregius': 56,
#  'II_Augusta': 56,
#  'annorum_hic': 56,
#  'Publi_filia': 56,
#  'annorum_IIII': 56,
#  'XL_stipendiorum': 56,
#  'Luci_Pulli': 56,
#  'collegii_fabrum': 56,
#  'Lusitanorum_et': 56,
#  'Aesculapio_et': 55,
#  'nostri_Imperatoris': 55,
#  'quicum_que': 55,
#  'potestate_VIII': 55,
#  'et_Iulius': 55,
#  'Hadriani_filio': 55,
#  'Antonio_Gordiano': 55,
#  'pondo_libras': 55,
#  'merentibus_posuit': 55,
#  'procurator_Augusti': 55,
#  'annos_II': 55,
#  'III_Italicae': 55,
#  'vivi_sibi': 55,
#  'Matronis_Vacallinehis': 55,
#  'consul_V': 54,
#  'viro_perfectissimo': 54,
#  'numini_eius': 54,
#  'in_foro': 54,
#  'devota_numini': 54,
#  'Augustus_et': 54,
#  'laetus_libens': 54,
#  'annorum_VII': 54,
#  'filius_votum': 54,
#  'Imperatore_Antonino': 54,
#  'singulas_ante': 54,
#  'perfectissimus_praeses': 53,
#  'annis_XXX': 53,
#  'X_viro': 53,
#  'est_in': 53,
#  'et_memoriae': 53,
#  'procuratori_Augusti': 53,
#  'annos_XII': 53,
#  'faciundum_curavit': 53,
#  'consul_designatus': 53,
#  'maximo_Germanico': 53,
#  'equiti_Romano': 53,
#  'ceteris_que': 53,
#  'Imperatore_domino': 53,
#  'heredes_faciendum': 53,
#  'Silvano_Silvestri': 53,
#  'I_Alpinorum': 53,
#  'equitum_Romanorum': 52,
#  'viro_stlitibus': 52,
#  'Divi_Iuli': 52,
#  'Publio_Septimio': 52,
#  'XXXXV_hic': 52,
#  'Constantino_Pio': 52,
#  'libertus_et': 52,
#  'marito_optimo': 52,
#  'Messio_Quinto': 52,
#  'Raetorum_et': 52,
#  'Auggustorum_nnostrorum': 51,
#  'et_Flavius': 51,
#  'Publi_filiae': 51,
#  'V_dies': 51,
#  'pedes_XV': 51,
#  'mulieris_libertus': 51,
#  'filii_et': 51,
#  'divi_Commodi': 51,
#  'Verus_Maximinus': 51,
#  'Maximinus_Pius': 51,
#  'est_Titus': 51,
#  'fecerunt_et': 51,
#  'II_proconsul': 51,
#  'imperator_XII': 51,
#  'Titus_Iulius': 51,
#  'suo_faciendum': 51,
#  'Lucio_Licinio': 51,
#  'Manibus_Iulia': 51,
#  'XXXV_stipendiorum': 51,
#  'Maximo_cohors': 51,
#  'Manibus_Aurelia': 51,
#  'legati_legionis': 51,
#  'ex_decurione': 51,
#  'fidelis_votum': 51,
#  'veterana_et': 51,
#  'adiutricis_votum': 51,
#  'coloniae_Aquincensium': 51,
#  'Minerviae_piae': 50,
#  'Iulio_Cai': 50,
#  'Quinti_filiae': 50,
#  'II_proconsuli': 50,
#  'est_et': 50,
#  'Lucio_Valerio': 50,
#  'IIII_consul': 50,
#  'Augustis_sacrum': 50,
#  'aram_posuit': 50,
#  'Aureli_Severi': 50,
#  'XL_hic': 50,
#  'salute_ddominorum': 50,
#  'sacrum_Titus': 50,
#  'Maximo_Titus': 50,
#  'mater_et': 50,
#  'VIII_Kalendas': 50,
#  'divinae_deo': 50,
#  'et_perpetuae': 50,
#  'stipendiorum_XX': 50,
#  'merito_posuit': 50,
#  ...}

# %%
N = 10
weighted_bigrams_all = []
for cat in EDH_sampled["type_of_inscription_clean"].unique():
    EDH_cat = EDH_sampled[EDH_sampled["type_of_inscription_clean"]==cat]
    bigrams_list = [el for sublist in EDH_cat["bigrams"].tolist() for el in sublist]
    cat_bigrams_freq_dict = dict(nltk.FreqDist(bigrams_list).most_common())
    weighted_bigrams = []
    for word in cat_bigrams_freq_dict.keys():
        if cat_bigrams_freq_dict[word] >= 5: # it it appears at least twice
            weighted_bigrams.append((word, cat_bigrams_freq_dict[word] / all_bigrams_freq_dict[word]))
    # choose only N of the most characteristic bigrams for given category
    weighted_bigrams = sorted(weighted_bigrams, key=lambda tup: tup[1], reverse=True)[:N]
    weighted_bigrams = [tup[0] for tup in weighted_bigrams]
    weighted_bigrams_all.extend(weighted_bigrams)

# %%
len(weighted_bigrams_all)
# Out:
# 172

# %%
def combine_status_list_and_bigrams(el_status, el_bigrams, el_material):
    # preprocess status:
    try: el_status = eval(el_status)
    except: pass
    if isinstance(el_status, list):
        new_el_status = el_status
    elif isinstance(el_status, str):
        new_el_status = [el_status]
    else: 
        new_el_status = []
    new_el_status = [el.replace(" ", "_") for el in new_el_status]
    # preprocess material:
    if el_material is None:
        el_material = []    
    else:
        el_material = el_material.partition(": ")[0] # 
        el_material = el_material.split(", ")
        el_material = [el.replace(" ", "_").replace("?", "") for el in el_material]
    # combine status, bigrams and material
    new_el = new_el_status + el_bigrams + el_material
    new_el = " ".join(new_el)
    return new_el, new_el_status, el_material

# %%
status_bigrams_list = []
status_list = []
material_list = []
for el_status, el_bigrams, el_material in zip(EDH_sampled["status_list"].tolist(), EDH_sampled["bigrams"].tolist(), EDH_sampled["Material"].tolist()):
    new_el, new_status, el_material = combine_status_list_and_bigrams(el_status, el_bigrams, el_material)
    status_bigrams_list.append(new_el)
    status_list.append(new_status)
    material_list.extend(el_material)

# %%
materials_freqdist = nltk.FreqDist(material_list).most_common()
len(materials_freqdist)
# Out:
# 18

# %%
materials_freqdist
# Out:
# [('lapis', 22042),
#  ('opus_figlinae', 2247),
#  ('aes', 796),
#  ('plumbum', 528),
#  ('lignum', 289),
#  ('argentum', 289),
#  ('aurum', 82),
#  ('vitrum', 63),
#  ('ferrum', 60),
#  ('tectorium', 58),
#  ('musivum', 27),
#  ('steatitis', 11),
#  ('os', 10),
#  ('cyprum', 6),
#  ('gemma', 4),
#  ('rupes', 4),
#  ('corium', 1),
#  ('sucineus', 1)]

# %%
N = 20
materials_N = [tup[0] for tup in materials_freqdist[:N]]
len(materials_N)
# Out:
# 18

# %%
status_bigrams_list[:10]
# Out:
# ['Augusti/Augustae litterae_erasae ordo_equester tituli_honorarii tria_nomina Fortissimo_et et_piissimo piissimo_Caesari Caesari_domino domino_nostro nostro_Galerio Galerio_Valerio Valerio_Maximiano Maximiano_Pio Pio_Felici Felici_Invicto Invicto_Coranius Coranius_Titianus Titianus_vir vir_perfectissimus perfectissimus_praeses praeses_provinciae provinciae_veteris veteris_Epiri Epiri_numini numini_eorum eorum_dicatissimus',
#  'Augusti/Augustae miliaria viri Imperatori_Caesari Caesari_Marco Marco_Annio Annio_Floriano Floriano_Pio Pio_Felici Felici_Augusto Augusto_patri patri_patriae patriae_milia milia_passuum passuum_III III_Imperatori Imperatori_Caesari Caesari_Marco Marco_Aurelio Aurelio_Probo Probo_Pio Pio_Felici Felici_Augusto Augusto_milia milia_passuum passuum_II lapis',
#  'Augusti/Augustae leges viri Tiberius_Claudius Claudius_Caesar Caesar_Augustus Augustus_Germanicus Germanicus_pontifex pontifex_maximus maximus_tribunicia tribunicia_potestate potestate_VIIII VIIII_imperator imperator_XVI XVI_pater pater_patriae patriae_dicit dicit_cum cum_et et_colonias colonias_et et_municipia municipia_non non_solum solum_Italiae Italiae_verum verum_etiam etiam_provinciarum provinciarum_item item_civitatium civitatium_cuius cuius_que que_provinciae provinciae_lebare lebare_oneribus oneribus_vehiculorum vehiculorum_praebendorum praebendorum_saepe saepe_temptavissem temptavissem_et et_cum cum_satis satis_multa multa_remedia remedia_invenisse invenisse_mihi mihi_viderer viderer_potuit potuit_tamen tamen_nequitiae nequitiae_hominum hominum_C C_RAS RAS_RVM RVM_aut aut_falsa falsa_nomina nomina_ius ius_dedit dedit_turo turo_ante ante_diem',
#  'litterae_erasae tituli_sacri Pro_salute salute_Imperatorum Imperatorum_Caesaris Caesaris_Luci Luci_Septimi Septimi_Severi Severi_et et_Marci Marci_Aureli Aureli_Antonini Antonini_Auggustorum Auggustorum_et et_Publi Publi_Septimi Septimi_Gaetae Gaetae_Caesaris Caesaris_Marcus Marcus_Aurelius Aurelius_Rufinus Rufinus_evocatus evocatus_Auggustorum Auggustorum_nnostrorum nnostrorum_Sancto Sancto_Deo Deo_Invicto Invicto_speleum speleum_constituit constituit_cum cum_militibus militibus_praetorianis praetorianis_Flavio Flavio_Clarino Clarino_Aelio Aelio_Messio Messio_Aurelio Aurelio_Iuliano',
#  'Octavius_Salutaris',
#  'tionee_praecepimus praecepimus_maiori maiori_exuberante exuberante_me me_aca aca_haberet haberet_etiam etiam_con con_nostrae nostrae_favor favor_AECT',
#  'Aulus_Didius Didius_Gallus Gallus_legatus legatus_Tiberi Tiberi_Claudi Claudi_Caesaris Caesaris_Augusti Augusti_Germanici Germanici_triumphalibus triumphalibus_ornamentis ornamentis_XV XV_vir vir_sacris sacris_faciundis faciundis_proconsul proconsul_Asiae Asiae_et et_Siciliae Siciliae_legatus legatus_Asiae Asiae_praefectus praefectus_equitatus equitatus_quaestor quaestor_imperatoris',
#  'Marcus_Agrippa',
#  'Augusti/Augustae tituli_fabricationis viri Neronis_Augusti plumbum',
#  'SPO_COS COS_O O_NIC NIC_CA CA_OR OR_RC RC_TV TV_GI GI_S S_LI LI_POT POT_O O_G G_CD CD_MM MM_SC SC_T T_S']

# %%
el_status = EDH_sampled["status_list"].tolist()[0]

# %%
status_bigrams_list[0]
# Out:
# 'Augusti/Augustae litterae_erasae ordo_equester tituli_honorarii tria_nomina Fortissimo_et et_piissimo piissimo_Caesari Caesari_domino domino_nostro nostro_Galerio Galerio_Valerio Valerio_Maximiano Maximiano_Pio Pio_Felici Felici_Invicto Invicto_Coranius Coranius_Titianus Titianus_vir vir_perfectissimus perfectissimus_praeses praeses_provinciae provinciae_veteris veteris_Epiri Epiri_numini numini_eorum eorum_dicatissimus'

# %%
status_list_flat = [el for sublist in status_list for el in sublist]
status_N = [tup[0] for tup in nltk.FreqDist(status_list_flat).most_common(100)] ### we had 228 in total
status_N[:10]
# Out:
# ['viri',
#  'tituli_sepulcrales',
#  'tria_nomina',
#  'tituli_sacri',
#  'mulieres',
#  'milites',
#  'nomen_singulare',
#  'Augusti/Augustae',
#  'tituli_operum',
#  'tituli_fabricationis']

# %%
len(status_N)
# Out:
# 37

# %% [markdown]
# # Experiments with one list of the most frequent bigrams

# %%
vocab = status_N + bigrams_mostfreq[:100] + materials_N

# %%
subset_size = 3000 # len(y)
vectorizer = TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=vocab)
X = vectorizer.fit_transform(status_bigrams_list[:subset_size])
X.todense().shape
X_train, X_test, y_train, y_test = train_test_split(X[:subset_size], y[:subset_size], test_size=0.1, random_state=1)

# %%
def train_svm(X, y):
    """
    Create and train the Support Vector Machine.
    """
    svm = SVC(C=1000000.0, gamma='auto', kernel='rbf', probability=True)
    svm.fit(X, y)
    return svm

# %%
# %%time
svm = train_svm(X_train, y_train)
# Out:
# CPU times: user 2.46 s, sys: 15 ms, total: 2.48 s
# Wall time: 2.48 s

# %%
print(svm.score(X_test, y_test))
# Out:
# 0.8333333333333334

# %%
# only where the predictor is present
predictors_present = [np.any(el) for el in X_test.todense()]
# check the performance on datapoints for which we have something in the "status_list"
svm.score(X_test.todense()[predictors_present], np.array(y_test)[predictors_present])
# Out:
# 0.8617021276595744

# %%
svm.classes_
# Out:
# array(['acclamation', 'assignation inscription', 'boundary inscription',
#        'building/dedicatory inscription', 'defixio', 'elogium', 'epitaph',
#        'honorific inscription', 'identification inscription', 'label',
#        'letter', 'list', 'mile-/leaguestone', 'military diploma',
#        'owner/artist inscription', 'prayer', 'private legal inscription',
#        'public legal inscription', 'seat inscription',
#        'votive inscription'], dtype='<U31')

# %%
test_pred_probs = [(svm.classes_[np.argmax(pred)], pred[np.argmax(pred)], real) for pred, real in zip(svm.predict_proba(X_test), y_test)]
test_pred_probs[:20]
# Out:
# [('epitaph', 0.5701242436459757, 'epitaph'),
#  ('epitaph', 0.9621257717863589, 'epitaph'),
#  ('building/dedicatory inscription', 0.3946471383724565, 'epitaph'),
#  ('owner/artist inscription',
#   0.6050564118603547,
#   'identification inscription'),
#  ('votive inscription', 0.9557391731241968, 'votive inscription'),
#  ('epitaph', 0.9432540245204908, 'epitaph'),
#  ('defixio', 0.4921905918450132, 'defixio'),
#  ('votive inscription', 0.9571153789522941, 'votive inscription'),
#  ('epitaph', 0.9187064590820762, 'epitaph'),
#  ('owner/artist inscription', 0.6617075497938236, 'owner/artist inscription'),
#  ('owner/artist inscription', 0.6765519220011015, 'owner/artist inscription'),
#  ('votive inscription', 0.6218476701820005, 'votive inscription'),
#  ('epitaph', 0.5051037826496995, 'votive inscription'),
#  ('epitaph', 0.9231800137716382, 'epitaph'),
#  ('owner/artist inscription', 0.6717331047636865, 'owner/artist inscription'),
#  ('mile-/leaguestone', 0.8268432464997768, 'mile-/leaguestone'),
#  ('epitaph', 0.9391083670405049, 'epitaph'),
#  ('epitaph', 0.9119474868863098, 'epitaph'),
#  ('votive inscription', 0.9592901355434619, 'votive inscription'),
#  ('votive inscription', 0.5780957298367141, 'honorific inscription')]

# %%
for threshold in [thres / 100 for thres in range(30, 100, 5)]:
    above_threshold = [tup for tup in test_pred_probs if tup[1] >= threshold]
    correct_count = len([tup for tup in above_threshold if tup[0] == tup[2]]) # correct total
    correct_proportion = correct_count / len(above_threshold)# correct ratio 
    proportion = len(above_threshold) / len(test_pred_probs)
    print("prob. threshold: {0}, proportion of inscr.: {1}, correctly classified: {2}".format(threshold, proportion, correct_proportion))
# Out:
# prob. threshold: 0.3, proportion of inscr.: 0.99, correctly classified: 0.8484848484848485
# prob. threshold: 0.35, proportion of inscr.: 0.96, correctly classified: 0.8506944444444444
# prob. threshold: 0.4, proportion of inscr.: 0.92, correctly classified: 0.8731884057971014
# prob. threshold: 0.45, proportion of inscr.: 0.9066666666666666, correctly classified: 0.8786764705882353
# prob. threshold: 0.5, proportion of inscr.: 0.8966666666666666, correctly classified: 0.8810408921933085
# prob. threshold: 0.55, proportion of inscr.: 0.8566666666666667, correctly classified: 0.8988326848249028
# prob. threshold: 0.6, proportion of inscr.: 0.76, correctly classified: 0.9385964912280702
# prob. threshold: 0.65, proportion of inscr.: 0.73, correctly classified: 0.9497716894977168
# prob. threshold: 0.7, proportion of inscr.: 0.69, correctly classified: 0.9516908212560387
# prob. threshold: 0.75, proportion of inscr.: 0.6633333333333333, correctly classified: 0.9547738693467337
# prob. threshold: 0.8, proportion of inscr.: 0.5966666666666667, correctly classified: 0.9832402234636871
# prob. threshold: 0.85, proportion of inscr.: 0.5533333333333333, correctly classified: 0.9879518072289156
# prob. threshold: 0.9, proportion of inscr.: 0.4533333333333333, correctly classified: 0.9926470588235294
# prob. threshold: 0.95, proportion of inscr.: 0.2733333333333333, correctly classified: 0.9878048780487805

# %% [markdown]
# # Testing different models

# %%
from sklearn import datasets
from sklearn import metrics
from sklearn.model_selection import KFold, cross_val_score
from sklearn.pipeline import make_pipeline 
from sklearn.pipeline import Pipeline 


from sklearn.linear_model import LogisticRegression 
from sklearn.preprocessing import StandardScaler

# %%
raw_features = status_N + bigrams_mostfreq[:100] + materials_N

# %%
vectorizer = TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=raw_features, lowercase=False)
X = vectorizer.fit_transform(status_bigrams_list)
X.todense().shape
# Out:
# (46171, 155)

# %% [markdown]
# ### Dummy

# %%
# build a dummy classifier
dummy = DummyClassifier(strategy='stratified', random_state=1)
# build a pipeline with it
pipeline = Pipeline(steps=[("vectorizer", vectorizer), ("classifier", dummy)]) 

#  pipeline parameters for testing
N = 5000 # number of observations
# Create k-Fold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=1)

cv_results = cross_val_score(
    pipeline, # Pipeline
    status_bigrams_list[:N], # Feature matrix
    y[:N], # Target vector 
    cv=kf, # Cross-validation technique 
    scoring="f1_weighted", # Loss function
    n_jobs=-1) # Use all CPU scores
print(cv_results)
print(cv_results.mean())
# Out:
# [0.30568086 0.31642284 0.28346112 0.30191908 0.29962008]
# 0.30142079524410104

# %% [markdown]
# For model evaluation, we use `f1_weighted` score. In the multi-class and multi-label case, this is the average of the F1 score of each class with weighting depending on the average parameter.

# %% [markdown]
# ### SVC

# %%
raw_features = list(set(status_N + materials_N + bigrams_mostfreq[:2000] + weighted_bigrams_all))

pipeline = Pipeline(steps=[
    ("vectorizer", TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=raw_features, lowercase=False)),
    ("classifier", SVC(C=1000000.0, gamma='auto', kernel='rbf', probability=True))
]) 

#  pipeline parameters for testing
N = 5000 # number of observations
# Create k-Fold cross-validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)

# Conduct k-fold cross-validation 
cv_results = cross_val_score(
    pipeline, # Pipeline
    status_bigrams_list[:N], # Feature matrix
    y[:N], # Target vector 
    cv=kf, # Cross-validation technique 
    scoring="f1_weighted", # Loss function
    n_jobs=-1) # Use all CPU scores
print(cv_results)
print(cv_results.mean())
# Out:
# [0.8441247  0.81207956 0.82703795 0.79978009 0.78690697]
# 0.8139858510323448

# %% [markdown]
# ### Decision Tree

# %%
raw_features = list(set(status_N + materials_N + bigrams_mostfreq[:2000] + weighted_bigrams_all))
#raw_features = status_N + materials_N + bigrams_mostfreq[:1000]

pipeline = Pipeline(steps=[
    ("vectorizer", TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=raw_features, lowercase=False)),
    ("classifier", DecisionTreeClassifier(random_state=1, max_depth=None))
]) 

#  pipeline parameters for testing
N = 5000 # number of observations
# Create k-Fold cross-validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)

# Conduct k-fold cross-validation 
cv_results = cross_val_score(
    pipeline, # Pipeline
    status_bigrams_list[:N], # Feature matrix
    y[:N], # Target vector 
    cv=kf, # Cross-validation technique 
    scoring="f1_weighted", # Loss function
    n_jobs=-1) # Use all CPU scores
print(cv_results)
print(cv_results.mean())
# Out:
# [0.81414832 0.78747084 0.80272851 0.79390465 0.78977883]
# 0.7976062287866688

# %% [markdown]
# ### Random forest classifier
#
# Breiman, “Random Forests”, Machine Learning, 45(1), 5-32, 2001.
#
# G. Louppe, “Understanding Random Forests: From Theory to Practice”, PhD Thesis, U. of Liege, 2014.

# %%
raw_features = list(set(status_N + materials_N + bigrams_mostfreq[:5000])) # + weighted_bigrams_all))
#raw_features = list(set(status_N + materials_N + bigrams_mostfreq[:1000] + weighted_bigrams_all))
#raw_features = status_N + materials_N + bigrams_mostfreq[:1000]

pipeline = Pipeline(steps=[
    ("vectorizer", TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=raw_features, lowercase=False)),
    ("classifier", RandomForestClassifier(random_state=1, n_jobs=-1))
]) 

#  pipeline parameters for testing
N = 5000 # number of observations
# Create k-Fold cross-validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=None)

# Conduct k-fold cross-validation 
cv_results = cross_val_score(
    pipeline, # Pipeline
    status_bigrams_list[:N], # Feature matrix
    y[:N], # Target vector 
    cv=kf, # Cross-validation technique 
    scoring="f1_weighted", # Loss function
    n_jobs=-1) # Use all CPU scores
print(cv_results)
print(cv_results.mean())
# Out:
# [0.8249471  0.82458837 0.83614358 0.82957414 0.82168963]
# 0.8273885625338251

# %% [markdown]
# ### Extremely randomized trees
# P. Geurts, D. Ernst., and L. Wehenkel, “Extremely randomized trees”, Machine Learning, 63(1), 3-42, 2006.

# %%
#raw_features = status_N + materials_N + bigrams_mostfreq[:1000]
raw_features = list(set(status_N + materials_N + bigrams_mostfreq[:10000])) # + weighted_bigrams_all))

pipeline = Pipeline(steps=[
    ("vectorizer", TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=raw_features, lowercase=False)),
    ("classifier", ExtraTreesClassifier(random_state=1, n_jobs=-1))
]) 

#  pipeline parameters for testing
N = 5000 # number of observations
# Create k-Fold cross-validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=None)

# Conduct k-fold cross-validation 
cv_results = cross_val_score(
    pipeline, # Pipeline
    status_bigrams_list[:N], # Feature matrix
    y[:N], # Target vector 
    cv=kf, # Cross-validation technique 
    scoring="f1_weighted", # Loss function
    n_jobs=-1) # Use all CPU scores
print(cv_results)
print(cv_results.mean())
# Out:
# [0.82957365 0.82986656 0.82312102 0.83080767 0.83962222]
# 0.8305982227473967

# %% [markdown]
# ### K-Nearest Neighbor Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
#raw_features = status_N + materials_N + bigrams_mostfreq[:1000]
raw_features = list(set(status_N + materials_N + bigrams_mostfreq[:10000])) # + weighted_bigrams_all))

pipeline = Pipeline(steps=[
    ("vectorizer", TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=raw_features, lowercase=False)),
    ("classifier", KNeighborsClassifier(n_neighbors=3, weights="distance", n_jobs=-1))
]) 

#  pipeline parameters for testing
N = 5000 # number of observations
# Create k-Fold cross-validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=None)

# Conduct k-fold cross-validation 
cv_results = cross_val_score(
    pipeline, # Pipeline
    status_bigrams_list[:N], # Feature matrix
    y[:N], # Target vector 
    cv=kf, # Cross-validation technique 
    scoring="f1_weighted", # Loss function
    n_jobs=-1) # Use all CPU scores
print(cv_results)
print(cv_results.mean())
# Out:
# [0.66595748 0.68311257 0.67430162 0.7029221  0.70797774]
# 0.686854303182178

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
#raw_features = status_N + materials_N + bigrams_mostfreq[:1000]
raw_features = list(set(status_N + materials_N + bigrams_mostfreq[:10000])) # + weighted_bigrams_all))

pipeline = Pipeline(steps=[
    ("vectorizer", TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=raw_features, lowercase=False)),
    ("classifier", LogisticRegression(penalty="l2", C=1000, n_jobs=-1))
]) 

#  pipeline parameters for testing
N = 5000 # number of observations
# Create k-Fold cross-validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=None)

# Conduct k-fold cross-validation 
cv_results = cross_val_score(
    pipeline, # Pipeline
    status_bigrams_list[:N], # Feature matrix
    y[:N], # Target vector 
    cv=kf, # Cross-validation technique 
    scoring="f1_weighted", # Loss function
    n_jobs=-1) # Use all CPU scores
print(cv_results)
print(cv_results.mean())
# Out:
# [0.83827197 0.8500859  0.82813589 0.83752569 0.8182156 ]
# 0.8344470094033852

# %% [markdown]
# ### Multinomial Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
#raw_features = status_N + materials_N + bigrams_mostfreq[:1000]
raw_features = list(set(status_N + materials_N + bigrams_mostfreq[:10000])) # + weighted_bigrams_all))

pipeline = Pipeline(steps=[
    ("vectorizer", TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=raw_features, lowercase=False)),
    ("classifier", MultinomialNB())
]) 

#  pipeline parameters for testing
N = 5000 # number of observations
# Create k-Fold cross-validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=None)

# Conduct k-fold cross-validation 
cv_results = cross_val_score(
    pipeline, # Pipeline
    status_bigrams_list[:N], # Feature matrix
    y[:N], # Target vector 
    cv=kf, # Cross-validation technique 
    scoring="f1_weighted", # Loss function
    n_jobs=-1) # Use all CPU scores
print(cv_results)
print(cv_results.mean())
# Out:
# [0.76537122 0.74506975 0.74200149 0.75235346 0.75308754]
# 0.7515766918484228

# %% [markdown]
# ## Model selection

# %%
vocabs = [
    status_N,
    status_N + materials_N,
    list(set(status_N + materials_N + bigrams_mostfreq[:100])),
    list(set(status_N + materials_N + bigrams_mostfreq[:1000])),
    list(set(status_N + materials_N + bigrams_mostfreq[:10000]))]

# %%
LR = LogisticRegression(penalty="l2", n_jobs=-1)
SVM = SVC(gamma='auto', kernel='rbf', probability=True)
MNB = MultinomialNB()
RF = RandomForestClassifier(n_jobs=-1)
ET = ExtraTreesClassifier(n_jobs=-1)

# %%
pipeline = Pipeline(steps=[
    ("vectorizer", TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=vocabs[4], lowercase=False)),
    ("classifier", LR)
]) 

# Create space of candidate values 
search_space = [
    {"classifier" : [LR],
    "classifier__C" : [1, 1000, 10000]},
    {"classifier" : [SVM],
    "classifier__C" : [1, 1000, 10000]},
    {"classifier" : [MNB]},
    {"classifier" : [RF],
     "classifier__n_estimators" : [10, 100, 1000]},
    {"classifier" : [ET],
    "classifier__n_estimators" : [10, 100, 1000]}, 
     ]

# Create grid search 
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)
clf = GridSearchCV(pipeline,
                   search_space,
                   cv=kf, 
                   verbose=0, 
                   scoring="f1_weighted",
                   n_jobs=-1)

# Fit grid search 
N = 5000
best_model = clf.fit(
    status_bigrams_list[:N], # Feature matrix
    y[:N])

# %%
classifiers_short = ["LR"]*3 + ["SVM"] * 3 + ["MNB"] + ["RF"] * 3 + ["ET"] * 3

# %%
clf_results = pd.DataFrame(clf.cv_results_["params"])
clf_results["avg. score"] = clf.cv_results_["mean_test_score"]
clf_results["classifier"] = classifiers_short
clf_results
# Out:
#    classifier  classifier__C  classifier__n_estimators  avg. score
# 0          LR            1.0                       NaN    0.808297
# 1          LR         1000.0                       NaN    0.831937
# 2          LR        10000.0                       NaN    0.830611
# 3         SVM            1.0                       NaN    0.310482
# 4         SVM         1000.0                       NaN    0.760049
# 5         SVM        10000.0                       NaN    0.828478
# 6         MNB            NaN                       NaN    0.750174
# 7          RF            NaN                      10.0    0.815809
# 8          RF            NaN                     100.0    0.825325
# 9          RF            NaN                    1000.0    0.826737
# 10         ET            NaN                      10.0    0.822891
# 11         ET            NaN                     100.0    0.831064
# 12         ET            NaN                    1000.0    0.830801

# %%
print(clf_results.to_latex(index=False, na_rep=""))
# Out:
# \begin{tabular}{lrrr}
# \toprule
# classifier &  classifier\_\_C &  classifier\_\_n\_estimators &  avg. score \\
# \midrule
#         LR &            1.0 &                           &    0.808297 \\
#         LR &         1000.0 &                           &    0.831937 \\
#         LR &        10000.0 &                           &    0.830611 \\
#        SVM &            1.0 &                           &    0.310482 \\
#        SVM &         1000.0 &                           &    0.760049 \\
#        SVM &        10000.0 &                           &    0.828478 \\
#        MNB &                &                           &    0.750174 \\
#         RF &                &                      10.0 &    0.815809 \\
#         RF &                &                     100.0 &    0.825325 \\
#         RF &                &                    1000.0 &    0.826737 \\
#         ET &                &                      10.0 &    0.822891 \\
#         ET &                &                     100.0 &    0.831064 \\
#         ET &                &                    1000.0 &    0.830801 \\
# \bottomrule
# \end{tabular}

# %%
best_model.best_estimator_.get_params()["classifier"]
# Out:
# LogisticRegression(C=10000, n_jobs=-1)

# %%
vocabs_tups = [
    ("status", status_N),
    ("status+material", status_N + materials_N),
    ("status+material+100bigrams", list(set(status_N + materials_N + bigrams_mostfreq[:100]))),
    ("status+material+100Obigrams", list(set(status_N + materials_N + bigrams_mostfreq[:1000]))),
    ("status+material+10000bigrams", list(set(status_N + materials_N + bigrams_mostfreq[:10000])))
]

def make_cv(pipeline, N=5000, splits=5):
    N = N # number of observations
    # Create k-Fold cross-validation
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)
    # Conduct k-fold cross-validation 
    cv_results = cross_val_score(
        pipeline, # Pipeline
        status_bigrams_list[:N], # Feature matrix
        y[:N], # Target vector 
        cv=kf, # Cross-validation technique 
        scoring="f1_weighted", # Loss function
        n_jobs=-1) # Use all CPU scores
    return cv_results


features_tests = []
for vocab_tup in vocabs_tups:
    ET_pipeline = Pipeline(steps=[
        ("vectorizer", TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=vocab_tup[1], lowercase=False)),
        ("classifier", LR)
    ]) 
    ET_cv_results = make_cv(ET_pipeline)
    features_test = ({"features" : vocab_tup[0], "avg. score" : ET_cv_results.mean()})
    print(features_test)
    features_tests.append(features_test)
# Out:
# {'features': 'status_list', 'avg. score': 0.7244000248255664}
# {'features': 'status+material', 'avg. score': 0.7341987251815294}
# {'features': 'status+material+100bigrams', 'avg. score': 0.7875156417891627}
# {'features': 'status+material+100Obigrams', 'avg. score': 0.8128055118209364}
# {'features': 'status+material+10000bigrams', 'avg. score': 0.8319369175400082}

# %%
# LR fully dataset
pipeline = Pipeline(steps=[
        ("vectorizer", TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=vocabs_tups[4][1], lowercase=False)),
        ("classifier", LogisticRegression(penalty="l2", n_jobs=-1, C=10000))]) 
LR_cv_results = make_cv(pipeline, N=len(y), splits=10)
features_test = ({"N" : len(y), "avg. $F_1$" : LR_cv_results.mean()})
print(features_test)
# Out:
# {'N': 46171, 'avg. $F_1$': 0.8683080027823852}

# %%
# ET fully dataset
pipeline = Pipeline(steps=[
        ("vectorizer", TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=vocabs_tups[4][1], lowercase=False)),
        ("classifier", ExtraTreesClassifier(n_jobs=-1, n_estimators=100))]) 
cv_results = make_cv(pipeline, N=len(y), splits=10)
features_test = ({"N" : len(y), "avg. $F_1$" : cv_results.mean()})
print(features_test)
# Out:
# {'N': 46171, 'avg. $F_1$': 0.877095857386245}

# %%
LR_cv_results
# Out:
# array([0.8733397 , 0.87246073, 0.86650758, 0.86483831, 0.86439371])

# %%
scipy.stats.ttest_ind(LR_cv_results, cv_results)
# Out:
# Ttest_indResult(statistic=-4.11475808426351, pvalue=0.003368456126920651)

# %% [markdown]
# # ET - Main training

# %%
#raw_features = status_N + materials_N + bigrams_mostfreq[:1000]
vocab = list(set(status_N + materials_N + bigrams_mostfreq[:10000])) # + weighted_bigrams_all))

vectorizer =  TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=vocab, lowercase=False)
X = vectorizer.fit_transform(status_bigrams_list)

classifier = ExtraTreesClassifier(random_state=1, n_jobs=-1, n_estimators=100)

# %%
# Create training and test set 
features_train, features_test, target_train, target_test = train_test_split(X, y, test_size=0.1, random_state=1)

# %%
len(np.unique(target_test))
# Out:
# 21

# %%
len(np.unique(target_predicted))
# Out:
# 20

# %%
target_predicted = classifier.fit(features_train, target_train).predict(features_test)

# %%
classifier.score(features_test, target_test)
# Out:
# 0.8867475097444781

# %%
test_pred_probs = [(classifier.classes_[np.argmax(pred)], pred[np.argmax(pred)], real) for pred, real in zip(classifier.predict_proba(features_test), target_test)]
test_pred_probs[:20]
# Out:
# [('votive inscription', 0.927, 'building/dedicatory inscription'),
#  ('votive inscription', 0.9636963696369635, 'votive inscription'),
#  ('votive inscription', 1.0, 'votive inscription'),
#  ('epitaph', 1.0, 'epitaph'),
#  ('epitaph', 1.0, 'epitaph'),
#  ('votive inscription', 0.9000000000000008, 'votive inscription'),
#  ('epitaph', 1.0, 'epitaph'),
#  ('votive inscription', 0.3346691729323308, 'building/dedicatory inscription'),
#  ('epitaph', 0.4293233082706769, 'epitaph'),
#  ('honorific inscription', 0.89, 'honorific inscription'),
#  ('epitaph', 1.0, 'epitaph'),
#  ('epitaph', 1.0, 'epitaph'),
#  ('votive inscription', 0.8666666666666651, 'votive inscription'),
#  ('epitaph', 0.91, 'epitaph'),
#  ('epitaph', 1.0, 'epitaph'),
#  ('epitaph', 1.0, 'epitaph'),
#  ('building/dedicatory inscription',
#   0.37555886736214533,
#   'building/dedicatory inscription'),
#  ('epitaph', 1.0, 'epitaph'),
#  ('votive inscription', 1.0, 'votive inscription'),
#  ('epitaph', 1.0, 'epitaph')]

# %%
test_results = []
for threshold in [thres / 100 for thres in range(30, 100, 5)]:
    above_threshold = [tup for tup in test_pred_probs if tup[1] >= threshold]
    correct_count = len([tup for tup in above_threshold if tup[0] == tup[2]]) # correct total
    correct_proportion = correct_count / len(above_threshold)# correct ratio 
    proportion = len(above_threshold) / len(test_pred_probs)
    test_results.append({"threshold (=/>)" : threshold, "proportion" : np.round(proportion, 2), "N" : len(above_threshold), "correct" : correct_proportion})
test_results_df = pd.DataFrame(test_results)
test_results_df
# Out:
#     threshold (=/>)  proportion     N   correct
# 0              0.30        1.00  4600  0.888696
# 1              0.35        0.99  4571  0.892802
# 2              0.40        0.96  4448  0.905800
# 3              0.45        0.91  4225  0.929467
# 4              0.50        0.89  4123  0.940092
# 5              0.55        0.87  4027  0.949839
# 6              0.60        0.85  3936  0.955539
# 7              0.65        0.83  3853  0.960550
# 8              0.70        0.81  3755  0.965379
# 9              0.75        0.79  3653  0.968519
# 10             0.80        0.76  3526  0.972490
# 11             0.85        0.70  3253  0.979096
# 12             0.90        0.67  3082  0.980208
# 13             0.95        0.60  2762  0.982259

# %%
N_labels = 10
matrix = confusion_matrix(target_test, target_predicted, labels=classes_sorted[:N_labels], normalize="true")
dataframe = pd.DataFrame(matrix, index=classes_sorted[:N_labels], columns=classes_sorted[:N_labels])

# %%
# row sum:
dataframe.iloc[0].sum()
# Out:
# 1.0

# %%
N_labels = 10
matrix = confusion_matrix(target_test, target_predicted, labels=classes_sorted[:N_labels], normalize="true")
dataframe = pd.DataFrame(matrix, index=classes_sorted[:N_labels], columns=classes_sorted[:N_labels])

plt.style.use("fast")
plt.rcParams["font.family"] = "serif"
plt.rcParams['font.size'] = 8

fig, ax = plt.subplots(figsize=(5.7, 5), dpi=300, tight_layout=True)

sns.heatmap(dataframe.round(3), annot=True, cbar=None, cmap="Blues", ax=ax) 

ax.set_ylabel("True Class")
ax.set_xlabel("Predicted Class")
plt.show()

# %% [markdown]
# The confusion matrix.
#
# For instance, we see that 86 % of owner/artist inscriptions has been correctly classified as owner/artist inscription. However, 2 % of them were incorrectly classified as identification inscription.

# %% [markdown]
# #  SVM main training

# %%
vocab = status_N + bigrams_mostfreq[:100] + materials_N
vectorizer = TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=vocab)
X = vectorizer.fit_transform(status_bigrams_list)
X.todense().shape
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1)

# %%
# %%time
svm = train_svm(X_train, y_train)
# Out:
# CPU times: user 4h 26min 11s, sys: 146 ms, total: 4h 26min 11s
# Wall time: 4h 26min 17s

# %%
print(svm.score(X_test, y_test))
# Out:
# 0.8607622347336509

# %%
# only where the predictor is present
predictors_present = [np.any(el) for el in X_test.todense()]
# check the performance on datapoints for which we have something in the "status_list"
svm.score(X_test.todense()[predictors_present], np.array(y_test)[predictors_present])
# Out:
# 0.8873664653971203

# %%
test_pred_probs = [(svm.classes_[np.argmax(pred)], pred[np.argmax(pred)], real) for pred, real in zip(svm.predict_proba(X_test), y_test)]
test_pred_probs[:20]
# Out:
# [('epitaph', 0.8076518568979559, 'epitaph'),
#  ('epitaph', 0.9175135155645008, 'epitaph'),
#  ('honorific inscription', 0.8175375756362547, 'epitaph'),
#  ('votive inscription', 0.9375336045590539, 'votive inscription'),
#  ('epitaph', 0.9889070296976127, 'epitaph'),
#  ('honorific inscription', 0.4244074964132119, 'honorific inscription'),
#  ('identification inscription', 0.38499247315960017, 'acclamation'),
#  ('epitaph', 0.6814848074358177, 'epitaph'),
#  ('votive inscription', 0.8981249140959828, 'votive inscription'),
#  ('epitaph', 0.9898373617328683, 'epitaph'),
#  ('epitaph', 0.9995455498440634, 'epitaph'),
#  ('owner/artist inscription', 0.7672183828711583, 'owner/artist inscription'),
#  ('building/dedicatory inscription', 0.3477246765155101, 'epitaph'),
#  ('building/dedicatory inscription',
#   0.5086770937852645,
#   'building/dedicatory inscription'),
#  ('votive inscription', 0.8722865158161045, 'votive inscription'),
#  ('votive inscription', 0.9771523245027367, 'votive inscription'),
#  ('votive inscription', 0.9764234178972918, 'votive inscription'),
#  ('votive inscription', 0.9294300077732595, 'votive inscription'),
#  ('epitaph', 0.99767174458914, 'epitaph'),
#  ('votive inscription', 0.9568323830816993, 'votive inscription')]

# %%
test_results = []
for threshold in [thres / 100 for thres in range(30, 100, 5)]:
    above_threshold = [tup for tup in test_pred_probs if tup[1] >= threshold]
    correct_count = len([tup for tup in above_threshold if tup[0] == tup[2]]) # correct total
    correct_proportion = correct_count / len(above_threshold)# correct ratio 
    proportion = len(above_threshold) / len(test_pred_probs)
    test_results.append({"threshold (=/>)" : threshold, "proportion" : np.round(proportion, 2), "N" : len(above_threshold), "correct" : correct_proportion})
test_results_df = pd.DataFrame(test_results)
test_results_df
# Out:
#     threshold (=/>)  proportion     N   correct
# 0              0.30        1.00  4601  0.862421
# 1              0.35        0.94  4337  0.890247
# 2              0.40        0.93  4310  0.894200
# 3              0.45        0.91  4213  0.898647
# 4              0.50        0.90  4162  0.901970
# 5              0.55        0.89  4092  0.905670
# 6              0.60        0.86  3955  0.908976
# 7              0.65        0.84  3898  0.910723
# 8              0.70        0.71  3264  0.957414
# 9              0.75        0.67  3078  0.968811
# 10             0.80        0.58  2694  0.971047
# 11             0.85        0.51  2336  0.977312
# 12             0.90        0.42  1957  0.984159
# 13             0.95        0.34  1563  0.989763

# %%
test_results_df.to_csv("../data/svm_v1_test_results.csv")

# %%
model_path = '../data/svm_model_v1.0.sav'
pickle.dump(svm, open(model_path, 'wb'))
vectorizer_path= '../data/svm_vectorizer_v1.0.sav'
pickle.dump(vectorizer, open(vectorizer_path, "wb"))

# %% [markdown]
# # Applying the model

# %%
# load the model and vectorizer back
svm_v1 = pickle.load(open('../data/svm_model_v1.0.sav', 'rb'))
vectorizer_v1 = pickle.load(open('../data/svm_vectorizer_v1.0.sav','rb'))

# %%
# we will apply the model to inscriptions which are only in EDCS
EDCS_unique = EDHCSg[(EDHCSg["EDH-ID"].isnull()) & (EDHCSg["EDCS-ID"].notnull())] 
EDCS_unique.head(5)
# Out:
#          EDCS-ID                                     publication  province  \
# 0  EDCS-71300269                                  AE 2014, 01203    Achaia
# 1  EDCS-21200140  CIL 03, 00079 = CIL 03, 14147,6 = IDakke 00028  Aegyptus
# 2  EDCS-21200142   CIL 03, 00081 = CIL 03, 13584 = IDakke 00064a  Aegyptus
# 3  EDCS-52100002                                    IDakke 00064  Aegyptus
# 4  EDCS-44500113                                    IDakke 00100  Aegyptus
#
#   province_list                                              place  \
# 0        Achaia         Mavrommati / Mavromati / Messini / Messene
# 1      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 2      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 3      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 4      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
#
#                                           place_list end_yr_list notes_dating  \
# 0  ['Mavrommati', 'Mavromati', 'Messini', 'Messene']          96
# 1  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         109
# 2  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         109
# 3  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         109
# 4  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         117
#
#                                          status_list  \
# 0  ['sigilla impressa', 'tituli fabricationis', '...
# 1  ['milites', 'tituli fabricationis', 'tituli sa...
# 2                                                 {}
# 3                                tituli possessionis
# 4  ['Augusti/Augustae', 'milites', 'ordo equester...
#
#                                  inscr_type  \
# 0                      tituli fabricationis
# 1  ['tituli fabricationis', 'tituli sacri']
# 2                                        {}
# 3                       tituli possessionis
# 4                              tituli sacri
#
#                                      status_notation     inscr_process  \
# 0                                               viri  sigilla impressa
# 1                 ['milites', 'tria nomina', 'viri']                {}
# 2                                                 {}                {}
# 3                                                 {}                {}
# 4  ['Augusti/Augustae', 'milites', 'ordo equester...                {}
#
#   notes_references notes_comments  \
# 0
# 1
# 2
# 3
# 4
#
#                                          inscription  \
# 0                                      De Rasticanis
# 1  Deo Magno Mercurio / adoravit vexillu / leg(io...
# 2                            Anno / XII [Tr]ai/a[ni]
# 3                                   Anno XX [Tra]ani
# 4  Pro salute Imp(eratoris) Nervae Traiani Caesar...
#
#                           inscription_stripped_final  \
# 0                                      De Rasticanis
# 1  Deo Magno Mercurio / adoravit vexillu / leg(io...
# 2                            Anno / XII [Tr]ai/a[ni]
# 3                                   Anno XX [Tra]ani
# 4  Pro salute Imp(eratoris) Nervae Traiani Caesar...
#
#                                                Links  dating from dating to  \
# 0                                               None         69.0        96
# 1  http://db.edcs.eu/epigr/partner.php?s_language...        109.0       109
# 2                                               None        109.0       109
# 3                                               None        109.0       109
# 4                                               None        103.0       117
#
#                                               status   Latitude  Longitude  \
# 0       sigilla impressa; tituli fabricationis; viri  37.179412  21.924179
# 1  milites; tituli fabricationis; tituli sacri; t...  23.200000  32.750000
# 2                                               None  23.200000  32.750000
# 3                                tituli possessionis  23.200000  32.750000
# 4  Augusti/Augustae; milites; ordo equester; titu...  23.200000  32.750000
#
#   photo       Material Comment EDH-ID language_EDCS  \
# 0  None  opus figlinae    None   None          None
# 1  None           None    None   None          None
# 2  None           None    None   None          None
# 3  None           None    None   None          None
# 4  None           None    None   None          None
#
#                    clean_text_interpretive_word_EDCS responsible_individual  \
# 0                                      De Rasticanis                   None
# 1  Deo Magno Mercurio adoravit vexillu legionis I...                   None
# 2                                   Anno XII Traiani                   None
# 3                                     Anno XX Traani                   None
# 4  Pro salute Imperatoris Nervae Traiani Caesaris...                   None
#
#   type_of_inscription letter_size literature work_status height  \
# 0                None        None       None        None   None
# 1                None        None       None        None   None
# 2                None        None       None        None   None
# 3                None        None       None        None   None
# 4                None        None       None        None   None
#
#   diplomatic_text people depth material type_of_monument province_label width  \
# 0            None   None  None     None             None           None  None
# 1            None   None  None     None             None           None  None
# 2            None   None  None     None             None           None  None
# 3            None   None  None     None             None           None  None
# 4            None   None  None     None             None           None  None
#
#   transcription country   uri findspot_ancient last_update modern_region  \
# 0          None    None  None             None        None          None
# 1          None    None  None             None        None          None
# 2          None    None  None             None        None          None
# 3          None    None  None             None        None          None
# 4          None    None  None             None        None          None
#
#   findspot_modern edh_geography_uri commentary trismegistos_uri  \
# 0            None              None       None             None
# 1            None              None       None             None
# 2            None              None       None             None
# 3            None              None       None             None
# 4            None              None       None             None
#
#   external_image_uris fotos idno_tm placenames_refs text_edition  \
# 0                None  None    None            None         None
# 1                None  None    None            None         None
# 2                None  None    None            None         None
# 3                None  None    None            None         None
# 4                None  None    None            None         None
#
#   origdate_text layout_execution layout_execution_text  support_objecttype  \
# 0          None             None                  None                 NaN
# 1          None             None                  None                 NaN
# 2          None             None                  None                 NaN
# 3          None             None                  None                 NaN
# 4          None             None                  None                 NaN
#
#   support_objecttype_text support_material support_material_text  \
# 0                    None             None                  None
# 1                    None             None                  None
# 2                    None             None                  None
# 3                    None             None                  None
# 4                    None             None                  None
#
#    support_decoration keywords_term keywords_term_text  \
# 0                 NaN          None               None
# 1                 NaN          None               None
# 2                 NaN          None               None
# 3                 NaN          None               None
# 4                 NaN          None               None
#
#   type_of_inscription_clean type_of_inscription_certainty  height_cm  \
# 0                      None                          None        NaN
# 1                      None                          None        NaN
# 2                      None                          None        NaN
# 3                      None                          None        NaN
# 4                      None                          None        NaN
#
#    width_cm  depth_cm material_clean type_of_monument_clean  \
# 0       NaN       NaN           None                   None
# 1       NaN       NaN           None                   None
# 2       NaN       NaN           None                   None
# 3       NaN       NaN           None                   None
# 4       NaN       NaN           None                   None
#
#   type_of_monument_certainty province_label_clean province_label_certainty  \
# 0                       None                 None                     None
# 1                       None                 None                     None
# 2                       None                 None                     None
# 3                       None                 None                     None
# 4                       None                 None                     None
#
#   country_clean country_certainty findspot_ancient_clean  \
# 0          None              None                   None
# 1          None              None                   None
# 2          None              None                   None
# 3          None              None                   None
# 4          None              None                   None
#
#   findspot_ancient_certainty modern_region_clean modern_region_certainty  \
# 0                       None                None                    None
# 1                       None                None                    None
# 2                       None                None                    None
# 3                       None                None                    None
# 4                       None                None                    None
#
#   findspot_modern_clean findspot_modern_certainty findspot_clean  \
# 0                  None                      None           None
# 1                  None                      None           None
# 2                  None                      None           None
# 3                  None                      None           None
# 4                  None                      None           None
#
#   findspot_certainty origdate_text_clean clean_text_conservative  \
# 0               None                None                    None
# 1               None                None                    None
# 2               None                None                    None
# 3               None                None                    None
# 4               None                None                    None
#
#   clean_text_interpretive_sentence findspot year_of_find present_location  \
# 0                             None     None         None             None
# 1                             None     None         None             None
# 2                             None     None         None             None
# 3                             None     None         None             None
# 4                             None     None         None             None
#
#   religion geography social_economic_legal_history military  not_after  \
# 0     None      None                          None     None       96.0
# 1     None      None                          None     None      109.0
# 2     None      None                          None     None      109.0
# 3     None      None                          None     None      109.0
# 4     None      None                          None     None      117.0
#
#   language  not_before                   coordinates  \
# 0    Latin        69.0  ['21.9241791', '37.1794122']
# 1    Latin       109.0    ['32.750000', '23.200000']
# 2    Latin       109.0    ['32.750000', '23.200000']
# 3    Latin       109.0    ['32.750000', '23.200000']
# 4    Latin       103.0    ['32.750000', '23.200000']
#
#                         clean_text_interpretive_word urban_context  \
# 0                                      De Rasticanis           big
# 1  Deo Magno Mercurio adoravit vexillu legionis I...          rest
# 2                                   Anno XII Traiani          rest
# 3                                     Anno XX Traani          rest
# 4  Pro salute Imperatoris Nervae Traiani Caesaris...          rest
#
#    within_rome nearest_city city_id_hanson  city_pop_est  \
# 0        False      Messene             59       22337.0
# 1        False  Elephantine            126       33806.0
# 2        False  Elephantine            126       33806.0
# 3        False  Elephantine            126       33806.0
# 4        False  Elephantine            126       33806.0
#
#             city_geometry nearest_city_type  nearest_city_dist  \
# 0  [22.008029, 37.051363]            middle           0.153060
# 1  [32.933333, 24.083333]               big           0.902158
# 2  [32.933333, 24.083333]               big           0.902158
# 3  [32.933333, 24.083333]               big           0.902158
# 4  [32.933333, 24.083333]               big           0.902158
#
#                     geometry  \
# 0  POINT (21.92418 37.17941)
# 1  POINT (32.75000 23.20000)
# 2  POINT (32.75000 23.20000)
# 3  POINT (32.75000 23.20000)
# 4  POINT (32.75000 23.20000)
#
#                                              bigrams
# 0                                    [De_Rasticanis]
# 1  [Deo_Magno, Magno_Mercurio, Mercurio_adoravit,...
# 2                            [Anno_XII, XII_Traiani]
# 3                               [Anno_XX, XX_Traani]
# 4  [Pro_salute, salute_Imperatoris, Imperatoris_N...

# %%
# first create bigrams
EDCS_unique["bigrams"] = EDCS_unique["clean_text_interpretive_word"].apply(get_bigrams_underscore)

# %%
# we need to extract all predictors from the dataframe
# into `status_bigrams_list_apply` (list of lists)
status_bigrams_list_apply = []
status_list = []
material_list = []
for el_status, el_bigrams, el_material in zip(EDCS_unique["status_list"].tolist(), EDCS_unique["bigrams"].tolist(), EDCS_unique["Material"].tolist()):
    new_el, new_status, el_material = combine_status_list_and_bigrams(el_status, el_bigrams, el_material)
    status_bigrams_list_apply.append(new_el)
    status_list.append(new_status)
    material_list.extend(el_material)

# %%
X_applied = vectorizer_v1.transform(status_bigrams_list_apply)

# %%
prediction = svm_v1.predict(X_applied)
prediction[:10]
# Out:
# array(['owner/artist inscription', 'owner/artist inscription', 'epitaph',
#        'votive inscription', 'votive inscription', 'epitaph', 'epitaph',
#        'honorific inscription', 'honorific inscription',
#        'honorific inscription'], dtype='<U31')

# %%
svm_v1.classes_
# Out:
# array(['acclamation', 'adnuntiatio', 'assignation inscription',
#        'boundary inscription', 'building/dedicatory inscription',
#        'calendar', 'defixio', 'elogium', 'epitaph',
#        'honorific inscription', 'identification inscription', 'label',
#        'letter', 'list', 'mile-/leaguestone', 'military diploma',
#        'owner/artist inscription', 'prayer', 'private legal inscription',
#        'public legal inscription', 'seat inscription',
#        'votive inscription'], dtype='<U31')

# %%
probs = [np.max(pred) for pred in svm_v1.predict_proba(X_applied)]
probs[:10]
# Out:
# [0.7857018706636444,
#  0.850080323385903,
#  0.696566811086934,
#  0.7255255264157866,
#  0.91963276157691,
#  0.9973812084603909,
#  0.722058041187063,
#  0.5854847852357029,
#  0.8361305582932681,
#  0.9281131587280677]

# %%
prediction_probs = [(svm_v1.classes_[np.argmax(pred)], pred[np.argmax(pred)]) for pred in svm_v1.predict_proba(X_applied)]
prediction_probs[:10]
# Out:
# [('owner/artist inscription', 0.7857018706636444),
#  ('owner/artist inscription', 0.850080323385903),
#  ('epitaph', 0.696566811086934),
#  ('votive inscription', 0.7255255264157866),
#  ('votive inscription', 0.91963276157691),
#  ('epitaph', 0.9973812084603909),
#  ('epitaph', 0.722058041187063),
#  ('honorific inscription', 0.5854847852357029),
#  ('honorific inscription', 0.8361305582932681),
#  ('honorific inscription', 0.9281131587280677)]

# %%
len(prediction_probs)
# Out:
# 83482

# %%
for threshold in [thres / 100 for thres in range(30, 100, 5)]:
    above_threshold = [tup for tup in prediction_probs if tup[1] >= threshold]
    proportion = len(above_threshold) / len(prediction_probs)
    print("prob. threshold: {0}, proportion of inscr.: {1}".format(threshold, proportion))
# Out:
# prob. threshold: 0.3, proportion of inscr.: 0.9917227665844134
# prob. threshold: 0.35, proportion of inscr.: 0.9776718334491268
# prob. threshold: 0.4, proportion of inscr.: 0.9708440142785271
# prob. threshold: 0.45, proportion of inscr.: 0.9533192784073213
# prob. threshold: 0.5, proportion of inscr.: 0.9454612970460698
# prob. threshold: 0.55, proportion of inscr.: 0.9377949737668
# prob. threshold: 0.6, proportion of inscr.: 0.9269543135047076
# prob. threshold: 0.65, proportion of inscr.: 0.920713447210177
# prob. threshold: 0.7, proportion of inscr.: 0.732073980019645
# prob. threshold: 0.75, proportion of inscr.: 0.7075776814163532
# prob. threshold: 0.8, proportion of inscr.: 0.605962962075657
# prob. threshold: 0.85, proportion of inscr.: 0.5564073692532522
# prob. threshold: 0.9, proportion of inscr.: 0.4863443616588007
# prob. threshold: 0.95, proportion of inscr.: 0.4326441628135406

# %%
threshold_results = []
for threshold in [thres / 100 for thres in range(30, 100, 5)]:
    above_threshold = [tup for tup in prediction_probs if tup[1] >= threshold]
    proportion = len(above_threshold) / len(prediction_probs)
    threshold_results.append({"threshold (=/>)" : threshold, "proportion" : np.round(proportion, 2), "N" : len(above_threshold)})
model_results_df = pd.DataFrame(threshold_results)
model_results_df
# Out:
#     threshold (=/>)  proportion      N
# 0              0.30        0.99  82791
# 1              0.35        0.98  81618
# 2              0.40        0.97  81048
# 3              0.45        0.95  79585
# 4              0.50        0.95  78929
# 5              0.55        0.94  78289
# 6              0.60        0.93  77384
# 7              0.65        0.92  76863
# 8              0.70        0.73  61115
# 9              0.75        0.71  59070
# 10             0.80        0.61  50587
# 11             0.85        0.56  46450
# 12             0.90        0.49  40601
# 13             0.95        0.43  36118

# %%
model_results_df.to_csv("../data/svm_v1_EDCS_results.csv")

# %%
test_results_df
# Out:
#     threshold (=/>)  proportion     N   correct
# 0              0.30        1.00  4601  0.862421
# 1              0.35        0.94  4337  0.890247
# 2              0.40        0.93  4310  0.894200
# 3              0.45        0.91  4213  0.898647
# 4              0.50        0.90  4162  0.901970
# 5              0.55        0.89  4092  0.905670
# 6              0.60        0.86  3955  0.908976
# 7              0.65        0.84  3898  0.910723
# 8              0.70        0.71  3264  0.957414
# 9              0.75        0.67  3078  0.968811
# 10             0.80        0.58  2694  0.971047
# 11             0.85        0.51  2336  0.977312
# 12             0.90        0.42  1957  0.984159
# 13             0.95        0.34  1563  0.989763

# %% [markdown]
# # Combining the data back

# %%
EDCS_unique["type_of_inscription_auto"] = prediction
EDCS_unique["type_of_inscription_auto_prob"] = probs

# %%
EDCS_unique.head(5)
# Out:
#          EDCS-ID                                     publication  province  \
# 0  EDCS-71300269                                  AE 2014, 01203    Achaia
# 1  EDCS-21200140  CIL 03, 00079 = CIL 03, 14147,6 = IDakke 00028  Aegyptus
# 2  EDCS-21200142   CIL 03, 00081 = CIL 03, 13584 = IDakke 00064a  Aegyptus
# 3  EDCS-52100002                                    IDakke 00064  Aegyptus
# 4  EDCS-44500113                                    IDakke 00100  Aegyptus
#
#   province_list                                              place  \
# 0        Achaia         Mavrommati / Mavromati / Messini / Messene
# 1      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 2      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 3      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 4      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
#
#                                           place_list end_yr_list notes_dating  \
# 0  ['Mavrommati', 'Mavromati', 'Messini', 'Messene']          96
# 1  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         109
# 2  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         109
# 3  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         109
# 4  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         117
#
#                                          status_list  \
# 0  ['sigilla impressa', 'tituli fabricationis', '...
# 1  ['milites', 'tituli fabricationis', 'tituli sa...
# 2                                                 {}
# 3                                tituli possessionis
# 4  ['Augusti/Augustae', 'milites', 'ordo equester...
#
#                                  inscr_type  \
# 0                      tituli fabricationis
# 1  ['tituli fabricationis', 'tituli sacri']
# 2                                        {}
# 3                       tituli possessionis
# 4                              tituli sacri
#
#                                      status_notation     inscr_process  \
# 0                                               viri  sigilla impressa
# 1                 ['milites', 'tria nomina', 'viri']                {}
# 2                                                 {}                {}
# 3                                                 {}                {}
# 4  ['Augusti/Augustae', 'milites', 'ordo equester...                {}
#
#   notes_references notes_comments  \
# 0
# 1
# 2
# 3
# 4
#
#                                          inscription  \
# 0                                      De Rasticanis
# 1  Deo Magno Mercurio / adoravit vexillu / leg(io...
# 2                            Anno / XII [Tr]ai/a[ni]
# 3                                   Anno XX [Tra]ani
# 4  Pro salute Imp(eratoris) Nervae Traiani Caesar...
#
#                           inscription_stripped_final  \
# 0                                      De Rasticanis
# 1  Deo Magno Mercurio / adoravit vexillu / leg(io...
# 2                            Anno / XII [Tr]ai/a[ni]
# 3                                   Anno XX [Tra]ani
# 4  Pro salute Imp(eratoris) Nervae Traiani Caesar...
#
#                                                Links  dating from dating to  \
# 0                                               None         69.0        96
# 1  http://db.edcs.eu/epigr/partner.php?s_language...        109.0       109
# 2                                               None        109.0       109
# 3                                               None        109.0       109
# 4                                               None        103.0       117
#
#                                               status   Latitude  Longitude  \
# 0       sigilla impressa; tituli fabricationis; viri  37.179412  21.924179
# 1  milites; tituli fabricationis; tituli sacri; t...  23.200000  32.750000
# 2                                               None  23.200000  32.750000
# 3                                tituli possessionis  23.200000  32.750000
# 4  Augusti/Augustae; milites; ordo equester; titu...  23.200000  32.750000
#
#   photo       Material Comment EDH-ID language_EDCS  \
# 0  None  opus figlinae    None   None          None
# 1  None           None    None   None          None
# 2  None           None    None   None          None
# 3  None           None    None   None          None
# 4  None           None    None   None          None
#
#                    clean_text_interpretive_word_EDCS responsible_individual  \
# 0                                      De Rasticanis                   None
# 1  Deo Magno Mercurio adoravit vexillu legionis I...                   None
# 2                                   Anno XII Traiani                   None
# 3                                     Anno XX Traani                   None
# 4  Pro salute Imperatoris Nervae Traiani Caesaris...                   None
#
#   type_of_inscription letter_size literature work_status height  \
# 0                None        None       None        None   None
# 1                None        None       None        None   None
# 2                None        None       None        None   None
# 3                None        None       None        None   None
# 4                None        None       None        None   None
#
#   diplomatic_text people depth material type_of_monument province_label width  \
# 0            None   None  None     None             None           None  None
# 1            None   None  None     None             None           None  None
# 2            None   None  None     None             None           None  None
# 3            None   None  None     None             None           None  None
# 4            None   None  None     None             None           None  None
#
#   transcription country   uri findspot_ancient last_update modern_region  \
# 0          None    None  None             None        None          None
# 1          None    None  None             None        None          None
# 2          None    None  None             None        None          None
# 3          None    None  None             None        None          None
# 4          None    None  None             None        None          None
#
#   findspot_modern edh_geography_uri commentary trismegistos_uri  \
# 0            None              None       None             None
# 1            None              None       None             None
# 2            None              None       None             None
# 3            None              None       None             None
# 4            None              None       None             None
#
#   external_image_uris fotos idno_tm placenames_refs text_edition  \
# 0                None  None    None            None         None
# 1                None  None    None            None         None
# 2                None  None    None            None         None
# 3                None  None    None            None         None
# 4                None  None    None            None         None
#
#   origdate_text layout_execution layout_execution_text  support_objecttype  \
# 0          None             None                  None                 NaN
# 1          None             None                  None                 NaN
# 2          None             None                  None                 NaN
# 3          None             None                  None                 NaN
# 4          None             None                  None                 NaN
#
#   support_objecttype_text support_material support_material_text  \
# 0                    None             None                  None
# 1                    None             None                  None
# 2                    None             None                  None
# 3                    None             None                  None
# 4                    None             None                  None
#
#    support_decoration keywords_term keywords_term_text  \
# 0                 NaN          None               None
# 1                 NaN          None               None
# 2                 NaN          None               None
# 3                 NaN          None               None
# 4                 NaN          None               None
#
#   type_of_inscription_clean type_of_inscription_certainty  height_cm  \
# 0                      None                          None        NaN
# 1                      None                          None        NaN
# 2                      None                          None        NaN
# 3                      None                          None        NaN
# 4                      None                          None        NaN
#
#    width_cm  depth_cm material_clean type_of_monument_clean  \
# 0       NaN       NaN           None                   None
# 1       NaN       NaN           None                   None
# 2       NaN       NaN           None                   None
# 3       NaN       NaN           None                   None
# 4       NaN       NaN           None                   None
#
#   type_of_monument_certainty province_label_clean province_label_certainty  \
# 0                       None                 None                     None
# 1                       None                 None                     None
# 2                       None                 None                     None
# 3                       None                 None                     None
# 4                       None                 None                     None
#
#   country_clean country_certainty findspot_ancient_clean  \
# 0          None              None                   None
# 1          None              None                   None
# 2          None              None                   None
# 3          None              None                   None
# 4          None              None                   None
#
#   findspot_ancient_certainty modern_region_clean modern_region_certainty  \
# 0                       None                None                    None
# 1                       None                None                    None
# 2                       None                None                    None
# 3                       None                None                    None
# 4                       None                None                    None
#
#   findspot_modern_clean findspot_modern_certainty findspot_clean  \
# 0                  None                      None           None
# 1                  None                      None           None
# 2                  None                      None           None
# 3                  None                      None           None
# 4                  None                      None           None
#
#   findspot_certainty origdate_text_clean clean_text_conservative  \
# 0               None                None                    None
# 1               None                None                    None
# 2               None                None                    None
# 3               None                None                    None
# 4               None                None                    None
#
#   clean_text_interpretive_sentence findspot year_of_find present_location  \
# 0                             None     None         None             None
# 1                             None     None         None             None
# 2                             None     None         None             None
# 3                             None     None         None             None
# 4                             None     None         None             None
#
#   religion geography social_economic_legal_history military  not_after  \
# 0     None      None                          None     None       96.0
# 1     None      None                          None     None      109.0
# 2     None      None                          None     None      109.0
# 3     None      None                          None     None      109.0
# 4     None      None                          None     None      117.0
#
#   language  not_before                   coordinates  \
# 0    Latin        69.0  ['21.9241791', '37.1794122']
# 1    Latin       109.0    ['32.750000', '23.200000']
# 2    Latin       109.0    ['32.750000', '23.200000']
# 3    Latin       109.0    ['32.750000', '23.200000']
# 4    Latin       103.0    ['32.750000', '23.200000']
#
#                         clean_text_interpretive_word urban_context  \
# 0                                      De Rasticanis           big
# 1  Deo Magno Mercurio adoravit vexillu legionis I...          rest
# 2                                   Anno XII Traiani          rest
# 3                                     Anno XX Traani          rest
# 4  Pro salute Imperatoris Nervae Traiani Caesaris...          rest
#
#    within_rome nearest_city city_id_hanson  city_pop_est  \
# 0        False      Messene             59       22337.0
# 1        False  Elephantine            126       33806.0
# 2        False  Elephantine            126       33806.0
# 3        False  Elephantine            126       33806.0
# 4        False  Elephantine            126       33806.0
#
#             city_geometry nearest_city_type  nearest_city_dist  \
# 0  [22.008029, 37.051363]            middle           0.153060
# 1  [32.933333, 24.083333]               big           0.902158
# 2  [32.933333, 24.083333]               big           0.902158
# 3  [32.933333, 24.083333]               big           0.902158
# 4  [32.933333, 24.083333]               big           0.902158
#
#                     geometry  \
# 0  POINT (21.92418 37.17941)
# 1  POINT (32.75000 23.20000)
# 2  POINT (32.75000 23.20000)
# 3  POINT (32.75000 23.20000)
# 4  POINT (32.75000 23.20000)
#
#                                              bigrams  \
# 0                                    [De_Rasticanis]
# 1  [Deo_Magno, Magno_Mercurio, Mercurio_adoravit,...
# 2                            [Anno_XII, XII_Traiani]
# 3                               [Anno_XX, XX_Traani]
# 4  [Pro_salute, salute_Imperatoris, Imperatoris_N...
#
#    type_of_inscription_auto  type_of_inscription_auto_prob
# 0  owner/artist inscription                       0.785702
# 1  owner/artist inscription                       0.850080
# 2                   epitaph                       0.696567
# 3        votive inscription                       0.725526
# 4        votive inscription                       0.919633

# %%
# prepare last part of the data - inscriptions we have only in EDH
# in this case, we can also use the information we already have
EDH_unique = EDHCSg[(EDHCSg["EDH-ID"].notnull()) & (EDHCSg["EDCS-ID"].isnull())] 
EDH_unique["type_of_inscription_auto"] = EDH_unique["type_of_inscription_clean"]
EDH_unique["type_of_inscription_auto_prob"] = [1] * len(EDH_unique)

# %%
EDH_overlap_all["type_of_inscription_auto"] = EDH_overlap_all["type_of_inscription_clean"]
EDH_overlap_all["type_of_inscription_auto_prob"] = [1] * len(EDH_overlap_all)

# %%
print("the dataset we used for training and testing (+NULLs): ", EDH_overlap_all.shape)
print("inscriptions in EDH only: ", EDH_unique.shape)
print("inscriptions in EDCS only, we wanted to classify: ", EDCS_unique.shape)
# Out:
# the dataset we used for training and testing (+NULLs):  (49916, 113)
# inscriptions in EDH only:  (3907, 113)
# inscriptions in EDCS only, we wanted to classify:  (83482, 113)

# %%
# combine together
EDHCS_autotypes = pd.concat([EDH_overlap_all, EDH_unique, EDCS_unique])
EDHCS_autotypes.head()
# Out:
#              EDCS-ID                                        publication  \
# 83482  EDCS-03700724  ZPE-108-159 = Thesprotia 00001 = AE 1993, 0140...
# 83483  EDCS-03300852                                     AE 1995, 01409
# 83484  EDCS-28500283  CIL 03, 07251 = D 00214 = NDIEC-07, p 81 = AE ...
# 83485  EDCS-09400671  CIMRM-02, 02350 = IG-12, 00274 = Andros 00124 ...
# 83486  EDCS-24600769                    AE 1995, 01407 = AE 2001, 01812
#
#       province province_list                                       place  \
# 83482   Achaia        Achaia                  Agios Athanasios / Photike
# 83483   Achaia        Achaia                                Alea / Tegea
# 83484   Achaia        Achaia                                Alea / Tegea
# 83485   Achaia        Achaia                                      Andros
# 83486   Achaia        Achaia  Archea Olimpia / Archaia Olympia / Olympia
#
#                                              place_list end_yr_list  \
# 83482                   ['Agios Athanasios', 'Photike']         313
# 83483                                 ['Alea', 'Tegea']         276
# 83484                                 ['Alea', 'Tegea']          50
# 83485                                            Andros         209
# 83486  ['Archea Olimpia', 'Archaia Olympia', 'Olympia']          96
#
#                                  notes_dating  \
# 83482
# 83483  to 276;   b:  276 to 282         \n\n
# 83484
# 83485
# 83486
#
#                                              status_list        inscr_type  \
# 83482  ['Augusti/Augustae', 'litterae erasae', 'ordo ...  tituli honorarii
# 83483           ['Augusti/Augustae', 'miliaria', 'viri']          miliaria
# 83484              ['Augusti/Augustae', 'leges', 'viri']             leges
# 83485                ['litterae erasae', 'tituli sacri']      tituli sacri
# 83486                                                 {}                {}
#
#                                          status_notation    inscr_process  \
# 83482  ['Augusti/Augustae', 'ordo equester', 'tria no...  litterae erasae
# 83483                       ['Augusti/Augustae', 'viri']               {}
# 83484                       ['Augusti/Augustae', 'viri']               {}
# 83485                                                 {}  litterae erasae
# 83486                                                 {}               {}
#
#       notes_references notes_comments  \
# 83482
# 83483
# 83484
# 83485
# 83486
#
#                                              inscription  \
# 83482  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 83483  to 276;   b:  276 to 282         \n\n \n \nImp...
# 83484  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 83485  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 83486                             Octa(vius) Sa(lutaris)
#
#                               inscription_stripped_final  \
# 83482  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 83483  Imp(eratori) / Floriano / P(io) F(elici) Aug(u...
# 83484  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 83485  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 83486                             Octa(vius) Sa(lutaris)
#
#                                                    Links  dating from  \
# 83482  http://db.edcs.eu/epigr/partner.php?s_language...        309.0
# 83483  http://db.edcs.eu/epigr/partner.php?s_language...          NaN
# 83484  http://db.edcs.eu/epigr/partner.php?s_language...         49.0
# 83485  http://db.edcs.eu/epigr/partner.php?s_language...        198.0
# 83486  http://db.edcs.eu/epigr/partner.php?s_language...         81.0
#
#       dating to                                             status   Latitude  \
# 83482       313  Augusti/Augustae; litterae erasae; ordo equest...  39.451218
# 83483       276                   Augusti/Augustae; miliaria; viri  37.454501
# 83484        50                      Augusti/Augustae; leges; viri  37.454501
# 83485       209                      litterae erasae; tituli sacri  37.837612
# 83486        96                                               None  37.643870
#
#        Longitude                                              photo Material  \
# 83482  20.766767  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None
# 83483  22.420877                                               None    lapis
# 83484  22.420877                                               None     None
# 83485  24.937637  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None
# 83486  21.625513                                               None     None
#
#       Comment    EDH-ID language_EDCS  \
# 83482    None  HD052964          None
# 83483    None  HD051000          None
# 83484    None  HD021396          None
# 83485    None  HD011892          None
# 83486    None  HD050999          None
#
#                        clean_text_interpretive_word_EDCS  \
# 83482  Fortissimo et Piissimo Caesari domino nostro G...
# 83483  Imperatori Floriano Pio Felici Augusto patri p...
# 83484  Tiberius Claudius Caesar Augustus Germanicus p...
# 83485  Pro salute Imperatoris Caesaris Luci Septimi S...
# 83486                                 Octavius Salutaris
#
#       responsible_individual       type_of_inscription letter_size  \
# 83482                  Cowey     honorific inscription    3-5.3 cm
# 83483                  Cowey         mile-/leaguestone    3.3-6 cm
# 83484                  Cowey  public legal inscription        None
# 83485                  Cowey        votive inscription  5.5-5.7 cm
# 83486                  Cowey  owner/artist inscription        None
#
#                                               literature         work_status  \
# 83482  AE 1993, 1406.; V. Papadopoulou, AD 43 B, 1988...  checked with photo
# 83483  AE 1995, 1409.; M. Iozzer - M. Pangano, ASAA 6...  checked with photo
# 83484  CIL 03, 07251.; ILS 0214.; AE 1941, 0119.; MAI...  checked with photo
# 83485  AE 1911, 0056. (B); T. Sauciuc, MDAI(R) 25, 19...  checked with photo
# 83486  AE 1995, 1407.; U. Sinn u. a., Nikephoros 8, 1...  checked with photo
#
#         height                                    diplomatic_text  \
# 83482    99 cm  FORTISSIMO ET PIIS / SIMO CAESARI D N / GAL VA...
# 83483  (44) cm  [ ] / AN[ ] FLORIANO / P F AVG / P P / M P III...
# 83484   160 cm  T[ ] CLAVDIVS CAESAR AVG / G[ ]ANICVS PONTIF M...
# 83485    48 cm  PRO SALVTE IMP CAESARI / L SEPTIMI SEVERI ET M...
# 83486     None                                           OCTA SAL
#
#                                                   people  depth material  \
# 83482  [{'name': 'Gal. Val. [[Maximiano]]', 'nomen': ...  67 cm     None
# 83483  [{'person_id': '1', 'nomen': 'Annius+', 'name'...   None     None
# 83484  [{'gender': 'male', 'cognomen': 'Caesar August...  17 cm     None
# 83485  [{'gender': 'male', 'praenomen': 'L.', 'name':...   None     None
# 83486  [{'person_id': '1', 'nomen': 'Octavius*', 'nam...   None     None
#
#               type_of_monument province_label   width  \
# 83482              statue base         Epirus   67 cm
# 83483        mile-/leaguestone         Achaia   24 cm
# 83484                   tabula         Achaia   58 cm
# 83485                     None         Achaia  126 cm
# 83486  instrumentum domesticum         Achaia    None
#
#                                            transcription country  \
# 83482  Fortissimo et piis/simo Caesari d(omino) n(ost...  Greece
# 83483  [Imp(eratori) Caes(ari) M(arco)] / An[nio] Flo...  Greece
# 83484  T[i(berius)] Claudius Caesar Aug(ustus) / G[er...  Greece
# 83485  Pro salute Imp(eratorum) Caesari(s) / L(uci) S...  Greece
# 83486                             Octa(vius) Sal(utaris)  Greece
#
#                                                      uri findspot_ancient  \
# 83482  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Photike
# 83483  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 83484  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 83485  https://edh-www.adw.uni-heidelberg.de/edh/insc...      Palaeopolis
# 83486  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Olympia
#
#       last_update  modern_region findspot_modern  \
# 83482  2014-09-16        Ípeiros      Paramythía
# 83483  2011-05-24   Pelopónissos            Alea
# 83484  2011-05-10   Pelopónissos            Alea
# 83485  2017-05-30   Nótio Aigaío     Palaiópolis
# 83486  2012-04-16  Stereá Elláda         Olympia
#
#                                        edh_geography_uri  \
# 83482  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83483  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83484  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83485  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83486  https://edh-www.adw.uni-heidelberg.de/edh/geog...
#
#                                               commentary  \
# 83482                                               None
# 83483   Die erste Inschrift ist auf 276, die zweite a...
# 83484                                               None
# 83485   Auf dem Foto sind die Buchstaben oft kaum erk...
# 83486       (B): Sa(lutaris) fehlerhaft für Sal(utaris).
#
#                                trismegistos_uri external_image_uris fotos  \
# 83482  https://www.trismegistos.org/text/121715                  {}    {}
# 83483  https://www.trismegistos.org/text/177273                  {}    {}
# 83484  https://www.trismegistos.org/text/177131                  {}    {}
# 83485  https://www.trismegistos.org/text/177087                  {}    {}
# 83486  https://www.trismegistos.org/text/177272                  {}    {}
#
#       idno_tm                                    placenames_refs  \
# 83482  121715  ['http://www.trismegistos.org/place/000655', '...
# 83483  177273  ['http://www.trismegistos.org/place/000078', '...
# 83484  177131  ['http://www.trismegistos.org/place/000078', '...
# 83485  177087                                                 []
# 83486  177272  ['http://www.trismegistos.org/place/000078', '...
#
#                                             text_edition  \
# 83482                  Fortissimo et piissimo Caesari...
# 83483  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 83484                  Tiberius Claudius Caesar Augus...
# 83485                  Pro salute Imperatorum Caesari...
# 83486                                 Octavius Salutaris
#
#                                      origdate_text layout_execution  \
# 83482  309 AD – 313 AD                                           21
# 83483           276 AD                                           21
# 83484    49 AD – 50 AD                                           21
# 83485  198 AD – 209 AD                                           21
# 83486    81 AD – 96 AD                                           21
#
#       layout_execution_text  support_objecttype  support_objecttype_text  \
# 83482            unbestimmt                57.0             Statuenbasis
# 83483            unbestimmt                89.0      Meilen-/Leugenstein
# 83484            unbestimmt               257.0                    Tafel
# 83485            unbestimmt                 2.0               unbestimmt
# 83486            unbestimmt               140.0  Instrumentum domesticum
#
#       support_material support_material_text  support_decoration  \
# 83482              138            unbestimmt              1000.0
# 83483              138            unbestimmt              1000.0
# 83484              138            unbestimmt              1000.0
# 83485              138            unbestimmt              1000.0
# 83486              138            unbestimmt              1000.0
#
#       keywords_term                keywords_term_text  \
# 83482            69                    Ehreninschrift
# 83483           102               Meilen-/Leugenstein
# 83484                Rechtliche Verfügung, öffentlich
# 83485            80                     Weihinschrift
# 83486           311     Besitzer-/Herstellerinschrift
#
#       type_of_inscription_clean type_of_inscription_certainty  height_cm  \
# 83482     honorific inscription                       Certain       99.0
# 83483         mile-/leaguestone                       Certain       44.0
# 83484  public legal inscription                       Certain      160.0
# 83485        votive inscription                       Certain       48.0
# 83486  owner/artist inscription                       Certain        NaN
#
#        width_cm  depth_cm material_clean   type_of_monument_clean  \
# 83482      67.0      67.0           NULL              statue base
# 83483      24.0       NaN           NULL        mile-/leaguestone
# 83484      58.0      17.0           NULL                   tabula
# 83485     126.0       NaN           NULL                     NULL
# 83486       NaN       NaN           NULL  instrumentum domesticum
#
#       type_of_monument_certainty province_label_clean  \
# 83482                    Certain               Epirus
# 83483                    Certain               Achaia
# 83484                    Certain               Achaia
# 83485                       NULL               Achaia
# 83486                    Certain               Achaia
#
#       province_label_certainty country_clean country_certainty  \
# 83482                  Certain        Greece           Certain
# 83483                  Certain        Greece           Certain
# 83484                  Certain        Greece           Certain
# 83485                  Certain        Greece           Certain
# 83486                  Certain        Greece           Certain
#
#       findspot_ancient_clean findspot_ancient_certainty modern_region_clean  \
# 83482                Photike                    Certain             Ípeiros
# 83483                  Tegea                    Certain        Pelopónissos
# 83484                  Tegea                    Certain        Pelopónissos
# 83485            Palaeopolis                    Certain        Nótio Aigaío
# 83486                Olympia                    Certain       Stereá Elláda
#
#       modern_region_certainty findspot_modern_clean findspot_modern_certainty  \
# 83482                 Certain            Paramythía                   Certain
# 83483                 Certain                  Alea                   Certain
# 83484                 Certain                  Alea                   Certain
# 83485                 Certain           Palaiópolis                   Certain
# 83486                 Certain               Olympia                   Certain
#
#                               findspot_clean findspot_certainty  \
# 83482                       Agios Athanasios            Certain
# 83483                           Stringu, bei            Certain
# 83484                                   NULL               NULL
# 83485  to Elleniko Mauer, sekundär verwendet            Certain
# 83486                      Haus der Athleten            Certain
#
#       origdate_text_clean                            clean_text_conservative  \
# 83482     309 AD – 313 AD  Fortissimo et piissimo Caesari d n Gal Val P F...
# 83483              276 AD  An Floriano P F Aug p p m p III Imp Caes M Aur...
# 83484       49 AD – 50 AD  T Claudius Caesar Aug Ganicus pontif max trib ...
# 83485     198 AD – 209 AD  Pro salute Imp Caesari L Septimi Severi et M A...
# 83486       81 AD – 96 AD                                           Octa Sal
#
#                         clean_text_interpretive_sentence  \
# 83482  Fortissimo et piissimo Caesari domino nostro G...
# 83483  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 83484  Tiberius Claudius Caesar Augustus Germanicus p...
# 83485  Pro salute Imperatorum Caesaris Luci Septimi S...
# 83486                                 Octavius Salutaris
#
#                                     findspot year_of_find  \
# 83482                       Agios Athanasios         None
# 83483                           Stringu, bei         None
# 83484                                   None         None
# 83485  to Elleniko Mauer, sekundär verwendet         None
# 83486                      Haus der Athleten         None
#
#                    present_location                religion       geography  \
# 83482                 Fragma Kalama                    None  data available
# 83483                   Tegea, Mus.                    None            None
# 83484                          None                    None            None
# 83485  to Elleniko Mauer, vermauert  names of pagan deities            None
# 83486                          None                    None            None
#
#       social_economic_legal_history        military  not_after language  \
# 83482                          None            None      313.0    Latin
# 83483                data available            None        NaN    Latin
# 83484                          None            None       50.0    Latin
# 83485                          None  data available      209.0    Latin
# 83486                          None            None       96.0    Latin
#
#        not_before         coordinates  \
# 83482       309.0  [20.7668, 39.4512]
# 83483       276.0  [22.4171, 37.4319]
# 83484        49.0  [22.4171, 37.4319]
# 83485       198.0  [24.8323, 37.8188]
# 83486        81.0  [21.6271, 37.6479]
#
#                             clean_text_interpretive_word urban_context  \
# 83482  Fortissimo et piissimo Caesari domino nostro G...          rest
# 83483  Imperatori Caesari Marco Annio Floriano Pio Fe...           big
# 83484  Tiberius Claudius Caesar Augustus Germanicus p...           big
# 83485  Pro salute Imperatorum Caesaris Luci Septimi S...          rest
# 83486                                 Octavius Salutaris           big
#
#        within_rome nearest_city city_id_hanson  city_pop_est  \
# 83482        False       Dodona             31        1000.0
# 83483        False        Tegea             97       46362.0
# 83484        False        Tegea             97       46362.0
# 83485        False       Ioulis             47        1000.0
# 83486        False         Elis             35        1000.0
#
#                 city_geometry nearest_city_type  nearest_city_dist  \
# 83482  [20.787767, 39.546432]             minor           0.097513
# 83483  [22.417226, 37.427653]               big           0.004249
# 83484  [22.417226, 37.427653]               big           0.004249
# 83485   [24.34625, 37.633122]             minor           0.520308
# 83486  [21.435443, 37.827452]             minor           0.262624
#
#                         geometry  \
# 83482  POINT (20.76680 39.45120)
# 83483  POINT (22.41710 37.43190)
# 83484  POINT (22.41710 37.43190)
# 83485  POINT (24.83230 37.81880)
# 83486  POINT (21.62710 37.64790)
#
#                                                  bigrams  \
# 83482  [Fortissimo_et, et_piissimo, piissimo_Caesari,...
# 83483  [Imperatori_Caesari, Caesari_Marco, Marco_Anni...
# 83484  [Tiberius_Claudius, Claudius_Caesar, Caesar_Au...
# 83485  [Pro_salute, salute_Imperatorum, Imperatorum_C...
# 83486                               [Octavius_Salutaris]
#
#        type_of_inscription_auto  type_of_inscription_auto_prob
# 83482     honorific inscription                            1.0
# 83483         mile-/leaguestone                            1.0
# 83484  public legal inscription                            1.0
# 83485        votive inscription                            1.0
# 83486  owner/artist inscription                            1.0

# %%
EDHCS_autotypes.drop(["bigrams"], axis=1, inplace=True)

# %%
EDHCS_autotypes.shape
# Out:
# (137305, 112)

# %%
EDHCS_autotypes.head(5)
# Out:
#              EDCS-ID                                        publication  \
# 83482  EDCS-03700724  ZPE-108-159 = Thesprotia 00001 = AE 1993, 0140...
# 83483  EDCS-03300852                                     AE 1995, 01409
# 83484  EDCS-28500283  CIL 03, 07251 = D 00214 = NDIEC-07, p 81 = AE ...
# 83485  EDCS-09400671  CIMRM-02, 02350 = IG-12, 00274 = Andros 00124 ...
# 83486  EDCS-24600769                    AE 1995, 01407 = AE 2001, 01812
#
#       province province_list                                       place  \
# 83482   Achaia        Achaia                  Agios Athanasios / Photike
# 83483   Achaia        Achaia                                Alea / Tegea
# 83484   Achaia        Achaia                                Alea / Tegea
# 83485   Achaia        Achaia                                      Andros
# 83486   Achaia        Achaia  Archea Olimpia / Archaia Olympia / Olympia
#
#                                              place_list end_yr_list  \
# 83482                   ['Agios Athanasios', 'Photike']         313
# 83483                                 ['Alea', 'Tegea']         276
# 83484                                 ['Alea', 'Tegea']          50
# 83485                                            Andros         209
# 83486  ['Archea Olimpia', 'Archaia Olympia', 'Olympia']          96
#
#                                  notes_dating  \
# 83482
# 83483  to 276;   b:  276 to 282         \n\n
# 83484
# 83485
# 83486
#
#                                              status_list        inscr_type  \
# 83482  ['Augusti/Augustae', 'litterae erasae', 'ordo ...  tituli honorarii
# 83483           ['Augusti/Augustae', 'miliaria', 'viri']          miliaria
# 83484              ['Augusti/Augustae', 'leges', 'viri']             leges
# 83485                ['litterae erasae', 'tituli sacri']      tituli sacri
# 83486                                                 {}                {}
#
#                                          status_notation    inscr_process  \
# 83482  ['Augusti/Augustae', 'ordo equester', 'tria no...  litterae erasae
# 83483                       ['Augusti/Augustae', 'viri']               {}
# 83484                       ['Augusti/Augustae', 'viri']               {}
# 83485                                                 {}  litterae erasae
# 83486                                                 {}               {}
#
#       notes_references notes_comments  \
# 83482
# 83483
# 83484
# 83485
# 83486
#
#                                              inscription  \
# 83482  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 83483  to 276;   b:  276 to 282         \n\n \n \nImp...
# 83484  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 83485  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 83486                             Octa(vius) Sa(lutaris)
#
#                               inscription_stripped_final  \
# 83482  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 83483  Imp(eratori) / Floriano / P(io) F(elici) Aug(u...
# 83484  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 83485  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 83486                             Octa(vius) Sa(lutaris)
#
#                                                    Links  dating from  \
# 83482  http://db.edcs.eu/epigr/partner.php?s_language...        309.0
# 83483  http://db.edcs.eu/epigr/partner.php?s_language...          NaN
# 83484  http://db.edcs.eu/epigr/partner.php?s_language...         49.0
# 83485  http://db.edcs.eu/epigr/partner.php?s_language...        198.0
# 83486  http://db.edcs.eu/epigr/partner.php?s_language...         81.0
#
#       dating to                                             status   Latitude  \
# 83482       313  Augusti/Augustae; litterae erasae; ordo equest...  39.451218
# 83483       276                   Augusti/Augustae; miliaria; viri  37.454501
# 83484        50                      Augusti/Augustae; leges; viri  37.454501
# 83485       209                      litterae erasae; tituli sacri  37.837612
# 83486        96                                               None  37.643870
#
#        Longitude                                              photo Material  \
# 83482  20.766767  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None
# 83483  22.420877                                               None    lapis
# 83484  22.420877                                               None     None
# 83485  24.937637  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None
# 83486  21.625513                                               None     None
#
#       Comment    EDH-ID language_EDCS  \
# 83482    None  HD052964          None
# 83483    None  HD051000          None
# 83484    None  HD021396          None
# 83485    None  HD011892          None
# 83486    None  HD050999          None
#
#                        clean_text_interpretive_word_EDCS  \
# 83482  Fortissimo et Piissimo Caesari domino nostro G...
# 83483  Imperatori Floriano Pio Felici Augusto patri p...
# 83484  Tiberius Claudius Caesar Augustus Germanicus p...
# 83485  Pro salute Imperatoris Caesaris Luci Septimi S...
# 83486                                 Octavius Salutaris
#
#       responsible_individual       type_of_inscription letter_size  \
# 83482                  Cowey     honorific inscription    3-5.3 cm
# 83483                  Cowey         mile-/leaguestone    3.3-6 cm
# 83484                  Cowey  public legal inscription        None
# 83485                  Cowey        votive inscription  5.5-5.7 cm
# 83486                  Cowey  owner/artist inscription        None
#
#                                               literature         work_status  \
# 83482  AE 1993, 1406.; V. Papadopoulou, AD 43 B, 1988...  checked with photo
# 83483  AE 1995, 1409.; M. Iozzer - M. Pangano, ASAA 6...  checked with photo
# 83484  CIL 03, 07251.; ILS 0214.; AE 1941, 0119.; MAI...  checked with photo
# 83485  AE 1911, 0056. (B); T. Sauciuc, MDAI(R) 25, 19...  checked with photo
# 83486  AE 1995, 1407.; U. Sinn u. a., Nikephoros 8, 1...  checked with photo
#
#         height                                    diplomatic_text  \
# 83482    99 cm  FORTISSIMO ET PIIS / SIMO CAESARI D N / GAL VA...
# 83483  (44) cm  [ ] / AN[ ] FLORIANO / P F AVG / P P / M P III...
# 83484   160 cm  T[ ] CLAVDIVS CAESAR AVG / G[ ]ANICVS PONTIF M...
# 83485    48 cm  PRO SALVTE IMP CAESARI / L SEPTIMI SEVERI ET M...
# 83486     None                                           OCTA SAL
#
#                                                   people  depth material  \
# 83482  [{'name': 'Gal. Val. [[Maximiano]]', 'nomen': ...  67 cm     None
# 83483  [{'person_id': '1', 'nomen': 'Annius+', 'name'...   None     None
# 83484  [{'gender': 'male', 'cognomen': 'Caesar August...  17 cm     None
# 83485  [{'gender': 'male', 'praenomen': 'L.', 'name':...   None     None
# 83486  [{'person_id': '1', 'nomen': 'Octavius*', 'nam...   None     None
#
#               type_of_monument province_label   width  \
# 83482              statue base         Epirus   67 cm
# 83483        mile-/leaguestone         Achaia   24 cm
# 83484                   tabula         Achaia   58 cm
# 83485                     None         Achaia  126 cm
# 83486  instrumentum domesticum         Achaia    None
#
#                                            transcription country  \
# 83482  Fortissimo et piis/simo Caesari d(omino) n(ost...  Greece
# 83483  [Imp(eratori) Caes(ari) M(arco)] / An[nio] Flo...  Greece
# 83484  T[i(berius)] Claudius Caesar Aug(ustus) / G[er...  Greece
# 83485  Pro salute Imp(eratorum) Caesari(s) / L(uci) S...  Greece
# 83486                             Octa(vius) Sal(utaris)  Greece
#
#                                                      uri findspot_ancient  \
# 83482  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Photike
# 83483  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 83484  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 83485  https://edh-www.adw.uni-heidelberg.de/edh/insc...      Palaeopolis
# 83486  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Olympia
#
#       last_update  modern_region findspot_modern  \
# 83482  2014-09-16        Ípeiros      Paramythía
# 83483  2011-05-24   Pelopónissos            Alea
# 83484  2011-05-10   Pelopónissos            Alea
# 83485  2017-05-30   Nótio Aigaío     Palaiópolis
# 83486  2012-04-16  Stereá Elláda         Olympia
#
#                                        edh_geography_uri  \
# 83482  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83483  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83484  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83485  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83486  https://edh-www.adw.uni-heidelberg.de/edh/geog...
#
#                                               commentary  \
# 83482                                               None
# 83483   Die erste Inschrift ist auf 276, die zweite a...
# 83484                                               None
# 83485   Auf dem Foto sind die Buchstaben oft kaum erk...
# 83486       (B): Sa(lutaris) fehlerhaft für Sal(utaris).
#
#                                trismegistos_uri external_image_uris fotos  \
# 83482  https://www.trismegistos.org/text/121715                  {}    {}
# 83483  https://www.trismegistos.org/text/177273                  {}    {}
# 83484  https://www.trismegistos.org/text/177131                  {}    {}
# 83485  https://www.trismegistos.org/text/177087                  {}    {}
# 83486  https://www.trismegistos.org/text/177272                  {}    {}
#
#       idno_tm                                    placenames_refs  \
# 83482  121715  ['http://www.trismegistos.org/place/000655', '...
# 83483  177273  ['http://www.trismegistos.org/place/000078', '...
# 83484  177131  ['http://www.trismegistos.org/place/000078', '...
# 83485  177087                                                 []
# 83486  177272  ['http://www.trismegistos.org/place/000078', '...
#
#                                             text_edition  \
# 83482                  Fortissimo et piissimo Caesari...
# 83483  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 83484                  Tiberius Claudius Caesar Augus...
# 83485                  Pro salute Imperatorum Caesari...
# 83486                                 Octavius Salutaris
#
#                                      origdate_text layout_execution  \
# 83482  309 AD – 313 AD                                           21
# 83483           276 AD                                           21
# 83484    49 AD – 50 AD                                           21
# 83485  198 AD – 209 AD                                           21
# 83486    81 AD – 96 AD                                           21
#
#       layout_execution_text  support_objecttype  support_objecttype_text  \
# 83482            unbestimmt                57.0             Statuenbasis
# 83483            unbestimmt                89.0      Meilen-/Leugenstein
# 83484            unbestimmt               257.0                    Tafel
# 83485            unbestimmt                 2.0               unbestimmt
# 83486            unbestimmt               140.0  Instrumentum domesticum
#
#       support_material support_material_text  support_decoration  \
# 83482              138            unbestimmt              1000.0
# 83483              138            unbestimmt              1000.0
# 83484              138            unbestimmt              1000.0
# 83485              138            unbestimmt              1000.0
# 83486              138            unbestimmt              1000.0
#
#       keywords_term                keywords_term_text  \
# 83482            69                    Ehreninschrift
# 83483           102               Meilen-/Leugenstein
# 83484                Rechtliche Verfügung, öffentlich
# 83485            80                     Weihinschrift
# 83486           311     Besitzer-/Herstellerinschrift
#
#       type_of_inscription_clean type_of_inscription_certainty  height_cm  \
# 83482     honorific inscription                       Certain       99.0
# 83483         mile-/leaguestone                       Certain       44.0
# 83484  public legal inscription                       Certain      160.0
# 83485        votive inscription                       Certain       48.0
# 83486  owner/artist inscription                       Certain        NaN
#
#        width_cm  depth_cm material_clean   type_of_monument_clean  \
# 83482      67.0      67.0           NULL              statue base
# 83483      24.0       NaN           NULL        mile-/leaguestone
# 83484      58.0      17.0           NULL                   tabula
# 83485     126.0       NaN           NULL                     NULL
# 83486       NaN       NaN           NULL  instrumentum domesticum
#
#       type_of_monument_certainty province_label_clean  \
# 83482                    Certain               Epirus
# 83483                    Certain               Achaia
# 83484                    Certain               Achaia
# 83485                       NULL               Achaia
# 83486                    Certain               Achaia
#
#       province_label_certainty country_clean country_certainty  \
# 83482                  Certain        Greece           Certain
# 83483                  Certain        Greece           Certain
# 83484                  Certain        Greece           Certain
# 83485                  Certain        Greece           Certain
# 83486                  Certain        Greece           Certain
#
#       findspot_ancient_clean findspot_ancient_certainty modern_region_clean  \
# 83482                Photike                    Certain             Ípeiros
# 83483                  Tegea                    Certain        Pelopónissos
# 83484                  Tegea                    Certain        Pelopónissos
# 83485            Palaeopolis                    Certain        Nótio Aigaío
# 83486                Olympia                    Certain       Stereá Elláda
#
#       modern_region_certainty findspot_modern_clean findspot_modern_certainty  \
# 83482                 Certain            Paramythía                   Certain
# 83483                 Certain                  Alea                   Certain
# 83484                 Certain                  Alea                   Certain
# 83485                 Certain           Palaiópolis                   Certain
# 83486                 Certain               Olympia                   Certain
#
#                               findspot_clean findspot_certainty  \
# 83482                       Agios Athanasios            Certain
# 83483                           Stringu, bei            Certain
# 83484                                   NULL               NULL
# 83485  to Elleniko Mauer, sekundär verwendet            Certain
# 83486                      Haus der Athleten            Certain
#
#       origdate_text_clean                            clean_text_conservative  \
# 83482     309 AD – 313 AD  Fortissimo et piissimo Caesari d n Gal Val P F...
# 83483              276 AD  An Floriano P F Aug p p m p III Imp Caes M Aur...
# 83484       49 AD – 50 AD  T Claudius Caesar Aug Ganicus pontif max trib ...
# 83485     198 AD – 209 AD  Pro salute Imp Caesari L Septimi Severi et M A...
# 83486       81 AD – 96 AD                                           Octa Sal
#
#                         clean_text_interpretive_sentence  \
# 83482  Fortissimo et piissimo Caesari domino nostro G...
# 83483  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 83484  Tiberius Claudius Caesar Augustus Germanicus p...
# 83485  Pro salute Imperatorum Caesaris Luci Septimi S...
# 83486                                 Octavius Salutaris
#
#                                     findspot year_of_find  \
# 83482                       Agios Athanasios         None
# 83483                           Stringu, bei         None
# 83484                                   None         None
# 83485  to Elleniko Mauer, sekundär verwendet         None
# 83486                      Haus der Athleten         None
#
#                    present_location                religion       geography  \
# 83482                 Fragma Kalama                    None  data available
# 83483                   Tegea, Mus.                    None            None
# 83484                          None                    None            None
# 83485  to Elleniko Mauer, vermauert  names of pagan deities            None
# 83486                          None                    None            None
#
#       social_economic_legal_history        military  not_after language  \
# 83482                          None            None      313.0    Latin
# 83483                data available            None        NaN    Latin
# 83484                          None            None       50.0    Latin
# 83485                          None  data available      209.0    Latin
# 83486                          None            None       96.0    Latin
#
#        not_before         coordinates  \
# 83482       309.0  [20.7668, 39.4512]
# 83483       276.0  [22.4171, 37.4319]
# 83484        49.0  [22.4171, 37.4319]
# 83485       198.0  [24.8323, 37.8188]
# 83486        81.0  [21.6271, 37.6479]
#
#                             clean_text_interpretive_word urban_context  \
# 83482  Fortissimo et piissimo Caesari domino nostro G...          rest
# 83483  Imperatori Caesari Marco Annio Floriano Pio Fe...           big
# 83484  Tiberius Claudius Caesar Augustus Germanicus p...           big
# 83485  Pro salute Imperatorum Caesaris Luci Septimi S...          rest
# 83486                                 Octavius Salutaris           big
#
#        within_rome nearest_city city_id_hanson  city_pop_est  \
# 83482        False       Dodona             31        1000.0
# 83483        False        Tegea             97       46362.0
# 83484        False        Tegea             97       46362.0
# 83485        False       Ioulis             47        1000.0
# 83486        False         Elis             35        1000.0
#
#                 city_geometry nearest_city_type  nearest_city_dist  \
# 83482  [20.787767, 39.546432]             minor           0.097513
# 83483  [22.417226, 37.427653]               big           0.004249
# 83484  [22.417226, 37.427653]               big           0.004249
# 83485   [24.34625, 37.633122]             minor           0.520308
# 83486  [21.435443, 37.827452]             minor           0.262624
#
#                         geometry  type_of_inscription_auto  \
# 83482  POINT (20.76680 39.45120)     honorific inscription
# 83483  POINT (22.41710 37.43190)         mile-/leaguestone
# 83484  POINT (22.41710 37.43190)  public legal inscription
# 83485  POINT (24.83230 37.81880)        votive inscription
# 83486  POINT (21.62710 37.64790)  owner/artist inscription
#
#        type_of_inscription_auto_prob
# 83482                            1.0
# 83483                            1.0
# 83484                            1.0
# 83485                            1.0
# 83486                            1.0

# %%
len(EDHCS_autotypes[EDHCS_autotypes["type_of_inscription_auto_prob"]>0.55])
# Out:
# 132112

# %%
len(EDHCS_autotypes[EDHCS_autotypes["type_of_inscription_auto"]=="NULL"])
# Out:
# 4339

# %%
def apply_threshold(inscr_type, prob):
    if (prob < 0.55) or (inscr_type == "NULL"):
        return None 
    else:
        return inscr_type
EDHCS_autotypes["type_of_inscription_auto"] =  EDHCS_autotypes.apply(lambda row: apply_threshold(row["type_of_inscription_auto"], row["type_of_inscription_auto_prob"]), axis=1)

# %%
def prob_to_zero(inscr_type, prob):
    if inscr_type == None:
        return 0
    else:
        return prob
EDHCS_autotypes["type_of_inscription_auto_prob"] =  EDHCS_autotypes.apply(lambda row: prob_to_zero(row["type_of_inscription_auto"], row["type_of_inscription_auto_prob"]), axis=1)

# %%
len(EDHCS_autotypes[EDHCS_autotypes["type_of_inscription_auto"].notnull()])
# Out:
# 127773

# %%
len(EDHCS_autotypes[(EDHCS_autotypes["type_of_inscription_auto"].notnull()) & (EDHCS_autotypes["type_of_inscription_auto_prob"] > 0.55)])
# Out:
# 127773

# %%
s = sddk.cloudSession("sciencedata.dk", "SDAM_root/SDAM_data/EDHCS", "648597@au.dk")
# Out:
# Your ScienceData username (e.g. '123456@au.dk'): 648597@au.dk
# Your ScienceData password: ········
# connection with shared folder established with you as its owner
# endpoint variable has been configured to: https://sciencedata.dk/files/SDAM_root/SDAM_data/EDHCS/

# %%
EDHCS_autotypes.head(5)
# Out:
#              EDCS-ID                                        publication  \
# 83482  EDCS-03700724  ZPE-108-159 = Thesprotia 00001 = AE 1993, 0140...
# 83483  EDCS-03300852                                     AE 1995, 01409
# 83484  EDCS-28500283  CIL 03, 07251 = D 00214 = NDIEC-07, p 81 = AE ...
# 83485  EDCS-09400671  CIMRM-02, 02350 = IG-12, 00274 = Andros 00124 ...
# 83486  EDCS-24600769                    AE 1995, 01407 = AE 2001, 01812
#
#       province province_list                                       place  \
# 83482   Achaia        Achaia                  Agios Athanasios / Photike
# 83483   Achaia        Achaia                                Alea / Tegea
# 83484   Achaia        Achaia                                Alea / Tegea
# 83485   Achaia        Achaia                                      Andros
# 83486   Achaia        Achaia  Archea Olimpia / Archaia Olympia / Olympia
#
#                                              place_list end_yr_list  \
# 83482                   ['Agios Athanasios', 'Photike']         313
# 83483                                 ['Alea', 'Tegea']         276
# 83484                                 ['Alea', 'Tegea']          50
# 83485                                            Andros         209
# 83486  ['Archea Olimpia', 'Archaia Olympia', 'Olympia']          96
#
#                                  notes_dating  \
# 83482
# 83483  to 276;   b:  276 to 282         \n\n
# 83484
# 83485
# 83486
#
#                                              status_list        inscr_type  \
# 83482  ['Augusti/Augustae', 'litterae erasae', 'ordo ...  tituli honorarii
# 83483           ['Augusti/Augustae', 'miliaria', 'viri']          miliaria
# 83484              ['Augusti/Augustae', 'leges', 'viri']             leges
# 83485                ['litterae erasae', 'tituli sacri']      tituli sacri
# 83486                                                 {}                {}
#
#                                          status_notation    inscr_process  \
# 83482  ['Augusti/Augustae', 'ordo equester', 'tria no...  litterae erasae
# 83483                       ['Augusti/Augustae', 'viri']               {}
# 83484                       ['Augusti/Augustae', 'viri']               {}
# 83485                                                 {}  litterae erasae
# 83486                                                 {}               {}
#
#       notes_references notes_comments  \
# 83482
# 83483
# 83484
# 83485
# 83486
#
#                                              inscription  \
# 83482  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 83483  to 276;   b:  276 to 282         \n\n \n \nImp...
# 83484  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 83485  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 83486                             Octa(vius) Sa(lutaris)
#
#                               inscription_stripped_final  \
# 83482  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 83483  Imp(eratori) / Floriano / P(io) F(elici) Aug(u...
# 83484  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 83485  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 83486                             Octa(vius) Sa(lutaris)
#
#                                                    Links  dating from  \
# 83482  http://db.edcs.eu/epigr/partner.php?s_language...        309.0
# 83483  http://db.edcs.eu/epigr/partner.php?s_language...          NaN
# 83484  http://db.edcs.eu/epigr/partner.php?s_language...         49.0
# 83485  http://db.edcs.eu/epigr/partner.php?s_language...        198.0
# 83486  http://db.edcs.eu/epigr/partner.php?s_language...         81.0
#
#       dating to                                             status   Latitude  \
# 83482       313  Augusti/Augustae; litterae erasae; ordo equest...  39.451218
# 83483       276                   Augusti/Augustae; miliaria; viri  37.454501
# 83484        50                      Augusti/Augustae; leges; viri  37.454501
# 83485       209                      litterae erasae; tituli sacri  37.837612
# 83486        96                                               None  37.643870
#
#        Longitude                                              photo Material  \
# 83482  20.766767  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None
# 83483  22.420877                                               None    lapis
# 83484  22.420877                                               None     None
# 83485  24.937637  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None
# 83486  21.625513                                               None     None
#
#       Comment    EDH-ID language_EDCS  \
# 83482    None  HD052964          None
# 83483    None  HD051000          None
# 83484    None  HD021396          None
# 83485    None  HD011892          None
# 83486    None  HD050999          None
#
#                        clean_text_interpretive_word_EDCS  \
# 83482  Fortissimo et Piissimo Caesari domino nostro G...
# 83483  Imperatori Floriano Pio Felici Augusto patri p...
# 83484  Tiberius Claudius Caesar Augustus Germanicus p...
# 83485  Pro salute Imperatoris Caesaris Luci Septimi S...
# 83486                                 Octavius Salutaris
#
#       responsible_individual       type_of_inscription letter_size  \
# 83482                  Cowey     honorific inscription    3-5.3 cm
# 83483                  Cowey         mile-/leaguestone    3.3-6 cm
# 83484                  Cowey  public legal inscription        None
# 83485                  Cowey        votive inscription  5.5-5.7 cm
# 83486                  Cowey  owner/artist inscription        None
#
#                                               literature         work_status  \
# 83482  AE 1993, 1406.; V. Papadopoulou, AD 43 B, 1988...  checked with photo
# 83483  AE 1995, 1409.; M. Iozzer - M. Pangano, ASAA 6...  checked with photo
# 83484  CIL 03, 07251.; ILS 0214.; AE 1941, 0119.; MAI...  checked with photo
# 83485  AE 1911, 0056. (B); T. Sauciuc, MDAI(R) 25, 19...  checked with photo
# 83486  AE 1995, 1407.; U. Sinn u. a., Nikephoros 8, 1...  checked with photo
#
#         height                                    diplomatic_text  \
# 83482    99 cm  FORTISSIMO ET PIIS / SIMO CAESARI D N / GAL VA...
# 83483  (44) cm  [ ] / AN[ ] FLORIANO / P F AVG / P P / M P III...
# 83484   160 cm  T[ ] CLAVDIVS CAESAR AVG / G[ ]ANICVS PONTIF M...
# 83485    48 cm  PRO SALVTE IMP CAESARI / L SEPTIMI SEVERI ET M...
# 83486     None                                           OCTA SAL
#
#                                                   people  depth material  \
# 83482  [{'name': 'Gal. Val. [[Maximiano]]', 'nomen': ...  67 cm     None
# 83483  [{'person_id': '1', 'nomen': 'Annius+', 'name'...   None     None
# 83484  [{'gender': 'male', 'cognomen': 'Caesar August...  17 cm     None
# 83485  [{'gender': 'male', 'praenomen': 'L.', 'name':...   None     None
# 83486  [{'person_id': '1', 'nomen': 'Octavius*', 'nam...   None     None
#
#               type_of_monument province_label   width  \
# 83482              statue base         Epirus   67 cm
# 83483        mile-/leaguestone         Achaia   24 cm
# 83484                   tabula         Achaia   58 cm
# 83485                     None         Achaia  126 cm
# 83486  instrumentum domesticum         Achaia    None
#
#                                            transcription country  \
# 83482  Fortissimo et piis/simo Caesari d(omino) n(ost...  Greece
# 83483  [Imp(eratori) Caes(ari) M(arco)] / An[nio] Flo...  Greece
# 83484  T[i(berius)] Claudius Caesar Aug(ustus) / G[er...  Greece
# 83485  Pro salute Imp(eratorum) Caesari(s) / L(uci) S...  Greece
# 83486                             Octa(vius) Sal(utaris)  Greece
#
#                                                      uri findspot_ancient  \
# 83482  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Photike
# 83483  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 83484  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 83485  https://edh-www.adw.uni-heidelberg.de/edh/insc...      Palaeopolis
# 83486  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Olympia
#
#       last_update  modern_region findspot_modern  \
# 83482  2014-09-16        Ípeiros      Paramythía
# 83483  2011-05-24   Pelopónissos            Alea
# 83484  2011-05-10   Pelopónissos            Alea
# 83485  2017-05-30   Nótio Aigaío     Palaiópolis
# 83486  2012-04-16  Stereá Elláda         Olympia
#
#                                        edh_geography_uri  \
# 83482  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83483  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83484  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83485  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83486  https://edh-www.adw.uni-heidelberg.de/edh/geog...
#
#                                               commentary  \
# 83482                                               None
# 83483   Die erste Inschrift ist auf 276, die zweite a...
# 83484                                               None
# 83485   Auf dem Foto sind die Buchstaben oft kaum erk...
# 83486       (B): Sa(lutaris) fehlerhaft für Sal(utaris).
#
#                                trismegistos_uri external_image_uris fotos  \
# 83482  https://www.trismegistos.org/text/121715                  {}    {}
# 83483  https://www.trismegistos.org/text/177273                  {}    {}
# 83484  https://www.trismegistos.org/text/177131                  {}    {}
# 83485  https://www.trismegistos.org/text/177087                  {}    {}
# 83486  https://www.trismegistos.org/text/177272                  {}    {}
#
#       idno_tm                                    placenames_refs  \
# 83482  121715  ['http://www.trismegistos.org/place/000655', '...
# 83483  177273  ['http://www.trismegistos.org/place/000078', '...
# 83484  177131  ['http://www.trismegistos.org/place/000078', '...
# 83485  177087                                                 []
# 83486  177272  ['http://www.trismegistos.org/place/000078', '...
#
#                                             text_edition  \
# 83482                  Fortissimo et piissimo Caesari...
# 83483  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 83484                  Tiberius Claudius Caesar Augus...
# 83485                  Pro salute Imperatorum Caesari...
# 83486                                 Octavius Salutaris
#
#                                      origdate_text layout_execution  \
# 83482  309 AD – 313 AD                                           21
# 83483           276 AD                                           21
# 83484    49 AD – 50 AD                                           21
# 83485  198 AD – 209 AD                                           21
# 83486    81 AD – 96 AD                                           21
#
#       layout_execution_text  support_objecttype  support_objecttype_text  \
# 83482            unbestimmt                57.0             Statuenbasis
# 83483            unbestimmt                89.0      Meilen-/Leugenstein
# 83484            unbestimmt               257.0                    Tafel
# 83485            unbestimmt                 2.0               unbestimmt
# 83486            unbestimmt               140.0  Instrumentum domesticum
#
#       support_material support_material_text  support_decoration  \
# 83482              138            unbestimmt              1000.0
# 83483              138            unbestimmt              1000.0
# 83484              138            unbestimmt              1000.0
# 83485              138            unbestimmt              1000.0
# 83486              138            unbestimmt              1000.0
#
#       keywords_term                keywords_term_text  \
# 83482            69                    Ehreninschrift
# 83483           102               Meilen-/Leugenstein
# 83484                Rechtliche Verfügung, öffentlich
# 83485            80                     Weihinschrift
# 83486           311     Besitzer-/Herstellerinschrift
#
#       type_of_inscription_clean type_of_inscription_certainty  height_cm  \
# 83482     honorific inscription                       Certain       99.0
# 83483         mile-/leaguestone                       Certain       44.0
# 83484  public legal inscription                       Certain      160.0
# 83485        votive inscription                       Certain       48.0
# 83486  owner/artist inscription                       Certain        NaN
#
#        width_cm  depth_cm material_clean   type_of_monument_clean  \
# 83482      67.0      67.0           NULL              statue base
# 83483      24.0       NaN           NULL        mile-/leaguestone
# 83484      58.0      17.0           NULL                   tabula
# 83485     126.0       NaN           NULL                     NULL
# 83486       NaN       NaN           NULL  instrumentum domesticum
#
#       type_of_monument_certainty province_label_clean  \
# 83482                    Certain               Epirus
# 83483                    Certain               Achaia
# 83484                    Certain               Achaia
# 83485                       NULL               Achaia
# 83486                    Certain               Achaia
#
#       province_label_certainty country_clean country_certainty  \
# 83482                  Certain        Greece           Certain
# 83483                  Certain        Greece           Certain
# 83484                  Certain        Greece           Certain
# 83485                  Certain        Greece           Certain
# 83486                  Certain        Greece           Certain
#
#       findspot_ancient_clean findspot_ancient_certainty modern_region_clean  \
# 83482                Photike                    Certain             Ípeiros
# 83483                  Tegea                    Certain        Pelopónissos
# 83484                  Tegea                    Certain        Pelopónissos
# 83485            Palaeopolis                    Certain        Nótio Aigaío
# 83486                Olympia                    Certain       Stereá Elláda
#
#       modern_region_certainty findspot_modern_clean findspot_modern_certainty  \
# 83482                 Certain            Paramythía                   Certain
# 83483                 Certain                  Alea                   Certain
# 83484                 Certain                  Alea                   Certain
# 83485                 Certain           Palaiópolis                   Certain
# 83486                 Certain               Olympia                   Certain
#
#                               findspot_clean findspot_certainty  \
# 83482                       Agios Athanasios            Certain
# 83483                           Stringu, bei            Certain
# 83484                                   NULL               NULL
# 83485  to Elleniko Mauer, sekundär verwendet            Certain
# 83486                      Haus der Athleten            Certain
#
#       origdate_text_clean                            clean_text_conservative  \
# 83482     309 AD – 313 AD  Fortissimo et piissimo Caesari d n Gal Val P F...
# 83483              276 AD  An Floriano P F Aug p p m p III Imp Caes M Aur...
# 83484       49 AD – 50 AD  T Claudius Caesar Aug Ganicus pontif max trib ...
# 83485     198 AD – 209 AD  Pro salute Imp Caesari L Septimi Severi et M A...
# 83486       81 AD – 96 AD                                           Octa Sal
#
#                         clean_text_interpretive_sentence  \
# 83482  Fortissimo et piissimo Caesari domino nostro G...
# 83483  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 83484  Tiberius Claudius Caesar Augustus Germanicus p...
# 83485  Pro salute Imperatorum Caesaris Luci Septimi S...
# 83486                                 Octavius Salutaris
#
#                                     findspot year_of_find  \
# 83482                       Agios Athanasios         None
# 83483                           Stringu, bei         None
# 83484                                   None         None
# 83485  to Elleniko Mauer, sekundär verwendet         None
# 83486                      Haus der Athleten         None
#
#                    present_location                religion       geography  \
# 83482                 Fragma Kalama                    None  data available
# 83483                   Tegea, Mus.                    None            None
# 83484                          None                    None            None
# 83485  to Elleniko Mauer, vermauert  names of pagan deities            None
# 83486                          None                    None            None
#
#       social_economic_legal_history        military  not_after language  \
# 83482                          None            None      313.0    Latin
# 83483                data available            None        NaN    Latin
# 83484                          None            None       50.0    Latin
# 83485                          None  data available      209.0    Latin
# 83486                          None            None       96.0    Latin
#
#        not_before         coordinates  \
# 83482       309.0  [20.7668, 39.4512]
# 83483       276.0  [22.4171, 37.4319]
# 83484        49.0  [22.4171, 37.4319]
# 83485       198.0  [24.8323, 37.8188]
# 83486        81.0  [21.6271, 37.6479]
#
#                             clean_text_interpretive_word urban_context  \
# 83482  Fortissimo et piissimo Caesari domino nostro G...          rest
# 83483  Imperatori Caesari Marco Annio Floriano Pio Fe...           big
# 83484  Tiberius Claudius Caesar Augustus Germanicus p...           big
# 83485  Pro salute Imperatorum Caesaris Luci Septimi S...          rest
# 83486                                 Octavius Salutaris           big
#
#        within_rome nearest_city city_id_hanson  city_pop_est  \
# 83482        False       Dodona             31        1000.0
# 83483        False        Tegea             97       46362.0
# 83484        False        Tegea             97       46362.0
# 83485        False       Ioulis             47        1000.0
# 83486        False         Elis             35        1000.0
#
#                 city_geometry nearest_city_type  nearest_city_dist  \
# 83482  [20.787767, 39.546432]             minor           0.097513
# 83483  [22.417226, 37.427653]               big           0.004249
# 83484  [22.417226, 37.427653]               big           0.004249
# 83485   [24.34625, 37.633122]             minor           0.520308
# 83486  [21.435443, 37.827452]             minor           0.262624
#
#                         geometry  type_of_inscription_auto  \
# 83482  POINT (20.76680 39.45120)     honorific inscription
# 83483  POINT (22.41710 37.43190)         mile-/leaguestone
# 83484  POINT (22.41710 37.43190)  public legal inscription
# 83485  POINT (24.83230 37.81880)        votive inscription
# 83486  POINT (21.62710 37.64790)  owner/artist inscription
#
#        type_of_inscription_auto_prob
# 83482                            1.0
# 83483                            1.0
# 83484                            1.0
# 83485                            1.0
# 83486                            1.0

# %%
s.write_file("EDHCSg.geojson", EDHCS_autotypes)
# Out:
# A file with the same name ("EDHCSg.geojson") already exists in this location.
# Press Enter to overwrite it or choose different path and filename:
# Your <class 'geopandas.geodataframe.GeoDataFrame'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/EDHCS/EDHCSg.geojson"

# %%
print(test_results_df.to_markdown(tablefmt="github"))
# Out:
# |    |   threshold (=/>) |   proportion |    N |   correct |
# |----|-------------------|--------------|------|-----------|
# |  0 |              0.3  |         1    | 4601 |  0.862421 |
# |  1 |              0.35 |         0.94 | 4337 |  0.890247 |
# |  2 |              0.4  |         0.93 | 4310 |  0.8942   |
# |  3 |              0.45 |         0.91 | 4213 |  0.898647 |
# |  4 |              0.5  |         0.9  | 4162 |  0.90197  |
# |  5 |              0.55 |         0.89 | 4092 |  0.90567  |
# |  6 |              0.6  |         0.86 | 3955 |  0.908976 |
# |  7 |              0.65 |         0.84 | 3898 |  0.910723 |
# |  8 |              0.7  |         0.71 | 3264 |  0.957414 |
# |  9 |              0.75 |         0.67 | 3078 |  0.968811 |
# | 10 |              0.8  |         0.58 | 2694 |  0.971047 |
# | 11 |              0.85 |         0.51 | 2336 |  0.977312 |
# | 12 |              0.9  |         0.42 | 1957 |  0.984159 |
# | 13 |              0.95 |         0.34 | 1563 |  0.989763 |

# %%
print(model_results_df.to_markdown(tablefmt="github"))
# Out:
# |    |   threshold (=/>) |   proportion |     N |
# |----|-------------------|--------------|-------|
# |  0 |              0.3  |         0.99 | 82791 |
# |  1 |              0.35 |         0.98 | 81618 |
# |  2 |              0.4  |         0.97 | 81048 |
# |  3 |              0.45 |         0.95 | 79585 |
# |  4 |              0.5  |         0.95 | 78929 |
# |  5 |              0.55 |         0.94 | 78289 |
# |  6 |              0.6  |         0.93 | 77384 |
# |  7 |              0.65 |         0.92 | 76863 |
# |  8 |              0.7  |         0.73 | 61115 |
# |  9 |              0.75 |         0.71 | 59070 |
# | 10 |              0.8  |         0.61 | 50587 |
# | 11 |              0.85 |         0.56 | 46450 |
# | 12 |              0.9  |         0.49 | 40601 |
# | 13 |              0.95 |         0.43 | 36118 |

# %% [markdown]
# # Automatic assigment of `type_of_inscription`
#
# The EDHCS dataset consists of 137,305 inscriptions. These inscriptions might be classified as falling into certain inscription categories. However, the two source datasets (EDH and EDCS) employ a different approach to inscription classification. First of all, EDH uses English labels (e.g. "epitaph", "votive inscription" etc.), while EDCS uses Latin labels (e.g. "tituli_sepulcrales" or "tituli sacri"). In some cases, these types can be matched upon each other in a straightforward manner, in other cases this is not so simple. For instance, since the typological categories employed by EDCS are not mutually exclusive, some inscriptions are classified by means of five different labels. Furthermore, one category in the first source might correspond to several categories within the second source. For instance, the `owner/artist inscription` category in EDH corresponds either to `tituli possessionis` and `tituli fabricationis` in EDCS.
#
# Since we attempt to make the dataset as a whole accessible to cross-category comparisons, we had to decide which one of the two classification systems to employ. We decided for the EDH categories, especially because they are mutually exclusive, what makes the comparison slighthly more straitforward.
#
# However, since the EDH labels are present only for inscriptions included in the EDH dataset, we had to come up with a solution how top assign them to inscriptions from the EDCS dataset as well. This is a typical **document classification task**, which might be solved by numourous supervised machine learning methods. Here we decided for [Support Vector Machine (SVM)](https://en.wikipedia.org/wiki/Support-vector_machine) model to be trained on a subset of inscriptions which are included both in EDCS and EDH (for the whole implementation, see `scripts/3_INSCR-TYPE-AUTO.ipynb`).
#
# From the total number of 137,305 inscriptions in the EDHCS dataset, 49,916 are shared by both the EDH and EDCS dataset. From this subset, 46,171 are classified by means of the `type_of_inscription_clean` attribute  in EDH (the remaining 3,745 inscriptions are classified as `NULL`).  To build the SVM model, this constrained subset was divided into *training* and *test* datasets (90% were used to train and 10% (4,617) to test the model).
#
# The aim was to use some attributes from EDCS to classify the EDCS inscriptions according to the EDH inscription categories (e.g. as "epitaph", "votive inscription" etc.). After some experimenting, we realized that we can use information from at least three different columns:
# * `status_list`, including information about the inscription category according to EDCS combined with some other metadata
# * `Material`, containing information about the material from which the inscription is built
# * `clean_text_interpretive_word`, a preprocessed text of the inscription
#
# These three columns were used to construct 157 features to feed a TFIDF vectorizer. The features were formed by 100 most common bigrams in the texts of the inscriptions (e.g. "Dis_Manibus", "vixit_annos" or "votum_solvit"). Further, 37 were based on all unqique categories within the attribute `status_list`. Finally, 20 features were based on 20 most common categories from the `Material` attribute (e.g. "lapis", "opus_figlinae", "aes"). (Underscore was used to treat multi-word features as one word features).
#
#
# ### Model Testing
#
# For testing of the model we used 4,617 labeled inscriptions, randomly selected from 46,171 inscriptions contained both in EDH and EDCS, which have a non-empty `type_of_inscription_clean` attribute and which have not been used to  train the model.
#
# Each prediction of the SVM model is accompanied by **probability** on scale {0-1}, expressing a level of certainty concerning the predicted classification category. Thus, for instance, the inscription `EDCS-44500113` is classified as `votive inscription` with 0.919633 probability. On closer inscpection, we see that EDCS classifies this inscription as `tituli sacri`, what is probably the most important feature driving the prediction in this case.
#
# These probabilities might be used to formulate certain thresholds under which the classification will not be accepted. In Table 1, we see that 90 % of inscriptions in the test dataset has been classified with probability equal to- or higher than 0.5 and that this classification was correct in 90 % of cases. Further, approximately 71 % of inscriptions has been classified  with probability equal to- or higher than 0.7. From these more than 95 % was classified correctly. These results can inform us when we apply the model upon an unlabled dataset, where we can expect a comparable ratios between threshold values, proportions of covered inscriptions and the extent of correct classifications.
#
#
# |    |   threshold (=/>) |   proportion |    N |   correct |
# |----|-------------------|--------------|------|-----------|
# |  0 |              0.3  |         1    | 4601 |  0.862421 |
# |  1 |              0.35 |         0.94 | 4337 |  0.890247 |
# |  2 |              0.4  |         0.93 | 4310 |  0.8942   |
# |  3 |              0.45 |         0.91 | 4213 |  0.898647 |
# |  4 |              0.5  |         0.9  | 4162 |  0.90197  |
# |  5 |              0.55 |         0.89 | 4092 |  0.90567  |
# |  6 |              0.6  |         0.86 | 3955 |  0.908976 |
# |  7 |              0.65 |         0.84 | 3898 |  0.910723 |
# |  8 |              0.7  |         0.71 | 3264 |  0.957414 |
# |  9 |              0.75 |         0.67 | 3078 |  0.968811 |
# | 10 |              0.8  |         0.58 | 2694 |  0.971047 |
# | 11 |              0.85 |         0.51 | 2336 |  0.977312 |
# | 12 |              0.9  |         0.42 | 1957 |  0.984159 |
# | 13 |              0.95 |         0.34 | 1563 |  0.989763 |
#
# After testing, both the model and the vectorizer used to preprocess the data were saved as pickles for future reuse as `data/svm_model_v1.0.sav` and `data/svm_vectorizer_v1.0.sav`.
#
# ### Model application
#
# After training and testing the model on labeled data, we proceeded to apply the model on 83,482 inscriptions which are exclusively in EDCS. In this case, we cannot directly measure the proportion of correctly classified inscriptions. But we can use the data from testing to make an estimate.
#
# |    |   threshold (=/>) |   proportion |     N |
# |----|-------------------|--------------|-------|
# |  0 |              0.3  |         0.99 | 82791 |
# |  1 |              0.35 |         0.98 | 81618 |
# |  2 |              0.4  |         0.97 | 81048 |
# |  3 |              0.45 |         0.95 | 79585 |
# |  4 |              0.5  |         0.95 | 78929 |
# |  5 |              0.55 |         0.94 | 78289 |
# |  6 |              0.6  |         0.93 | 77384 |
# |  7 |              0.65 |         0.92 | 76863 |
# |  8 |              0.7  |         0.73 | 61115 |
# |  9 |              0.75 |         0.71 | 59070 |
# | 10 |              0.8  |         0.61 | 50587 |
# | 11 |              0.85 |         0.56 | 46450 |
# | 12 |              0.9  |         0.49 | 40601 |
# | 13 |              0.95 |         0.43 | 36118 |
#
#
# As a result of applying the model, we enriched the whole EDHCS dataset by 2 new attributes:
# * `type_of_inscription_auto`, containing either the predicted label or - where available - the label from `type_of_inscription_clean`
# * `type_of_inscription_auto_prob`, expressing the probability on the scale from 0 to 1 (1 is used for datapoints where the `type_of_inscription_clean` was used)
#
# When we look at the dataset as whole, we see that from the 137,305 inscriptions, 127,773 (93 %) are classified in `type_of_inscription_auto` with probability equal to- or higher than 0.55. Using the 0.55 threshold, this proportion of the dataset can be used for further comparisons.

# %%
# to train the model, we will work with a subset of the for which we have both the EDH and EDCS attributes
# we will call it EDHg
EDH_overlap_all = EDHCSg[(EDHCSg["EDH-ID"].notnull()) & (EDHCSg["EDCS-ID"].notnull())] 
EDH_overlap_all.groupby("type_of_inscription_clean").size().sort_values(ascending=False)
# Out:
# type_of_inscription_clean
# epitaph                            21520
# votive inscription                 11728
# NULL                                3745
# owner/artist inscription            3340
# honorific inscription               3003
# building/dedicatory inscription     2561
# mile-/leaguestone                   1307
# identification inscription           850
# acclamation                          287
# defixio                              269
# list                                 246
# military diploma                     209
# label                                194
# boundary inscription                 175
# elogium                              132
# letter                               119
# public legal inscription             109
# seat inscription                      42
# private legal inscription             36
# prayer                                18
# assignation inscription               15
# calendar                              10
# adnuntiatio                            1
# dtype: int64

# %%
EDHCS_autotypes.groupby("type_of_inscription_auto").size().sort_values(ascending=False)
# Out:
# type_of_inscription_auto
# epitaph                            85259
# votive inscription                 16338
# owner/artist inscription           10677
# honorific inscription               5344
# building/dedicatory inscription     3634
# mile-/leaguestone                   2798
# identification inscription          1205
# boundary inscription                 399
# acclamation                          368
# military diploma                     348
# list                                 338
# defixio                              298
# label                                220
# elogium                              141
# public legal inscription             137
# letter                               130
# seat inscription                      46
# private legal inscription             39
# assignation inscription               21
# prayer                                20
# calendar                              11
# adnuntiatio                            2
# dtype: int64
