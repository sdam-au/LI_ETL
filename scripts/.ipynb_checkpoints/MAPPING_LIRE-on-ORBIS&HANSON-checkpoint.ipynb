# %%
import sddk
import pandas as pd
import requests
pd.options.display.max_columns = 1000 # to see all columns
import json
import re
import geopandas as gpd
import warnings
from shapely.geometry import Point
from functools import partial
from shapely.ops import transform
import pyproj
warnings.filterwarnings('ignore')
import numpy as np
from scipy.spatial import cKDTree
import matplotlib.pyplot as plt
import geoplot as gplt
import networkx as nx
import numbers
from interval import interval

# %%
plt.rcParams['figure.dpi'] = 300

# %%
# read LIRE dataset from zenodo
# !!! use carefully - takes time 
LIRE = gpd.read_file("https://zenodo.org/record/5074774/files/LIREg.geojson?download=1", driver="geoJSON")
LIRE.head(5)
# Out:
#          EDCS-ID                                        publication province  \
# 0  EDCS-03700724  ZPE-108-159 = Thesprotia 00001 = AE 1993, 0140...   Achaia
# 1  EDCS-03300852                                     AE 1995, 01409   Achaia
# 2  EDCS-28500283  CIL 03, 07251 = D 00214 = NDIEC-07, p 81 = AE ...   Achaia
# 3  EDCS-09400671  CIMRM-02, 02350 = IG-12, 00274 = Andros 00124 ...   Achaia
# 4  EDCS-24600769                    AE 1995, 01407 = AE 2001, 01812   Achaia
#
#   province_list                                       place  \
# 0        Achaia                  Agios Athanasios / Photike
# 1        Achaia                                Alea / Tegea
# 2        Achaia                                Alea / Tegea
# 3        Achaia                                      Andros
# 4        Achaia  Archea Olimpia / Archaia Olympia / Olympia
#
#                                          place_list end_yr_list  \
# 0                   ['Agios Athanasios', 'Photike']         313
# 1                                 ['Alea', 'Tegea']         276
# 2                                 ['Alea', 'Tegea']          50
# 3                                            Andros         209
# 4  ['Archea Olimpia', 'Archaia Olympia', 'Olympia']          96
#
#                              notes_dating  \
# 0
# 1  to 276;   b:  276 to 282         \n\n
# 2
# 3
# 4
#
#                                          status_list        inscr_type  \
# 0  ['Augusti/Augustae', 'litterae erasae', 'ordo ...  tituli honorarii
# 1           ['Augusti/Augustae', 'miliaria', 'viri']          miliaria
# 2              ['Augusti/Augustae', 'leges', 'viri']             leges
# 3                ['litterae erasae', 'tituli sacri']      tituli sacri
# 4                                                { }               { }
#
#                                      status_notation    inscr_process  \
# 0  ['Augusti/Augustae', 'ordo equester', 'tria no...  litterae erasae
# 1                       ['Augusti/Augustae', 'viri']              { }
# 2                       ['Augusti/Augustae', 'viri']              { }
# 3                                                { }  litterae erasae
# 4                                                { }              { }
#
#   notes_references notes_comments  \
# 0
# 1
# 2
# 3
# 4
#
#                                          inscription  \
# 0  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 1  to 276;   b:  276 to 282         \n\n \n \nImp...
# 2  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 3  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 4                             Octa(vius) Sa(lutaris)
#
#                           inscription_stripped_final  \
# 0  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 1  Imp(eratori) / Floriano / P(io) F(elici) Aug(u...
# 2  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 3  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 4                             Octa(vius) Sa(lutaris)
#
#                                                Links  dating from dating to  \
# 0  http://db.edcs.eu/epigr/partner.php?s_language...        309.0       313
# 1  http://db.edcs.eu/epigr/partner.php?s_language...          NaN       276
# 2  http://db.edcs.eu/epigr/partner.php?s_language...         49.0        50
# 3  http://db.edcs.eu/epigr/partner.php?s_language...        198.0       209
# 4  http://db.edcs.eu/epigr/partner.php?s_language...         81.0        96
#
#                                               status   Latitude  Longitude  \
# 0  Augusti/Augustae; litterae erasae; ordo equest...  39.451218  20.766767
# 1                   Augusti/Augustae; miliaria; viri  37.454501  22.420877
# 2                      Augusti/Augustae; leges; viri  37.454501  22.420877
# 3                      litterae erasae; tituli sacri  37.837612  24.937637
# 4                                               None  37.643870  21.625513
#
#                                                photo Material Comment  \
# 0  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None    None
# 1                                               None    lapis    None
# 2                                               None     None    None
# 3  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None    None
# 4                                               None     None    None
#
#      EDH-ID language_EDCS                  clean_text_interpretive_word_EDCS  \
# 0  HD052964          None  Fortissimo et Piissimo Caesari domino nostro G...
# 1  HD051000          None  Imperatori Floriano Pio Felici Augusto patri p...
# 2  HD021396          None  Tiberius Claudius Caesar Augustus Germanicus p...
# 3  HD011892          None  Pro salute Imperatoris Caesaris Luci Septimi S...
# 4  HD050999          None                                 Octavius Salutaris
#
#   responsible_individual       type_of_inscription letter_size  \
# 0                  Cowey     honorific inscription    3-5.3 cm
# 1                  Cowey         mile-/leaguestone    3.3-6 cm
# 2                  Cowey  public legal inscription        None
# 3                  Cowey        votive inscription  5.5-5.7 cm
# 4                  Cowey  owner/artist inscription        None
#
#                                           literature         work_status  \
# 0  AE 1993, 1406.; V. Papadopoulou, AD 43 B, 1988...  checked with photo
# 1  AE 1995, 1409.; M. Iozzer - M. Pangano, ASAA 6...  checked with photo
# 2  CIL 03, 07251.; ILS 0214.; AE 1941, 0119.; MAI...  checked with photo
# 3  AE 1911, 0056. (B); T. Sauciuc, MDAI(R) 25, 19...  checked with photo
# 4  AE 1995, 1407.; U. Sinn u. a., Nikephoros 8, 1...  checked with photo
#
#     height                                    diplomatic_text  \
# 0    99 cm  FORTISSIMO ET PIIS / SIMO CAESARI D N / GAL VA...
# 1  (44) cm  [ ] / AN[ ] FLORIANO / P F AVG / P P / M P III...
# 2   160 cm  T[ ] CLAVDIVS CAESAR AVG / G[ ]ANICVS PONTIF M...
# 3    48 cm  PRO SALVTE IMP CAESARI / L SEPTIMI SEVERI ET M...
# 4     None                                           OCTA SAL
#
#                                               people  depth material  \
# 0  [{'name': 'Gal. Val. [[Maximiano]]', 'nomen': ...  67 cm     None
# 1  [{'person_id': '1', 'nomen': 'Annius+', 'name'...   None     None
# 2  [{'gender': 'male', 'cognomen': 'Caesar August...  17 cm     None
# 3  [{'gender': 'male', 'praenomen': 'L.', 'name':...   None     None
# 4  [{'person_id': '1', 'nomen': 'Octavius*', 'nam...   None     None
#
#           type_of_monument province_label   width  \
# 0              statue base         Epirus   67 cm
# 1        mile-/leaguestone         Achaia   24 cm
# 2                   tabula         Achaia   58 cm
# 3                     None         Achaia  126 cm
# 4  instrumentum domesticum         Achaia    None
#
#                                        transcription country  \
# 0  Fortissimo et piis/simo Caesari d(omino) n(ost...  Greece
# 1  [Imp(eratori) Caes(ari) M(arco)] / An[nio] Flo...  Greece
# 2  T[i(berius)] Claudius Caesar Aug(ustus) / G[er...  Greece
# 3  Pro salute Imp(eratorum) Caesari(s) / L(uci) S...  Greece
# 4                             Octa(vius) Sal(utaris)  Greece
#
#                                                  uri findspot_ancient  \
# 0  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Photike
# 1  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 2  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 3  https://edh-www.adw.uni-heidelberg.de/edh/insc...      Palaeopolis
# 4  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Olympia
#
#   last_update  modern_region findspot_modern  \
# 0  2014-09-16        Ípeiros      Paramythía
# 1  2011-05-24   Pelopónissos            Alea
# 2  2011-05-10   Pelopónissos            Alea
# 3  2017-05-30   Nótio Aigaío     Palaiópolis
# 4  2012-04-16  Stereá Elláda         Olympia
#
#                                    edh_geography_uri  \
# 0  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 1  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 2  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 3  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 4  https://edh-www.adw.uni-heidelberg.de/edh/geog...
#
#                                           commentary  \
# 0                                               None
# 1   Die erste Inschrift ist auf 276, die zweite a...
# 2                                               None
# 3   Auf dem Foto sind die Buchstaben oft kaum erk...
# 4       (B): Sa(lutaris) fehlerhaft für Sal(utaris).
#
#                            trismegistos_uri external_image_uris fotos idno_tm  \
# 0  https://www.trismegistos.org/text/121715                 { }   { }  121715
# 1  https://www.trismegistos.org/text/177273                 { }   { }  177273
# 2  https://www.trismegistos.org/text/177131                 { }   { }  177131
# 3  https://www.trismegistos.org/text/177087                 { }   { }  177087
# 4  https://www.trismegistos.org/text/177272                 { }   { }  177272
#
#                                      placenames_refs  \
# 0  ['http://www.trismegistos.org/place/000655', '...
# 1  ['http://www.trismegistos.org/place/000078', '...
# 2  ['http://www.trismegistos.org/place/000078', '...
# 3                                                 []
# 4  ['http://www.trismegistos.org/place/000078', '...
#
#                                         text_edition  \
# 0                  Fortissimo et piissimo Caesari...
# 1  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 2                  Tiberius Claudius Caesar Augus...
# 3                  Pro salute Imperatorum Caesari...
# 4                                 Octavius Salutaris
#
#                                  origdate_text layout_execution  \
# 0  309 AD – 313 AD                                           21
# 1           276 AD                                           21
# 2    49 AD – 50 AD                                           21
# 3  198 AD – 209 AD                                           21
# 4    81 AD – 96 AD                                           21
#
#   layout_execution_text  support_objecttype  support_objecttype_text  \
# 0            unbestimmt                57.0             Statuenbasis
# 1            unbestimmt                89.0      Meilen-/Leugenstein
# 2            unbestimmt               257.0                    Tafel
# 3            unbestimmt                 2.0               unbestimmt
# 4            unbestimmt               140.0  Instrumentum domesticum
#
#   support_material support_material_text  support_decoration keywords_term  \
# 0              138            unbestimmt              1000.0            69
# 1              138            unbestimmt              1000.0           102
# 2              138            unbestimmt              1000.0
# 3              138            unbestimmt              1000.0            80
# 4              138            unbestimmt              1000.0           311
#
#                  keywords_term_text type_of_inscription_clean  \
# 0                    Ehreninschrift     honorific inscription
# 1               Meilen-/Leugenstein         mile-/leaguestone
# 2  Rechtliche Verfügung, öffentlich  public legal inscription
# 3                     Weihinschrift        votive inscription
# 4     Besitzer-/Herstellerinschrift  owner/artist inscription
#
#   type_of_inscription_certainty  height_cm  width_cm  depth_cm material_clean  \
# 0                       Certain       99.0      67.0      67.0           NULL
# 1                       Certain       44.0      24.0       NaN           NULL
# 2                       Certain      160.0      58.0      17.0           NULL
# 3                       Certain       48.0     126.0       NaN           NULL
# 4                       Certain        NaN       NaN       NaN           NULL
#
#     type_of_monument_clean type_of_monument_certainty province_label_clean  \
# 0              statue base                    Certain               Epirus
# 1        mile-/leaguestone                    Certain               Achaia
# 2                   tabula                    Certain               Achaia
# 3                     NULL                       NULL               Achaia
# 4  instrumentum domesticum                    Certain               Achaia
#
#   province_label_certainty country_clean country_certainty  \
# 0                  Certain        Greece           Certain
# 1                  Certain        Greece           Certain
# 2                  Certain        Greece           Certain
# 3                  Certain        Greece           Certain
# 4                  Certain        Greece           Certain
#
#   findspot_ancient_clean findspot_ancient_certainty modern_region_clean  \
# 0                Photike                    Certain             Ípeiros
# 1                  Tegea                    Certain        Pelopónissos
# 2                  Tegea                    Certain        Pelopónissos
# 3            Palaeopolis                    Certain        Nótio Aigaío
# 4                Olympia                    Certain       Stereá Elláda
#
#   modern_region_certainty findspot_modern_clean findspot_modern_certainty  \
# 0                 Certain            Paramythía                   Certain
# 1                 Certain                  Alea                   Certain
# 2                 Certain                  Alea                   Certain
# 3                 Certain           Palaiópolis                   Certain
# 4                 Certain               Olympia                   Certain
#
#                           findspot_clean findspot_certainty  \
# 0                       Agios Athanasios            Certain
# 1                           Stringu, bei            Certain
# 2                                   NULL               NULL
# 3  to Elleniko Mauer, sekundär verwendet            Certain
# 4                      Haus der Athleten            Certain
#
#   origdate_text_clean                            clean_text_conservative  \
# 0     309 AD – 313 AD  Fortissimo et piissimo Caesari d n Gal Val P F...
# 1              276 AD  An Floriano P F Aug p p m p III Imp Caes M Aur...
# 2       49 AD – 50 AD  T Claudius Caesar Aug Ganicus pontif max trib ...
# 3     198 AD – 209 AD  Pro salute Imp Caesari L Septimi Severi et M A...
# 4       81 AD – 96 AD                                           Octa Sal
#
#                     clean_text_interpretive_sentence  \
# 0  Fortissimo et piissimo Caesari domino nostro G...
# 1  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 2  Tiberius Claudius Caesar Augustus Germanicus p...
# 3  Pro salute Imperatorum Caesaris Luci Septimi S...
# 4                                 Octavius Salutaris
#
#                                 findspot year_of_find  \
# 0                       Agios Athanasios         None
# 1                           Stringu, bei         None
# 2                                   None         None
# 3  to Elleniko Mauer, sekundär verwendet         None
# 4                      Haus der Athleten         None
#
#                present_location                religion       geography  \
# 0                 Fragma Kalama                    None  data available
# 1                   Tegea, Mus.                    None            None
# 2                          None                    None            None
# 3  to Elleniko Mauer, vermauert  names of pagan deities            None
# 4                          None                    None            None
#
#   social_economic_legal_history        military  not_after language  \
# 0                          None            None      313.0    Latin
# 1                data available            None        NaN    Latin
# 2                          None            None       50.0    Latin
# 3                          None  data available      209.0    Latin
# 4                          None            None       96.0    Latin
#
#    not_before         coordinates  \
# 0       309.0  [20.7668, 39.4512]
# 1       276.0  [22.4171, 37.4319]
# 2        49.0  [22.4171, 37.4319]
# 3       198.0  [24.8323, 37.8188]
# 4        81.0  [21.6271, 37.6479]
#
#                         clean_text_interpretive_word urban_context  \
# 0  Fortissimo et piissimo Caesari domino nostro G...          rest
# 1  Imperatori Caesari Marco Annio Floriano Pio Fe...           big
# 2  Tiberius Claudius Caesar Augustus Germanicus p...           big
# 3  Pro salute Imperatorum Caesaris Luci Septimi S...          rest
# 4                                 Octavius Salutaris           big
#
#    within_rome nearest_city city_id_hanson  city_pop_est  \
# 0        False       Dodona             31        1000.0
# 1        False        Tegea             97       46362.0
# 2        False        Tegea             97       46362.0
# 3        False       Ioulis             47        1000.0
# 4        False         Elis             35        1000.0
#
#             city_geometry nearest_city_type  nearest_city_dist  \
# 0  [20.787767, 39.546432]             minor           0.097513
# 1  [22.417226, 37.427653]               big           0.004249
# 2  [22.417226, 37.427653]               big           0.004249
# 3   [24.34625, 37.633122]             minor           0.520308
# 4  [21.435443, 37.827452]             minor           0.262624
#
#    type_of_inscription_auto  type_of_inscription_auto_prob  \
# 0     honorific inscription                            1.0
# 1         mile-/leaguestone                            1.0
# 2  public legal inscription                            1.0
# 3        votive inscription                            1.0
# 4  owner/artist inscription                            1.0
#
#                     geometry
# 0  POINT (20.76680 39.45120)
# 1  POINT (22.41710 37.43190)
# 2  POINT (22.41710 37.43190)
# 3  POINT (24.83230 37.81880)
# 4  POINT (21.62710 37.64790)

# %%
orbis_hanson_gpd = gpd.read_parquet("../data/orbis_hanson_gpd.par")
orbis_hanson_gpd.head(5)
# Out:
#         id                      label       x       y  \
# 521  50474              Portus Magnus  35.808  -0.266
# 458  50418                     Vienna  45.524   4.878
# 210  50131                    Corduba  37.884  -4.780
# 319  50172                   Faventia  44.285  11.883
# 109  50125  Ulpia Traiana Tricensimae  51.668   6.445
#
#                       geometry           hanson_label hanson_ID  pop_est  \
# 521  POINT (-0.26600 35.80800)          Portus Magnus      1182   1000.0
# 458   POINT (4.87800 45.52400)                 Vienna       658  15332.0
# 210  POINT (-4.78000 37.88400)                Corduba       336  19404.0
# 319  POINT (11.88300 44.28500)               Faventia      1014   5399.0
# 109   POINT (6.44500 51.66800)  Colonia Ulpia Traiana       661  14596.0
#
#                  hanson_geo      dist
# 521  [-0.266018, 35.807917]  0.000085
# 458   [4.878056, 45.524167]  0.000176
# 210    [-4.78025, 37.88376]  0.000347
# 319  [11.882989, 44.285348]  0.000348
# 109   [6.444591, 51.668014]  0.000409

# %% [markdown]
# # Map inscriptions on orbis sites

# %%
def ckdnearest(inscriptions, sites_gdf):
    sites_gdf = sites_gdf[["id", "geometry"]] 
    sites_gdf.rename(columns={"id" : "orbis_id"}, inplace=True)
    nA = np.array(list(inscriptions.geometry.apply(lambda x: (x.x, x.y))))
    nB = np.array(list(sites_gdf.geometry.apply(lambda x: (x.x, x.y))))
    btree = cKDTree(nB)
    dist, idx = btree.query(nA, k=1)
    gdB_nearest = sites_gdf.iloc[idx].rename(columns={"geometry": "city_geometry"}).reset_index(drop=True)
    gdB_nearest["city_geometry"] = [[geom.x, geom.y] for geom in gdB_nearest["city_geometry"]]
    gdf = pd.concat(
        [
            inscriptions.reset_index(drop=True),
            gdB_nearest,
            pd.Series(dist, name='orbis_site_dist')
        ], 
        axis=1)
    return gdf

#ckdnearest(gpd1, gpd2)

# %%
# %%time
LIRE = ckdnearest(LIRE, orbis_hanson_gpd)
LIRE.head(5)
# Out:
# CPU times: user 5.74 s, sys: 207 ms, total: 5.95 s
# Wall time: 5.95 s
#          EDCS-ID                                        publication province  \
# 0  EDCS-03700724  ZPE-108-159 = Thesprotia 00001 = AE 1993, 0140...   Achaia
# 1  EDCS-03300852                                     AE 1995, 01409   Achaia
# 2  EDCS-28500283  CIL 03, 07251 = D 00214 = NDIEC-07, p 81 = AE ...   Achaia
# 3  EDCS-09400671  CIMRM-02, 02350 = IG-12, 00274 = Andros 00124 ...   Achaia
# 4  EDCS-24600769                    AE 1995, 01407 = AE 2001, 01812   Achaia
#
#   province_list                                       place  \
# 0        Achaia                  Agios Athanasios / Photike
# 1        Achaia                                Alea / Tegea
# 2        Achaia                                Alea / Tegea
# 3        Achaia                                      Andros
# 4        Achaia  Archea Olimpia / Archaia Olympia / Olympia
#
#                                          place_list end_yr_list  \
# 0                   ['Agios Athanasios', 'Photike']         313
# 1                                 ['Alea', 'Tegea']         276
# 2                                 ['Alea', 'Tegea']          50
# 3                                            Andros         209
# 4  ['Archea Olimpia', 'Archaia Olympia', 'Olympia']          96
#
#                              notes_dating  \
# 0
# 1  to 276;   b:  276 to 282         \n\n
# 2
# 3
# 4
#
#                                          status_list        inscr_type  \
# 0  ['Augusti/Augustae', 'litterae erasae', 'ordo ...  tituli honorarii
# 1           ['Augusti/Augustae', 'miliaria', 'viri']          miliaria
# 2              ['Augusti/Augustae', 'leges', 'viri']             leges
# 3                ['litterae erasae', 'tituli sacri']      tituli sacri
# 4                                                { }               { }
#
#                                      status_notation    inscr_process  \
# 0  ['Augusti/Augustae', 'ordo equester', 'tria no...  litterae erasae
# 1                       ['Augusti/Augustae', 'viri']              { }
# 2                       ['Augusti/Augustae', 'viri']              { }
# 3                                                { }  litterae erasae
# 4                                                { }              { }
#
#   notes_references notes_comments  \
# 0
# 1
# 2
# 3
# 4
#
#                                          inscription  \
# 0  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 1  to 276;   b:  276 to 282         \n\n \n \nImp...
# 2  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 3  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 4                             Octa(vius) Sa(lutaris)
#
#                           inscription_stripped_final  \
# 0  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 1  Imp(eratori) / Floriano / P(io) F(elici) Aug(u...
# 2  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 3  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 4                             Octa(vius) Sa(lutaris)
#
#                                                Links  dating from dating to  \
# 0  http://db.edcs.eu/epigr/partner.php?s_language...        309.0       313
# 1  http://db.edcs.eu/epigr/partner.php?s_language...          NaN       276
# 2  http://db.edcs.eu/epigr/partner.php?s_language...         49.0        50
# 3  http://db.edcs.eu/epigr/partner.php?s_language...        198.0       209
# 4  http://db.edcs.eu/epigr/partner.php?s_language...         81.0        96
#
#                                               status   Latitude  Longitude  \
# 0  Augusti/Augustae; litterae erasae; ordo equest...  39.451218  20.766767
# 1                   Augusti/Augustae; miliaria; viri  37.454501  22.420877
# 2                      Augusti/Augustae; leges; viri  37.454501  22.420877
# 3                      litterae erasae; tituli sacri  37.837612  24.937637
# 4                                               None  37.643870  21.625513
#
#                                                photo Material Comment  \
# 0  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None    None
# 1                                               None    lapis    None
# 2                                               None     None    None
# 3  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None    None
# 4                                               None     None    None
#
#      EDH-ID language_EDCS                  clean_text_interpretive_word_EDCS  \
# 0  HD052964          None  Fortissimo et Piissimo Caesari domino nostro G...
# 1  HD051000          None  Imperatori Floriano Pio Felici Augusto patri p...
# 2  HD021396          None  Tiberius Claudius Caesar Augustus Germanicus p...
# 3  HD011892          None  Pro salute Imperatoris Caesaris Luci Septimi S...
# 4  HD050999          None                                 Octavius Salutaris
#
#   responsible_individual       type_of_inscription letter_size  \
# 0                  Cowey     honorific inscription    3-5.3 cm
# 1                  Cowey         mile-/leaguestone    3.3-6 cm
# 2                  Cowey  public legal inscription        None
# 3                  Cowey        votive inscription  5.5-5.7 cm
# 4                  Cowey  owner/artist inscription        None
#
#                                           literature         work_status  \
# 0  AE 1993, 1406.; V. Papadopoulou, AD 43 B, 1988...  checked with photo
# 1  AE 1995, 1409.; M. Iozzer - M. Pangano, ASAA 6...  checked with photo
# 2  CIL 03, 07251.; ILS 0214.; AE 1941, 0119.; MAI...  checked with photo
# 3  AE 1911, 0056. (B); T. Sauciuc, MDAI(R) 25, 19...  checked with photo
# 4  AE 1995, 1407.; U. Sinn u. a., Nikephoros 8, 1...  checked with photo
#
#     height                                    diplomatic_text  \
# 0    99 cm  FORTISSIMO ET PIIS / SIMO CAESARI D N / GAL VA...
# 1  (44) cm  [ ] / AN[ ] FLORIANO / P F AVG / P P / M P III...
# 2   160 cm  T[ ] CLAVDIVS CAESAR AVG / G[ ]ANICVS PONTIF M...
# 3    48 cm  PRO SALVTE IMP CAESARI / L SEPTIMI SEVERI ET M...
# 4     None                                           OCTA SAL
#
#                                               people  depth material  \
# 0  [{'name': 'Gal. Val. [[Maximiano]]', 'nomen': ...  67 cm     None
# 1  [{'person_id': '1', 'nomen': 'Annius+', 'name'...   None     None
# 2  [{'gender': 'male', 'cognomen': 'Caesar August...  17 cm     None
# 3  [{'gender': 'male', 'praenomen': 'L.', 'name':...   None     None
# 4  [{'person_id': '1', 'nomen': 'Octavius*', 'nam...   None     None
#
#           type_of_monument province_label   width  \
# 0              statue base         Epirus   67 cm
# 1        mile-/leaguestone         Achaia   24 cm
# 2                   tabula         Achaia   58 cm
# 3                     None         Achaia  126 cm
# 4  instrumentum domesticum         Achaia    None
#
#                                        transcription country  \
# 0  Fortissimo et piis/simo Caesari d(omino) n(ost...  Greece
# 1  [Imp(eratori) Caes(ari) M(arco)] / An[nio] Flo...  Greece
# 2  T[i(berius)] Claudius Caesar Aug(ustus) / G[er...  Greece
# 3  Pro salute Imp(eratorum) Caesari(s) / L(uci) S...  Greece
# 4                             Octa(vius) Sal(utaris)  Greece
#
#                                                  uri findspot_ancient  \
# 0  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Photike
# 1  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 2  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 3  https://edh-www.adw.uni-heidelberg.de/edh/insc...      Palaeopolis
# 4  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Olympia
#
#   last_update  modern_region findspot_modern  \
# 0  2014-09-16        Ípeiros      Paramythía
# 1  2011-05-24   Pelopónissos            Alea
# 2  2011-05-10   Pelopónissos            Alea
# 3  2017-05-30   Nótio Aigaío     Palaiópolis
# 4  2012-04-16  Stereá Elláda         Olympia
#
#                                    edh_geography_uri  \
# 0  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 1  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 2  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 3  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 4  https://edh-www.adw.uni-heidelberg.de/edh/geog...
#
#                                           commentary  \
# 0                                               None
# 1   Die erste Inschrift ist auf 276, die zweite a...
# 2                                               None
# 3   Auf dem Foto sind die Buchstaben oft kaum erk...
# 4       (B): Sa(lutaris) fehlerhaft für Sal(utaris).
#
#                            trismegistos_uri external_image_uris fotos idno_tm  \
# 0  https://www.trismegistos.org/text/121715                 { }   { }  121715
# 1  https://www.trismegistos.org/text/177273                 { }   { }  177273
# 2  https://www.trismegistos.org/text/177131                 { }   { }  177131
# 3  https://www.trismegistos.org/text/177087                 { }   { }  177087
# 4  https://www.trismegistos.org/text/177272                 { }   { }  177272
#
#                                      placenames_refs  \
# 0  ['http://www.trismegistos.org/place/000655', '...
# 1  ['http://www.trismegistos.org/place/000078', '...
# 2  ['http://www.trismegistos.org/place/000078', '...
# 3                                                 []
# 4  ['http://www.trismegistos.org/place/000078', '...
#
#                                         text_edition  \
# 0                  Fortissimo et piissimo Caesari...
# 1  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 2                  Tiberius Claudius Caesar Augus...
# 3                  Pro salute Imperatorum Caesari...
# 4                                 Octavius Salutaris
#
#                                  origdate_text layout_execution  \
# 0  309 AD – 313 AD                                           21
# 1           276 AD                                           21
# 2    49 AD – 50 AD                                           21
# 3  198 AD – 209 AD                                           21
# 4    81 AD – 96 AD                                           21
#
#   layout_execution_text  support_objecttype  support_objecttype_text  \
# 0            unbestimmt                57.0             Statuenbasis
# 1            unbestimmt                89.0      Meilen-/Leugenstein
# 2            unbestimmt               257.0                    Tafel
# 3            unbestimmt                 2.0               unbestimmt
# 4            unbestimmt               140.0  Instrumentum domesticum
#
#   support_material support_material_text  support_decoration keywords_term  \
# 0              138            unbestimmt              1000.0            69
# 1              138            unbestimmt              1000.0           102
# 2              138            unbestimmt              1000.0
# 3              138            unbestimmt              1000.0            80
# 4              138            unbestimmt              1000.0           311
#
#                  keywords_term_text type_of_inscription_clean  \
# 0                    Ehreninschrift     honorific inscription
# 1               Meilen-/Leugenstein         mile-/leaguestone
# 2  Rechtliche Verfügung, öffentlich  public legal inscription
# 3                     Weihinschrift        votive inscription
# 4     Besitzer-/Herstellerinschrift  owner/artist inscription
#
#   type_of_inscription_certainty  height_cm  width_cm  depth_cm material_clean  \
# 0                       Certain       99.0      67.0      67.0           NULL
# 1                       Certain       44.0      24.0       NaN           NULL
# 2                       Certain      160.0      58.0      17.0           NULL
# 3                       Certain       48.0     126.0       NaN           NULL
# 4                       Certain        NaN       NaN       NaN           NULL
#
#     type_of_monument_clean type_of_monument_certainty province_label_clean  \
# 0              statue base                    Certain               Epirus
# 1        mile-/leaguestone                    Certain               Achaia
# 2                   tabula                    Certain               Achaia
# 3                     NULL                       NULL               Achaia
# 4  instrumentum domesticum                    Certain               Achaia
#
#   province_label_certainty country_clean country_certainty  \
# 0                  Certain        Greece           Certain
# 1                  Certain        Greece           Certain
# 2                  Certain        Greece           Certain
# 3                  Certain        Greece           Certain
# 4                  Certain        Greece           Certain
#
#   findspot_ancient_clean findspot_ancient_certainty modern_region_clean  \
# 0                Photike                    Certain             Ípeiros
# 1                  Tegea                    Certain        Pelopónissos
# 2                  Tegea                    Certain        Pelopónissos
# 3            Palaeopolis                    Certain        Nótio Aigaío
# 4                Olympia                    Certain       Stereá Elláda
#
#   modern_region_certainty findspot_modern_clean findspot_modern_certainty  \
# 0                 Certain            Paramythía                   Certain
# 1                 Certain                  Alea                   Certain
# 2                 Certain                  Alea                   Certain
# 3                 Certain           Palaiópolis                   Certain
# 4                 Certain               Olympia                   Certain
#
#                           findspot_clean findspot_certainty  \
# 0                       Agios Athanasios            Certain
# 1                           Stringu, bei            Certain
# 2                                   NULL               NULL
# 3  to Elleniko Mauer, sekundär verwendet            Certain
# 4                      Haus der Athleten            Certain
#
#   origdate_text_clean                            clean_text_conservative  \
# 0     309 AD – 313 AD  Fortissimo et piissimo Caesari d n Gal Val P F...
# 1              276 AD  An Floriano P F Aug p p m p III Imp Caes M Aur...
# 2       49 AD – 50 AD  T Claudius Caesar Aug Ganicus pontif max trib ...
# 3     198 AD – 209 AD  Pro salute Imp Caesari L Septimi Severi et M A...
# 4       81 AD – 96 AD                                           Octa Sal
#
#                     clean_text_interpretive_sentence  \
# 0  Fortissimo et piissimo Caesari domino nostro G...
# 1  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 2  Tiberius Claudius Caesar Augustus Germanicus p...
# 3  Pro salute Imperatorum Caesaris Luci Septimi S...
# 4                                 Octavius Salutaris
#
#                                 findspot year_of_find  \
# 0                       Agios Athanasios         None
# 1                           Stringu, bei         None
# 2                                   None         None
# 3  to Elleniko Mauer, sekundär verwendet         None
# 4                      Haus der Athleten         None
#
#                present_location                religion       geography  \
# 0                 Fragma Kalama                    None  data available
# 1                   Tegea, Mus.                    None            None
# 2                          None                    None            None
# 3  to Elleniko Mauer, vermauert  names of pagan deities            None
# 4                          None                    None            None
#
#   social_economic_legal_history        military  not_after language  \
# 0                          None            None      313.0    Latin
# 1                data available            None        NaN    Latin
# 2                          None            None       50.0    Latin
# 3                          None  data available      209.0    Latin
# 4                          None            None       96.0    Latin
#
#    not_before         coordinates  \
# 0       309.0  [20.7668, 39.4512]
# 1       276.0  [22.4171, 37.4319]
# 2        49.0  [22.4171, 37.4319]
# 3       198.0  [24.8323, 37.8188]
# 4        81.0  [21.6271, 37.6479]
#
#                         clean_text_interpretive_word urban_context  \
# 0  Fortissimo et piissimo Caesari domino nostro G...          rest
# 1  Imperatori Caesari Marco Annio Floriano Pio Fe...           big
# 2  Tiberius Claudius Caesar Augustus Germanicus p...           big
# 3  Pro salute Imperatorum Caesaris Luci Septimi S...          rest
# 4                                 Octavius Salutaris           big
#
#    within_rome nearest_city city_id_hanson  city_pop_est  \
# 0        False       Dodona             31        1000.0
# 1        False        Tegea             97       46362.0
# 2        False        Tegea             97       46362.0
# 3        False       Ioulis             47        1000.0
# 4        False         Elis             35        1000.0
#
#             city_geometry nearest_city_type  nearest_city_dist  \
# 0  [20.787767, 39.546432]             minor           0.097513
# 1  [22.417226, 37.427653]               big           0.004249
# 2  [22.417226, 37.427653]               big           0.004249
# 3   [24.34625, 37.633122]             minor           0.520308
# 4  [21.435443, 37.827452]             minor           0.262624
#
#    type_of_inscription_auto  type_of_inscription_auto_prob  \
# 0     honorific inscription                            1.0
# 1         mile-/leaguestone                            1.0
# 2  public legal inscription                            1.0
# 3        votive inscription                            1.0
# 4  owner/artist inscription                            1.0
#
#                     geometry  orbis_id     city_geometry  orbis_site_dist
# 0  POINT (20.76680 39.45120)     50273  [20.735, 39.007]         0.445337
# 1  POINT (22.41710 37.43190)     50549  [22.886, 37.912]         0.671091
# 2  POINT (22.41710 37.43190)     50549  [22.886, 37.912]         0.671091
# 3  POINT (24.83230 37.81880)     50778  [24.933, 37.833]         0.101696
# 4  POINT (21.62710 37.64790)     50542    [21.45, 37.61]         0.181110

# %%
# testing overlap between two intervals
# len 0 = no overlap
# len 1 = overlap
not_before, not_after = 0, 300
period_start, period_end = 101, 200
len(interval[period_start, period_end] & interval[not_before, not_after])
# Out:
# 1

# %%
def temporal_overlap(period_start, period_end, inscr_start, inscr_end):
    if np.isnan(inscr_start):
        inscr_start = inscr_end
    if np.isnan(inscr_end):
        inscr_end = inscr_start
    if len(interval[period_start, period_end] & interval[inscr_start, inscr_end]) > 0:
        return True
    else:
        return False

# %%
# %%time
LIRE_period1 = LIRE[LIRE.apply(lambda row: temporal_overlap(1, 100, row["not_before"], row["not_after"]), axis=1)] 
LIRE_period2 = LIRE[LIRE.apply(lambda row: temporal_overlap(101, 200, row["not_before"], row["not_after"]), axis=1)] 
LIRE_period3 = LIRE[LIRE.apply(lambda row: temporal_overlap(201, 300, row["not_before"], row["not_after"]), axis=1)]
# Out:
# CPU times: user 26.2 s, sys: 269 ms, total: 26.4 s
# Wall time: 26.4 s

# %%
for per in [LIRE_period1, LIRE_period2, LIRE_period3]:
    print(len(per))
# Out:
# 56000
# 67838
# 43973

# %%
def get_inscr_ids(orbis_id, source, LIRE_period):
    LIRE_subset = LIRE_period[LIRE_period["orbis_id"]==orbis_id]
    if source == "EDCS":
        ids = LIRE_subset[LIRE_subset["EDCS-ID"].notnull() & LIRE_subset["EDH-ID"].isnull()]["EDCS-ID"].tolist()
    else:
        ids = LIRE_subset[LIRE_subset["EDH-ID"].notnull()]["EDH-ID"].tolist()
    return ids

# %%
get_inscr_ids(50474, "EDH", LIRE_period3)
# Out:
# ['HD033385',
#  'HD000463',
#  'HD052542',
#  'HD033325',
#  'HD033415',
#  'HD033388',
#  'HD030633']

# %%
orbis_hanson_gpd.head(5)
# Out:
#         id                      label       x       y  \
# 521  50474              Portus Magnus  35.808  -0.266
# 458  50418                     Vienna  45.524   4.878
# 210  50131                    Corduba  37.884  -4.780
# 319  50172                   Faventia  44.285  11.883
# 109  50125  Ulpia Traiana Tricensimae  51.668   6.445
#
#                       geometry           hanson_label hanson_ID  pop_est  \
# 521  POINT (-0.26600 35.80800)          Portus Magnus      1182   1000.0
# 458   POINT (4.87800 45.52400)                 Vienna       658  15332.0
# 210  POINT (-4.78000 37.88400)                Corduba       336  19404.0
# 319  POINT (11.88300 44.28500)               Faventia      1014   5399.0
# 109   POINT (6.44500 51.66800)  Colonia Ulpia Traiana       661  14596.0
#
#                  hanson_geo      dist
# 521  [-0.266018, 35.807917]  0.000085
# 458   [4.878056, 45.524167]  0.000176
# 210    [-4.78025, 37.88376]  0.000347
# 319  [11.882989, 44.285348]  0.000348
# 109   [6.444591, 51.668014]  0.000409

# %%
orbis_hanson_gpd["EDH_all"] = orbis_hanson_gpd["id"].apply(lambda x: get_inscr_ids(x, "EDH", LIRE))
orbis_hanson_gpd["EDCS_all"] = orbis_hanson_gpd["id"].apply(lambda x: get_inscr_ids(x, "EDCS", LIRE))

# %%
orbis_hanson_gpd["LIRE_total_N"] = orbis_hanson_gpd.apply(lambda row: len(row["EDH_all"])+len(row["EDCS_all"]), axis=1)

# %%
orbis_hanson_gpd.sort_values("pop_est", ascending=False).head(5)
# Out:
#         id         label       x       y                   geometry  \
# 2    50327          Roma  41.891  12.485  POINT (12.48500 41.89100)
# 164  50017    Alexandria  31.200  29.910  POINT (29.91000 31.20000)
# 359  50230  Lepcis Magna  32.637  14.292  POINT (14.29200 32.63700)
# 433  50613        Rhodos  36.440  28.230  POINT (28.23000 36.44000)
# 302  50024     Antiochia  36.208  36.169  POINT (36.16900 36.20800)
#
#               hanson_label hanson_ID   pop_est  \
# 2                     Roma       992  923313.0
# 164  Alexandria (Aegyptus)       110  410502.0
# 359           Lepcis Magna       180  153722.0
# 433                 Rhodus       309  130398.0
# 302      Antiochia (Syria)      1324  124930.0
#
#                           hanson_geo      dist  \
# 2             [12.485098, 41.892777]  0.001780
# 164  [29.903728000000005, 31.195024]  0.008006
# 359             [14.29306, 32.63833]  0.001701
# 433           [28.227007, 36.443235]  0.004407
# 302           [36.169629, 36.210172]  0.002261
#
#                                                EDH_all  \
# 2    [HD016234, HD007300, HD006780, HD016689, HD002...
# 164  [HD025477, HD017883, HD032199, HD045448, HD019...
# 359  [HD021906, HD045234, HD045235, HD018125, HD021...
# 433                                                 []
# 302                                         [HD061603]
#
#                                               EDCS_all  LIRE_total_N
# 2    [EDCS-22700240, EDCS-22700241, EDCS-22700242, ...         38647
# 164  [EDCS-71300297, EDCS-58200213, EDCS-20800415, ...            37
# 359  [EDCS-51500074, EDCS-51500075, EDCS-51500076, ...           319
# 433                                    [EDCS-70200274]             1
# 302                                                 []             1

# %%
# %%time
orbis_hanson_gpd["EDH_per1"] = orbis_hanson_gpd["id"].apply(lambda x: get_inscr_ids(x, "EDH", LIRE_period1))
orbis_hanson_gpd["EDCS_per1"] = orbis_hanson_gpd["id"].apply(lambda x: get_inscr_ids(x, "EDCS", LIRE_period1))

orbis_hanson_gpd["EDH_per2"] = orbis_hanson_gpd["id"].apply(lambda x: get_inscr_ids(x, "EDH", LIRE_period2))
orbis_hanson_gpd["EDCS_per2"] = orbis_hanson_gpd["id"].apply(lambda x: get_inscr_ids(x, "EDCS", LIRE_period2))

orbis_hanson_gpd["EDH_per3"] = orbis_hanson_gpd["id"].apply(lambda x: get_inscr_ids(x, "EDH", LIRE_period3))
orbis_hanson_gpd["EDCS_per3"] = orbis_hanson_gpd["id"].apply(lambda x: get_inscr_ids(x, "EDCS", LIRE_period3))
# Out:
# CPU times: user 33.3 s, sys: 10.2 ms, total: 33.3 s
# Wall time: 33.3 s

# %%
orbis_hanson_gpd["LIRE_per1_N"] = orbis_hanson_gpd.apply(lambda row: len(row["EDH_per1"])+len(row["EDCS_per1"]), axis=1)
orbis_hanson_gpd["LIRE_per2_N"] = orbis_hanson_gpd.apply(lambda row: len(row["EDH_per2"])+len(row["EDCS_per2"]), axis=1)
orbis_hanson_gpd["LIRE_per3_N"] = orbis_hanson_gpd.apply(lambda row: len(row["EDH_per3"])+len(row["EDCS_per3"]), axis=1)

# %%
orbis_hanson_gpd.head(5)
# Out:
#         id                      label       x       y  \
# 521  50474              Portus Magnus  35.808  -0.266
# 458  50418                     Vienna  45.524   4.878
# 210  50131                    Corduba  37.884  -4.780
# 319  50172                   Faventia  44.285  11.883
# 109  50125  Ulpia Traiana Tricensimae  51.668   6.445
#
#                       geometry           hanson_label hanson_ID  pop_est  \
# 521  POINT (-0.26600 35.80800)          Portus Magnus      1182   1000.0
# 458   POINT (4.87800 45.52400)                 Vienna       658  15332.0
# 210  POINT (-4.78000 37.88400)                Corduba       336  19404.0
# 319  POINT (11.88300 44.28500)               Faventia      1014   5399.0
# 109   POINT (6.44500 51.66800)  Colonia Ulpia Traiana       661  14596.0
#
#                  hanson_geo      dist  \
# 521  [-0.266018, 35.807917]  0.000085
# 458   [4.878056, 45.524167]  0.000176
# 210    [-4.78025, 37.88376]  0.000347
# 319  [11.882989, 44.285348]  0.000348
# 109   [6.444591, 51.668014]  0.000409
#
#                                                EDH_all  \
# 521  [HD047307, HD033385, HD000463, HD052542, HD033...
# 458  [HD052078, HD052079, HD001171, HD001626, HD001...
# 210  [HD006608, HD006605, HD006602, HD006599, HD000...
# 319  [HD017246, HD016084, HD018809, HD008967, HD032...
# 109  [HD031155, HD050305, HD050306, HD050307, HD022...
#
#                                               EDCS_all  LIRE_total_N  \
# 521  [EDCS-75300340, EDCS-25500569, EDCS-25500582, ...            16
# 458  [EDCS-09200591, EDCS-09200592, EDCS-09500338, ...           119
# 210  [EDCS-72600014, EDCS-72600015, EDCS-75900070, ...          1290
# 319  [EDCS-64901116, EDCS-30200030, EDCS-30400520, ...            99
# 109  [EDCS-78300132, EDCS-78300660, EDCS-72700161, ...           424
#
#                                               EDH_per1  \
# 521                                                 []
# 458  [HD001171, HD001626, HD001620, HD001623, HD049...
# 210  [HD006599, HD000035, HD028010, HD013569, HD028...
# 319  [HD018809, HD032458, HD005009, HD003863, HD003...
# 109  [HD050305, HD050306, HD040731, HD040731, HD040...
#
#                                              EDCS_per1  \
# 521                                    [EDCS-25500582]
# 458  [EDCS-09200592, EDCS-09200607, EDCS-09200608, ...
# 210  [EDCS-72600014, EDCS-75900070, EDCS-75900071, ...
# 319  [EDCS-04900283, EDCS-04900288, EDCS-20402028, ...
# 109  [EDCS-78300132, EDCS-78300660, EDCS-72700161, ...
#
#                                               EDH_per2  \
# 521                                                 []
# 458  [HD052078, HD052079, HD001617, HD052073, HD050...
# 210  [HD006608, HD006605, HD006602, HD006599, HD000...
# 319  [HD017246, HD016084, HD018809, HD008967, HD010...
# 109  [HD031155, HD050305, HD050307, HD022736, HD022...
#
#                                              EDCS_per2  \
# 521                                    [EDCS-25500569]
# 458  [EDCS-09200591, EDCS-09200607, EDCS-09200608, ...
# 210  [EDCS-72600015, EDCS-73900025, EDCS-76900064, ...
# 319  [EDCS-30200030, EDCS-30400520, EDCS-31200405, ...
# 109  [EDCS-72700161, EDCS-72700161, EDCS-76400130, ...
#
#                                               EDH_per3  \
# 521  [HD033385, HD000463, HD052542, HD033325, HD033...
# 458                     [HD001617, HD050227, HD053527]
# 210  [HD006602, HD031526, HD030365, HD030401, HD030...
# 319                               [HD018809, HD010890]
# 109  [HD031155, HD040405, HD040405, HD040353, HD040...
#
#                                              EDCS_per3  LIRE_per1_N  \
# 521      [EDCS-25500560, EDCS-26800812, EDCS-26800790]            1
# 458  [EDCS-09200591, EDCS-09500338, EDCS-09200688, ...           53
# 210  [EDCS-05600095, EDCS-05600096, EDCS-21700295, ...          540
# 319  [EDCS-64901116, EDCS-12300341, EDCS-04900290, ...           41
# 109  [EDCS-17000012, EDCS-69300353, EDCS-74100142, ...          181
#
#      LIRE_per2_N  LIRE_per3_N
# 521            1           10
# 458           73           30
# 210          720          309
# 319           51           20
# 109          249          205

# %% [markdown]
# # Save for future usage

# %%
s = sddk.cloudSession("sciencedata.dk", "SDAM_root", "648597@au.dk")
# Out:
# Your ScienceData username (e.g. '123456@au.dk'): 648597@au.dk
# Your ScienceData password: ········
# connection with shared folder established with you as its owner
# endpoint variable has been configured to: https://sciencedata.dk/files/SDAM_root/

# %%
def to_list(nparray):
    try: return list(nparray)
    except: return None
orbis_hanson_gpd["hanson_geo"] = orbis_hanson_gpd["hanson_geo"].apply(to_list)

# %%
# save it as json (you have to drop the geometry first)
s.write_file("SDAM_data/urban/orbis_hanson_lire.json", pd.DataFrame(orbis_hanson_gpd).drop(["geometry"], axis=1))
# Out:
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/urban/orbis_hanson_lire.json"

# %%
# save as geojson (be careful in reading back)
s.write_file("SDAM_data/urban/orbis_hanson_lire.geojson", orbis_hanson_gpd)
# Out:
# Your <class 'geopandas.geodataframe.GeoDataFrame'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/urban/orbis_hanson_lire.geojson"

# %%
# save as csv (be careful in reading back)
s.write_file("SDAM_data/urban/orbis_hanson_lire.csv", orbis_hanson_gpd)
# Out:
# Your <class 'geopandas.geodataframe.GeoDataFrame'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/urban/orbis_hanson_lire.csv"

# %%
# save locally as csv
orbis_hanson_gpd.to_csv("../data/orbis_hanson_lire.csv")

# %%
# save locally as parquet
orbis_hanson_gpd.to_parquet("../data/orbis_hanson_lire.par")

# %% [markdown]
# # Final Network Construction

# %%
orbis_hanson_gpd = gpd.read_parquet("../data/orbis_hanson_lire.par")

# %%
url = "https://stacks.stanford.edu/file/druid:mn425tz9757/orbis_edges_0514.csv"
orbis_edges_stanford = pd.read_csv(url)
len(orbis_edges_stanford)
# Out:
# 2208

# %%
orbis_edges_stanford.head(5)
# Out:
#    source  target       km   days  expense  type
# 0   50001   50056   54.539  1.818    1.909  road
# 1   50001   50100   50.135  1.671    1.755  road
# 2   50001   50293   65.681  2.189    2.299  road
# 3   50001   50473  225.368  7.512    7.888  road
# 4   50002   50275   92.174  3.072    3.226  road

# %%
orbis_hanson_gpd.columns
# Out:
# Index(['id', 'label', 'x', 'y', 'geometry', 'hanson_label', 'hanson_ID',
#        'pop_est', 'hanson_geo', 'dist', 'EDH_all', 'EDCS_all', 'LIRE_total_N',
#        'EDH_per1', 'EDCS_per1', 'EDH_per2', 'EDCS_per2', 'EDH_per3',
#        'EDCS_per3', 'LIRE_per1_N', 'LIRE_per2_N', 'LIRE_per3_N'],
#       dtype='object')

# %%
orbis_edges_stanford.rename(columns={"type" : "route_type"}, inplace=True)

# %%
orbis_edges_stanford.head()
# Out:
#    source  target       km   days  expense route_type
# 0   50001   50056   54.539  1.818    1.909       road
# 1   50001   50100   50.135  1.671    1.755       road
# 2   50001   50293   65.681  2.189    2.299       road
# 3   50001   50473  225.368  7.512    7.888       road
# 4   50002   50275   92.174  3.072    3.226       road

# %%
orbis_edges_stanford["expense_inverse"] = orbis_edges_stanford["expense"].apply(lambda x: 1 / x)

# %%
# create a network from the edges data
G = nx.convert_matrix.from_pandas_edgelist(orbis_edges_stanford, "source", "target")

# add edge attributes
edge_keys = [(s, t) for s,t in zip(orbis_edges_stanford["source"], orbis_edges_stanford["target"])]
edge_values = orbis_edges_stanford[["km", "expense_inverse", "expense", "days", "route_type"]].to_dict("records")
edge_dict = dict(zip(edge_keys, edge_values))
nx.set_edge_attributes(G, edge_dict)

# add node attributes
nodes_keys = orbis_hanson_gpd["id"].tolist()
nodes_values_raw = orbis_hanson_gpd[["label", "x", "y", 'hanson_label', 'hanson_ID', 'pop_est', 'LIRE_total_N', 'LIRE_per1_N', 'LIRE_per2_N', 'LIRE_per3_N']].to_dict("records")
nodes_values = []  
for value_dict in nodes_values_raw: # remove "None", which is unacceptible for exports etc.
    for key in value_dict:
        if value_dict[key] == None:
            value_dict[key] = ""
    nodes_values.append(value_dict)
nodes_dict = dict(zip(nodes_keys, nodes_values))
nx.set_node_attributes(G, nodes_dict)

# %%
G.nodes(data=True)
# Out:
# NodeDataView({50001: {'label': 'Abodiacum', 'x': 47.909, 'y': 10.909, 'hanson_label': 'Abodiacum', 'hanson_ID': '1287', 'pop_est': 1000.0, 'LIRE_total_N': 73, 'LIRE_per1_N': 50, 'LIRE_per2_N': 35, 'LIRE_per3_N': 35}, 50056: {'label': 'Augusta Vindelicum', 'x': 48.364, 'y': 10.894, 'hanson_label': 'Augusta Vindelicum', 'hanson_ID': '1288', 'pop_est': 10608.0, 'LIRE_total_N': 219, 'LIRE_per1_N': 88, 'LIRE_per2_N': 171, 'LIRE_per3_N': 142}, 50100: {'label': 'Cambodunum', 'x': 47.726, 'y': 10.326, 'hanson_label': 'Cambodunum', 'hanson_ID': '1290', 'pop_est': 1000.0, 'LIRE_total_N': 37, 'LIRE_per1_N': 23, 'LIRE_per2_N': 23, 'LIRE_per3_N': 26}, 50293: {'label': 'Parthanum', 'x': 47.491, 'y': 11.085, 'hanson_label': '', 'hanson_ID': '', 'pop_est': 1000.0, 'LIRE_total_N': 8, 'LIRE_per1_N': 3, 'LIRE_per2_N': 4, 'LIRE_per3_N': 5}, 50473: {'label': 'Maiensis Statio', 'x': 46.659, 'y': 11.169, 'hanson_label': '', 'hanson_ID': '', 'pop_est': 1000.0, 'LIRE_total_N': 10, 'LIRE_per1_N': 6, 'LIRE_per2_N': 5, 'LIRE_per3_N': 5}, 50002: {'label': 'Ad fl. Tigrim', 'x': 37.341, 'y': 42.191, 'hanson_label': '', 'hanson_ID': '', 'pop_est': 1000.0, 'LIRE_total_N': 0, 'LIRE_per1_N': 0, 'LIRE_per2_N': 0, 'LIRE_per3_N': 0}, 50275: {'label': 'Nisibis', 'x': 37.077, 'y': 41.244, 'hanson_label': '', 'hanson_ID': '', 'pop_est': 1000.0, 'LIRE_total_N': 2, 'LIRE_per1_N': 0, 'LIRE_per2_N': 1, 'LIRE_per3_N': 1}, 50003: {'label': 'Ad Publicanos', 'x': 45.671, 'y': 6.374, 'hanson_label': '', 'hanson_ID': '', 'pop_est': 1000.0, 'LIRE_total_N': 88, 'LIRE_per1_N': 54, 'LIRE_per2_N': 61, 'LIRE_per3_N': 50}, 50052: {'label': 'Augusta Praetoria', 'x': 45.736, 'y': 7.313, 'hanson_label': 'Augusta Praetoria', 'hanson_ID': '225', 'pop_est': 5976.0, 'LIRE_total_N': 176, 'LIRE_per1_N': 131, 'LIRE_per2_N': 122, 'LIRE_per3_N': 77}, 50182: {'label': 'Genava', 'x': 46.202, 'y': 6.138, 'hanson_label': 'Genava', 'hanson_ID': '646', 'pop_est': 3590.0, 'LIRE_total_N': 136, 'LIRE_per1_N': 80, 'LIRE_per2_N': 69, 'LIRE_per3_N': 65}, 50004: {'label': 'Ad Tricesimum', 'x': 46.157, 'y': 13.215, 'hanson_label': '', 'hanson_ID': '', 'pop_est': 1000.0, 'LIRE_total_N': 85, 'LIRE_per1_N': 59, 'LIRE_per2_N': 20, 'LIRE_per3_N': 11}, 50034: {'label': 'Aquileia', 'x': 45.767, 'y': 13.364, 'hanson_label': 'Aquileia', 'hanson_ID': '1045', 'pop_est': 14596.0, 'LIRE_total_N': 1948, 'LIRE_per1_N': 940, 'LIRE_per2_N': 757, 'LIRE_per3_N': 326}, 50747: {'label': 'x', 'x': 46.371, 'y': 13.128, 'hanson_label': '', 'hanson_ID': '', 'pop_est': 1000.0, 'LIRE_total_N': 21, 'LIRE_per1_N': 6, 'LIRE_per2_N': 13, 'LIRE_per3_N': 4}, 50005: {'label': 'Ad Aras', 'x': 38.736, 'y': -0.977, 'hanson_label': '', 'hanson_ID': '', 'pop_est': 1000.0, 'LIRE_total_N': 207, 'LIRE_per1_N': 115, 'LIRE_per2_N': 112, 'LIRE_per3_N': 34}, 50108: {'label': 'Carthago Nova', 'x': 37.605, 'y': -0.992, 'hanson_label': 'Carthago Nova', 'hanson_ID': '693', 'pop_est': 9498.0, 'LIRE_total_N': 278, 'LIRE_per1_N': 180, 'LIRE_per2_N': 58, 'LIRE_per3_N': 18}, 50248: {'label': 'Mariana', 'x': 38.558, 'y': -2.926, 'hanson_label': '', 'hanson_ID': '', 'pop_est': 1000.0, 'LIRE_total_N': 78, 'LIRE_per1_N': 30, 'LIRE_per2_N': 40, 'LIRE_per3_N': 26}, 50332: {'label': 'Saguntum', 'x': 39.666, 'y': -0.269, 'hanson_label': 'Saguntum', 'hanson_ID': '725', 'pop_est': 3420.0, 'LIRE_total_N': 783, 'LIRE_per1_N': 532, 'LIRE_per2_N': 477, 'LIRE_per3_N': 103}, 50006: {'label': 'Adramyttium', 'x': 39.504, 'y': 26.937, 'hanson_label': 'Adramyttium', 'hanson_ID': '245', 'pop_est': 1000.0, 'LIRE_total_N': 1, 'LIRE_per1_N': 0, 'LIRE_per2_N': 0, 'LIRE_per3_N': 0}, 50019: {'label': 'Alexandria Troas', 'x': 39.76, 'y': 26.152, 'hanson_label': 'Alexandria (Asia)', 'hanson_ID': '249', 'pop_est': 80443.0, 'LIRE_total_N': 24, 'LIRE_per1_N': 15, 'LIRE_per2_N': 7, 'LIRE_per3_N': 4}, 50300: {'label': 'Pergamum', 'x': 39.14, 'y': 27.181, 'hanson_label': 'Pergamum', 'hanson_ID': '305', 'pop_est': 56393.0, 'LIRE_total_N': 9, 'LIRE_per1_N': 2, 'LIRE_per2_N': 2, 'LIRE_per3_N': 1}, 50 ...

# %%
positions = dict(zip(orbis_hanson_gpd["id"].tolist(), list(np.column_stack((orbis_hanson_gpd["y"], orbis_hanson_gpd["x"])))))

# %%
### # pelagios provinces - to be used as a base map in our plots
url = "https://raw.githubusercontent.com/pelagios/magis-pleiades-regions/main/pleiades-regions-magis-pelagios.geojson"
pleiades_regions = gpd.read_file(url)
pleiades_regions.head(5)
# Out:
#                  name                                     uri  \
# 0           Lusitania    http://pleiades.stoa.org/places/1101
# 1            Byzacena  http://pleiades.stoa.org/places/991345
# 2          Viennensis  http://pleiades.stoa.org/places/992074
# 3  Lycia et Pamphylia  http://pleiades.stoa.org/places/981530
# 4               Savia  http://pleiades.stoa.org/places/991357
#
#                                             geometry
# 0  POLYGON ((-7.31057 37.19663, -7.32457 37.19556...
# 1  MULTIPOLYGON (((11.01815 34.62424, 11.00879 34...
# 2  POLYGON ((4.62344 45.60642, 4.71224 45.60876, ...
# 3  MULTIPOLYGON (((29.62331 36.07470, 29.61295 36...
# 4  POLYGON ((18.10598 45.77203, 18.10654 45.71079...

# %%
fig, ax = plt.subplots(figsize=[5.2, 4], tight_layout=True)
pleiades_regions.plot(color="lightgray", ax=ax)

nx.draw(G, positions, with_labels=False, node_size=5, node_color="darkblue", node_shape="o", linewidths=1, ax=ax)
ax.set_axis_off()

# %%
# export for future reuse (within python)
nx.write_gpickle(G, "../data/orbis_network_enriched.pickle")

# %%
nx.write_graphml(G, "../data/orbis_network_enriched.graphml")

# %%
G_graphml = nx.read_graphml("../data/orbis_network_enriched.graphml")
G_graphml.edges(data=True)
# Out:
# EdgeDataView([('50001', '50056', {'km': 54.539, 'expense_inverse': 0.5238344683080146, 'expense': 1.909, 'days': 1.818, 'route_type': 'road'}), ('50001', '50100', {'km': 50.135, 'expense_inverse': 0.5698005698005698, 'expense': 1.755, 'days': 1.671, 'route_type': 'road'}), ('50001', '50293', {'km': 65.681, 'expense_inverse': 0.43497172683775553, 'expense': 2.299, 'days': 2.189, 'route_type': 'road'}), ('50001', '50473', {'km': 225.368, 'expense_inverse': 0.12677484787018256, 'expense': 7.888, 'days': 7.512, 'route_type': 'road'}), ('50056', '50314', {'km': 126.177, 'expense_inverse': 0.22644927536231882, 'expense': 4.416, 'days': 4.206, 'route_type': 'road'}), ('50056', '50370', {'km': 32.01, 'expense_inverse': 0.8928571428571428, 'expense': 1.12, 'days': 1.067, 'route_type': 'road'}), ('50100', '50083', {'km': 58.819, 'expense_inverse': 0.4856726566294317, 'expense': 2.059, 'days': 1.961, 'route_type': 'road'}), ('50293', '50408', {'km': 52.83, 'expense_inverse': 0.5408328826392644, 'expense': 1.849, 'days': 1.761, 'route_type': 'road'}), ('50473', '50315', {'km': 25.576, 'expense_inverse': 1.1173184357541899, 'expense': 0.895, 'days': 0.853, 'route_type': 'road'}), ('50002', '50275', {'km': 92.174, 'expense_inverse': 0.30998140111593303, 'expense': 3.226, 'days': 3.072, 'route_type': 'road'}), ('50275', '50119', {'km': 280.885, 'expense_inverse': 1.0471204188481675, 'expense': 0.955, 'days': 2.341, 'route_type': 'fastdown'}), ('50275', '50161', {'km': 225.509, 'expense_inverse': 0.12669453946534906, 'expense': 7.893, 'days': 7.517, 'route_type': 'road'}), ('50275', '50355', {'km': 101.456, 'expense_inverse': 0.28161081385525205, 'expense': 3.551, 'days': 3.382, 'route_type': 'road'}), ('50003', '50052', {'km': 109.155, 'expense_inverse': 0.2617801047120419, 'expense': 3.82, 'days': 3.639, 'route_type': 'road'}), ('50003', '50182', {'km': 81.192, 'expense_inverse': 0.3518648838845883, 'expense': 2.842, 'days': 2.706, 'route_type': 'road'}), ('50052', '50298', {'km': 96.213, 'expense_inverse': 0.297000297000297, 'expense': 3.367, 'days': 3.207, 'route_type': 'road'}), ('50052', '50413', {'km': 109.691, 'expense_inverse': 0.26048450117218025, 'expense': 3.839, 'days': 3.656, 'route_type': 'road'}), ('50182', '50236', {'km': 59.858, 'expense_inverse': 0.477326968973747, 'expense': 2.095, 'days': 1.995, 'route_type': 'road'}), ('50182', '50418', {'km': 147.734, 'expense_inverse': 0.19338619222587505, 'expense': 5.171, 'days': 4.924, 'route_type': 'road'}), ('50004', '50034', {'km': 45.801, 'expense_inverse': 0.6238303181534622, 'expense': 1.603, 'days': 1.527, 'route_type': 'road'}), ('50004', '50747', {'km': 26.316, 'expense_inverse': 1.0857763300760044, 'expense': 0.921, 'days': 0.877, 'route_type': 'road'}), ('50034', '50166', {'km': 105.86, 'expense_inverse': 0.2699055330634278, 'expense': 3.705, 'days': 3.529, 'route_type': 'road'}), ('50034', '50209', {'km': 42.968, 'expense_inverse': 0.6648936170212766, 'expense': 1.504, 'days': 1.432, 'route_type': 'road'}), ('50034', '50336', {'km': 431.935, 'expense_inverse': 2.8901734104046244, 'expense': 0.346, 'days': 3.464, 'route_type': 'coastal'}), ('50034', '50383', {'km': 41.471, 'expense_inverse': 31.25, 'expense': 0.032, 'days': 0.315, 'route_type': 'coastal'}), ('50034', '50509', {'km': 43.806, 'expense_inverse': 32.25806451612903, 'expense': 0.031, 'days': 0.307, 'route_type': 'coastal'}), ('50034', '50533', {'km': 818.454, 'expense_inverse': 1.3869625520110958, 'expense': 0.721, 'days': 7.206, 'route_type': 'overseas'}), ('50747', '50211', {'km': 15.165, 'expense_inverse': 1.8832391713747645, 'expense': 0.531, 'days': 0.506, 'route_type': 'road'}), ('50747', '50339', {'km': 76.54, 'expense_inverse': 0.3732736095558044, 'expense': 2.679, 'days': 2.551, 'route_type': 'road'}), ('50005', '50108', {'km': 143.569, 'expense_inverse': 0.1990049751243781, 'expense': 5.025, 'days': 4.786, 'route_type': 'road'}), ('50005', '50248', {'km': 196.645, 'expense_inverse': 0.145285485979950 ...
