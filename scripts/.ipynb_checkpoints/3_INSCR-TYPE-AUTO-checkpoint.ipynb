# %%
import sddk
import pandas as pd
import tabulate
pd.options.display.max_columns = 1000 # to see all columns
import json
import re
import geopandas as gpd
from shapely.geometry import Point
from functools import partial
from shapely.ops import transform
import pyproj
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from scipy.spatial import cKDTree
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer


from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix

import pickle

import nltk
from nltk.util import bigrams

# %%
EDHCSg = sddk.read_file("EDHCSg.geojson", "gdf", "a9237c5ea642d4714bcdefb03f70a1f4")
# Out:
# reading file located in a public folder

# %%
# to train the model, we will work with a subset of the for which we have both the EDH and EDCS attributes
# we will call it EDHg
EDH_overlap_all = EDHCSg[(EDHCSg["EDH-ID"].notnull()) & (EDHCSg["EDCS-ID"].notnull())] 
EDH_overlap_all.groupby("type_of_inscription_clean").size().sort_values(ascending=False)
# Out:
# type_of_inscription_clean
# epitaph                            21520
# votive inscription                 11728
# NULL                                3745
# owner/artist inscription            3340
# honorific inscription               3003
# building/dedicatory inscription     2561
# mile-/leaguestone                   1307
# identification inscription           850
# acclamation                          287
# defixio                              269
# list                                 246
# military diploma                     209
# label                                194
# boundary inscription                 175
# elogium                              132
# letter                               119
# public legal inscription             109
# seat inscription                      42
# private legal inscription             36
# prayer                                18
# assignation inscription               15
# calendar                              10
# adnuntiatio                            1
# dtype: int64

# %%
EDH_overlap = EDH_overlap_all[~EDH_overlap_all["type_of_inscription_clean"].str.contains("NULL")]

# %% [markdown]
# Now we can focus on some EDCS attributes (i.e. firt 28 columns) which might be good predictors of `type_of_inscription_clean` in EDH. First, look at `status_list`:

# %%
EDH_overlap.groupby("type_of_inscription_clean").size().sort_values(ascending=False)
# Out:
# type_of_inscription_clean
# epitaph                            21520
# votive inscription                 11728
# owner/artist inscription            3340
# honorific inscription               3003
# building/dedicatory inscription     2561
# mile-/leaguestone                   1307
# identification inscription           850
# acclamation                          287
# defixio                              269
# list                                 246
# military diploma                     209
# label                                194
# boundary inscription                 175
# elogium                              132
# letter                               119
# public legal inscription             109
# seat inscription                      42
# private legal inscription             36
# prayer                                18
# assignation inscription               15
# calendar                              10
# adnuntiatio                            1
# dtype: int64

# %% [markdown]
# # Dealing with unbalancies between categories -> resampling
#
# - not employed right now, since it seems that SVM work pretty well with inbalanced data

# %%
# what are the most common types of inscriptions
EDH_major_cats = EDH_overlap.groupby("type_of_inscription_clean").size().sort_values(ascending=False).index[:6]
EDH_major_cats

EDH_minor_cats = EDH_overlap.groupby("type_of_inscription_clean").size().sort_values(ascending=False).index[6:]
EDH_minor_cats
# Out:
# Index(['identification inscription', 'acclamation', 'defixio', 'list',
#        'military diploma', 'label', 'boundary inscription', 'elogium',
#        'letter', 'public legal inscription', 'seat inscription',
#        'private legal inscription', 'prayer', 'assignation inscription',
#        'calendar', 'adnuntiatio'],
#       dtype='object', name='type_of_inscription_clean')

# %%
EDH_sampled_major = EDH_overlap[EDH_overlap["type_of_inscription_clean"].isin(EDH_major_cats)].groupby("type_of_inscription_clean").sample(5000, replace=True, random_state=1)
EDH_sampled_major
# Out:
#               EDCS-ID                                        publication  \
# 94097   EDCS-07900742                                      RIB-01, 01933
# 88882   EDCS-10600421  CIL 13, 03653 = D 04562 = CSIR-D-04-03, 00178 ...
# 94205   EDCS-44600194                                      RIB-03, 03385
# 93467   EDCS-07900478                                      RIB-01, 01670
# 93626   EDCS-07801231                                      RIB-01, 00940
# ...               ...                                                ...
# 105232  EDCS-15800317  Nesselhauf 00184 = CBI 00046 = AE 1930, 00033 ...
# 95760   EDCS-16100253                         ILD 00577 = AE 1933, 00020
# 124730  EDCS-17800007  RIU-06, 01489 = EpPann-03, p 40 = CIMRM-02, 01...
# 127994  EDCS-11301026                                          AIJ 00330
# 95045   EDCS-27800812  CIL 03, 06260 (p 1390) = IDR-03-05-01, 00167 =...
#
#                  province      province_list  \
# 94097           Britannia          Britannia
# 88882             Belgica            Belgica
# 94205           Britannia          Britannia
# 93467           Britannia          Britannia
# 93626           Britannia          Britannia
# ...                   ...                ...
# 105232  Germania inferior  Germania inferior
# 95760               Dacia              Dacia
# 124730  Pannonia inferior  Pannonia inferior
# 127994  Pannonia superior  Pannonia superior
# 95045               Dacia              Dacia
#
#                                      place  \
# 94097              Turret 50A / High House
# 88882           Trier / Augusta Treverorum
# 94205                       Walltown Crags
# 93467            Milecastle 42 / Cawfields
# 93626                 Old Penrith / Voreda
# ...                                    ...
# 105232                        Bonn / Bonna
# 95760   Cluj-Napoca / Klausenburg / Napoca
# 124730                  Sarkeszi / Gorsium
# 127994                     Ptuj / Poetovio
# 95045                  Alba Iulia / Apulum
#
#                                       place_list end_yr_list notes_dating  \
# 94097               ['Turret 50A', 'High House']         138
# 88882            ['Trier', 'Augusta Treverorum']         300
# 94205                             Walltown Crags         128
# 93467             ['Milecastle 42', 'Cawfields']         138
# 93626                  ['Old Penrith', 'Voreda']         300
# ...                                          ...         ...          ...
# 105232                         ['Bonn', 'Bonna']         226
# 95760   ['Cluj-Napoca', 'Klausenburg', 'Napoca']         275
# 124730                   ['Sarkeszi', 'Gorsium']         300
# 127994                      ['Ptuj', 'Poetovio']         300
# 95045                   ['Alba Iulia', 'Apulum']         250
#
#                                               status_list  \
# 94097                                                  {}
# 88882                                        tituli sacri
# 94205   ['milites', 'tituli operum', 'tria nomina', 'v...
# 93467                                                  {}
# 93626                                                  {}
# ...                                                   ...
# 105232  ['milites', 'tituli sacri', 'tria nomina', 'vi...
# 95760         ['nomen singulare', 'tituli sacri', 'viri']
# 124730                  ['tituli operum', 'tituli sacri']
# 127994            ['tituli sacri', 'tria nomina', 'viri']
# 95045             ['tituli sacri', 'tria nomina', 'viri']
#
#                                inscr_type                     status_notation  \
# 94097                                  {}                                  {}
# 88882                        tituli sacri                                  {}
# 94205                       tituli operum  ['milites', 'tria nomina', 'viri']
# 93467                                  {}                                  {}
# 93626                                  {}                                  {}
# ...                                   ...                                 ...
# 105232                       tituli sacri  ['milites', 'tria nomina', 'viri']
# 95760                        tituli sacri         ['nomen singulare', 'viri']
# 124730  ['tituli operum', 'tituli sacri']                                  {}
# 127994                       tituli sacri             ['tria nomina', 'viri']
# 95045                        tituli sacri             ['tria nomina', 'viri']
#
#        inscr_process notes_references notes_comments  \
# 94097             {}
# 88882             {}
# 94205             {}
# 93467             {}
# 93626             {}
# ...              ...              ...            ...
# 105232            {}
# 95760             {}
# 124730            {}
# 127994            {}
# 95045             {}
#
#                                               inscription  \
# 94097    Vex]sil(latio) / [leg(ionis) VI Vi]c(tricis) / [
# 88882   In h(onorem) d(omus) d(ivinae) deo Marti Inta/...
# 94205                    |(Centuria) Caledon(i) / Secundi
# 93467                        |(Centuria) Romu/lei / Iusti
# 93626   [Num(ini) A]ug(usti) vex(illatio) / [leg(ionis...
# ...                                                   ...
# 105232  [I(ovi)] O(ptimo) M(aximo) Gen(io) loc(i) / Tu...
# 95760   Silvano Si/lvestri po/suit For/tunatus / Theup...
# 124730  [D(eo) I(nvicto) S(oli)] M(ithrae) / [6] / [6]...
# 127994  Nutricibus Aug(ustis) / Val(erius) Secu(n)dian...
# 95045   I(ovi) O(ptimo) M(aximo) / Aul(us) Tapetius / ...
#
#                                inscription_stripped_final  \
# 94097    Vex]sil(latio) / [leg(ionis) VI Vi]c(tricis) / [
# 88882   In h(onorem) d(omus) d(ivinae) deo Marti Inta/...
# 94205                    |(Centuria) Caledon(i) / Secundi
# 93467                        |(Centuria) Romu/lei / Iusti
# 93626   [Num(ini) A]ug(usti) vex(illatio) / [leg(ionis...
# ...                                                   ...
# 105232  [I(ovi)] O(ptimo) M(aximo) Gen(io) loc(i) / Tu...
# 95760   Silvano Si/lvestri po/suit For/tunatus / Theup...
# 124730  [D(eo) I(nvicto) S(oli)] M(ithrae) / [6] / [6]...
# 127994  Nutricibus Aug(ustis) / Val(erius) Secu(n)dian...
# 95045   I(ovi) O(ptimo) M(aximo) / Aul(us) Tapetius / ...
#
#                                                     Links  dating from  \
# 94097   http://db.edcs.eu/epigr/partner.php?s_language...        122.0
# 88882   http://db.edcs.eu/epigr/partner.php?s_language...          1.0
# 94205   http://db.edcs.eu/epigr/partner.php?s_language...        125.0
# 93467   http://db.edcs.eu/epigr/partner.php?s_language...        122.0
# 93626   http://db.edcs.eu/epigr/partner.php?s_language...        122.0
# ...                                                   ...          ...
# 105232  http://db.edcs.eu/epigr/partner.php?s_language...        226.0
# 95760   http://db.edcs.eu/epigr/partner.php?s_language...        107.0
# 124730  http://db.edcs.eu/epigr/partner.php?s_language...        101.0
# 127994  http://db.edcs.eu/epigr/partner.php?s_language...        201.0
# 95045   http://db.edcs.eu/epigr/partner.php?s_language...        131.0
#
#        dating to                                     status   Latitude  \
# 94097        138                                       None  54.985780
# 88882        300                               tituli sacri  49.759621
# 94205        128  milites; tituli operum; tria nomina; viri  54.993588
# 93467        138                                       None  54.993989
# 93626        300                                       None  54.738539
# ...          ...                                        ...        ...
# 105232       226   milites; tituli sacri; tria nomina; viri  50.735851
# 95760        275        nomen singulare; tituli sacri; viri  46.769475
# 124730       300                tituli operum; tituli sacri  47.158255
# 127994       300            tituli sacri; tria nomina; viri  46.419351
# 95045        250            tituli sacri; tria nomina; viri  46.068739
#
#         Longitude                                              photo Material  \
# 94097   -2.623401                                               None    lapis
# 88882    6.644188                                               None    lapis
# 94205   -2.506039  http://db.edcs.eu/epigr/bilder.php?bilder.php?...    lapis
# 93467   -2.445784                                               None    lapis
# 93626   -2.788352                                               None    lapis
# ...           ...                                                ...      ...
# 105232   7.100660  http://db.edcs.eu/epigr/bilder.php?bilder.php?...    lapis
# 95760   23.589741  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None
# 124730  18.285122                                               None    lapis
# 127994  15.870984  http://db.edcs.eu/epigr/bilder.php?bilder.php?...    lapis
# 95045   23.570440  http://db.edcs.eu/epigr/bilder.php?bilder.php?...    lapis
#
#        Comment    EDH-ID language_EDCS  \
# 94097     None  HD071082          None
# 88882     None  HD023294          None
# 94205     None  HD073105          None
# 93467     None  HD070841          None
# 93626     None  HD070181          None
# ...        ...       ...           ...
# 105232    None  HD025635          None
# 95760     None  HD023673          None
# 124730    None  HD032083          None
# 127994    None  HD067381          None
# 95045     None  HD020497          None
#
#                         clean_text_interpretive_word_EDCS  \
# 94097                   Vexsillatio legionis VI Victricis
# 88882   In honorem domus divinae deo Marti Intarabo Vi...
# 94205                           Centuria Caledoni Secundi
# 93467                              Centuria Romulei Iusti
# 93626   Numini Augusti vexillatio legionis XX Valeriae...
# ...                                                   ...
# 105232  Iovi Optimo Maximo Genio loci Tutelae Maturini...
# 95760   Silvano Silvestri posuit Fortunatus Theupropi ...
# 124730  Deo Invicto Soli Mithrae templum vetustate con...
# 127994  Nutricibus Augustis Valerius Secundianus votum...
# 95045   Iovi Optimo Maximo Aulus Tapetius Amethystus v...
#
#        responsible_individual               type_of_inscription letter_size  \
# 94097                   Cowey  building/dedicatory inscription?        None
# 88882                   Cowey   building/dedicatory inscription      2.5 cm
# 94205                   Cowey   building/dedicatory inscription        None
# 93467                   Cowey   building/dedicatory inscription        None
# 93626                   Cowey   building/dedicatory inscription        None
# ...                       ...                               ...         ...
# 105232                Feraudi                votive inscription        None
# 95760                    Gräf                votive inscription        3 cm
# 124730                Feraudi                votive inscription  5.4-3.5 cm
# 127994                   Gräf                votive inscription        2 cm
# 95045                    Gräf                votive inscription    7.5-7 cm
#
#                                                literature  \
# 94097     EphEp 9, p. 689 n. 1388b.; RIB 1933; Zeichnung.
# 88882   AE 1896, 0100. (B); H. Lehner, KWDZ 15, 1896, ...
# 94205                        RIB 3385; Foto u. Zeichnung.
# 93467      EphEp 9, p. 593 n. 1189.; RIB 1670; Zeichnung.
# 93626      EphEp 9, p. 567 n. 1126.; RIB 0940; Zeichnung.
# ...                                                   ...
# 105232  AE 1930, 0033.; AE 1939, p. 74 s. n. 235.; H. ...
# 95760   AE 1933, 0020.; O. Floca, AISC 1, 1, 1928-1932...
# 124730  RIU 1489; Abb. 1489 (Zeichnung).; CIMRM 1814.;...
# 127994  AIJ 330; Foto.; AIJ 330 add. p. 5*.; G. Alföld...
# 95045                IDR 3, 5, 167; Foto.; CIL 03, 06260.
#
#                  work_status     height  \
# 94097   checked with drawing  (40.6) cm
# 88882     checked with photo    (27) cm
# 94205     checked with photo      18 cm
# 93467   checked with drawing    20.3 cm
# 93626   checked with drawing       None
# ...                      ...        ...
# 105232    checked with photo    (62) cm
# 95760     checked with photo      58 cm
# 124730  checked with drawing       None
# 127994    checked with photo      52 cm
# 95045     checked with photo     110 cm
#
#                                           diplomatic_text  \
# 94097                             [ ] SIL / [ ]C[ ] / [ ]
# 88882   IN H D D DEO MARTI INTA / RABO VITALIVS VICTOR...
# 94205                                 | CALEDON / SECVNDI
# 93467                                | ROMV / LEI / IVSTI
# 93626                      [ ]VG VEX / [ ]X [ ] VIC / [ ]
# ...                                                   ...
# 105232  [ ] O M ET GEN LOC / [ ] TVTELLAE / MATVRINIVS...
# 95760   SILVANO SI / LVESTRI PO / SVIT FOR / TVNATVS /...
# 124730      [ ] M / [ ] / [ ] / [ ]M / [ ]N / [ ]ES / [ ]
# 127994       NVTRICIBVS AVG / VAL SECVNNDIANS / V S L L M
# 95045         I O M / AVL TAPETIVS / AMETHYSTVS / V S L M
#
#                                                    people    depth  \
# 94097                                                  {}     None
# 88882   [{'nomen': 'Vitalius', 'person_id': '1', 'name...    19 cm
# 94205   [{'gender': 'male', 'person_id': '1', 'cognome...  30.5 cm
# 93467   [{'name': 'Romulei Iusti', 'cognomen': 'Iustus...     None
# 93626                                                  {}     None
# ...                                                   ...      ...
# 105232  [{'cognomen': 'Victor', 'nomen': 'Maturnius', ...     None
# 95760   [{'cognomen': 'Fortunatus', 'name': 'Fortunatu...    20 cm
# 124730  [{'gender': 'male', 'praenomen': '[-]', 'name'...     None
# 127994  [{'person_id': '1', 'nomen': 'Valerius*', 'gen...     6 cm
# 95045   [{'cognomen': 'Amethystus', 'praenomen': 'A.',...    57 cm
#
#                                     material type_of_monument  \
# 94097   sandstone: rocks - clastic sediments             slab
# 88882   limestone: rocks - clastic sediments            block
# 94205   sandstone: rocks - clastic sediments            block
# 93467   sandstone: rocks - clastic sediments            block
# 93626   sandstone: rocks - clastic sediments           block?
# ...                                      ...              ...
# 105232  limestone: rocks - clastic sediments            altar
# 95760                                   None             base
# 124730  limestone: rocks - clastic sediments            altar
# 127994                          Marmor, weiß           relief
# 95045   limestone: rocks - clastic sediments            altar
#
#            province_label      width  \
# 94097           Britannia  (27.9) cm
# 88882             Belgica      88 cm
# 94205           Britannia      28 cm
# 93467           Britannia    20.3 cm
# 93626           Britannia       None
# ...                   ...        ...
# 105232  Germania inferior    (37) cm
# 95760               Dacia      28 cm
# 124730  Pannonia inferior       None
# 127994  Pannonia superior      35 cm
# 95045               Dacia      65 cm
#
#                                             transcription         country  \
# 94097                     [---] SIL / [--- A]C[-] / [---]  United Kingdom
# 88882   In h(onorem) d(omus) d(ivinae) deo Marti Inta/...         Germany
# 94205                    |(Centuria) Caledon(i) / Secundi  United Kingdom
# 93467                        |(centuria) Romu/lei / Iusti  United Kingdom
# 93626   [Num(inibus) A]ug(ustorum) vex(illatio) / [leg...  United Kingdom
# ...                                                   ...             ...
# 105232  [I(ovi)] O(ptimo) M(aximo) et Gen(io) loc(i) /...         Germany
# 95760   Silvano Si/lvestri po/suit For/tunatus / Theup...         Romania
# 124730  [D(eo) I(nvicto) S(oli)] M(ithrae) / [------] ...         Hungary
# 127994  Nutricibus Aug(ustis) / Val(erius) Secun{n}dia...        Slovenia
# 95045   I(ovi) O(ptimo) M(aximo) / Aul(us) Tapetius / ...         Romania
#
#                                                       uri    findspot_ancient  \
# 94097   https://edh-www.adw.uni-heidelberg.de/edh/insc...                None
# 88882   https://edh-www.adw.uni-heidelberg.de/edh/insc...  Augusta Treverorum
# 94205   https://edh-www.adw.uni-heidelberg.de/edh/insc...              Magnae
# 93467   https://edh-www.adw.uni-heidelberg.de/edh/insc...                None
# 93626   https://edh-www.adw.uni-heidelberg.de/edh/insc...              Voreda
# ...                                                   ...                 ...
# 105232  https://edh-www.adw.uni-heidelberg.de/edh/insc...               Bonna
# 95760   https://edh-www.adw.uni-heidelberg.de/edh/insc...                None
# 124730  https://edh-www.adw.uni-heidelberg.de/edh/insc...       Aquincum, bei
# 127994  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Poetovio
# 95045   https://edh-www.adw.uni-heidelberg.de/edh/insc...              Apulum
#
#        last_update                 modern_region  \
# 94097   2017-12-04                       Cumbria
# 88882   2018-12-11               Rheinland-Pfalz
# 94205   2020-03-10                Northumberland
# 93467   2017-03-07                Northumberland
# 93626   2017-12-15                       Cumbria
# ...            ...                           ...
# 105232  2020-02-11           Nordrhein-Westfalen
# 95760   2008-02-29                          Cluj
# 124730  2017-05-04                   Fejér megye
# 127994  2015-08-26  Podravska statistična regija
# 95045   2013-06-21                          Alba
#
#                                findspot_modern  \
# 94097      Birdoswald - Castlesteads, zwischen
# 88882                                    Trier
# 94205                                 Carvoran
# 93467   Housesteads - Great Chesters, zwischen
# 93626                                 Plumpton
# ...                                        ...
# 105232                                    Bonn
# 95760                                 Chinteni
# 124730                                Sárkeszi
# 127994                                    Ptuj
# 95045                               Alba Iulia
#
#                                         edh_geography_uri  \
# 94097   https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 88882   https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 94205   https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 93467   https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 93626   https://edh-www.adw.uni-heidelberg.de/edh/geog...
# ...                                                   ...
# 105232  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 95760   https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 124730  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 127994  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 95045   https://edh-www.adw.uni-heidelberg.de/edh/geog...
#
#                                                commentary  \
# 94097                                                None
# 88882    (B): Z. 3 Mallus statt Maiius (CIL bietet Les...
# 94205                                                None
# 93467                                                None
# 93626                                                None
# ...                                                   ...
# 105232                                               None
# 95760    Basis; darauf noch der untere Teil eines Reli...
# 124730   Möglicherweise zusammengehörig mit CIMRM 1813...
# 127994   Z. 2 (Ende): möglicherweise auch Secun{n}dian...
# 95045       Linker oberer Teil des Altars nicht erhalten.
#
#                                 trismegistos_uri   external_image_uris  \
# 94097   https://www.trismegistos.org/text/156426                    {}
# 88882   https://www.trismegistos.org/text/208305                    {}
# 94205   https://www.trismegistos.org/text/167480                    {}
# 93467   https://www.trismegistos.org/text/156163                    {}
# 93626   https://www.trismegistos.org/text/155433                    {}
# ...                                          ...                   ...
# 105232  https://www.trismegistos.org/text/209355                    {}
# 95760   https://www.trismegistos.org/text/179143  http://lupa.at/15105
# 124730  https://www.trismegistos.org/text/194613                    {}
# 127994  https://www.trismegistos.org/text/407207                    {}
# 95045   https://www.trismegistos.org/text/179009  http://lupa.at/11504
#
#                                                     fotos idno_tm  \
# 94097                                                  {}  156426
# 88882                                                  {}  208305
# 94205                                                  {}  167480
# 93467                                                  {}  156163
# 93626                                                  {}  155433
# ...                                                   ...     ...
# 105232  https://edh-www.adw.uni-heidelberg.de/fotos/F0...  209355
# 95760   https://edh-www.adw.uni-heidelberg.de/fotos/F0...  179143
# 124730                                                 {}  194613
# 127994                                                 {}  407207
# 95045   ['https://edh-www.adw.uni-heidelberg.de/fotos/...  179009
#
#                                           placenames_refs  \
# 94097   ['http://www.trismegistos.org/place/003201', '...
# 88882   ['http://www.trismegistos.org/place/023540', '...
# 94205                                                  []
# 93467   ['http://www.trismegistos.org/place/003201', '...
# 93626   ['http://www.trismegistos.org/place/003201', '...
# ...                                                   ...
# 105232  ['http://www.trismegistos.org/place/016530', '...
# 95760   ['http://www.trismegistos.org/place/004366', '...
# 124730  ['http://www.trismegistos.org/place/016529', '...
# 127994  ['http://www.trismegistos.org/place/016532', '...
# 95045   ['http://www.trismegistos.org/place/004366', '...
#
#                                              text_edition  \
# 94097                                             SIL AC
# 88882                   In honorem domus divinae deo M...
# 94205                   |(Centuria) Caledoni Secundi  ...
# 93467                 centuria Romulei Iusti
# 93626   Numinibus Augustorum vexillatio legionis XX Va...
# ...                                                   ...
# 105232  Iovi Optimo Maximo et Genio loci et Tutellae s...
# 95760                   Silvano Silvestri posuit Fortu...
# 124730  Deo Invicto Soli Mithrae   templum vetustate c...
# 127994                  Nutricibus Augustis Valerius S...
# 95045   Iovi Optimo Maximo Aulus Tapetius Amethystus v...
#
#                                       origdate_text layout_execution  \
# 94097   122 AD – 138 AD                                           21
# 88882     1 AD – 300 AD                                           21
# 94205   125 AD – 128 AD                                           21
# 93467   122 AD – 138 AD                                           21
# 93626   122 AD – 300 AD                                           21
# ...                                             ...              ...
# 105232           226 AD                                           21
# 95760   107 AD – 275 AD                                           21
# 124730  101 AD – 300 AD                                           21
# 127994  201 AD – 300 AD                                           21
# 95045   131 AD – 250 AD                                           21
#
#        layout_execution_text  support_objecttype support_objecttype_text  \
# 94097             unbestimmt               309.0                  Platte
# 88882             unbestimmt               189.0                   Block
# 94205             unbestimmt               189.0                   Block
# 93467             unbestimmt               189.0                   Block
# 93626             unbestimmt               189.0                  Block?
# ...                      ...                 ...                     ...
# 105232            unbestimmt                29.0                   Altar
# 95760             unbestimmt                53.0                   Basis
# 124730            unbestimmt                29.0                   Altar
# 127994            unbestimmt                24.0                  Relief
# 95045             unbestimmt                29.0                   Altar
#
#        support_material support_material_text  support_decoration  \
# 94097                75             Sandstein              1000.0
# 88882                60             Kalkstein              1000.0
# 94205                75             Sandstein              1000.0
# 93467                75             Sandstein              1000.0
# 93626                75             Sandstein              1000.0
# ...                 ...                   ...                 ...
# 105232               60             Kalkstein              1000.0
# 95760               138            unbestimmt              2000.0
# 124730               60             Kalkstein              1000.0
# 127994               48          Marmor, weiß              2000.0
# 95045                60             Kalkstein              2000.0
#
#        keywords_term      keywords_term_text        type_of_inscription_clean  \
# 94097            261  Bau-/Stifterinschrift?  building/dedicatory inscription
# 88882            261   Bau-/Stifterinschrift  building/dedicatory inscription
# 94205            261   Bau-/Stifterinschrift  building/dedicatory inscription
# 93467            261   Bau-/Stifterinschrift  building/dedicatory inscription
# 93626            261   Bau-/Stifterinschrift  building/dedicatory inscription
# ...              ...                     ...                              ...
# 105232            80           Weihinschrift               votive inscription
# 95760             80           Weihinschrift               votive inscription
# 124730            80           Weihinschrift               votive inscription
# 127994            80           Weihinschrift               votive inscription
# 95045             80           Weihinschrift               votive inscription
#
#        type_of_inscription_certainty  height_cm  width_cm  depth_cm  \
# 94097                      Uncertain       40.6      27.9       NaN
# 88882                        Certain       27.0      88.0      19.0
# 94205                        Certain       18.0      28.0      30.5
# 93467                        Certain       20.3      20.3       NaN
# 93626                        Certain        NaN       NaN       NaN
# ...                              ...        ...       ...       ...
# 105232                       Certain       62.0      37.0       NaN
# 95760                        Certain       58.0      28.0      20.0
# 124730                       Certain        NaN       NaN       NaN
# 127994                       Certain       52.0      35.0       6.0
# 95045                        Certain      110.0      65.0      57.0
#
#        material_clean type_of_monument_clean type_of_monument_certainty  \
# 94097       Sandstone                   slab                    Certain
# 88882       Limestone                  block                    Certain
# 94205       Sandstone                  block                    Certain
# 93467       Sandstone                  block                    Certain
# 93626       Sandstone                  block                  Uncertain
# ...               ...                    ...                        ...
# 105232      Limestone                  altar                    Certain
# 95760            NULL                   base                    Certain
# 124730      Limestone                  altar                    Certain
# 127994         Marble                 relief                    Certain
# 95045       Limestone                  altar                    Certain
#
#        province_label_clean province_label_certainty   country_clean  \
# 94097             Britannia                  Certain  United Kingdom
# 88882               Belgica                  Certain         Germany
# 94205             Britannia                  Certain  United Kingdom
# 93467             Britannia                  Certain  United Kingdom
# 93626             Britannia                  Certain  United Kingdom
# ...                     ...                      ...             ...
# 105232    Germania inferior                  Certain         Germany
# 95760                 Dacia                  Certain         Romania
# 124730    Pannonia inferior                  Certain         Hungary
# 127994    Pannonia superior                  Certain        Slovenia
# 95045                 Dacia                  Certain         Romania
#
#        country_certainty findspot_ancient_clean findspot_ancient_certainty  \
# 94097            Certain                   NULL                       NULL
# 88882            Certain     Augusta Treverorum                    Certain
# 94205            Certain                 Magnae                    Certain
# 93467            Certain                   NULL                       NULL
# 93626            Certain                 Voreda                    Certain
# ...                  ...                    ...                        ...
# 105232           Certain                  Bonna                    Certain
# 95760            Certain                   NULL                       NULL
# 124730           Certain               Aquincum                  Estimated
# 127994           Certain               Poetovio                    Certain
# 95045            Certain                 Apulum                    Certain
#
#                  modern_region_clean modern_region_certainty  \
# 94097                        Cumbria                 Certain
# 88882                Rheinland-Pfalz                 Certain
# 94205                 Northumberland                 Certain
# 93467                 Northumberland                 Certain
# 93626                        Cumbria                 Certain
# ...                              ...                     ...
# 105232           Nordrhein-Westfalen                 Certain
# 95760                           Cluj                 Certain
# 124730                   Fejér megye                 Certain
# 127994  Podravska statistična regija                 Certain
# 95045                           Alba                 Certain
#
#                          findspot_modern_clean findspot_modern_certainty  \
# 94097      Birdoswald - Castlesteads, zwischen                   Certain
# 88882                                    Trier                   Certain
# 94205                                 Carvoran                   Certain
# 93467   Housesteads - Great Chesters, zwischen                   Certain
# 93626                                 Plumpton                   Certain
# ...                                        ...                       ...
# 105232                                    Bonn                   Certain
# 95760                                 Chinteni                   Certain
# 124730                                Sárkeszi                   Certain
# 127994                                    Ptuj                   Certain
# 95045                               Alba Iulia                   Certain
#
#                                            findspot_clean findspot_certainty  \
# 94097                                       Milecastle 50            Certain
# 88882                                          Saarstraße            Certain
# 94205                           Turret 45 A, westlich von            Certain
# 93467                                  Milecastle 42, bei            Certain
# 93626                                                NULL               NULL
# ...                                                   ...                ...
# 105232  Münster, unter, frühchristlicher Bau (Märtyrer...          Uncertain
# 95760                                           Satu Lung            Certain
# 124730                                Ságivölgy, Mithräum            Certain
# 127994  Zgornji Breg, Parzelle Nr. 293 (alter Kataster...            Certain
# 95045                                              Partoş            Certain
#
#        origdate_text_clean                            clean_text_conservative  \
# 94097      122 AD – 138 AD                                              SIL C
# 88882        1 AD – 300 AD  In h d d deo Marti Intarabo Vitalius Victorinu...
# 94205      125 AD – 128 AD                                    Caledon Secundi
# 93467      122 AD – 138 AD                                      Romulei Iusti
# 93626      122 AD – 300 AD                                       ug vex X vic
# ...                    ...                                                ...
# 105232              226 AD  O M et Gen loc Tutellae Maturinius Victor sign...
# 95760      107 AD – 275 AD  Silvano Silvestri posuit Fortunatus Theupropi ...
# 124730     101 AD – 300 AD                                            M m nes
# 127994     201 AD – 300 AD           Nutricibus Aug Val Secunndians v s l l m
# 95045      131 AD – 250 AD              I O M Aul Tapetius Amethystus v s l m
#
#                          clean_text_interpretive_sentence  \
# 94097                                              SIL AC
# 88882   In honorem domus divinae deo Marti Intarabo Vi...
# 94205                           Centuria Caledoni Secundi
# 93467                              centuria Romulei Iusti
# 93626   Numinibus Augustorum vexillatio legionis XX Va...
# ...                                                   ...
# 105232  Iovi Optimo Maximo et Genio loci et Tutellae M...
# 95760   Silvano Silvestri posuit Fortunatus Theupropi ...
# 124730  Deo Invicto Soli Mithrae templum vetustate con...
# 127994  Nutricibus Augustis Valerius Secunndianus votu...
# 95045   Iovi Optimo Maximo Aulus Tapetius Amethystus v...
#
#                                                  findspot year_of_find  \
# 94097                                       Milecastle 50         1911
# 88882                                          Saarstraße         1896
# 94205                           Turret 45 A, westlich von         1959
# 93467                                  Milecastle 42, bei         1905
# 93626                                                None  before 1688
# ...                                                   ...          ...
# 105232  Münster, unter, frühchristlicher Bau (Märtyrer...         1928
# 95760                                           Satu Lung         None
# 124730                                Ságivölgy, Mithräum         None
# 127994  Zgornji Breg, Parzelle Nr. 293 (alter Kataster...         1911
# 95045                                              Partoş         None
#
#                                         present_location  \
# 94097                        Carlisle, Tullie House Mus.
# 88882                           Trier, Rhein. Landesmus.
# 94205                Newcastle upon Tyne, Mus. of Antiq.
# 93467   Newcastle upon Tyne, Great North Museum, Hancock
# 93626                                               lost
# ...                                                  ...
# 105232                           Bonn, Rhein. Landesmus.
# 95760              Cluj-Napoca, Muz. Naţ. Ist. Transilv.
# 124730          Székesfehérvár, Szent István Király Múz.
# 127994                         Maribor, Pokrajinski Muz.
# 95045                             Sibiu, Muz. Brukenthal
#
#                       religion       geography social_economic_legal_history  \
# 94097                     None            None                          None
# 88882   names of pagan deities            None                          None
# 94205                     None            None                          None
# 93467                     None            None                          None
# 93626                     None            None                          None
# ...                        ...             ...                           ...
# 105232  names of pagan deities            None                          None
# 95760   names of pagan deities            None                          None
# 124730  names of pagan deities  data available                          None
# 127994  names of pagan deities            None                          None
# 95045   names of pagan deities            None                          None
#
#               military  not_after language  not_before         coordinates  \
# 94097             None      138.0    Latin       122.0  [-2.6161, 54.9872]
# 88882             None      300.0    Latin         1.0    [6.6344, 49.744]
# 94205   data available      128.0    Latin       125.0  [-2.5129, 54.9901]
# 93467   data available      138.0    Latin       122.0   [-2.442, 54.9952]
# 93626   data available      300.0    Latin       122.0  [-2.7881, 54.7381]
# ...                ...        ...      ...         ...                 ...
# 105232            None        NaN    Latin       226.0   [7.0996, 50.7334]
# 95760             None      275.0    Latin       107.0  [23.5997, 46.9077]
# 124730            None      300.0    Latin       101.0   [18.285, 47.1583]
# 127994            None      300.0    Latin       201.0  [15.8544, 46.4165]
# 95045             None      250.0    Latin       131.0  [23.5667, 46.0463]
#
#                              clean_text_interpretive_word urban_context  \
# 94097                                              SIL AC          rest
# 88882   In honorem domus divinae deo Marti Intarabo Vi...        middle
# 94205                           Centuria Caledoni Secundi          rest
# 93467                              centuria Romulei Iusti          rest
# 93626   Numinibus Augustorum vexillatio legionis XX Va...          rest
# ...                                                   ...           ...
# 105232  Iovi Optimo Maximo et Genio loci et Tutellae M...          rest
# 95760   Silvano Silvestri posuit Fortunatus Theupropi ...        middle
# 124730  Deo Invicto Soli Mithrae templum vetustate con...          rest
# 127994  Nutricibus Augustis Valerius Secunndianus votu...          rest
# 95045   Iovi Optimo Maximo Aulus Tapetius Amethystus v...        middle
#
#         within_rome                nearest_city city_id_hanson  city_pop_est  \
# 94097         False                  Luguvalium            400        3590.0
# 88882         False  Colonia Augusta Treverorum            587       28210.0
# 94205         False                  Luguvalium            400        3590.0
# 93467         False                 Corstopitum            388        1700.0
# 93626         False                  Luguvalium            400        3590.0
# ...             ...                         ...            ...           ...
# 105232        False       Colonia Agrippinensis            660       13391.0
# 95760         False                      Napoca            496        5399.0
# 124730        False                     Gorsium           1271         359.0
# 127994        False                    Poetovio           1235        1000.0
# 95045         False                  Apulum (2)            493       16831.0
#
#                  city_geometry nearest_city_type  nearest_city_dist  \
# 94097    [-2.938982, 54.89532]            middle           0.335700
# 88882    [6.637075, 49.752611]            middle           0.009017
# 94205    [-2.938982, 54.89532]            middle           0.436496
# 93467   [-2.029155, 54.978122]            middle           0.413198
# 93626    [-2.938982, 54.89532]            middle           0.217907
# ...                        ...               ...                ...
# 105232   [6.959912, 50.940664]            middle           0.249942
# 95760    [23.60429, 46.776306]            middle           0.131474
# 124730   [18.419781, 47.09017]             minor           0.151022
# 127994  [15.869928, 46.419789]             minor           0.015873
# 95045   [23.572315, 46.066695]            middle           0.021154
#
#                          geometry
# 94097   POINT (-2.61610 54.98720)
# 88882    POINT (6.63440 49.74400)
# 94205   POINT (-2.51290 54.99010)
# 93467   POINT (-2.44200 54.99520)
# 93626   POINT (-2.78810 54.73810)
# ...                           ...
# 105232   POINT (7.09960 50.73340)
# 95760   POINT (23.59970 46.90770)
# 124730  POINT (18.28500 47.15830)
# 127994  POINT (15.85440 46.41650)
# 95045   POINT (23.56670 46.04630)
#
# [30000 rows x 110 columns]

# %%
EDH_sampled_minor = EDH_overlap[EDH_overlap["type_of_inscription_clean"].isin(EDH_minor_cats)].groupby("type_of_inscription_clean").sample(frac=5, replace=True, random_state=1)
len(EDH_sampled_minor) # 2712
# Out:
# 13560

# %%
EDH_sampled = pd.concat([EDH_sampled_major, EDH_sampled_minor])
EDH_sampled.groupby("type_of_inscription_clean").size().sort_values(ascending=False)
# Out:
# type_of_inscription_clean
# votive inscription                 5000
# mile-/leaguestone                  5000
# building/dedicatory inscription    5000
# epitaph                            5000
# honorific inscription              5000
# owner/artist inscription           5000
# identification inscription         4250
# acclamation                        1435
# defixio                            1345
# list                               1230
# military diploma                   1045
# label                               970
# boundary inscription                875
# elogium                             660
# letter                              595
# public legal inscription            545
# seat inscription                    210
# private legal inscription           180
# prayer                               90
# assignation inscription              75
# calendar                             50
# adnuntiatio                           5
# dtype: int64

# %% [markdown]
# # Without resampling

# %%
# alternative, treat whole dataset as a sample
EDH_sampled = EDH_overlap

# %%
# random shuffle
EDH_sampled = EDH_sampled.sample(frac=1)

# %%
y = EDH_sampled["type_of_inscription_clean"].tolist()

# %% [markdown]
# # Minimal model based on `status_list` only

# %%
EDH_sampled["status"].tolist()[:10]
# Out:
# ['nomen singulare; sigilla impressa; tituli fabricationis; viri',
#  'liberti/libertae; tituli sepulcrales; tria nomina; viri',
#  'nomen singulare; servi/servae; tituli sacri; viri',
#  'tituli sacri',
#  'mulieres; nomen singulare; tituli sacri; tria nomina; viri',
#  'tituli sepulcrales',
#  'milites; tituli operum',
#  None,
#  'tituli sepulcrales',
#  'mulieres; tituli sepulcrales; tria nomina; viri']

# %%
# among other information, status list also contains an information about inscription type:
EDH_sampled["inscr_type"].tolist()[:10]
# Out:
# ['tituli fabricationis',
#  'tituli sepulcrales',
#  'tituli sacri',
#  'tituli sacri',
#  'tituli sacri',
#  'tituli sepulcrales',
#  'tituli operum',
#  {},
#  'tituli sepulcrales',
#  'tituli sepulcrales']

# %%
# for some applications, it will be useful to transform it into string, with all two-word phrases treated as one word 
# (therefore underscore)
status_lists = []
for el in EDH_sampled["status_list"].tolist():
    try: el = eval(el)
    except: pass
    if isinstance(el, list):
        new_el = el
    elif isinstance(el, str):
        new_el = [el]
    else: 
        new_el = []
    new_el = " ".join([el.replace(" ", "_") for el in new_el])
    status_lists.append(new_el)

# %%
status_lists[:10]
# Out:
# ['nomen_singulare sigilla_impressa tituli_fabricationis viri',
#  'liberti/libertae tituli_sepulcrales tria_nomina viri',
#  'nomen_singulare servi/servae tituli_sacri viri',
#  'tituli_sacri',
#  'mulieres nomen_singulare tituli_sacri tria_nomina viri',
#  'tituli_sepulcrales',
#  'milites tituli_operum',
#  '',
#  'tituli_sepulcrales',
#  'mulieres tituli_sepulcrales tria_nomina viri']

# %% [markdown]
# # Build a SVM model combining `status_list` & `clean_text_interpretive_word`

# %% [markdown]
# next step would be to build a model combining the information from the `status_list` with an informatation from the text of the inscription (i.e. `clean_text_interpretive_word`).

# %%
EDH_sampled.head(5)
# Out:
#               EDCS-ID                                        publication  \
# 83509   EDCS-04900946                                    AE 1992, 01553f
# 111088  EDCS-05502848          CIL 02, 03465 = CartNova 00097 = D 05256a
# 104209  EDCS-06100231  AE 1989, 00305 = AE 2006, +00106 = AE 2007, +0...
# 85137   EDCS-63600160                                   AlpCott-G, 00138
# 118951  EDCS-14400096  CSIR-Oe-02-05, 00441 = ILLPRON 00214 = Gerstl ...
#
#                    province        province_list  \
# 83509                Achaia               Achaia
# 111088    Hispania citerior    Hispania citerior
# 104209  Etruria / Regio VII  Etruria / Regio VII
# 85137         Alpes Cottiae        Alpes Cottiae
# 118951              Noricum              Noricum
#
#                                            place  \
# 83509                 Athens / Athinai / Athenae
# 111088                 Cartagena / Carthago Nova
# 104209                Cerveteri / Agylla / Caere
# 85137   Montgenevre / Monte Genevris / Druantium
# 118951                       Landskron / Virunum
#
#                                             place_list end_yr_list  \
# 83509                 ['Athens', 'Athinai', 'Athenae']         100
# 111088                  ['Cartagena', 'Carthago Nova']          30
# 104209                ['Cerveteri', 'Agylla', 'Caere']         300
# 85137   ['Montgenevre', 'Monte Genevris', 'Druantium']         355
# 118951                        ['Landskron', 'Virunum']         170
#
#        notes_dating                                        status_list  \
# 83509                ['nomen singulare', 'sigilla impressa', 'titul...
# 111088               ['liberti/libertae', 'tituli sepulcrales', 'tr...
# 104209               ['nomen singulare', 'servi/servae', 'tituli sa...
# 85137                                                     tituli sacri
# 118951               ['mulieres', 'nomen singulare', 'tituli sacri'...
#
#                   inscr_type  \
# 83509   tituli fabricationis
# 111088    tituli sepulcrales
# 104209          tituli sacri
# 85137           tituli sacri
# 118951          tituli sacri
#
#                                           status_notation     inscr_process  \
# 83509                         ['nomen singulare', 'viri']  sigilla impressa
# 111088        ['liberti/libertae', 'tria nomina', 'viri']                {}
# 104209        ['nomen singulare', 'servi/servae', 'viri']                {}
# 85137                                                  {}                {}
# 118951  ['mulieres', 'nomen singulare', 'tria nomina',...                {}
#
#        notes_references notes_comments  \
# 83509
# 111088
# 104209
# 85137
# 118951
#
#                                               inscription  \
# 83509                                               Marus
# 111088  L(ucius) Fufius L(uci) l(ibertus) / Varus / pi...
# 104209  Iovi Font[i] / Aquar(um) Caeretanar(um) / Flor...
# 85137   [3]O[3]CEL[3] / [3] v(otum) [s(olvit) l(ibens)...
# 118951  [V]ocretan[o] / Aug(usto) sacrum / [3] Iul(ius...
#
#                                inscription_stripped_final  \
# 83509                                               Marus
# 111088  L(ucius) Fufius L(uci) l(ibertus) / Varus / pi...
# 104209  Iovi Font[i] / Aquar(um) Caeretanar(um) / Flor...
# 85137   [3]O[3]CEL[3] / [3] v(otum) [s(olvit) l(ibens)...
# 118951  [V]ocretan[o] / Aug(usto) sacrum / [3] Iul(ius...
#
#                                                     Links  dating from  \
# 83509   http://db.edcs.eu/epigr/partner.php?s_language...       -100.0
# 111088  http://db.edcs.eu/epigr/partner.php?s_language...          1.0
# 104209  http://db.edcs.eu/epigr/partner.php?s_language...        101.0
# 85137   http://db.edcs.eu/epigr/partner.php?s_language...          1.0
# 118951  http://db.edcs.eu/epigr/partner.php?s_language...        131.0
#
#        dating to                                             status  \
# 83509        100  nomen singulare; sigilla impressa; tituli fabr...
# 111088        30  liberti/libertae; tituli sepulcrales; tria nom...
# 104209       300  nomen singulare; servi/servae; tituli sacri; viri
# 85137        355                                       tituli sacri
# 118951       170  mulieres; nomen singulare; tituli sacri; tria ...
#
#          Latitude  Longitude photo       Material Comment    EDH-ID  \
# 83509   37.984149  23.727984  None  opus figlinae    None  HD053831
# 111088  37.626787  -1.000618  None           None    None  HD037640
# 104209  41.998360  12.098851  None           None    None  HD015033
# 85137   44.930013   6.718415  None           None    None  HD066278
# 118951  46.633637  13.887272  None          lapis    None  HD042471
#
#        language_EDCS                  clean_text_interpretive_word_EDCS  \
# 83509           None                                              Marus
# 111088          None  Lucius Fufius Luci libertus Varus pius vixit s...
# 104209          None  Iovi Fonti Aquarum Caeretanarum Florentinus Au...
# 85137           None                   O CEL votum solvit libens merito
# 118951          None  Vocretano Augusto sacrum Iulius Tertius et Max...
#
#        responsible_individual       type_of_inscription letter_size  \
# 83509                   Cowey  owner/artist inscription        None
# 111088                 Garcia                   epitaph        None
# 104209                   Gräf        votive inscription    2-2.5 cm
# 85137               Cimarosti        votive inscription        None
# 118951                   Gräf        votive inscription        None
#
#                                                literature         work_status  \
# 83509   AE 1992, 1553f.; B. Böttger, MDAI(A) 107, 1992...  checked with photo
# 111088  J.M. Abascal Palazón - S.F. Ramallo Asensio, L...            no image
# 104209  AE 1989, 0305.; R. Consentino - P. Sabbatini T...  checked with photo
# 85137   C.F. Capello, RII 7, 1941, 127, Nr. 205.; E. C...            no image
# 118951  AE 1959, 0150a.; ILLPRON 0214.; P.S. Leber, Di...  checked with photo
#
#           height                                    diplomatic_text  \
# 83509       None                                              MARVS
# 111088      None          L FVFIVS L L / VARVS / PIVS VIXIT / SALVE
# 104209  (106) cm  IOVI FONT[ ] / AQVAR CAERETANAR / FLORENTINVS ...
# 85137       None                        [ ]O[ ]CEL[ ] / [ ] V [ ] M
# 118951   (72) cm  [ ]OCRETAN[ ] / AVG SACRVM / [ ] IVL [ ]ERTIV[...
#
#                                                    people    depth  \
# 83509   [{'name': 'Marus', 'gender': 'male', 'cognomen...     None
# 111088  [{'status': 'freedmen / freedwomen', 'nomen': ...     None
# 104209  [{'name': 'Florentinus Aug.', 'person_id': '1'...     None
# 85137                                                  {}     None
# 118951  [{'gender': 'male', 'nomen': 'Iulius*', 'perso...  (38) cm
#
#                         material         type_of_monument  \
# 83509                       None  instrumentum domesticum
# 111088                      None                  tabula?
# 104209                      None                     base
# 85137                        Ton      instrumentum sacrum
# 118951  Marmor, geädert / farbig                    altar
#
#              province_label    width  \
# 83509                Achaia     None
# 111088    Hispania citerior     None
# 104209  Etruria (Regio VII)    30 cm
# 85137         Alpes Cottiae     None
# 118951              Noricum  (45) cm
#
#                                             transcription  country  \
# 83509                                               Marus   Greece
# 111088  L(ucius) Fufius L(uci) l(ibertus) / Varus / pi...    Spain
# 104209  Iovi Font[i] / Aquar(um) Caeretanar(um) / Flor...    Italy
# 85137   [---]O[---]CEL[---] / [---] v(otum) [s(olvit) ...    Italy
# 118951  [V]ocretan[o] / Aug(usto) sacrum / [-] Iul(ius...  Austria
#
#                                                       uri findspot_ancient  \
# 83509   https://edh-www.adw.uni-heidelberg.de/edh/insc...          Athenae
# 111088  https://edh-www.adw.uni-heidelberg.de/edh/insc...    Carthago Nova
# 104209  https://edh-www.adw.uni-heidelberg.de/edh/insc...       Caere, bei
# 85137   https://edh-www.adw.uni-heidelberg.de/edh/insc...        Ad Martis
# 118951  https://edh-www.adw.uni-heidelberg.de/edh/insc...    Santicum, bei
#
#        last_update modern_region findspot_modern  \
# 83509   2011-05-02        Attikí         Athínai
# 111088  2005-07-19          None       Cartagena
# 104209  2004-07-06          None  Cerveteri, bei
# 85137   2013-07-18      Piemonte    Sauze d'Oulx
# 118951  2014-07-15       Kärnten         Villach
#
#                                         edh_geography_uri  \
# 83509   https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 111088  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 104209  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 85137   https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 118951  https://edh-www.adw.uni-heidelberg.de/edh/geog...
#
#                                                commentary  \
# 83509                                    Amphorenstempel.
# 111088   Inschrift verschollen. Ursprünglich aus der n...
# 104209            Kleine Säule; wohl Basis für ein Votiv.
# 85137                                 Cronologia incerta.
# 118951   Zwei fast aneinanderpassende Fragmente; Maße ...
#
#                                 trismegistos_uri  external_image_uris fotos  \
# 83509   https://www.trismegistos.org/text/177285                   {}    {}
# 111088  https://www.trismegistos.org/text/229039                   {}    {}
# 104209  https://www.trismegistos.org/text/248121                   {}    {}
# 85137   https://www.trismegistos.org/text/654775                   {}    {}
# 118951  https://www.trismegistos.org/text/215473  http://lupa.at/6370    {}
#
#        idno_tm                                    placenames_refs  \
# 83509   177285                                                 []
# 111088  229039  ['http://www.trismegistos.org/place/016933', '...
# 104209  248121                                                 []
# 85137   654775  ['http://www.trismegistos.org/place/022433', '...
# 118951  215473  ['http://www.trismegistos.org/place/003230', '...
#
#                                              text_edition  \
# 83509                                  Marus
# 111088  Lucius Fufius Luci libertus Varus pius vixit s...
# 104209                  Iovi Fonti Aquarum Caeretanaru...
# 85137                    OCEL  votum solvit libens merito
# 118951  Vocretano Augusto sacrum  Iulius Tertius et Ma...
#
#                                       origdate_text layout_execution  \
# 83509   100 BC – 100 AD                                           21
# 111088     1 AD – 30 AD                                           21
# 104209    1 AD – 100 AD                                           21
# 85137     1 AD – 355 AD                                           21
# 118951  131 AD – 170 AD                                           21
#
#        layout_execution_text  support_objecttype  support_objecttype_text  \
# 83509             unbestimmt               140.0  Instrumentum domesticum
# 111088            unbestimmt               257.0                   Tafel?
# 104209            unbestimmt                53.0                    Basis
# 85137             unbestimmt               142.0      Instrumentum sacrum
# 118951            unbestimmt                29.0                    Altar
#
#        support_material     support_material_text  support_decoration  \
# 83509               138                unbestimmt              1000.0
# 111088              138                unbestimmt              1000.0
# 104209              138                unbestimmt              1000.0
# 85137               131                       Ton              1000.0
# 118951                   Marmor, geädert / farbig              2000.0
#
#        keywords_term             keywords_term_text type_of_inscription_clean  \
# 83509            311  Besitzer-/Herstellerinschrift  owner/artist inscription
# 111088            92                  Grabinschrift                   epitaph
# 104209            80                  Weihinschrift        votive inscription
# 85137             80                  Weihinschrift        votive inscription
# 118951            80                  Weihinschrift        votive inscription
#
#        type_of_inscription_certainty  height_cm  width_cm  depth_cm  \
# 83509                        Certain        NaN       NaN       NaN
# 111088                       Certain        NaN       NaN       NaN
# 104209                       Certain      106.0      30.0       NaN
# 85137                        Certain        NaN       NaN       NaN
# 118951                       Certain       72.0      45.0      38.0
#
#        material_clean   type_of_monument_clean type_of_monument_certainty  \
# 83509            NULL  instrumentum domesticum                    Certain
# 111088           NULL                   tabula                  Uncertain
# 104209           NULL                     base                    Certain
# 85137            Clay      instrumentum sacrum                    Certain
# 118951         Marble                    altar                    Certain
#
#        province_label_clean province_label_certainty country_clean  \
# 83509                Achaia                  Certain        Greece
# 111088    Hispania citerior                  Certain         Spain
# 104209  Etruria (Regio VII)                  Certain         Italy
# 85137         Alpes Cottiae                  Certain         Italy
# 118951              Noricum                  Certain       Austria
#
#        country_certainty findspot_ancient_clean findspot_ancient_certainty  \
# 83509            Certain                Athenae                    Certain
# 111088           Certain          Carthago Nova                    Certain
# 104209           Certain                  Caere                  Estimated
# 85137            Certain              Ad Martis                    Certain
# 118951           Certain               Santicum                  Estimated
#
#        modern_region_clean modern_region_certainty findspot_modern_clean  \
# 83509               Attikí                 Certain               Athínai
# 111088                NULL                    NULL             Cartagena
# 104209                NULL                    NULL        Cerveteri, bei
# 85137             Piemonte                 Certain          Sauze d'Oulx
# 118951             Kärnten                 Certain               Villach
#
#        findspot_modern_certainty  \
# 83509                    Certain
# 111088                   Certain
# 104209                   Certain
# 85137                    Certain
# 118951                   Certain
#
#                                        findspot_clean findspot_certainty  \
# 83509                                      Kerameikos            Certain
# 111088                                        Malecón            Certain
# 104209                           Piano della Carlotta            Certain
# 85137                                       Richardet            Certain
# 118951  Landskron, Burg Landskron, sekundär verwendet            Certain
#
#        origdate_text_clean                           clean_text_conservative  \
# 83509      100 BC – 100 AD                                             Marus
# 111088        1 AD – 30 AD               L Fufius L l Varus pius vixit salve
# 104209       1 AD – 100 AD    Iovi Font Aquar Caeretanar Florentinus Aug d d
# 85137        1 AD – 355 AD                                          OCEL v m
# 118951     131 AD – 170 AD  ocretan Aug sacrum Iul ertiu t Maima iutis fil m
#
#                          clean_text_interpretive_sentence  \
# 83509                                               Marus
# 111088  Lucius Fufius Luci libertus Varus pius vixit s...
# 104209  Iovi Fonti Aquarum Caeretanarum Florentinus Au...
# 85137                    O CEL votum solvit libens merito
# 118951  Vocretano Augusto sacrum Iulius Tertius et Max...
#
#                                              findspot year_of_find  \
# 83509                                      Kerameikos         None
# 111088                                        Malecón         None
# 104209                           Piano della Carlotta         None
# 85137                                       Richardet         1933
# 118951  Landskron, Burg Landskron, sekundär verwendet         1952
#
#                           present_location                religion  \
# 83509                                 None                    None
# 111088                                lost                    None
# 104209                                None  names of pagan deities
# 85137                                 lost  names of pagan deities
# 118951  Villach, Landskron, Burg Landskron  names of pagan deities
#
#              geography social_economic_legal_history military  not_after  \
# 83509             None                          None     None      100.0
# 111088            None                          None     None       30.0
# 104209  data available                          None     None      100.0
# 85137             None                          None     None      355.0
# 118951            None                          None     None      170.0
#
#        language  not_before         coordinates  \
# 83509     Latin      -100.0  [23.7166, 37.9832]
# 111088    Latin         1.0  [-0.9862, 37.6051]
# 104209    Latin         1.0  [12.0935, 41.9938]
# 85137     Latin         1.0   [6.8838, 45.0336]
# 118951    Latin       131.0  [13.8969, 46.6424]
#
#                              clean_text_interpretive_word urban_context  \
# 83509                                               Marus           big
# 111088  Lucius Fufius Luci libertus Varus pius vixit s...        middle
# 104209  Iovi Fonti Aquarum Caeretanarum Florentinus Au...           big
# 85137                    O CEL votum solvit libens merito          rest
# 118951  Vocretano Augusto sacrum Iulius Tertius et Max...          rest
#
#         within_rome   nearest_city city_id_hanson  city_pop_est  \
# 83509         False        Athenae             14       58112.0
# 111088        False  Carthago Nova            693        9498.0
# 104209         True          Caere            965       25091.0
# 85137         False        Segusio            224         563.0
# 118951        False        Virunum           1237        7172.0
#
#                  city_geometry nearest_city_type  nearest_city_dist  \
# 83509   [23.726559, 37.971119]               big           0.015657
# 111088  [-0.984266, 37.599656]            middle           0.005777
# 104209  [12.093463, 41.993778]            middle           0.000043
# 85137    [7.048414, 45.138485]             minor           0.195189
# 118951   [14.366944, 46.69775]            middle           0.473292
#
#                          geometry
# 83509   POINT (23.71660 37.98320)
# 111088  POINT (-0.98620 37.60510)
# 104209  POINT (12.09350 41.99380)
# 85137    POINT (6.88380 45.03360)
# 118951  POINT (13.89690 46.64240)

# %%
inscr_texts = EDH_sampled["clean_text_interpretive_word"].tolist()

# %% [markdown]
# The language of inscriptions is characterized by a number of standardized phrases, which often determine the type of insription. Treated separately, "Dis" and "Manibus" might be confusing, but treated as a bigram, they bear a crucial information about the type of inscription.

# %%
def get_bigrams_underscore(inscr_text):
    try:
        inscr_bigrams = [" ".join(el) for el in list(bigrams(inscr_text.split()))]
        inscr_bigrams_ = [bigram.replace(" ", "_") for bigram in inscr_bigrams]
    except:
        inscr_bigrams_ = []
    return inscr_bigrams_

# %%
EDH_bigrams_ = [get_bigrams_underscore(inscr_text) for inscr_text in inscr_texts]
EDH_bigrams_[:5]
# Out:
# [[],
#  ['Lucius_Fufius',
#   'Fufius_Luci',
#   'Luci_libertus',
#   'libertus_Varus',
#   'Varus_pius',
#   'pius_vixit',
#   'vixit_salve'],
#  ['Iovi_Fonti',
#   'Fonti_Aquarum',
#   'Aquarum_Caeretanarum',
#   'Caeretanarum_Florentinus',
#   'Florentinus_Augusti',
#   'Augusti_dono',
#   'dono_dedit'],
#  ['O_CEL', 'CEL_votum', 'votum_solvit', 'solvit_libens', 'libens_merito'],
#  ['Vocretano_Augusto',
#   'Augusto_sacrum',
#   'sacrum_Iulius',
#   'Iulius_Tertius',
#   'Tertius_et',
#   'et_Maxima',
#   'Maxima_Adiutoris',
#   'Adiutoris_filia',
#   'filia_votum',
#   'votum_solverunt',
#   'solverunt_libentes',
#   'libentes_merito']]

# %%
# flat list of all bigrams
bigrams_list = [el for sublist in EDH_bigrams_ for el in sublist]
bigrams_list[:10]
# Out:
# ['Lucius_Fufius',
#  'Fufius_Luci',
#  'Luci_libertus',
#  'libertus_Varus',
#  'Varus_pius',
#  'pius_vixit',
#  'vixit_salve',
#  'Iovi_Fonti',
#  'Fonti_Aquarum',
#  'Aquarum_Caeretanarum']

# %%
# ok, let's list only N of the most common
bigrams_mostfreq = nltk.FreqDist(bigrams_list).most_common()
bigrams_mostfreq = [tup[0] for tup in bigrams_mostfreq]
bigrams_mostfreq[:10]
# Out:
# ['Dis_Manibus',
#  'vixit_annos',
#  'votum_solvit',
#  'solvit_libens',
#  'libens_merito',
#  'Iovi_Optimo',
#  'Optimo_Maximo',
#  'hic_situs',
#  'situs_est',
#  'tribunicia_potestate']

# %%
all_bigrams_freq_dict = dict(nltk.FreqDist(bigrams_list).most_common())

# %%
EDH_sampled["bigrams"] = EDH_bigrams_

# %%
len(EDH_sampled["type_of_inscription_clean"].unique())
# Out:
# 22

# %%
all_bigrams_freq_dict
# Out:
# {'Dis_Manibus': 7844,
#  'vixit_annos': 4084,
#  'votum_solvit': 3335,
#  'solvit_libens': 2982,
#  'libens_merito': 2710,
#  'Iovi_Optimo': 2413,
#  'Optimo_Maximo': 2399,
#  'hic_situs': 2338,
#  'situs_est': 2228,
#  'tribunicia_potestate': 1990,
#  'Manibus_sacrum': 1865,
#  'bene_merenti': 1585,
#  'sibi_et': 1476,
#  'Imperatori_Caesari': 1256,
#  'hic_sita': 1216,
#  'sita_est': 1155,
#  'faciendum_curavit': 1118,
#  'pro_salute': 1117,
#  'terra_levis': 1111,
#  'Imperator_Caesar': 1099,
#  'tibi_terra': 1029,
#  'sit_tibi': 999,
#  'vixit_annis': 996,
#  'pro_praetore': 932,
#  'pontifex_maximus': 837,
#  'miles_legionis': 783,
#  'pontifici_maximo': 780,
#  'est_sit': 749,
#  'maximus_tribunicia': 708,
#  'maximo_tribunicia': 706,
#  'ex_voto': 701,
#  'Pio_Felici': 698,
#  'pater_patriae': 698,
#  'patri_patriae': 687,
#  'divi_Nervae': 670,
#  'et_suis': 664,
#  'et_I': 663,
#  'Marcus_Aurelius': 656,
#  'qui_vixit': 634,
#  'piae_fidelis': 611,
#  'Caius_Iulius': 608,
#  'Marco_Aurelio': 600,
#  'libens_laetus': 588,
#  'decreto_decurionum': 585,
#  'divi_Traiani': 559,
#  'et_sibi': 558,
#  'laetus_merito': 548,
#  'legionis_II': 544,
#  'fecit_sibi': 530,
#  'vivus_fecit': 522,
#  'Augusti_pro': 521,
#  'Traiani_Parthici': 504,
#  'legionis_I': 500,
#  'quae_vixit': 462,
#  'civium_Romanorum': 459,
#  'Cai_filius': 451,
#  'Imperatoris_Caesaris': 448,
#  'beneficiarius_consularis': 445,
#  'domus_divinae': 429,
#  'pro_se': 424,
#  'Luci_filius': 420,
#  'milia_passuum': 420,
#  'Augusto_pontifici': 410,
#  'Caesari_Marco': 406,
#  'merenti_posuit': 406,
#  'annorum_XXX': 396,
#  'honorem_domus': 390,
#  'Antonini_Pii': 390,
#  'veteranus_legionis': 390,
#  'In_honorem': 387,
#  'se_et': 386,
#  'II_adiutricis': 381,
#  'Caesar_divi': 380,
#  'de_suo': 376,
#  'divi_Hadriani': 374,
#  'Maximo_et': 372,
#  'cohortis_I': 372,
#  'Marci_Aureli': 365,
#  'legato_Augusti': 355,
#  'Augustus_pontifex': 355,
#  'centurio_legionis': 354,
#  'in_suis': 345,
#  'coniugi_bene': 343,
#  'Felici_Augusto': 341,
#  'Publius_Aelius': 335,
#  'faciendum_curaverunt': 322,
#  'Caesar_Marcus': 319,
#  'Aurelio_Antonino': 315,
#  'annorum_L': 311,
#  'votum_solverunt': 305,
#  'fronte_pedes': 303,
#  'Pius_Felix': 302,
#  'in_fronte': 301,
#  'Antonino_Augusto': 300,
#  'posteris_que': 300,
#  'que_eorum': 299,
#  'Marci_filius': 297,
#  'II_vir': 296,
#  'Titus_Flavius': 296,
#  'Luci_filio': 295,
#  'ex_testamento': 293,
#  'filio_divi': 288,
#  'annorum_XX': 288,
#  'annorum_LX': 286,
#  'suis_hic': 280,
#  'votum_libens': 280,
#  'fieri_iussit': 278,
#  'in_agro': 278,
#  'annorum_XXV': 277,
#  'sua_pecunia': 276,
#  'libentes_merito': 275,
#  'Iunoni_Reginae': 274,
#  'II_viro': 269,
#  'heres_faciendum': 262,
#  'et_II': 261,
#  'Invicto_Augusto': 261,
#  'solverunt_libentes': 260,
#  'Caesari_divi': 260,
#  'Romanorum_et': 257,
#  'agro_pedes': 256,
#  'divi_Antonini': 255,
#  'viva_fecit': 255,
#  'divi_Augusti': 252,
#  'Cai_filio': 251,
#  'filio_annorum': 251,
#  'Septimi_Severi': 248,
#  'voto_posuit': 248,
#  'consul_III': 247,
#  'legionis_VII': 246,
#  'et_Genio': 245,
#  'filius_divi': 244,
#  'Felici_Invicto': 244,
#  'legionis_XIIII': 242,
#  'Pii_Felicis': 241,
#  'salute_Imperatoris': 241,
#  'Marcus_Ulpius': 239,
#  'coniugi_et': 237,
#  'testamento_fieri': 236,
#  'Tiberius_Claudius': 234,
#  'sacrum_Caius': 233,
#  'Augusti_et': 228,
#  'et_Iuliae': 228,
#  'Augusto_sacrum': 226,
#  'salute_sua': 225,
#  'Luci_Septimi': 225,
#  'legionis_XIII': 222,
#  'vivi_fecerunt': 222,
#  'Invicto_Mithrae': 221,
#  'XIII_geminae': 221,
#  'XIIII_geminae': 219,
#  'Augustus_Germanicus': 219,
#  'suis_votum': 218,
#  'Caio_Iulio': 217,
#  'Aureli_Antonini': 215,
#  'Severi_Pii': 214,
#  'annos_LX': 214,
#  'sacrum_Lucius': 213,
#  'honesta_missione': 213,
#  'consuli_II': 211,
#  'Aurelius_Antoninus': 211,
#  'consuli_III': 210,
#  'defuncto_annorum': 209,
#  'II_et': 208,
#  'iure_dicundo': 202,
#  'fecit_et': 201,
#  'annos_L': 200,
#  'miles_cohortis': 200,
#  'Silvano_Domestico': 200,
#  'rei_publicae': 199,
#  'maiestati_que': 199,
#  'Augusti_nostri': 199,
#  'filio_et': 199,
#  'numini_maiestati': 197,
#  'decurio_coloniae': 197,
#  'annos_XXX': 197,
#  'cui_praeest': 197,
#  'annorum_XXXV': 196,
#  'Marci_filio': 195,
#  'Caesaris_Augusti': 195,
#  'quorum_nomina': 194,
#  'legionis_XV': 193,
#  'I_adiutricis': 193,
#  'Felix_Augustus': 193,
#  'filius_annorum': 192,
#  'militavit_annos': 192,
#  'annorum_XL': 191,
#  'nobilissimo_Caesari': 191,
#  'Quinti_filius': 189,
#  'nepoti_divi': 189,
#  'legionis_III': 188,
#  'domini_nostri': 187,
#  'que_eius': 187,
#  'militum_legionis': 187,
#  'Felicis_Augusti': 187,
#  'defunctae_annorum': 186,
#  'Deo_Invicto': 186,
#  'patriae_proconsuli': 185,
#  'pius_in': 185,
#  'hoc_monumentum': 185,
#  'legionis_X': 185,
#  'annorum_LXX': 184,
#  'filio_Galeria': 184,
#  'legionis_XI': 184,
#  'merenti_fecit': 184,
#  'Lucius_Septimius': 183,
#  'Publi_filius': 182,
#  'Pro_salute': 182,
#  'XV_Apollinaris': 181,
#  'consul_II': 180,
#  'nomina_subscripta': 179,
#  'subscripta_sunt': 178,
#  'heredem_non': 178,
#  'non_sequetur': 178,
#  'Parthico_maximo': 177,
#  'Antoninus_Augustus': 176,
#  'filia_annorum': 176,
#  'legionis_IIII': 175,
#  'bene_merentibus': 175,
#  'sacrum_Marcus': 174,
#  'annos_XXV': 173,
#  'annos_XX': 173,
#  'Augusti_filio': 172,
#  'pia_in': 172,
#  'Lucio_Septimio': 172,
#  'praetore_provinciae': 172,
#  'legionis_XXII': 171,
#  'Genio_loci': 169,
#  'V_Macedonicae': 168,
#  'Pertinacis_Augusti': 165,
#  'annos_XXXV': 165,
#  'locus_datus': 165,
#  'tribuno_militum': 164,
#  'Antonini_Augusti': 164,
#  'Caesaris_Marci': 164,
#  'legatus_Augusti': 163,
#  'consularis_votum': 163,
#  'veteranus_ex': 163,
#  'Maximo_Dolicheno': 163,
#  'libertis_libertabus': 162,
#  'adiutricis_piae': 162,
#  'et_conubium': 162,
#  'conubium_cum': 162,
#  'Parthici_maximi': 162,
#  'Claudiae_piae': 161,
#  'Caius_Valerius': 161,
#  'Tiberio_Claudio': 161,
#  'cum_uxoribus': 161,
#  'hic_siti': 161,
#  'libens_posuit': 160,
#  'militi_legionis': 160,
#  'et_III': 160,
#  'donum_dedit': 160,
#  'dedit_et': 160,
#  'Augusto_et': 160,
#  'Antonino_Pio': 159,
#  'sua_et': 159,
#  'Luci_filia': 158,
#  'tribuniciae_potestatis': 158,
#  'et_Imperator': 158,
#  'Pii_Pertinacis': 158,
#  'Libero_Patri': 158,
#  'XI_Claudiae': 156,
#  'filius_Quirina': 156,
#  'legionis_V': 156,
#  'Maximo_Iunoni': 155,
#  'Flavio_Valerio': 155,
#  'Augustae_sacrum': 155,
#  'VII_Claudiae': 155,
#  'datus_decreto': 155,
#  'siti_sunt': 154,
#  'de_sua': 154,
#  'Septimio_Severo': 153,
#  'cohortis_II': 153,
#  'Augusto_Germanico': 153,
#  'quas_postea': 153,
#  'qui_militaverunt': 151,
#  'potestate_consuli': 151,
#  'I_Thracum': 151,
#  'sunt_in': 150,
#  'uxoribus_quas': 150,
#  'ponendum_curavit': 149,
#  'et_Marco': 149,
#  'L_hic': 149,
#  'dimissis_honesta': 148,
#  'monumentum_heredem': 147,
#  'libens_solvit': 147,
#  'pecunia_publica': 146,
#  'Antoninus_Pius': 146,
#  'Parthicus_maximus': 146,
#  'III_et': 146,
#  'patris_patriae': 146,
#  'et_coniugi': 146,
#  'Septimius_Severus': 146,
#  'potestate_II': 146,
#  'I_Italicae': 145,
#  'Caesar_Lucius': 145,
#  'Arabici_Adiabenici': 145,
#  'postea_duxissent': 145,
#  'XXII_Primigeniae': 144,
#  'deabus_que': 144,
#  'Caesari_Lucio': 144,
#  'quas_tunc': 144,
#  'tunc_habuissent': 144,
#  'est_civitas': 143,
#  'duxissent_dumtaxat': 143,
#  'filius_et': 143,
#  'Titi_filius': 143,
#  'Augusto_Pio': 142,
#  'militaverunt_in': 142,
#  'pia_fidelis': 142,
#  'patriae_et': 142,
#  'libertabus_que': 142,
#  'I_Minerviae': 142,
#  'habuissent_cum': 142,
#  'cum_est': 142,
#  'data_aut': 141,
#  'Titus_Aelius': 141,
#  'consularis_legionis': 139,
#  'domino_nostro': 139,
#  'alae_I': 139,
#  'filius_Galeria': 138,
#  'ante_diem': 138,
#  'divi_Marci': 138,
#  'dono_dedit': 137,
#  'maximus_pontifex': 137,
#  'plus_minus': 137,
#  'fecerunt_sibi': 137,
#  'III_pater': 136,
#  'si_quis': 136,
#  'et_Iunoni': 135,
#  'sacrum_Quintus': 135,
#  'LX_hic': 135,
#  'X_geminae': 135,
#  'Luci_filiae': 134,
#  'Imperatore_Caesare': 133,
#  'annorum_X': 133,
#  'cohors_I': 133,
#  'emeritis_dimissis': 133,
#  'potestate_IIII': 132,
#  'a_solo': 132,
#  'et_Caio': 132,
#  'Marci_Antonini': 132,
#  'Adiabenici_Parthici': 132,
#  'XXV_hic': 131,
#  'filiae_annorum': 131,
#  'Manibus_Marcus': 131,
#  'et_Marcus': 131,
#  'eius_et': 131,
#  'pronepoti_divi': 131,
#  'Tito_Aelio': 130,
#  'Soli_Invicto': 130,
#  'Germanicus_pontifex': 130,
#  'Marcus_Iulius': 130,
#  'Severo_Pio': 130,
#  'Manibus_Marco': 130,
#  'stipendiis_emeritis': 129,
#  'missione_quorum': 129,
#  'proconsul_et': 129,
#  'patriae_proconsul': 128,
#  'Lucius_Valerius': 128,
#  'Maximo_pro': 128,
#  'praefectus_cohortis': 127,
#  'Cai_filia': 126,
#  'IIII_Flaviae': 126,
#  'et_recognitum': 126,
#  'Manibus_Lucio': 126,
#  'cum_iis': 126,
#  'Severus_Pius': 125,
#  'ex_imperio': 125,
#  'Augusti_Arabici': 124,
#  'Manibus_Caio': 124,
#  'descriptum_et': 124,
#  'recognitum_ex': 124,
#  'Cai_Iuli': 124,
#  'ob_honorem': 123,
#  'et_sunt': 123,
#  'Iuliae_Augustae': 123,
#  'et_suorum': 123,
#  'Pertinax_Augustus': 123,
#  'Manibus_Caius': 123,
#  'Germanici_Sarmatici': 123,
#  'consul_IIII': 122,
#  'pecunia_sua': 122,
#  'sub_cura': 122,
#  'Manibus_Aurelius': 122,
#  'res_publica': 121,
#  'annos_LXX': 121,
#  'XX_hic': 121,
#  'Caesar_Augustus': 121,
#  'cum_suis': 120,
#  'et_peditibus': 120,
#  'III_patri': 120,
#  'et_Aurelia': 120,
#  'ex_tabula': 120,
#  'iis_quas': 120,
#  'Pertinaci_Augusto': 119,
#  'Auggustorum_pro': 119,
#  'Pius_Pertinax': 119,
#  'iis_data': 119,
#  'equitibus_et': 118,
#  'peditibus_qui': 117,
#  'Pio_Pertinaci': 117,
#  'merenti_posuerunt': 117,
#  'quae_fixa': 117,
#  'fixa_est': 117,
#  'potestate_III': 117,
#  'nepos_divi': 117,
#  'Augustus_Pius': 117,
#  'Legio_XIII': 116,
#  'nobilissimus_Caesar': 116,
#  'civitas_iis': 116,
#  'Quinti_filio': 115,
#  'Tito_Flavio': 115,
#  'est_Romae': 115,
#  'XXX_hic': 115,
#  'Marcus_Valerius': 115,
#  'legato_pro': 115,
#  'Luci_libertus': 114,
#  'et_heres': 114,
#  'sacrum_Iulia': 114,
#  'Titus_Aurelius': 114,
#  'Traianus_Hadrianus': 113,
#  'in_alis': 112,
#  'et_cohortibus': 112,
#  'filio_Quirina': 112,
#  'liberis_posteris': 112,
#  'coniugi_pientissimae': 112,
#  'et_Flavio': 112,
#  'Hadriano_Augusto': 111,
#  'quae_appellantur': 111,
#  'XIII_gemina': 111,
#  'et_Publius': 111,
#  'Hadrianus_Augustus': 111,
#  'annos_LXXX': 110,
#  'Manibus_et': 110,
#  'maximo_pontifici': 109,
#  'Publi_filio': 109,
#  'Arabico_Adiabenico': 109,
#  'Nerva_Traianus': 109,
#  'sacrum_Publius': 109,
#  'filio_pientissimo': 109,
#  'annorum_V': 108,
#  'Romae_in': 108,
#  'suo_posuit': 108,
#  'Caesari_Caio': 108,
#  'annos_XL': 108,
#  'Aelio_Hadriano': 107,
#  'Hadriano_Antonino': 107,
#  'III_Augustae': 107,
#  'Traiano_Hadriano': 106,
#  'II_consul': 106,
#  'annorum_XXXX': 106,
#  'et_Lucio': 106,
#  'Augustus_Arabicus': 106,
#  'et_Caius': 106,
#  'ex_decreto': 105,
#  'Manibus_Lucius': 105,
#  'et_Aureliae': 105,
#  'et_Marci': 105,
#  'tribunus_militum': 105,
#  'hic_sit': 105,
#  'Arabicus_Adiabenicus': 105,
#  'et_filio': 104,
#  'coniugi_carissimae': 104,
#  'legionis_VI': 104,
#  'potestate_VIIII': 104,
#  'ipsis_liberis': 104,
#  'in_pace': 104,
#  'clarissimo_viro': 104,
#  'patriae_consuli': 103,
#  'veterano_legionis': 102,
#  'et_Imperatori': 102,
#  'sunt_ipsis': 102,
#  'Pii_Germanici': 102,
#  'Marci_filiae': 102,
#  'annos_X': 102,
#  'Caesaris_Luci': 101,
#  'annos_LV': 101,
#  'Maximo_sacrum': 101,
#  'et_Iulia': 100,
#  'Augusto_Arabico': 100,
#  'Augustalis_coloniae': 100,
#  'XXXV_hic': 100,
#  'civitatem_dedit': 100,
#  'Marcus_Antonius': 100,
#  'IIIIII_vir': 100,
#  'VIII_Augustae': 100,
#  'quin_que': 99,
#  'Augustus_tribunicia': 99,
#  'et_Aurelius': 99,
#  'titulum_posuit': 99,
#  'eques_alae': 98,
#  'legionis_XXX': 98,
#  'cohortis_III': 98,
#  'IIII_pater': 98,
#  'Nervae_nepos': 98,
#  'nepos_Traianus': 98,
#  'pontificis_maximi': 98,
#  'sacrum_pro': 98,
#  'eorum_civitatem': 98,
#  'Gaius_Iulius': 97,
#  'Parthici_filius': 97,
#  'potestate_XVI': 97,
#  'Valerio_Maximiano': 97,
#  'et_V': 97,
#  'Luci_liberta': 96,
#  'Manibus_Aurelio': 96,
#  'annorum_XVIII': 96,
#  'Adiabenicus_Parthicus': 96,
#  'Cai_libertus': 96,
#  'annorum_LXXX': 96,
#  'annos_LXV': 95,
#  'decurionum_pecunia': 95,
#  'II_consulibus': 95,
#  'filius_Voltinia': 95,
#  'equo_publico': 95,
#  'dis_deabus': 95,
#  'Domino_nostro': 95,
#  'Augusti_ad': 95,
#  'potestate_consul': 95,
#  'Augusti_Germanici': 95,
#  'legionis_VIII': 95,
#  'patriae_equitibus': 95,
#  'Titi_filio': 95,
#  'Lucius_Iulius': 94,
#  'Pius_Augustus': 94,
#  'legato_Auggustorum': 94,
#  'consuli_proconsuli': 94,
#  'tribuno_plebis': 94,
#  'ddominorum_nnostrorum': 94,
#  'consuli_IIII': 93,
#  'votum_posuit': 93,
#  'decurio_municipii': 93,
#  'pro_pietate': 92,
#  'Augusti_Pii': 92,
#  'que_omnibus': 92,
#  'Adiabenico_Parthico': 92,
#  'pedes_XII': 92,
#  'vivus_sibi': 92,
#  'imperio_ipsarum': 92,
#  'Iulius_Verus': 92,
#  'Cai_filiae': 92,
#  'Maximo_Marcus': 91,
#  'Primigeniae_piae': 91,
#  'Publio_Aelio': 91,
#  'annos_XXXX': 91,
#  'annorum_XV': 91,
#  'I_Flavia': 91,
#  'Marco_Iulio': 91,
#  'II_patri': 90,
#  'Marci_filia': 90,
#  'sit_est': 90,
#  'annorum_LV': 90,
#  'vir_perfectissimus': 89,
#  'posuit_et': 89,
#  'dumtaxat_singuli': 89,
#  'patriae_consul': 89,
#  'Caesari_Augusto': 89,
#  'II_Augustae': 88,
#  'que_et': 88,
#  'vir_Augustalis': 88,
#  'singuli_singulas': 88,
#  'Nervae_filius': 88,
#  'aedili_II': 88,
#  'IIII_viro': 88,
#  'legati_Augusti': 88,
#  'II_consuli': 88,
#  'Aelius_Hadrianus': 88,
#  'Hadrianus_Antoninus': 88,
#  'Augusti_libertus': 88,
#  'filius_Nerva': 87,
#  'Maximo_Caius': 87,
#  'coniugi_suae': 87,
#  'coniugi_annorum': 86,
#  'filiae_et': 86,
#  'obito_annorum': 86,
#  'legato_legionis': 86,
#  'imperator_II': 86,
#  'abnepoti_divi': 86,
#  'salute_et': 86,
#  'Deo_Soli': 85,
#  'legionis_XX': 85,
#  'LXX_hic': 85,
#  'Valerio_Constantino': 85,
#  'Tiberi_Caesaris': 85,
#  'devotus_numini': 85,
#  'et_Lucius': 85,
#  'Germanici_Caesaris': 85,
#  'Quintus_Iulius': 85,
#  'caelibes_essent': 85,
#  'filio_dulcissimo': 84,
#  'heres_posuit': 84,
#  'provinciae_Africae': 83,
#  'Germanico_maximo': 83,
#  'uxori_et': 83,
#  'annos_LXXV': 83,
#  'et_castrorum': 83,
#  'praefecto_cohortis': 83,
#  'essent_cum': 83,
#  'militi_cohortis': 82,
#  'in_muro': 82,
#  'ad_Minervam': 82,
#  'merenti_et': 82,
#  'Quinti_filia': 82,
#  'ad_que': 82,
#  'Augusto_tribunicia': 81,
#  'XXX_Ulpiae': 81,
#  'filiae_coniugi': 81,
#  'mulieris_liberta': 81,
#  'ab_Aquinco': 81,
#  'Manibus_Tito': 81,
#  'muro_post': 81,
#  'post_templum': 81,
#  'templum_divi': 81,
#  'Traianus_Augustus': 81,
#  'II_pater': 81,
#  'que_suis': 81,
#  'LXXX_hic': 81,
#  'idem_que': 80,
#  'et_Publio': 80,
#  'posuit_libens': 80,
#  'consuli_patri': 80,
#  'civitatem_Romanam': 80,
#  'Marco_Antonio': 79,
#  'Deo_Mercurio': 79,
#  'Aquinco_milia': 79,
#  'heres_ex': 79,
#  'annorum_XXII': 79,
#  'Manibus_Publius': 79,
#  'potestate_VI': 78,
#  'est_heres': 78,
#  'Marci_libertus': 78,
#  'II_viri': 78,
#  'Nervae_adnepoti': 78,
#  'annos_V': 78,
#  'Aurelio_Valerio': 78,
#  'et_in': 77,
#  'ne_que': 77,
#  'Invictus_Augustus': 77,
#  'patri_et': 77,
#  'qui_et': 77,
#  'pedes_XX': 77,
#  'filius_Claudia': 77,
#  'legionis_eiusdem': 77,
#  'suorum_que': 77,
#  'XX_Valeriae': 76,
#  'XXX_stipendiorum': 76,
#  'pater_et': 76,
#  'LV_hic': 76,
#  'Manibus_Iuliae': 76,
#  'Tiberi_Claudi': 76,
#  'sibi_viva': 76,
#  'filius_vivus': 75,
#  'potestate_patri': 75,
#  'viro_iure': 75,
#  'vir_iure': 75,
#  'I_Hispanorum': 75,
#  'et_divi': 75,
#  'LX_et': 75,
#  'supra_scriptae': 75,
#  'potestate_V': 74,
#  'I_I': 74,
#  'dedit_dedicavit': 74,
#  'Germanicus_maximus': 74,
#  'et_Aurelio': 74,
#  'Deo_Marti': 74,
#  'L_et': 74,
#  'maximi_tribunicia': 74,
#  'testamento_faciendum': 74,
#  'stlitibus_iudicandis': 74,
#  'et_Hygiae': 74,
#  'ex_beneficiario': 74,
#  'Augustae_matri': 74,
#  'Manibus_Publio': 74,
#  'Manibus_Titus': 73,
#  'divi_Vespasiani': 73,
#  'decurioni_coloniae': 73,
#  'proconsuli_et': 73,
#  'que_posteris': 73,
#  'suo_fecit': 73,
#  'Augusti_filius': 73,
#  'Domestico_sacrum': 73,
#  'Felix_Invictus': 73,
#  'et_Flavia': 73,
#  'filiae_uxori': 73,
#  'et_libertis': 73,
#  'coniugi_karissimae': 73,
#  'hic_est': 73,
#  'pontifice_maximo': 72,
#  'patri_bene': 72,
#  'II_Italicae': 72,
#  'annorum_III': 72,
#  'menses_V': 72,
#  'sibi_fecit': 72,
#  'filio_piissimo': 72,
#  'Severi_et': 72,
#  'annorum_XVI': 72,
#  'Parthici_filio': 71,
#  'annorum_LXV': 71,
#  'annos_LXXXV': 71,
#  'Septimius_Geta': 71,
#  'ob_merita': 71,
#  'Iulio_Philippo': 71,
#  'Hadriani_filius': 71,
#  'tabula_aenea': 71,
#  'LXXV_hic': 71,
#  'fidelis_et': 70,
#  'Augusto_Parthico': 70,
#  'annorum_XLV': 70,
#  'Iulio_Vero': 70,
#  'aut_si': 70,
#  'annos_XXXXV': 70,
#  'Iulius_Cai': 70,
#  'appellantur_I': 70,
#  'Galerio_Valerio': 70,
#  'Caesar_Caius': 70,
#  'patri_pientissimo': 70,
#  'annorum_XII': 70,
#  'mater_filio': 70,
#  'Apollinaris_annorum': 69,
#  'curam_agente': 69,
#  'matri_et': 69,
#  'centurioni_legionis': 69,
#  'Nervae_pronepos': 69,
#  'annorum_et': 69,
#  'III_consuli': 68,
#  'et_Aelia': 68,
#  'Severi_Alexandri': 68,
#  'filius_Sergia': 68,
#  'sibi_vivus': 68,
#  'coniugi_incomparabili': 68,
#  'et_vicenis': 68,
#  'pluribusve_stipendiis': 68,
#  'Parthici_et': 68,
#  'Pius_pontifex': 68,
#  'filius_Papiria': 67,
#  'III_consul': 67,
#  'Lucius_Cornelius': 67,
#  'praefecto_fabrum': 67,
#  'filius_Augustus': 67,
#  'sacris_faciundis': 67,
#  'suo_et': 67,
#  'libentes_laeti': 67,
#  'menses_VI': 67,
#  'Gallorum_et': 67,
#  'aenea_quae': 67,
#  'salute_domini': 66,
#  'LXV_hic': 66,
#  'Valeriae_victricis': 66,
#  'patre_patriae': 66,
#  'matri_pientissimae': 66,
#  'si_qui': 66,
#  'sunt_civitatem': 66,
#  'qui_eorum': 66,
#  'coniugi_eius': 66,
#  'Ulpiae_victricis': 65,
#  'X_hic': 65,
#  'Publi_libertus': 65,
#  'XXX_et': 65,
#  'in_honorem': 65,
#  'et_et': 65,
#  'Auggustorum_et': 65,
#  'consul_pater': 65,
#  'Hadriani_Augusti': 65,
#  'consularis_pro': 65,
#  'filio_suo': 65,
#  'quo_que': 65,
#  'et_Aeliae': 65,
#  'annorum_II': 64,
#  'annos_XV': 64,
#  'obitae_annorum': 64,
#  'solvit_merito': 64,
#  'VI_victricis': 64,
#  'annos_III': 64,
#  'est_Caius': 64,
#  'V_et': 64,
#  'Germanicus_Dacicus': 64,
#  'annorum_XXVI': 64,
#  'Caio_Valerio': 64,
#  'vir_clarissimus': 64,
#  'ex_HS': 63,
#  'filia_vixit': 63,
#  'libens_animo': 63,
#  'Herculi_Augusto': 63,
#  'viva_sibi': 63,
#  'pientissimo_et': 63,
#  'consulibus_cohortis': 63,
#  'et_filiae': 63,
#  'et_pontes': 63,
#  'filius_Pollia': 63,
#  'IIIIII_viro': 63,
#  'consul_proconsul': 63,
#  'Parthici_nepos': 63,
#  'pronepos_Titus': 63,
#  'centurio_cohortis': 63,
#  'pedes_X': 63,
#  'beneficiario_consularis': 63,
#  'Publio_Licinio': 63,
#  'et_filiis': 62,
#  'Silvano_sacrum': 62,
#  'stipendiorum_X': 62,
#  'I_et': 62,
#  'Publius_Septimius': 62,
#  'praeses_provinciae': 62,
#  'Tiberius_Iulius': 62,
#  'Romanam_qui': 62,
#  'eorum_non': 62,
#  'non_haberent': 62,
#  'divinae_Iovi': 62,
#  'sua_suorum': 62,
#  'Titi_Aeli': 61,
#  'geminae_votum': 61,
#  'VI_vir': 61,
#  'vias_et': 61,
#  'est_testamento': 61,
#  'XXXX_hic': 61,
#  'quinis_et': 61,
#  'Severo_Alexandro': 61,
#  'qui_caelibes': 61,
#  'filiae_dulcissimae': 61,
#  'Lucius_Aemilius': 61,
#  'dumtaxat_singulis': 61,
#  'semper_Augusto': 61,
#  'Silvano_Augusto': 61,
#  'filiae_pientissimae': 61,
#  'voto_suscepto': 61,
#  'Marco_Ulpio': 61,
#  'at_que': 61,
#  'poni_iussit': 60,
#  'primus_pilus': 60,
#  'LXXXV_hic': 60,
#  'coniux_et': 60,
#  'et_Valeria': 60,
#  'VIIII_imperator': 60,
#  'XII_in': 60,
#  'se_vivo': 60,
#  'Constantio_et': 60,
#  'IIII_vir': 60,
#  'Augustae_matris': 60,
#  'geminae_Martiae': 60,
#  'laeti_merito': 60,
#  'III_Thracum': 60,
#  'maximus_tribuniciae': 59,
#  'Maximo_Lucius': 59,
#  'filio_Papiria': 59,
#  'voto_libens': 59,
#  'annos_XLV': 59,
#  'IIII_patri': 58,
#  'Britannico_maximo': 58,
#  'Lucius_Aurelius': 58,
#  'procuratoris_Augusti': 58,
#  'coloniae_Sarmizegetusae': 58,
#  'Septimio_Getae': 58,
#  'nostro_Flavio': 58,
#  'Lucio_Aurelio': 58,
#  'annorum_LXXV': 58,
#  'potestate_XV': 58,
#  'divi_Severi': 58,
#  'vicenis_pluribusve': 58,
#  'et_heredes': 58,
#  'proconsuli_provinciae': 58,
#  'aut_cum': 58,
#  'Sexti_filius': 58,
#  'pronepos_divi': 58,
#  'Nervae_nepoti': 57,
#  'nepoti_Traiano': 57,
#  'coniugi_pientissimo': 57,
#  'principi_iuventutis': 57,
#  'Caesari_Flavio': 57,
#  'II_Flavia': 57,
#  'I_Aelia': 57,
#  'cohortis_IIII': 57,
#  'marito_bene': 57,
#  'annorum_XXIII': 57,
#  'IIII_et': 57,
#  'Valerio_Constantio': 57,
#  'suorum_votum': 57,
#  'Martiae_victricis': 57,
#  'annos_XVIII': 57,
#  'et_IIII': 57,
#  'perpetuae_securitati': 57,
#  'veterano_ex': 57,
#  'annos_XXVI': 57,
#  'filio_eius': 57,
#  'vir_egregius': 56,
#  'maximo_Britannico': 56,
#  'annos_XVI': 56,
#  'annos_VII': 56,
#  'Lusitanorum_et': 56,
#  'imperatori_II': 56,
#  'Luci_Pulli': 56,
#  'annorum_IIII': 56,
#  'voto_posuerunt': 56,
#  'XL_stipendiorum': 56,
#  'in_suo': 56,
#  'viro_Augustali': 56,
#  'collegii_fabrum': 56,
#  'annorum_hic': 56,
#  'Publi_filia': 56,
#  'II_Augusta': 56,
#  'militavit_annis': 56,
#  'Augusti_legionis': 56,
#  'Antonio_Gordiano': 55,
#  'Hadriani_filio': 55,
#  'pondo_libras': 55,
#  'et_Iulius': 55,
#  'merentibus_posuit': 55,
#  'nostri_Imperatoris': 55,
#  'Aesculapio_et': 55,
#  'Matronis_Vacallinehis': 55,
#  'quicum_que': 55,
#  'III_Italicae': 55,
#  'procurator_Augusti': 55,
#  'potestate_VIII': 55,
#  'vivi_sibi': 55,
#  'annos_II': 55,
#  'devota_numini': 54,
#  'filius_votum': 54,
#  'laetus_libens': 54,
#  'annorum_VII': 54,
#  'consul_V': 54,
#  'Imperatore_Antonino': 54,
#  'Augustus_et': 54,
#  'singulas_ante': 54,
#  'in_foro': 54,
#  'numini_eius': 54,
#  'viro_perfectissimo': 54,
#  'ceteris_que': 53,
#  'maximo_Germanico': 53,
#  'Silvano_Silvestri': 53,
#  'consul_designatus': 53,
#  'annos_XII': 53,
#  'equiti_Romano': 53,
#  'X_viro': 53,
#  'annis_XXX': 53,
#  'Imperatore_domino': 53,
#  'faciundum_curavit': 53,
#  'et_memoriae': 53,
#  'heredes_faciendum': 53,
#  'perfectissimus_praeses': 53,
#  'procuratori_Augusti': 53,
#  'est_in': 53,
#  'I_Alpinorum': 53,
#  'XXXXV_hic': 52,
#  'equitum_Romanorum': 52,
#  'marito_optimo': 52,
#  'Publio_Septimio': 52,
#  'viro_stlitibus': 52,
#  'Constantino_Pio': 52,
#  'Divi_Iuli': 52,
#  'Messio_Quinto': 52,
#  'libertus_et': 52,
#  'Raetorum_et': 52,
#  'Lucio_Licinio': 51,
#  'veterana_et': 51,
#  'Manibus_Iulia': 51,
#  'et_Flavius': 51,
#  'Maximo_cohors': 51,
#  'coloniae_Aquincensium': 51,
#  'Auggustorum_nnostrorum': 51,
#  'imperator_XII': 51,
#  'fecerunt_et': 51,
#  'II_proconsul': 51,
#  'V_dies': 51,
#  'ex_decurione': 51,
#  'Publi_filiae': 51,
#  'Verus_Maximinus': 51,
#  'Maximinus_Pius': 51,
#  'divi_Commodi': 51,
#  'filii_et': 51,
#  'fidelis_votum': 51,
#  'XXXV_stipendiorum': 51,
#  'suo_faciendum': 51,
#  'legati_legionis': 51,
#  'adiutricis_votum': 51,
#  'Manibus_Aurelia': 51,
#  'Titus_Iulius': 51,
#  'est_Titus': 51,
#  'pedes_XV': 51,
#  'mulieris_libertus': 51,
#  'Iulio_Cai': 50,
#  'mater_et': 50,
#  'Aureli_Severi': 50,
#  'Manibus_Aureliae': 50,
#  'sacrum_Titus': 50,
#  'II_proconsuli': 50,
#  'IIII_consul': 50,
#  'aram_posuit': 50,
#  'XL_hic': 50,
#  'stipendiorum_XX': 50,
#  'merito_posuit': 50,
#  'Augustis_sacrum': 50,
#  'VIII_Kalendas': 50,
#  'divinae_deo': 50,
#  'salute_ddominorum': 50,
#  'LXX_et': 50,
#  'Maximo_Titus': 50,
#  'et_perpetuae': 50,
#  'Minerviae_piae': 50,
#  'est_et': 50,
#  ...}

# %%
N = 10
weighted_bigrams_all = []
for cat in EDH_sampled["type_of_inscription_clean"].unique():
    EDH_cat = EDH_sampled[EDH_sampled["type_of_inscription_clean"]==cat]
    bigrams_list = [el for sublist in EDH_cat["bigrams"].tolist() for el in sublist]
    cat_bigrams_freq_dict = dict(nltk.FreqDist(bigrams_list).most_common())
    weighted_bigrams = []
    for word in cat_bigrams_freq_dict.keys():
        if cat_bigrams_freq_dict[word] >= 10: # it it appears at least twice
            weighted_bigrams.append((word, cat_bigrams_freq_dict[word] / all_bigrams_freq_dict[word]))
    # choose only N of the most characteristic bigrams for given category
    weighted_bigrams = sorted(weighted_bigrams, key=lambda tup: tup[1], reverse=True)[:N]
    weighted_bigrams = [tup[0] for tup in weighted_bigrams]
    weighted_bigrams_all.extend(weighted_bigrams)

# %%
len(weighted_bigrams_all)
# Out:
# 132

# %%
def combine_status_list_and_bigrams(el_status, el_bigrams, el_material):
    # preprocess status:
    try: el_status = eval(el_status)
    except: pass
    if isinstance(el_status, list):
        new_el_status = el_status
    elif isinstance(el_status, str):
        new_el_status = [el_status]
    else: 
        new_el_status = []
    new_el_status = [el.replace(" ", "_") for el in new_el_status]
    # preprocess material:
    if el_material is None:
        el_material = []    
    else:
        el_material = el_material.partition(": ")[0] # 
        el_material = el_material.split(", ")
        el_material = [el.replace(" ", "_").replace("?", "") for el in el_material]
    # combine status, bigrams and material
    new_el = new_el_status + el_bigrams + el_material
    new_el = " ".join(new_el)
    return new_el, new_el_status, el_material

# %%
status_bigrams_list = []
status_list = []
material_list = []
for el_status, el_bigrams, el_material in zip(EDH_sampled["status_list"].tolist(), EDH_sampled["bigrams"].tolist(), EDH_sampled["Material"].tolist()):
    new_el, new_status, el_material = combine_status_list_and_bigrams(el_status, el_bigrams, el_material)
    status_bigrams_list.append(new_el)
    status_list.append(new_status)
    material_list.extend(el_material)

# %%
materials_freqdist = nltk.FreqDist(material_list).most_common()
materials_freqdist[:20]
# Out:
# [('lapis', 22042),
#  ('opus_figlinae', 2247),
#  ('aes', 796),
#  ('plumbum', 528),
#  ('argentum', 289),
#  ('lignum', 289),
#  ('aurum', 82),
#  ('vitrum', 63),
#  ('ferrum', 60),
#  ('tectorium', 58),
#  ('musivum', 27),
#  ('steatitis', 11),
#  ('os', 10),
#  ('cyprum', 6),
#  ('rupes', 4),
#  ('gemma', 4),
#  ('corium', 1),
#  ('sucineus', 1)]

# %%
status_bigrams_list[:10]
# Out:
# ['nomen_singulare sigilla_impressa tituli_fabricationis viri opus_figlinae',
#  'liberti/libertae tituli_sepulcrales tria_nomina viri Lucius_Fufius Fufius_Luci Luci_libertus libertus_Varus Varus_pius pius_vixit vixit_salve',
#  'nomen_singulare servi/servae tituli_sacri viri Iovi_Fonti Fonti_Aquarum Aquarum_Caeretanarum Caeretanarum_Florentinus Florentinus_Augusti Augusti_dono dono_dedit',
#  'tituli_sacri O_CEL CEL_votum votum_solvit solvit_libens libens_merito',
#  'mulieres nomen_singulare tituli_sacri tria_nomina viri Vocretano_Augusto Augusto_sacrum sacrum_Iulius Iulius_Tertius Tertius_et et_Maxima Maxima_Adiutoris Adiutoris_filia filia_votum votum_solverunt solverunt_libentes libentes_merito lapis',
#  'tituli_sepulcrales Dis_Manibus Manibus_Liberali Liberali_Iuvenilis Iuvenilis_filio filio_Natalis Natalis_socer socer_ponendum ponendum_curavit',
#  'milites tituli_operum Legio_XX XX_Valeria Valeria_Victrix lapis',
#  'Imperatori_Caesari Caesari_Tito Tito_Aelio Aelio_Hadriano Hadriano_Antonino Antonino_Augusto Augusto_Pio Pio_patri patri_patriae patriae_Marcus Marcus_Acilius Acilius_Mani Mani_filius filius_Papiria Papiria_Concessus Concessus_aedilis aedilis_praefectus praefectus_iure iure_dicundo dicundo_ob ob_honorem honorem_aedilitatis aedilitatis_super super_legitimam legitimam_quam quam_rei rei_publicae publicae_intulit intulit_adiectis adiectis_at at_HS HS_II II_nummum nummum_quanti quanti_pollicitus pollicitus_est est_HS HS_II II_nummum nummum_ex ex_HS HS_IIII IIII_nummum nummum_posuit posuit_idem idem_que que_dedicavit dedicavit_tempore tempore_aedilitatis aedilitatis_suae suae_decreto decreto_decurionum',
#  'tituli_sepulcrales Gacalia_Tritei Tritei_filia filia_hic hic_sita sita_est est_annorum annorum_LXX',
#  'mulieres tituli_sepulcrales tria_nomina viri Dis_Manibus Manibus_Caesidiae Caesidiae_Romanae Romanae_Pomponius Pomponius_Crescens Crescens_coniugi coniugi_bene bene_merenti']

# %%
N = 20
materials_N = [tup[0] for tup in materials_freqdist[:N]]

# %%
el_status = EDH_sampled["status_list"].tolist()[0]

# %%
status_bigrams_list[0]
# Out:
# 'nomen_singulare sigilla_impressa tituli_fabricationis viri opus_figlinae'

# %%
status_list_flat = [el for sublist in status_list for el in sublist]
status_N = [tup[0] for tup in nltk.FreqDist(status_list_flat).most_common(100)] ### we had 228 in total
status_N[:10]
# Out:
# ['viri',
#  'tituli_sepulcrales',
#  'tria_nomina',
#  'tituli_sacri',
#  'mulieres',
#  'milites',
#  'nomen_singulare',
#  'Augusti/Augustae',
#  'tituli_operum',
#  'tituli_fabricationis']

# %%
len(status_N)
# Out:
# 37

# %% [markdown]
# # Experiments with one list of the most frequent bigrams

# %%
subset_size = 3000 # len(y)
vocab = status_N + bigrams_mostfreq[:100] + materials_N
vectorizer = TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=vocab)
X = vectorizer.fit_transform(status_bigrams_list[:subset_size])
X.todense().shape
X_train, X_test, y_train, y_test = train_test_split(X[:subset_size], y[:subset_size], test_size=0.1, random_state=1)

# %%
def train_svm(X, y):
    """
    Create and train the Support Vector Machine.
    """
    svm = SVC(C=1000000.0, gamma='auto', kernel='rbf', probability=True)
    svm.fit(X, y)
    return svm

# %%
# %%time
svm = train_svm(X_train, y_train)
# Out:
# CPU times: user 2.91 s, sys: 13 µs, total: 2.91 s
# Wall time: 2.91 s

# %%
print(svm.score(X_test, y_test))
# Out:
# 0.8533333333333334

# %%
# only where the predictor is present
predictors_present = [np.any(el) for el in X_test.todense()]
# check the performance on datapoints for which we have something in the "status_list"
svm.score(X_test.todense()[predictors_present], np.array(y_test)[predictors_present])
# Out:
# 0.8825622775800712

# %%
svm.classes_
# Out:
# array(['acclamation', 'boundary inscription',
#        'building/dedicatory inscription', 'calendar', 'defixio',
#        'elogium', 'epitaph', 'honorific inscription',
#        'identification inscription', 'label', 'letter', 'list',
#        'mile-/leaguestone', 'military diploma',
#        'owner/artist inscription', 'private legal inscription',
#        'public legal inscription', 'seat inscription',
#        'votive inscription'], dtype='<U31')

# %%
test_pred_probs = [(svm.classes_[np.argmax(pred)], pred[np.argmax(pred)], real) for pred, real in zip(svm.predict_proba(X_test), y_test)]
test_pred_probs[:20]
# Out:
# [('votive inscription', 0.8714806621652981, 'votive inscription'),
#  ('epitaph', 0.6553905458065716, 'votive inscription'),
#  ('epitaph', 0.899032975604153, 'epitaph'),
#  ('epitaph', 0.8429716820268507, 'epitaph'),
#  ('epitaph', 0.6553905458065716, 'public legal inscription'),
#  ('votive inscription', 0.5422059525444386, 'votive inscription'),
#  ('owner/artist inscription', 0.7001535620756715, 'owner/artist inscription'),
#  ('honorific inscription', 0.5071577259646999, 'honorific inscription'),
#  ('epitaph', 0.7865163928198973, 'epitaph'),
#  ('votive inscription', 0.7017705697391524, 'votive inscription'),
#  ('epitaph', 0.961161135288192, 'epitaph'),
#  ('epitaph', 0.9838944906905805, 'epitaph'),
#  ('epitaph', 0.6553905458065716, 'epitaph'),
#  ('votive inscription', 0.949783460907678, 'votive inscription'),
#  ('epitaph', 0.6080102672062603, 'epitaph'),
#  ('epitaph', 0.9744275343272499, 'epitaph'),
#  ('epitaph', 0.7783721192839056, 'epitaph'),
#  ('mile-/leaguestone', 0.7052301371665558, 'mile-/leaguestone'),
#  ('epitaph', 0.9427270916123758, 'epitaph'),
#  ('mile-/leaguestone', 0.7940130290132327, 'mile-/leaguestone')]

# %%
for threshold in [thres / 100 for thres in range(30, 100, 5)]:
    above_threshold = [tup for tup in test_pred_probs if tup[1] >= threshold]
    correct_count = len([tup for tup in above_threshold if tup[0] == tup[2]]) # correct total
    correct_proportion = correct_count / len(above_threshold)# correct ratio 
    proportion = len(above_threshold) / len(test_pred_probs)
    print("prob. threshold: {0}, proportion of inscr.: {1}, correctly classified: {2}".format(threshold, proportion, correct_proportion))
# Out:
#     threshold (=/>)  proportion     N
# 0              0.30        1.00  4601
# 1              0.35        0.94  4337
# 2              0.40        0.93  4310
# 3              0.45        0.91  4213
# 4              0.50        0.90  4162
# 5              0.55        0.89  4092
# 6              0.60        0.86  3955
# 7              0.65        0.84  3898
# 8              0.70        0.71  3264
# 9              0.75        0.67  3078
# 10             0.80        0.58  2694
# 11             0.85        0.51  2336
# 12             0.90        0.42  1957
# 13             0.95        0.34  1563

# %% [markdown]
# # ALTERNATIVE: Experiments with the most typical bigrams for each category (skip!)

# %% [markdown]
# - quite surprisingly, a model combining status list with 100 most frequent bigrams outperforms a model based on 10 most typical bigrams within each category

# %%
subset_size = 3000 # len(y)
vocab = status_N + weighted_bigrams_all
vectorizer = TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=vocab)
X = vectorizer.fit_transform(status_bigrams_list[:subset_size])
X.todense().shape
X_train, X_test, y_train, y_test = train_test_split(X[:subset_size], y[:subset_size], test_size=0.1, random_state=1)

# %%
# %%time
svm = train_svm(X_train, y_train)
# Out:
# CPU times: user 3.82 s, sys: 0 ns, total: 3.82 s
# Wall time: 3.82 s

# %%
print(svm.score(X_test, y_test))
# Out:
# 0.8166666666666667

# %%
# only where the predictor is present
predictors_present = [np.any(el) for el in X_test.todense()]
# check the performance on datapoints for which we have something in the "status_list"
svm.score(X_test.todense()[predictors_present], np.array(y_test)[predictors_present])
# Out:
# 0.8935361216730038

# %% [markdown]
# #  Main training

# %%
vocab = status_N + bigrams_mostfreq[:100] + materials_N
vectorizer = TfidfVectorizer(token_pattern=r"\w+\/?|\_\w+", vocabulary=vocab)
X = vectorizer.fit_transform(status_bigrams_list)
X.todense().shape
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1)

# %%
# %%time
svm = train_svm(X_train, y_train)
# Out:
# CPU times: user 4h 26min 11s, sys: 146 ms, total: 4h 26min 11s
# Wall time: 4h 26min 17s

# %%
print(svm.score(X_test, y_test))
# Out:
# 0.8607622347336509

# %%
# only where the predictor is present
predictors_present = [np.any(el) for el in X_test.todense()]
# check the performance on datapoints for which we have something in the "status_list"
svm.score(X_test.todense()[predictors_present], np.array(y_test)[predictors_present])
# Out:
# 0.8873664653971203

# %%
test_pred_probs = [(svm.classes_[np.argmax(pred)], pred[np.argmax(pred)], real) for pred, real in zip(svm.predict_proba(X_test), y_test)]
test_pred_probs[:20]
# Out:
# [('epitaph', 0.8076518568979559, 'epitaph'),
#  ('epitaph', 0.9175135155645008, 'epitaph'),
#  ('honorific inscription', 0.8175375756362547, 'epitaph'),
#  ('votive inscription', 0.9375336045590539, 'votive inscription'),
#  ('epitaph', 0.9889070296976127, 'epitaph'),
#  ('honorific inscription', 0.4244074964132119, 'honorific inscription'),
#  ('identification inscription', 0.38499247315960017, 'acclamation'),
#  ('epitaph', 0.6814848074358177, 'epitaph'),
#  ('votive inscription', 0.8981249140959828, 'votive inscription'),
#  ('epitaph', 0.9898373617328683, 'epitaph'),
#  ('epitaph', 0.9995455498440634, 'epitaph'),
#  ('owner/artist inscription', 0.7672183828711583, 'owner/artist inscription'),
#  ('building/dedicatory inscription', 0.3477246765155101, 'epitaph'),
#  ('building/dedicatory inscription',
#   0.5086770937852645,
#   'building/dedicatory inscription'),
#  ('votive inscription', 0.8722865158161045, 'votive inscription'),
#  ('votive inscription', 0.9771523245027367, 'votive inscription'),
#  ('votive inscription', 0.9764234178972918, 'votive inscription'),
#  ('votive inscription', 0.9294300077732595, 'votive inscription'),
#  ('epitaph', 0.99767174458914, 'epitaph'),
#  ('votive inscription', 0.9568323830816993, 'votive inscription')]

# %%
test_results = []
for threshold in [thres / 100 for thres in range(30, 100, 5)]:
    above_threshold = [tup for tup in test_pred_probs if tup[1] >= threshold]
    correct_count = len([tup for tup in above_threshold if tup[0] == tup[2]]) # correct total
    correct_proportion = correct_count / len(above_threshold)# correct ratio 
    proportion = len(above_threshold) / len(test_pred_probs)
    test_results.append({"threshold (=/>)" : threshold, "proportion" : np.round(proportion, 2), "N" : len(above_threshold), "correct" : correct_proportion})
test_results_df = pd.DataFrame(test_results)
test_results_df
# Out:
#     threshold (=/>)  proportion     N   correct
# 0              0.30        1.00  4601  0.862421
# 1              0.35        0.94  4337  0.890247
# 2              0.40        0.93  4310  0.894200
# 3              0.45        0.91  4213  0.898647
# 4              0.50        0.90  4162  0.901970
# 5              0.55        0.89  4092  0.905670
# 6              0.60        0.86  3955  0.908976
# 7              0.65        0.84  3898  0.910723
# 8              0.70        0.71  3264  0.957414
# 9              0.75        0.67  3078  0.968811
# 10             0.80        0.58  2694  0.971047
# 11             0.85        0.51  2336  0.977312
# 12             0.90        0.42  1957  0.984159
# 13             0.95        0.34  1563  0.989763

# %%
test_results_df.to_csv("../data/svm_v1_test_results.csv")

# %%
model_path = '../data/svm_model_v1.0.sav'
pickle.dump(svm, open(model_path, 'wb'))
vectorizer_path= '../data/svm_vectorizer_v1.0.sav'
pickle.dump(vectorizer, open(vectorizer_path, "wb"))

# %% [markdown]
# # Applying the model

# %%
# load the model and vectorizer back
svm_v1 = pickle.load(open('../data/svm_model_v1.0.sav', 'rb'))
vectorizer_v1 = pickle.load(open('../data/svm_vectorizer_v1.0.sav','rb'))

# %%
# we will apply the model to inscriptions which are only in EDCS
EDCS_unique = EDHCSg[(EDHCSg["EDH-ID"].isnull()) & (EDHCSg["EDCS-ID"].notnull())] 
EDCS_unique.head(5)
# Out:
#          EDCS-ID                                     publication  province  \
# 0  EDCS-71300269                                  AE 2014, 01203    Achaia
# 1  EDCS-21200140  CIL 03, 00079 = CIL 03, 14147,6 = IDakke 00028  Aegyptus
# 2  EDCS-21200142   CIL 03, 00081 = CIL 03, 13584 = IDakke 00064a  Aegyptus
# 3  EDCS-52100002                                    IDakke 00064  Aegyptus
# 4  EDCS-44500113                                    IDakke 00100  Aegyptus
#
#   province_list                                              place  \
# 0        Achaia         Mavrommati / Mavromati / Messini / Messene
# 1      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 2      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 3      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 4      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
#
#                                           place_list end_yr_list notes_dating  \
# 0  ['Mavrommati', 'Mavromati', 'Messini', 'Messene']          96
# 1  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         109
# 2  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         109
# 3  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         109
# 4  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         117
#
#                                          status_list  \
# 0  ['sigilla impressa', 'tituli fabricationis', '...
# 1  ['milites', 'tituli fabricationis', 'tituli sa...
# 2                                                 {}
# 3                                tituli possessionis
# 4  ['Augusti/Augustae', 'milites', 'ordo equester...
#
#                                  inscr_type  \
# 0                      tituli fabricationis
# 1  ['tituli fabricationis', 'tituli sacri']
# 2                                        {}
# 3                       tituli possessionis
# 4                              tituli sacri
#
#                                      status_notation     inscr_process  \
# 0                                               viri  sigilla impressa
# 1                 ['milites', 'tria nomina', 'viri']                {}
# 2                                                 {}                {}
# 3                                                 {}                {}
# 4  ['Augusti/Augustae', 'milites', 'ordo equester...                {}
#
#   notes_references notes_comments  \
# 0
# 1
# 2
# 3
# 4
#
#                                          inscription  \
# 0                                      De Rasticanis
# 1  Deo Magno Mercurio / adoravit vexillu / leg(io...
# 2                            Anno / XII [Tr]ai/a[ni]
# 3                                   Anno XX [Tra]ani
# 4  Pro salute Imp(eratoris) Nervae Traiani Caesar...
#
#                           inscription_stripped_final  \
# 0                                      De Rasticanis
# 1  Deo Magno Mercurio / adoravit vexillu / leg(io...
# 2                            Anno / XII [Tr]ai/a[ni]
# 3                                   Anno XX [Tra]ani
# 4  Pro salute Imp(eratoris) Nervae Traiani Caesar...
#
#                                                Links  dating from dating to  \
# 0                                               None         69.0        96
# 1  http://db.edcs.eu/epigr/partner.php?s_language...        109.0       109
# 2                                               None        109.0       109
# 3                                               None        109.0       109
# 4                                               None        103.0       117
#
#                                               status   Latitude  Longitude  \
# 0       sigilla impressa; tituli fabricationis; viri  37.179412  21.924179
# 1  milites; tituli fabricationis; tituli sacri; t...  23.200000  32.750000
# 2                                               None  23.200000  32.750000
# 3                                tituli possessionis  23.200000  32.750000
# 4  Augusti/Augustae; milites; ordo equester; titu...  23.200000  32.750000
#
#   photo       Material Comment EDH-ID language_EDCS  \
# 0  None  opus figlinae    None   None          None
# 1  None           None    None   None          None
# 2  None           None    None   None          None
# 3  None           None    None   None          None
# 4  None           None    None   None          None
#
#                    clean_text_interpretive_word_EDCS responsible_individual  \
# 0                                      De Rasticanis                   None
# 1  Deo Magno Mercurio adoravit vexillu legionis I...                   None
# 2                                   Anno XII Traiani                   None
# 3                                     Anno XX Traani                   None
# 4  Pro salute Imperatoris Nervae Traiani Caesaris...                   None
#
#   type_of_inscription letter_size literature work_status height  \
# 0                None        None       None        None   None
# 1                None        None       None        None   None
# 2                None        None       None        None   None
# 3                None        None       None        None   None
# 4                None        None       None        None   None
#
#   diplomatic_text people depth material type_of_monument province_label width  \
# 0            None   None  None     None             None           None  None
# 1            None   None  None     None             None           None  None
# 2            None   None  None     None             None           None  None
# 3            None   None  None     None             None           None  None
# 4            None   None  None     None             None           None  None
#
#   transcription country   uri findspot_ancient last_update modern_region  \
# 0          None    None  None             None        None          None
# 1          None    None  None             None        None          None
# 2          None    None  None             None        None          None
# 3          None    None  None             None        None          None
# 4          None    None  None             None        None          None
#
#   findspot_modern edh_geography_uri commentary trismegistos_uri  \
# 0            None              None       None             None
# 1            None              None       None             None
# 2            None              None       None             None
# 3            None              None       None             None
# 4            None              None       None             None
#
#   external_image_uris fotos idno_tm placenames_refs text_edition  \
# 0                None  None    None            None         None
# 1                None  None    None            None         None
# 2                None  None    None            None         None
# 3                None  None    None            None         None
# 4                None  None    None            None         None
#
#   origdate_text layout_execution layout_execution_text  support_objecttype  \
# 0          None             None                  None                 NaN
# 1          None             None                  None                 NaN
# 2          None             None                  None                 NaN
# 3          None             None                  None                 NaN
# 4          None             None                  None                 NaN
#
#   support_objecttype_text support_material support_material_text  \
# 0                    None             None                  None
# 1                    None             None                  None
# 2                    None             None                  None
# 3                    None             None                  None
# 4                    None             None                  None
#
#    support_decoration keywords_term keywords_term_text  \
# 0                 NaN          None               None
# 1                 NaN          None               None
# 2                 NaN          None               None
# 3                 NaN          None               None
# 4                 NaN          None               None
#
#   type_of_inscription_clean type_of_inscription_certainty  height_cm  \
# 0                      None                          None        NaN
# 1                      None                          None        NaN
# 2                      None                          None        NaN
# 3                      None                          None        NaN
# 4                      None                          None        NaN
#
#    width_cm  depth_cm material_clean type_of_monument_clean  \
# 0       NaN       NaN           None                   None
# 1       NaN       NaN           None                   None
# 2       NaN       NaN           None                   None
# 3       NaN       NaN           None                   None
# 4       NaN       NaN           None                   None
#
#   type_of_monument_certainty province_label_clean province_label_certainty  \
# 0                       None                 None                     None
# 1                       None                 None                     None
# 2                       None                 None                     None
# 3                       None                 None                     None
# 4                       None                 None                     None
#
#   country_clean country_certainty findspot_ancient_clean  \
# 0          None              None                   None
# 1          None              None                   None
# 2          None              None                   None
# 3          None              None                   None
# 4          None              None                   None
#
#   findspot_ancient_certainty modern_region_clean modern_region_certainty  \
# 0                       None                None                    None
# 1                       None                None                    None
# 2                       None                None                    None
# 3                       None                None                    None
# 4                       None                None                    None
#
#   findspot_modern_clean findspot_modern_certainty findspot_clean  \
# 0                  None                      None           None
# 1                  None                      None           None
# 2                  None                      None           None
# 3                  None                      None           None
# 4                  None                      None           None
#
#   findspot_certainty origdate_text_clean clean_text_conservative  \
# 0               None                None                    None
# 1               None                None                    None
# 2               None                None                    None
# 3               None                None                    None
# 4               None                None                    None
#
#   clean_text_interpretive_sentence findspot year_of_find present_location  \
# 0                             None     None         None             None
# 1                             None     None         None             None
# 2                             None     None         None             None
# 3                             None     None         None             None
# 4                             None     None         None             None
#
#   religion geography social_economic_legal_history military  not_after  \
# 0     None      None                          None     None       96.0
# 1     None      None                          None     None      109.0
# 2     None      None                          None     None      109.0
# 3     None      None                          None     None      109.0
# 4     None      None                          None     None      117.0
#
#   language  not_before                   coordinates  \
# 0    Latin        69.0  ['21.9241791', '37.1794122']
# 1    Latin       109.0    ['32.750000', '23.200000']
# 2    Latin       109.0    ['32.750000', '23.200000']
# 3    Latin       109.0    ['32.750000', '23.200000']
# 4    Latin       103.0    ['32.750000', '23.200000']
#
#                         clean_text_interpretive_word urban_context  \
# 0                                      De Rasticanis           big
# 1  Deo Magno Mercurio adoravit vexillu legionis I...          rest
# 2                                   Anno XII Traiani          rest
# 3                                     Anno XX Traani          rest
# 4  Pro salute Imperatoris Nervae Traiani Caesaris...          rest
#
#    within_rome nearest_city city_id_hanson  city_pop_est  \
# 0        False      Messene             59       22337.0
# 1        False  Elephantine            126       33806.0
# 2        False  Elephantine            126       33806.0
# 3        False  Elephantine            126       33806.0
# 4        False  Elephantine            126       33806.0
#
#             city_geometry nearest_city_type  nearest_city_dist  \
# 0  [22.008029, 37.051363]            middle           0.153060
# 1  [32.933333, 24.083333]               big           0.902158
# 2  [32.933333, 24.083333]               big           0.902158
# 3  [32.933333, 24.083333]               big           0.902158
# 4  [32.933333, 24.083333]               big           0.902158
#
#                     geometry  \
# 0  POINT (21.92418 37.17941)
# 1  POINT (32.75000 23.20000)
# 2  POINT (32.75000 23.20000)
# 3  POINT (32.75000 23.20000)
# 4  POINT (32.75000 23.20000)
#
#                                              bigrams
# 0                                    [De_Rasticanis]
# 1  [Deo_Magno, Magno_Mercurio, Mercurio_adoravit,...
# 2                            [Anno_XII, XII_Traiani]
# 3                               [Anno_XX, XX_Traani]
# 4  [Pro_salute, salute_Imperatoris, Imperatoris_N...

# %%
# first create bigrams
EDCS_unique["bigrams"] = EDCS_unique["clean_text_interpretive_word"].apply(get_bigrams_underscore)

# %%
# we need to extract all predictors from the dataframe
# into `status_bigrams_list_apply` (list of lists)
status_bigrams_list_apply = []
status_list = []
material_list = []
for el_status, el_bigrams, el_material in zip(EDCS_unique["status_list"].tolist(), EDCS_unique["bigrams"].tolist(), EDCS_unique["Material"].tolist()):
    new_el, new_status, el_material = combine_status_list_and_bigrams(el_status, el_bigrams, el_material)
    status_bigrams_list_apply.append(new_el)
    status_list.append(new_status)
    material_list.extend(el_material)

# %%
X_applied = vectorizer_v1.transform(status_bigrams_list_apply)

# %%
prediction = svm_v1.predict(X_applied)
prediction[:10]
# Out:
# array(['owner/artist inscription', 'owner/artist inscription', 'epitaph',
#        'votive inscription', 'votive inscription', 'epitaph', 'epitaph',
#        'honorific inscription', 'honorific inscription',
#        'honorific inscription'], dtype='<U31')

# %%
probs = [np.max(pred) for pred in svm_v1.predict_proba(X_applied)]
probs[:10]
# Out:
# [0.7857018706636444,
#  0.850080323385903,
#  0.696566811086934,
#  0.7255255264157866,
#  0.91963276157691,
#  0.9973812084603909,
#  0.722058041187063,
#  0.5854847852357029,
#  0.8361305582932681,
#  0.9281131587280677]

# %%
prediction_probs = [(svm_v1.classes_[np.argmax(pred)], pred[np.argmax(pred)]) for pred in svm_v1.predict_proba(X_applied)]
prediction_probs[:10]
# Out:
# [('owner/artist inscription', 0.7857018706636444),
#  ('owner/artist inscription', 0.850080323385903),
#  ('epitaph', 0.696566811086934),
#  ('votive inscription', 0.7255255264157866),
#  ('votive inscription', 0.91963276157691),
#  ('epitaph', 0.9973812084603909),
#  ('epitaph', 0.722058041187063),
#  ('honorific inscription', 0.5854847852357029),
#  ('honorific inscription', 0.8361305582932681),
#  ('honorific inscription', 0.9281131587280677)]

# %%
len(prediction_probs)
# Out:
# 83482

# %%
for threshold in [thres / 100 for thres in range(30, 100, 5)]:
    above_threshold = [tup for tup in prediction_probs if tup[1] >= threshold]
    proportion = len(above_threshold) / len(prediction_probs)
    print("prob. threshold: {0}, proportion of inscr.: {1}".format(threshold, proportion))
# Out:
# prob. threshold: 0.3, proportion of inscr.: 0.9917227665844134
# prob. threshold: 0.35, proportion of inscr.: 0.9776718334491268
# prob. threshold: 0.4, proportion of inscr.: 0.9708440142785271
# prob. threshold: 0.45, proportion of inscr.: 0.9533192784073213
# prob. threshold: 0.5, proportion of inscr.: 0.9454612970460698
# prob. threshold: 0.55, proportion of inscr.: 0.9377949737668
# prob. threshold: 0.6, proportion of inscr.: 0.9269543135047076
# prob. threshold: 0.65, proportion of inscr.: 0.920713447210177
# prob. threshold: 0.7, proportion of inscr.: 0.732073980019645
# prob. threshold: 0.75, proportion of inscr.: 0.7075776814163532
# prob. threshold: 0.8, proportion of inscr.: 0.605962962075657
# prob. threshold: 0.85, proportion of inscr.: 0.5564073692532522
# prob. threshold: 0.9, proportion of inscr.: 0.4863443616588007
# prob. threshold: 0.95, proportion of inscr.: 0.4326441628135406

# %%
threshold_results = []
for threshold in [thres / 100 for thres in range(30, 100, 5)]:
    above_threshold = [tup for tup in prediction_probs if tup[1] >= threshold]
    proportion = len(above_threshold) / len(prediction_probs)
    threshold_results.append({"threshold (=/>)" : threshold, "proportion" : np.round(proportion, 2), "N" : len(above_threshold)})
model_results_df = pd.DataFrame(threshold_results)
model_results_df
# Out:
#     threshold (=/>)  proportion      N
# 0              0.30        0.99  82791
# 1              0.35        0.98  81618
# 2              0.40        0.97  81048
# 3              0.45        0.95  79585
# 4              0.50        0.95  78929
# 5              0.55        0.94  78289
# 6              0.60        0.93  77384
# 7              0.65        0.92  76863
# 8              0.70        0.73  61115
# 9              0.75        0.71  59070
# 10             0.80        0.61  50587
# 11             0.85        0.56  46450
# 12             0.90        0.49  40601
# 13             0.95        0.43  36118

# %%
model_results_df.to_csv("../data/svm_v1_EDCS_results.csv")

# %%
test_results_df
# Out:
#     threshold (=/>)  proportion     N   correct
# 0              0.30        1.00  4601  0.862421
# 1              0.35        0.94  4337  0.890247
# 2              0.40        0.93  4310  0.894200
# 3              0.45        0.91  4213  0.898647
# 4              0.50        0.90  4162  0.901970
# 5              0.55        0.89  4092  0.905670
# 6              0.60        0.86  3955  0.908976
# 7              0.65        0.84  3898  0.910723
# 8              0.70        0.71  3264  0.957414
# 9              0.75        0.67  3078  0.968811
# 10             0.80        0.58  2694  0.971047
# 11             0.85        0.51  2336  0.977312
# 12             0.90        0.42  1957  0.984159
# 13             0.95        0.34  1563  0.989763

# %% [markdown]
# # Combining the data back

# %%
EDCS_unique["type_of_inscription_auto"] = prediction
EDCS_unique["type_of_inscription_auto_prob"] = probs

# %%
EDCS_unique.head(5)
# Out:
#          EDCS-ID                                     publication  province  \
# 0  EDCS-71300269                                  AE 2014, 01203    Achaia
# 1  EDCS-21200140  CIL 03, 00079 = CIL 03, 14147,6 = IDakke 00028  Aegyptus
# 2  EDCS-21200142   CIL 03, 00081 = CIL 03, 13584 = IDakke 00064a  Aegyptus
# 3  EDCS-52100002                                    IDakke 00064  Aegyptus
# 4  EDCS-44500113                                    IDakke 00100  Aegyptus
#
#   province_list                                              place  \
# 0        Achaia         Mavrommati / Mavromati / Messini / Messene
# 1      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 2      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 3      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 4      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
#
#                                           place_list end_yr_list notes_dating  \
# 0  ['Mavrommati', 'Mavromati', 'Messini', 'Messene']          96
# 1  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         109
# 2  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         109
# 3  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         109
# 4  ['Ad-Dakka', 'El-Dakka', 'Dakke', 'Pselqet', '...         117
#
#                                          status_list  \
# 0  ['sigilla impressa', 'tituli fabricationis', '...
# 1  ['milites', 'tituli fabricationis', 'tituli sa...
# 2                                                 {}
# 3                                tituli possessionis
# 4  ['Augusti/Augustae', 'milites', 'ordo equester...
#
#                                  inscr_type  \
# 0                      tituli fabricationis
# 1  ['tituli fabricationis', 'tituli sacri']
# 2                                        {}
# 3                       tituli possessionis
# 4                              tituli sacri
#
#                                      status_notation     inscr_process  \
# 0                                               viri  sigilla impressa
# 1                 ['milites', 'tria nomina', 'viri']                {}
# 2                                                 {}                {}
# 3                                                 {}                {}
# 4  ['Augusti/Augustae', 'milites', 'ordo equester...                {}
#
#   notes_references notes_comments  \
# 0
# 1
# 2
# 3
# 4
#
#                                          inscription  \
# 0                                      De Rasticanis
# 1  Deo Magno Mercurio / adoravit vexillu / leg(io...
# 2                            Anno / XII [Tr]ai/a[ni]
# 3                                   Anno XX [Tra]ani
# 4  Pro salute Imp(eratoris) Nervae Traiani Caesar...
#
#                           inscription_stripped_final  \
# 0                                      De Rasticanis
# 1  Deo Magno Mercurio / adoravit vexillu / leg(io...
# 2                            Anno / XII [Tr]ai/a[ni]
# 3                                   Anno XX [Tra]ani
# 4  Pro salute Imp(eratoris) Nervae Traiani Caesar...
#
#                                                Links  dating from dating to  \
# 0                                               None         69.0        96
# 1  http://db.edcs.eu/epigr/partner.php?s_language...        109.0       109
# 2                                               None        109.0       109
# 3                                               None        109.0       109
# 4                                               None        103.0       117
#
#                                               status   Latitude  Longitude  \
# 0       sigilla impressa; tituli fabricationis; viri  37.179412  21.924179
# 1  milites; tituli fabricationis; tituli sacri; t...  23.200000  32.750000
# 2                                               None  23.200000  32.750000
# 3                                tituli possessionis  23.200000  32.750000
# 4  Augusti/Augustae; milites; ordo equester; titu...  23.200000  32.750000
#
#   photo       Material Comment EDH-ID language_EDCS  \
# 0  None  opus figlinae    None   None          None
# 1  None           None    None   None          None
# 2  None           None    None   None          None
# 3  None           None    None   None          None
# 4  None           None    None   None          None
#
#                    clean_text_interpretive_word_EDCS responsible_individual  \
# 0                                      De Rasticanis                   None
# 1  Deo Magno Mercurio adoravit vexillu legionis I...                   None
# 2                                   Anno XII Traiani                   None
# 3                                     Anno XX Traani                   None
# 4  Pro salute Imperatoris Nervae Traiani Caesaris...                   None
#
#   type_of_inscription letter_size literature work_status height  \
# 0                None        None       None        None   None
# 1                None        None       None        None   None
# 2                None        None       None        None   None
# 3                None        None       None        None   None
# 4                None        None       None        None   None
#
#   diplomatic_text people depth material type_of_monument province_label width  \
# 0            None   None  None     None             None           None  None
# 1            None   None  None     None             None           None  None
# 2            None   None  None     None             None           None  None
# 3            None   None  None     None             None           None  None
# 4            None   None  None     None             None           None  None
#
#   transcription country   uri findspot_ancient last_update modern_region  \
# 0          None    None  None             None        None          None
# 1          None    None  None             None        None          None
# 2          None    None  None             None        None          None
# 3          None    None  None             None        None          None
# 4          None    None  None             None        None          None
#
#   findspot_modern edh_geography_uri commentary trismegistos_uri  \
# 0            None              None       None             None
# 1            None              None       None             None
# 2            None              None       None             None
# 3            None              None       None             None
# 4            None              None       None             None
#
#   external_image_uris fotos idno_tm placenames_refs text_edition  \
# 0                None  None    None            None         None
# 1                None  None    None            None         None
# 2                None  None    None            None         None
# 3                None  None    None            None         None
# 4                None  None    None            None         None
#
#   origdate_text layout_execution layout_execution_text  support_objecttype  \
# 0          None             None                  None                 NaN
# 1          None             None                  None                 NaN
# 2          None             None                  None                 NaN
# 3          None             None                  None                 NaN
# 4          None             None                  None                 NaN
#
#   support_objecttype_text support_material support_material_text  \
# 0                    None             None                  None
# 1                    None             None                  None
# 2                    None             None                  None
# 3                    None             None                  None
# 4                    None             None                  None
#
#    support_decoration keywords_term keywords_term_text  \
# 0                 NaN          None               None
# 1                 NaN          None               None
# 2                 NaN          None               None
# 3                 NaN          None               None
# 4                 NaN          None               None
#
#   type_of_inscription_clean type_of_inscription_certainty  height_cm  \
# 0                      None                          None        NaN
# 1                      None                          None        NaN
# 2                      None                          None        NaN
# 3                      None                          None        NaN
# 4                      None                          None        NaN
#
#    width_cm  depth_cm material_clean type_of_monument_clean  \
# 0       NaN       NaN           None                   None
# 1       NaN       NaN           None                   None
# 2       NaN       NaN           None                   None
# 3       NaN       NaN           None                   None
# 4       NaN       NaN           None                   None
#
#   type_of_monument_certainty province_label_clean province_label_certainty  \
# 0                       None                 None                     None
# 1                       None                 None                     None
# 2                       None                 None                     None
# 3                       None                 None                     None
# 4                       None                 None                     None
#
#   country_clean country_certainty findspot_ancient_clean  \
# 0          None              None                   None
# 1          None              None                   None
# 2          None              None                   None
# 3          None              None                   None
# 4          None              None                   None
#
#   findspot_ancient_certainty modern_region_clean modern_region_certainty  \
# 0                       None                None                    None
# 1                       None                None                    None
# 2                       None                None                    None
# 3                       None                None                    None
# 4                       None                None                    None
#
#   findspot_modern_clean findspot_modern_certainty findspot_clean  \
# 0                  None                      None           None
# 1                  None                      None           None
# 2                  None                      None           None
# 3                  None                      None           None
# 4                  None                      None           None
#
#   findspot_certainty origdate_text_clean clean_text_conservative  \
# 0               None                None                    None
# 1               None                None                    None
# 2               None                None                    None
# 3               None                None                    None
# 4               None                None                    None
#
#   clean_text_interpretive_sentence findspot year_of_find present_location  \
# 0                             None     None         None             None
# 1                             None     None         None             None
# 2                             None     None         None             None
# 3                             None     None         None             None
# 4                             None     None         None             None
#
#   religion geography social_economic_legal_history military  not_after  \
# 0     None      None                          None     None       96.0
# 1     None      None                          None     None      109.0
# 2     None      None                          None     None      109.0
# 3     None      None                          None     None      109.0
# 4     None      None                          None     None      117.0
#
#   language  not_before                   coordinates  \
# 0    Latin        69.0  ['21.9241791', '37.1794122']
# 1    Latin       109.0    ['32.750000', '23.200000']
# 2    Latin       109.0    ['32.750000', '23.200000']
# 3    Latin       109.0    ['32.750000', '23.200000']
# 4    Latin       103.0    ['32.750000', '23.200000']
#
#                         clean_text_interpretive_word urban_context  \
# 0                                      De Rasticanis           big
# 1  Deo Magno Mercurio adoravit vexillu legionis I...          rest
# 2                                   Anno XII Traiani          rest
# 3                                     Anno XX Traani          rest
# 4  Pro salute Imperatoris Nervae Traiani Caesaris...          rest
#
#    within_rome nearest_city city_id_hanson  city_pop_est  \
# 0        False      Messene             59       22337.0
# 1        False  Elephantine            126       33806.0
# 2        False  Elephantine            126       33806.0
# 3        False  Elephantine            126       33806.0
# 4        False  Elephantine            126       33806.0
#
#             city_geometry nearest_city_type  nearest_city_dist  \
# 0  [22.008029, 37.051363]            middle           0.153060
# 1  [32.933333, 24.083333]               big           0.902158
# 2  [32.933333, 24.083333]               big           0.902158
# 3  [32.933333, 24.083333]               big           0.902158
# 4  [32.933333, 24.083333]               big           0.902158
#
#                     geometry  \
# 0  POINT (21.92418 37.17941)
# 1  POINT (32.75000 23.20000)
# 2  POINT (32.75000 23.20000)
# 3  POINT (32.75000 23.20000)
# 4  POINT (32.75000 23.20000)
#
#                                              bigrams  \
# 0                                    [De_Rasticanis]
# 1  [Deo_Magno, Magno_Mercurio, Mercurio_adoravit,...
# 2                            [Anno_XII, XII_Traiani]
# 3                               [Anno_XX, XX_Traani]
# 4  [Pro_salute, salute_Imperatoris, Imperatoris_N...
#
#    type_of_inscription_auto  type_of_inscription_auto_prob
# 0  owner/artist inscription                       0.785702
# 1  owner/artist inscription                       0.850080
# 2                   epitaph                       0.696567
# 3        votive inscription                       0.725526
# 4        votive inscription                       0.919633

# %%
# prepare last part of the data - inscriptions we have only in EDH
# in this case, we can also use the information we already have
EDH_unique = EDHCSg[(EDHCSg["EDH-ID"].notnull()) & (EDHCSg["EDCS-ID"].isnull())] 
EDH_unique["type_of_inscription_auto"] = EDH_unique["type_of_inscription_clean"]
EDH_unique["type_of_inscription_auto_prob"] = [1] * len(EDH_unique)

# %%
EDH_overlap_all["type_of_inscription_auto"] = EDH_overlap_all["type_of_inscription_clean"]
EDH_overlap_all["type_of_inscription_auto_prob"] = [1] * len(EDH_overlap_all)

# %%
print("the dataset we used for training and testing (+NULLs): ", EDH_overlap_all.shape)
print("inscriptions in EDH only: ", EDH_unique.shape)
print("inscriptions in EDCS only, we wanted to classify: ", EDCS_unique.shape)
# Out:
# the dataset we used for training and testing (+NULLs):  (49916, 113)
# inscriptions in EDH only:  (3907, 113)
# inscriptions in EDCS only, we wanted to classify:  (83482, 113)

# %%
# combine together
EDHCS_autotypes = pd.concat([EDH_overlap_all, EDH_unique, EDCS_unique])
EDHCS_autotypes.head()
# Out:
#              EDCS-ID                                        publication  \
# 83482  EDCS-03700724  ZPE-108-159 = Thesprotia 00001 = AE 1993, 0140...
# 83483  EDCS-03300852                                     AE 1995, 01409
# 83484  EDCS-28500283  CIL 03, 07251 = D 00214 = NDIEC-07, p 81 = AE ...
# 83485  EDCS-09400671  CIMRM-02, 02350 = IG-12, 00274 = Andros 00124 ...
# 83486  EDCS-24600769                    AE 1995, 01407 = AE 2001, 01812
#
#       province province_list                                       place  \
# 83482   Achaia        Achaia                  Agios Athanasios / Photike
# 83483   Achaia        Achaia                                Alea / Tegea
# 83484   Achaia        Achaia                                Alea / Tegea
# 83485   Achaia        Achaia                                      Andros
# 83486   Achaia        Achaia  Archea Olimpia / Archaia Olympia / Olympia
#
#                                              place_list end_yr_list  \
# 83482                   ['Agios Athanasios', 'Photike']         313
# 83483                                 ['Alea', 'Tegea']         276
# 83484                                 ['Alea', 'Tegea']          50
# 83485                                            Andros         209
# 83486  ['Archea Olimpia', 'Archaia Olympia', 'Olympia']          96
#
#                                  notes_dating  \
# 83482
# 83483  to 276;   b:  276 to 282         \n\n
# 83484
# 83485
# 83486
#
#                                              status_list        inscr_type  \
# 83482  ['Augusti/Augustae', 'litterae erasae', 'ordo ...  tituli honorarii
# 83483           ['Augusti/Augustae', 'miliaria', 'viri']          miliaria
# 83484              ['Augusti/Augustae', 'leges', 'viri']             leges
# 83485                ['litterae erasae', 'tituli sacri']      tituli sacri
# 83486                                                 {}                {}
#
#                                          status_notation    inscr_process  \
# 83482  ['Augusti/Augustae', 'ordo equester', 'tria no...  litterae erasae
# 83483                       ['Augusti/Augustae', 'viri']               {}
# 83484                       ['Augusti/Augustae', 'viri']               {}
# 83485                                                 {}  litterae erasae
# 83486                                                 {}               {}
#
#       notes_references notes_comments  \
# 83482
# 83483
# 83484
# 83485
# 83486
#
#                                              inscription  \
# 83482  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 83483  to 276;   b:  276 to 282         \n\n \n \nImp...
# 83484  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 83485  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 83486                             Octa(vius) Sa(lutaris)
#
#                               inscription_stripped_final  \
# 83482  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 83483  Imp(eratori) / Floriano / P(io) F(elici) Aug(u...
# 83484  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 83485  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 83486                             Octa(vius) Sa(lutaris)
#
#                                                    Links  dating from  \
# 83482  http://db.edcs.eu/epigr/partner.php?s_language...        309.0
# 83483  http://db.edcs.eu/epigr/partner.php?s_language...          NaN
# 83484  http://db.edcs.eu/epigr/partner.php?s_language...         49.0
# 83485  http://db.edcs.eu/epigr/partner.php?s_language...        198.0
# 83486  http://db.edcs.eu/epigr/partner.php?s_language...         81.0
#
#       dating to                                             status   Latitude  \
# 83482       313  Augusti/Augustae; litterae erasae; ordo equest...  39.451218
# 83483       276                   Augusti/Augustae; miliaria; viri  37.454501
# 83484        50                      Augusti/Augustae; leges; viri  37.454501
# 83485       209                      litterae erasae; tituli sacri  37.837612
# 83486        96                                               None  37.643870
#
#        Longitude                                              photo Material  \
# 83482  20.766767  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None
# 83483  22.420877                                               None    lapis
# 83484  22.420877                                               None     None
# 83485  24.937637  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None
# 83486  21.625513                                               None     None
#
#       Comment    EDH-ID language_EDCS  \
# 83482    None  HD052964          None
# 83483    None  HD051000          None
# 83484    None  HD021396          None
# 83485    None  HD011892          None
# 83486    None  HD050999          None
#
#                        clean_text_interpretive_word_EDCS  \
# 83482  Fortissimo et Piissimo Caesari domino nostro G...
# 83483  Imperatori Floriano Pio Felici Augusto patri p...
# 83484  Tiberius Claudius Caesar Augustus Germanicus p...
# 83485  Pro salute Imperatoris Caesaris Luci Septimi S...
# 83486                                 Octavius Salutaris
#
#       responsible_individual       type_of_inscription letter_size  \
# 83482                  Cowey     honorific inscription    3-5.3 cm
# 83483                  Cowey         mile-/leaguestone    3.3-6 cm
# 83484                  Cowey  public legal inscription        None
# 83485                  Cowey        votive inscription  5.5-5.7 cm
# 83486                  Cowey  owner/artist inscription        None
#
#                                               literature         work_status  \
# 83482  AE 1993, 1406.; V. Papadopoulou, AD 43 B, 1988...  checked with photo
# 83483  AE 1995, 1409.; M. Iozzer - M. Pangano, ASAA 6...  checked with photo
# 83484  CIL 03, 07251.; ILS 0214.; AE 1941, 0119.; MAI...  checked with photo
# 83485  AE 1911, 0056. (B); T. Sauciuc, MDAI(R) 25, 19...  checked with photo
# 83486  AE 1995, 1407.; U. Sinn u. a., Nikephoros 8, 1...  checked with photo
#
#         height                                    diplomatic_text  \
# 83482    99 cm  FORTISSIMO ET PIIS / SIMO CAESARI D N / GAL VA...
# 83483  (44) cm  [ ] / AN[ ] FLORIANO / P F AVG / P P / M P III...
# 83484   160 cm  T[ ] CLAVDIVS CAESAR AVG / G[ ]ANICVS PONTIF M...
# 83485    48 cm  PRO SALVTE IMP CAESARI / L SEPTIMI SEVERI ET M...
# 83486     None                                           OCTA SAL
#
#                                                   people  depth material  \
# 83482  [{'name': 'Gal. Val. [[Maximiano]]', 'nomen': ...  67 cm     None
# 83483  [{'person_id': '1', 'nomen': 'Annius+', 'name'...   None     None
# 83484  [{'gender': 'male', 'cognomen': 'Caesar August...  17 cm     None
# 83485  [{'gender': 'male', 'praenomen': 'L.', 'name':...   None     None
# 83486  [{'person_id': '1', 'nomen': 'Octavius*', 'nam...   None     None
#
#               type_of_monument province_label   width  \
# 83482              statue base         Epirus   67 cm
# 83483        mile-/leaguestone         Achaia   24 cm
# 83484                   tabula         Achaia   58 cm
# 83485                     None         Achaia  126 cm
# 83486  instrumentum domesticum         Achaia    None
#
#                                            transcription country  \
# 83482  Fortissimo et piis/simo Caesari d(omino) n(ost...  Greece
# 83483  [Imp(eratori) Caes(ari) M(arco)] / An[nio] Flo...  Greece
# 83484  T[i(berius)] Claudius Caesar Aug(ustus) / G[er...  Greece
# 83485  Pro salute Imp(eratorum) Caesari(s) / L(uci) S...  Greece
# 83486                             Octa(vius) Sal(utaris)  Greece
#
#                                                      uri findspot_ancient  \
# 83482  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Photike
# 83483  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 83484  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 83485  https://edh-www.adw.uni-heidelberg.de/edh/insc...      Palaeopolis
# 83486  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Olympia
#
#       last_update  modern_region findspot_modern  \
# 83482  2014-09-16        Ípeiros      Paramythía
# 83483  2011-05-24   Pelopónissos            Alea
# 83484  2011-05-10   Pelopónissos            Alea
# 83485  2017-05-30   Nótio Aigaío     Palaiópolis
# 83486  2012-04-16  Stereá Elláda         Olympia
#
#                                        edh_geography_uri  \
# 83482  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83483  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83484  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83485  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83486  https://edh-www.adw.uni-heidelberg.de/edh/geog...
#
#                                               commentary  \
# 83482                                               None
# 83483   Die erste Inschrift ist auf 276, die zweite a...
# 83484                                               None
# 83485   Auf dem Foto sind die Buchstaben oft kaum erk...
# 83486       (B): Sa(lutaris) fehlerhaft für Sal(utaris).
#
#                                trismegistos_uri external_image_uris fotos  \
# 83482  https://www.trismegistos.org/text/121715                  {}    {}
# 83483  https://www.trismegistos.org/text/177273                  {}    {}
# 83484  https://www.trismegistos.org/text/177131                  {}    {}
# 83485  https://www.trismegistos.org/text/177087                  {}    {}
# 83486  https://www.trismegistos.org/text/177272                  {}    {}
#
#       idno_tm                                    placenames_refs  \
# 83482  121715  ['http://www.trismegistos.org/place/000655', '...
# 83483  177273  ['http://www.trismegistos.org/place/000078', '...
# 83484  177131  ['http://www.trismegistos.org/place/000078', '...
# 83485  177087                                                 []
# 83486  177272  ['http://www.trismegistos.org/place/000078', '...
#
#                                             text_edition  \
# 83482                  Fortissimo et piissimo Caesari...
# 83483  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 83484                  Tiberius Claudius Caesar Augus...
# 83485                  Pro salute Imperatorum Caesari...
# 83486                                 Octavius Salutaris
#
#                                      origdate_text layout_execution  \
# 83482  309 AD – 313 AD                                           21
# 83483           276 AD                                           21
# 83484    49 AD – 50 AD                                           21
# 83485  198 AD – 209 AD                                           21
# 83486    81 AD – 96 AD                                           21
#
#       layout_execution_text  support_objecttype  support_objecttype_text  \
# 83482            unbestimmt                57.0             Statuenbasis
# 83483            unbestimmt                89.0      Meilen-/Leugenstein
# 83484            unbestimmt               257.0                    Tafel
# 83485            unbestimmt                 2.0               unbestimmt
# 83486            unbestimmt               140.0  Instrumentum domesticum
#
#       support_material support_material_text  support_decoration  \
# 83482              138            unbestimmt              1000.0
# 83483              138            unbestimmt              1000.0
# 83484              138            unbestimmt              1000.0
# 83485              138            unbestimmt              1000.0
# 83486              138            unbestimmt              1000.0
#
#       keywords_term                keywords_term_text  \
# 83482            69                    Ehreninschrift
# 83483           102               Meilen-/Leugenstein
# 83484                Rechtliche Verfügung, öffentlich
# 83485            80                     Weihinschrift
# 83486           311     Besitzer-/Herstellerinschrift
#
#       type_of_inscription_clean type_of_inscription_certainty  height_cm  \
# 83482     honorific inscription                       Certain       99.0
# 83483         mile-/leaguestone                       Certain       44.0
# 83484  public legal inscription                       Certain      160.0
# 83485        votive inscription                       Certain       48.0
# 83486  owner/artist inscription                       Certain        NaN
#
#        width_cm  depth_cm material_clean   type_of_monument_clean  \
# 83482      67.0      67.0           NULL              statue base
# 83483      24.0       NaN           NULL        mile-/leaguestone
# 83484      58.0      17.0           NULL                   tabula
# 83485     126.0       NaN           NULL                     NULL
# 83486       NaN       NaN           NULL  instrumentum domesticum
#
#       type_of_monument_certainty province_label_clean  \
# 83482                    Certain               Epirus
# 83483                    Certain               Achaia
# 83484                    Certain               Achaia
# 83485                       NULL               Achaia
# 83486                    Certain               Achaia
#
#       province_label_certainty country_clean country_certainty  \
# 83482                  Certain        Greece           Certain
# 83483                  Certain        Greece           Certain
# 83484                  Certain        Greece           Certain
# 83485                  Certain        Greece           Certain
# 83486                  Certain        Greece           Certain
#
#       findspot_ancient_clean findspot_ancient_certainty modern_region_clean  \
# 83482                Photike                    Certain             Ípeiros
# 83483                  Tegea                    Certain        Pelopónissos
# 83484                  Tegea                    Certain        Pelopónissos
# 83485            Palaeopolis                    Certain        Nótio Aigaío
# 83486                Olympia                    Certain       Stereá Elláda
#
#       modern_region_certainty findspot_modern_clean findspot_modern_certainty  \
# 83482                 Certain            Paramythía                   Certain
# 83483                 Certain                  Alea                   Certain
# 83484                 Certain                  Alea                   Certain
# 83485                 Certain           Palaiópolis                   Certain
# 83486                 Certain               Olympia                   Certain
#
#                               findspot_clean findspot_certainty  \
# 83482                       Agios Athanasios            Certain
# 83483                           Stringu, bei            Certain
# 83484                                   NULL               NULL
# 83485  to Elleniko Mauer, sekundär verwendet            Certain
# 83486                      Haus der Athleten            Certain
#
#       origdate_text_clean                            clean_text_conservative  \
# 83482     309 AD – 313 AD  Fortissimo et piissimo Caesari d n Gal Val P F...
# 83483              276 AD  An Floriano P F Aug p p m p III Imp Caes M Aur...
# 83484       49 AD – 50 AD  T Claudius Caesar Aug Ganicus pontif max trib ...
# 83485     198 AD – 209 AD  Pro salute Imp Caesari L Septimi Severi et M A...
# 83486       81 AD – 96 AD                                           Octa Sal
#
#                         clean_text_interpretive_sentence  \
# 83482  Fortissimo et piissimo Caesari domino nostro G...
# 83483  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 83484  Tiberius Claudius Caesar Augustus Germanicus p...
# 83485  Pro salute Imperatorum Caesaris Luci Septimi S...
# 83486                                 Octavius Salutaris
#
#                                     findspot year_of_find  \
# 83482                       Agios Athanasios         None
# 83483                           Stringu, bei         None
# 83484                                   None         None
# 83485  to Elleniko Mauer, sekundär verwendet         None
# 83486                      Haus der Athleten         None
#
#                    present_location                religion       geography  \
# 83482                 Fragma Kalama                    None  data available
# 83483                   Tegea, Mus.                    None            None
# 83484                          None                    None            None
# 83485  to Elleniko Mauer, vermauert  names of pagan deities            None
# 83486                          None                    None            None
#
#       social_economic_legal_history        military  not_after language  \
# 83482                          None            None      313.0    Latin
# 83483                data available            None        NaN    Latin
# 83484                          None            None       50.0    Latin
# 83485                          None  data available      209.0    Latin
# 83486                          None            None       96.0    Latin
#
#        not_before         coordinates  \
# 83482       309.0  [20.7668, 39.4512]
# 83483       276.0  [22.4171, 37.4319]
# 83484        49.0  [22.4171, 37.4319]
# 83485       198.0  [24.8323, 37.8188]
# 83486        81.0  [21.6271, 37.6479]
#
#                             clean_text_interpretive_word urban_context  \
# 83482  Fortissimo et piissimo Caesari domino nostro G...          rest
# 83483  Imperatori Caesari Marco Annio Floriano Pio Fe...           big
# 83484  Tiberius Claudius Caesar Augustus Germanicus p...           big
# 83485  Pro salute Imperatorum Caesaris Luci Septimi S...          rest
# 83486                                 Octavius Salutaris           big
#
#        within_rome nearest_city city_id_hanson  city_pop_est  \
# 83482        False       Dodona             31        1000.0
# 83483        False        Tegea             97       46362.0
# 83484        False        Tegea             97       46362.0
# 83485        False       Ioulis             47        1000.0
# 83486        False         Elis             35        1000.0
#
#                 city_geometry nearest_city_type  nearest_city_dist  \
# 83482  [20.787767, 39.546432]             minor           0.097513
# 83483  [22.417226, 37.427653]               big           0.004249
# 83484  [22.417226, 37.427653]               big           0.004249
# 83485   [24.34625, 37.633122]             minor           0.520308
# 83486  [21.435443, 37.827452]             minor           0.262624
#
#                         geometry  \
# 83482  POINT (20.76680 39.45120)
# 83483  POINT (22.41710 37.43190)
# 83484  POINT (22.41710 37.43190)
# 83485  POINT (24.83230 37.81880)
# 83486  POINT (21.62710 37.64790)
#
#                                                  bigrams  \
# 83482  [Fortissimo_et, et_piissimo, piissimo_Caesari,...
# 83483  [Imperatori_Caesari, Caesari_Marco, Marco_Anni...
# 83484  [Tiberius_Claudius, Claudius_Caesar, Caesar_Au...
# 83485  [Pro_salute, salute_Imperatorum, Imperatorum_C...
# 83486                               [Octavius_Salutaris]
#
#        type_of_inscription_auto  type_of_inscription_auto_prob
# 83482     honorific inscription                            1.0
# 83483         mile-/leaguestone                            1.0
# 83484  public legal inscription                            1.0
# 83485        votive inscription                            1.0
# 83486  owner/artist inscription                            1.0

# %%
EDHCS_autotypes.drop(["bigrams"], axis=1, inplace=True)

# %%
EDHCS_autotypes.shape
# Out:
# (137305, 112)

# %%
EDHCS_autotypes.head(5)
# Out:
#              EDCS-ID                                        publication  \
# 83482  EDCS-03700724  ZPE-108-159 = Thesprotia 00001 = AE 1993, 0140...
# 83483  EDCS-03300852                                     AE 1995, 01409
# 83484  EDCS-28500283  CIL 03, 07251 = D 00214 = NDIEC-07, p 81 = AE ...
# 83485  EDCS-09400671  CIMRM-02, 02350 = IG-12, 00274 = Andros 00124 ...
# 83486  EDCS-24600769                    AE 1995, 01407 = AE 2001, 01812
#
#       province province_list                                       place  \
# 83482   Achaia        Achaia                  Agios Athanasios / Photike
# 83483   Achaia        Achaia                                Alea / Tegea
# 83484   Achaia        Achaia                                Alea / Tegea
# 83485   Achaia        Achaia                                      Andros
# 83486   Achaia        Achaia  Archea Olimpia / Archaia Olympia / Olympia
#
#                                              place_list end_yr_list  \
# 83482                   ['Agios Athanasios', 'Photike']         313
# 83483                                 ['Alea', 'Tegea']         276
# 83484                                 ['Alea', 'Tegea']          50
# 83485                                            Andros         209
# 83486  ['Archea Olimpia', 'Archaia Olympia', 'Olympia']          96
#
#                                  notes_dating  \
# 83482
# 83483  to 276;   b:  276 to 282         \n\n
# 83484
# 83485
# 83486
#
#                                              status_list        inscr_type  \
# 83482  ['Augusti/Augustae', 'litterae erasae', 'ordo ...  tituli honorarii
# 83483           ['Augusti/Augustae', 'miliaria', 'viri']          miliaria
# 83484              ['Augusti/Augustae', 'leges', 'viri']             leges
# 83485                ['litterae erasae', 'tituli sacri']      tituli sacri
# 83486                                                 {}                {}
#
#                                          status_notation    inscr_process  \
# 83482  ['Augusti/Augustae', 'ordo equester', 'tria no...  litterae erasae
# 83483                       ['Augusti/Augustae', 'viri']               {}
# 83484                       ['Augusti/Augustae', 'viri']               {}
# 83485                                                 {}  litterae erasae
# 83486                                                 {}               {}
#
#       notes_references notes_comments  \
# 83482
# 83483
# 83484
# 83485
# 83486
#
#                                              inscription  \
# 83482  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 83483  to 276;   b:  276 to 282         \n\n \n \nImp...
# 83484  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 83485  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 83486                             Octa(vius) Sa(lutaris)
#
#                               inscription_stripped_final  \
# 83482  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 83483  Imp(eratori) / Floriano / P(io) F(elici) Aug(u...
# 83484  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 83485  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 83486                             Octa(vius) Sa(lutaris)
#
#                                                    Links  dating from  \
# 83482  http://db.edcs.eu/epigr/partner.php?s_language...        309.0
# 83483  http://db.edcs.eu/epigr/partner.php?s_language...          NaN
# 83484  http://db.edcs.eu/epigr/partner.php?s_language...         49.0
# 83485  http://db.edcs.eu/epigr/partner.php?s_language...        198.0
# 83486  http://db.edcs.eu/epigr/partner.php?s_language...         81.0
#
#       dating to                                             status   Latitude  \
# 83482       313  Augusti/Augustae; litterae erasae; ordo equest...  39.451218
# 83483       276                   Augusti/Augustae; miliaria; viri  37.454501
# 83484        50                      Augusti/Augustae; leges; viri  37.454501
# 83485       209                      litterae erasae; tituli sacri  37.837612
# 83486        96                                               None  37.643870
#
#        Longitude                                              photo Material  \
# 83482  20.766767  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None
# 83483  22.420877                                               None    lapis
# 83484  22.420877                                               None     None
# 83485  24.937637  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None
# 83486  21.625513                                               None     None
#
#       Comment    EDH-ID language_EDCS  \
# 83482    None  HD052964          None
# 83483    None  HD051000          None
# 83484    None  HD021396          None
# 83485    None  HD011892          None
# 83486    None  HD050999          None
#
#                        clean_text_interpretive_word_EDCS  \
# 83482  Fortissimo et Piissimo Caesari domino nostro G...
# 83483  Imperatori Floriano Pio Felici Augusto patri p...
# 83484  Tiberius Claudius Caesar Augustus Germanicus p...
# 83485  Pro salute Imperatoris Caesaris Luci Septimi S...
# 83486                                 Octavius Salutaris
#
#       responsible_individual       type_of_inscription letter_size  \
# 83482                  Cowey     honorific inscription    3-5.3 cm
# 83483                  Cowey         mile-/leaguestone    3.3-6 cm
# 83484                  Cowey  public legal inscription        None
# 83485                  Cowey        votive inscription  5.5-5.7 cm
# 83486                  Cowey  owner/artist inscription        None
#
#                                               literature         work_status  \
# 83482  AE 1993, 1406.; V. Papadopoulou, AD 43 B, 1988...  checked with photo
# 83483  AE 1995, 1409.; M. Iozzer - M. Pangano, ASAA 6...  checked with photo
# 83484  CIL 03, 07251.; ILS 0214.; AE 1941, 0119.; MAI...  checked with photo
# 83485  AE 1911, 0056. (B); T. Sauciuc, MDAI(R) 25, 19...  checked with photo
# 83486  AE 1995, 1407.; U. Sinn u. a., Nikephoros 8, 1...  checked with photo
#
#         height                                    diplomatic_text  \
# 83482    99 cm  FORTISSIMO ET PIIS / SIMO CAESARI D N / GAL VA...
# 83483  (44) cm  [ ] / AN[ ] FLORIANO / P F AVG / P P / M P III...
# 83484   160 cm  T[ ] CLAVDIVS CAESAR AVG / G[ ]ANICVS PONTIF M...
# 83485    48 cm  PRO SALVTE IMP CAESARI / L SEPTIMI SEVERI ET M...
# 83486     None                                           OCTA SAL
#
#                                                   people  depth material  \
# 83482  [{'name': 'Gal. Val. [[Maximiano]]', 'nomen': ...  67 cm     None
# 83483  [{'person_id': '1', 'nomen': 'Annius+', 'name'...   None     None
# 83484  [{'gender': 'male', 'cognomen': 'Caesar August...  17 cm     None
# 83485  [{'gender': 'male', 'praenomen': 'L.', 'name':...   None     None
# 83486  [{'person_id': '1', 'nomen': 'Octavius*', 'nam...   None     None
#
#               type_of_monument province_label   width  \
# 83482              statue base         Epirus   67 cm
# 83483        mile-/leaguestone         Achaia   24 cm
# 83484                   tabula         Achaia   58 cm
# 83485                     None         Achaia  126 cm
# 83486  instrumentum domesticum         Achaia    None
#
#                                            transcription country  \
# 83482  Fortissimo et piis/simo Caesari d(omino) n(ost...  Greece
# 83483  [Imp(eratori) Caes(ari) M(arco)] / An[nio] Flo...  Greece
# 83484  T[i(berius)] Claudius Caesar Aug(ustus) / G[er...  Greece
# 83485  Pro salute Imp(eratorum) Caesari(s) / L(uci) S...  Greece
# 83486                             Octa(vius) Sal(utaris)  Greece
#
#                                                      uri findspot_ancient  \
# 83482  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Photike
# 83483  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 83484  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 83485  https://edh-www.adw.uni-heidelberg.de/edh/insc...      Palaeopolis
# 83486  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Olympia
#
#       last_update  modern_region findspot_modern  \
# 83482  2014-09-16        Ípeiros      Paramythía
# 83483  2011-05-24   Pelopónissos            Alea
# 83484  2011-05-10   Pelopónissos            Alea
# 83485  2017-05-30   Nótio Aigaío     Palaiópolis
# 83486  2012-04-16  Stereá Elláda         Olympia
#
#                                        edh_geography_uri  \
# 83482  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83483  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83484  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83485  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 83486  https://edh-www.adw.uni-heidelberg.de/edh/geog...
#
#                                               commentary  \
# 83482                                               None
# 83483   Die erste Inschrift ist auf 276, die zweite a...
# 83484                                               None
# 83485   Auf dem Foto sind die Buchstaben oft kaum erk...
# 83486       (B): Sa(lutaris) fehlerhaft für Sal(utaris).
#
#                                trismegistos_uri external_image_uris fotos  \
# 83482  https://www.trismegistos.org/text/121715                  {}    {}
# 83483  https://www.trismegistos.org/text/177273                  {}    {}
# 83484  https://www.trismegistos.org/text/177131                  {}    {}
# 83485  https://www.trismegistos.org/text/177087                  {}    {}
# 83486  https://www.trismegistos.org/text/177272                  {}    {}
#
#       idno_tm                                    placenames_refs  \
# 83482  121715  ['http://www.trismegistos.org/place/000655', '...
# 83483  177273  ['http://www.trismegistos.org/place/000078', '...
# 83484  177131  ['http://www.trismegistos.org/place/000078', '...
# 83485  177087                                                 []
# 83486  177272  ['http://www.trismegistos.org/place/000078', '...
#
#                                             text_edition  \
# 83482                  Fortissimo et piissimo Caesari...
# 83483  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 83484                  Tiberius Claudius Caesar Augus...
# 83485                  Pro salute Imperatorum Caesari...
# 83486                                 Octavius Salutaris
#
#                                      origdate_text layout_execution  \
# 83482  309 AD – 313 AD                                           21
# 83483           276 AD                                           21
# 83484    49 AD – 50 AD                                           21
# 83485  198 AD – 209 AD                                           21
# 83486    81 AD – 96 AD                                           21
#
#       layout_execution_text  support_objecttype  support_objecttype_text  \
# 83482            unbestimmt                57.0             Statuenbasis
# 83483            unbestimmt                89.0      Meilen-/Leugenstein
# 83484            unbestimmt               257.0                    Tafel
# 83485            unbestimmt                 2.0               unbestimmt
# 83486            unbestimmt               140.0  Instrumentum domesticum
#
#       support_material support_material_text  support_decoration  \
# 83482              138            unbestimmt              1000.0
# 83483              138            unbestimmt              1000.0
# 83484              138            unbestimmt              1000.0
# 83485              138            unbestimmt              1000.0
# 83486              138            unbestimmt              1000.0
#
#       keywords_term                keywords_term_text  \
# 83482            69                    Ehreninschrift
# 83483           102               Meilen-/Leugenstein
# 83484                Rechtliche Verfügung, öffentlich
# 83485            80                     Weihinschrift
# 83486           311     Besitzer-/Herstellerinschrift
#
#       type_of_inscription_clean type_of_inscription_certainty  height_cm  \
# 83482     honorific inscription                       Certain       99.0
# 83483         mile-/leaguestone                       Certain       44.0
# 83484  public legal inscription                       Certain      160.0
# 83485        votive inscription                       Certain       48.0
# 83486  owner/artist inscription                       Certain        NaN
#
#        width_cm  depth_cm material_clean   type_of_monument_clean  \
# 83482      67.0      67.0           NULL              statue base
# 83483      24.0       NaN           NULL        mile-/leaguestone
# 83484      58.0      17.0           NULL                   tabula
# 83485     126.0       NaN           NULL                     NULL
# 83486       NaN       NaN           NULL  instrumentum domesticum
#
#       type_of_monument_certainty province_label_clean  \
# 83482                    Certain               Epirus
# 83483                    Certain               Achaia
# 83484                    Certain               Achaia
# 83485                       NULL               Achaia
# 83486                    Certain               Achaia
#
#       province_label_certainty country_clean country_certainty  \
# 83482                  Certain        Greece           Certain
# 83483                  Certain        Greece           Certain
# 83484                  Certain        Greece           Certain
# 83485                  Certain        Greece           Certain
# 83486                  Certain        Greece           Certain
#
#       findspot_ancient_clean findspot_ancient_certainty modern_region_clean  \
# 83482                Photike                    Certain             Ípeiros
# 83483                  Tegea                    Certain        Pelopónissos
# 83484                  Tegea                    Certain        Pelopónissos
# 83485            Palaeopolis                    Certain        Nótio Aigaío
# 83486                Olympia                    Certain       Stereá Elláda
#
#       modern_region_certainty findspot_modern_clean findspot_modern_certainty  \
# 83482                 Certain            Paramythía                   Certain
# 83483                 Certain                  Alea                   Certain
# 83484                 Certain                  Alea                   Certain
# 83485                 Certain           Palaiópolis                   Certain
# 83486                 Certain               Olympia                   Certain
#
#                               findspot_clean findspot_certainty  \
# 83482                       Agios Athanasios            Certain
# 83483                           Stringu, bei            Certain
# 83484                                   NULL               NULL
# 83485  to Elleniko Mauer, sekundär verwendet            Certain
# 83486                      Haus der Athleten            Certain
#
#       origdate_text_clean                            clean_text_conservative  \
# 83482     309 AD – 313 AD  Fortissimo et piissimo Caesari d n Gal Val P F...
# 83483              276 AD  An Floriano P F Aug p p m p III Imp Caes M Aur...
# 83484       49 AD – 50 AD  T Claudius Caesar Aug Ganicus pontif max trib ...
# 83485     198 AD – 209 AD  Pro salute Imp Caesari L Septimi Severi et M A...
# 83486       81 AD – 96 AD                                           Octa Sal
#
#                         clean_text_interpretive_sentence  \
# 83482  Fortissimo et piissimo Caesari domino nostro G...
# 83483  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 83484  Tiberius Claudius Caesar Augustus Germanicus p...
# 83485  Pro salute Imperatorum Caesaris Luci Septimi S...
# 83486                                 Octavius Salutaris
#
#                                     findspot year_of_find  \
# 83482                       Agios Athanasios         None
# 83483                           Stringu, bei         None
# 83484                                   None         None
# 83485  to Elleniko Mauer, sekundär verwendet         None
# 83486                      Haus der Athleten         None
#
#                    present_location                religion       geography  \
# 83482                 Fragma Kalama                    None  data available
# 83483                   Tegea, Mus.                    None            None
# 83484                          None                    None            None
# 83485  to Elleniko Mauer, vermauert  names of pagan deities            None
# 83486                          None                    None            None
#
#       social_economic_legal_history        military  not_after language  \
# 83482                          None            None      313.0    Latin
# 83483                data available            None        NaN    Latin
# 83484                          None            None       50.0    Latin
# 83485                          None  data available      209.0    Latin
# 83486                          None            None       96.0    Latin
#
#        not_before         coordinates  \
# 83482       309.0  [20.7668, 39.4512]
# 83483       276.0  [22.4171, 37.4319]
# 83484        49.0  [22.4171, 37.4319]
# 83485       198.0  [24.8323, 37.8188]
# 83486        81.0  [21.6271, 37.6479]
#
#                             clean_text_interpretive_word urban_context  \
# 83482  Fortissimo et piissimo Caesari domino nostro G...          rest
# 83483  Imperatori Caesari Marco Annio Floriano Pio Fe...           big
# 83484  Tiberius Claudius Caesar Augustus Germanicus p...           big
# 83485  Pro salute Imperatorum Caesaris Luci Septimi S...          rest
# 83486                                 Octavius Salutaris           big
#
#        within_rome nearest_city city_id_hanson  city_pop_est  \
# 83482        False       Dodona             31        1000.0
# 83483        False        Tegea             97       46362.0
# 83484        False        Tegea             97       46362.0
# 83485        False       Ioulis             47        1000.0
# 83486        False         Elis             35        1000.0
#
#                 city_geometry nearest_city_type  nearest_city_dist  \
# 83482  [20.787767, 39.546432]             minor           0.097513
# 83483  [22.417226, 37.427653]               big           0.004249
# 83484  [22.417226, 37.427653]               big           0.004249
# 83485   [24.34625, 37.633122]             minor           0.520308
# 83486  [21.435443, 37.827452]             minor           0.262624
#
#                         geometry  type_of_inscription_auto  \
# 83482  POINT (20.76680 39.45120)     honorific inscription
# 83483  POINT (22.41710 37.43190)         mile-/leaguestone
# 83484  POINT (22.41710 37.43190)  public legal inscription
# 83485  POINT (24.83230 37.81880)        votive inscription
# 83486  POINT (21.62710 37.64790)  owner/artist inscription
#
#        type_of_inscription_auto_prob
# 83482                            1.0
# 83483                            1.0
# 83484                            1.0
# 83485                            1.0
# 83486                            1.0

# %%
len(EDHCS_autotypes[EDHCS_autotypes["type_of_inscription_auto_prob"]>0.55])
# Out:
# 132112

# %%
len(EDHCS_autotypes[EDHCS_autotypes["type_of_inscription_auto"]=="NULL"])
# Out:
# 4339

# %%
def apply_threshold(inscr_type, prob):
    if (prob < 0.55) or (inscr_type == "NULL"):
        return None 
    else:
        return inscr_type
EDHCS_autotypes["type_of_inscription_auto"] =  EDHCS_autotypes.apply(lambda row: apply_threshold(row["type_of_inscription_auto"], row["type_of_inscription_auto_prob"]), axis=1)

# %%
def prob_to_zero(inscr_type, prob):
    if inscr_type == None:
        return 0
    else:
        return prob
EDHCS_autotypes["type_of_inscription_auto_prob"] =  EDHCS_autotypes.apply(lambda row: prob_to_zero(row["type_of_inscription_auto"], row["type_of_inscription_auto_prob"]), axis=1)

# %%
len(EDHCS_autotypes[EDHCS_autotypes["type_of_inscription_auto"].notnull()])
# Out:
# 127773

# %%
len(EDHCS_autotypes[(EDHCS_autotypes["type_of_inscription_auto"].notnull()) & (EDHCS_autotypes["type_of_inscription_auto_prob"] > 0.55)])
# Out:
# 127773

# %%
s = sddk.cloudSession("sciencedata.dk", "SDAM_root/SDAM_data/EDHCS", "648597@au.dk")
# Out:
# Your ScienceData username (e.g. '123456@au.dk'): 648597@au.dk
# Your ScienceData password: ········
# connection with shared folder established with you as its owner
# endpoint variable has been configured to: https://sciencedata.dk/files/SDAM_root/SDAM_data/EDHCS/

# %%
s.write_file("EDHCSg.geojson", EDHCS_autotypes)
# Out:
# A file with the same name ("EDHCSg.geojson") already exists in this location.
# Press Enter to overwrite it or choose different path and filename:
# Your <class 'geopandas.geodataframe.GeoDataFrame'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/EDHCS/EDHCSg.geojson"

# %%
print(test_results_df.to_markdown(tablefmt="github"))
# Out:
# |    |   threshold (=/>) |   proportion |    N |   correct |
# |----|-------------------|--------------|------|-----------|
# |  0 |              0.3  |         1    | 4601 |  0.862421 |
# |  1 |              0.35 |         0.94 | 4337 |  0.890247 |
# |  2 |              0.4  |         0.93 | 4310 |  0.8942   |
# |  3 |              0.45 |         0.91 | 4213 |  0.898647 |
# |  4 |              0.5  |         0.9  | 4162 |  0.90197  |
# |  5 |              0.55 |         0.89 | 4092 |  0.90567  |
# |  6 |              0.6  |         0.86 | 3955 |  0.908976 |
# |  7 |              0.65 |         0.84 | 3898 |  0.910723 |
# |  8 |              0.7  |         0.71 | 3264 |  0.957414 |
# |  9 |              0.75 |         0.67 | 3078 |  0.968811 |
# | 10 |              0.8  |         0.58 | 2694 |  0.971047 |
# | 11 |              0.85 |         0.51 | 2336 |  0.977312 |
# | 12 |              0.9  |         0.42 | 1957 |  0.984159 |
# | 13 |              0.95 |         0.34 | 1563 |  0.989763 |

# %%
print(model_results_df.to_markdown(tablefmt="github"))
# Out:
# |    |   threshold (=/>) |   proportion |     N |
# |----|-------------------|--------------|-------|
# |  0 |              0.3  |         0.99 | 82791 |
# |  1 |              0.35 |         0.98 | 81618 |
# |  2 |              0.4  |         0.97 | 81048 |
# |  3 |              0.45 |         0.95 | 79585 |
# |  4 |              0.5  |         0.95 | 78929 |
# |  5 |              0.55 |         0.94 | 78289 |
# |  6 |              0.6  |         0.93 | 77384 |
# |  7 |              0.65 |         0.92 | 76863 |
# |  8 |              0.7  |         0.73 | 61115 |
# |  9 |              0.75 |         0.71 | 59070 |
# | 10 |              0.8  |         0.61 | 50587 |
# | 11 |              0.85 |         0.56 | 46450 |
# | 12 |              0.9  |         0.49 | 40601 |
# | 13 |              0.95 |         0.43 | 36118 |

# %% [markdown]
# # Automatic assigment of `type_of_inscription`
#
# The EDHCS dataset consists of 137,305 inscriptions. These inscriptions might be classified as falling into certain inscription categories. However, the two source datasets (EDH and EDCS) employ a different approach to inscription classification. First of all, EDH uses English labels (e.g. "epitaph", "votive inscription" etc.), while EDCS uses Latin labels (e.g. "tituli_sepulcrales" or "tituli sacri"). In some cases, these types can be matched upon each other in a straightforward manner, in other cases this is not so simple. For instance, since the typological categories employed by EDCS are not mutually exclusive, some inscriptions are classified by means of five different labels. Furthermore, one category in the first source might correspond to several categories within the second source. For instance, the `owner/artist inscription` category in EDH corresponds either to `tituli possessionis` and `tituli fabricationis` in EDCS.
#
# Since we attempt to make the dataset as a whole accessible to cross-category comparisons, we had to decide which one of the two classification systems to employ. We decided for the EDH categories, especially because they are mutually exclusive, what makes the comparison slighthly more straitforward.
#
# However, since the EDH labels are present only for inscriptions included in the EDH dataset, we had to come up with a solution how top assign them to inscriptions from the EDCS dataset as well. This is a typical **document classification task**, which might be solved by numourous supervised machine learning methods. Here we decided for [Support Vector Machine (SVM)](https://en.wikipedia.org/wiki/Support-vector_machine) model to be trained on a subset of inscriptions which are included both in EDCS and EDH (for the whole implementation, see `scripts/3_INSCR-TYPE-AUTO.ipynb`).
#
# From the total number of 137,305 inscriptions in the EDHCS dataset, 49,916 are shared by both the EDH and EDCS dataset. From this subset, 46,171 are classified by means of the `type_of_inscription_clean` attribute  in EDH (the remaining 3,745 inscriptions are classified as `NULL`).  To build the SVM model, this constrained subset was divided into *training* and *test* datasets (90% were used to train and 10% (4,617) to test the model).
#
# The aim was to use some attributes from EDCS to classify the EDCS inscriptions according to the EDH inscription categories (e.g. as "epitaph", "votive inscription" etc.). After some experimenting, we realized that we can use information from at least three different columns:
# * `status_list`, including information about the inscription category according to EDCS combined with some other metadata
# * `Material`, containing information about the material from which the inscription is built
# * `clean_text_interpretive_word`, a preprocessed text of the inscription
#
# These three columns were used to construct 157 features to feed a TFIDF vectorizer. The features were formed by 100 most common bigrams in the texts of the inscriptions (e.g. "Dis_Manibus", "vixit_annos" or "votum_solvit"). Further, 37 were based on all unqique categories within the attribute `status_list`. Finally, 20 features were based on 20 most common categories from the `Material` attribute (e.g. "lapis", "opus_figlinae", "aes"). (Underscore was used to treat multi-word features as one word features).
#
#
# ### Model Testing
#
# For testing of the model we used 4,617 labeled inscriptions, randomly selected from 46,171 inscriptions contained both in EDH and EDCS, which have a non-empty `type_of_inscription_clean` attribute and which have not been used to  train the model.
#
# Each prediction of the SVM model is accompanied by **probability** on scale {0-1}, expressing a level of certainty concerning the predicted classification category. Thus, for instance, the inscription `EDCS-44500113` is classified as `votive inscription` with 0.919633 probability. On closer inscpection, we see that EDCS classifies this inscription as `tituli sacri`, what is probably the most important feature driving the prediction in this case.
#
# These probabilities might be used to formulate certain thresholds under which the classification will not be accepted. In Table 1, we see that 90 % of inscriptions in the test dataset has been classified with probability equal to- or higher than 0.5 and that this classification was correct in 90 % of cases. Further, approximately 71 % of inscriptions has been classified  with probability equal to- or higher than 0.7. From these more than 95 % was classified correctly. These results can inform us when we apply the model upon an unlabled dataset, where we can expect a comparable ratios between threshold values, proportions of covered inscriptions and the extent of correct classifications.
#
#
# |    |   threshold (=/>) |   proportion |    N |   correct |
# |----|-------------------|--------------|------|-----------|
# |  0 |              0.3  |         1    | 4601 |  0.862421 |
# |  1 |              0.35 |         0.94 | 4337 |  0.890247 |
# |  2 |              0.4  |         0.93 | 4310 |  0.8942   |
# |  3 |              0.45 |         0.91 | 4213 |  0.898647 |
# |  4 |              0.5  |         0.9  | 4162 |  0.90197  |
# |  5 |              0.55 |         0.89 | 4092 |  0.90567  |
# |  6 |              0.6  |         0.86 | 3955 |  0.908976 |
# |  7 |              0.65 |         0.84 | 3898 |  0.910723 |
# |  8 |              0.7  |         0.71 | 3264 |  0.957414 |
# |  9 |              0.75 |         0.67 | 3078 |  0.968811 |
# | 10 |              0.8  |         0.58 | 2694 |  0.971047 |
# | 11 |              0.85 |         0.51 | 2336 |  0.977312 |
# | 12 |              0.9  |         0.42 | 1957 |  0.984159 |
# | 13 |              0.95 |         0.34 | 1563 |  0.989763 |
#
# After testing, both the model and the vectorizer used to preprocess the data were saved as pickles for future reuse as `data/svm_model_v1.0.sav` and `data/svm_vectorizer_v1.0.sav`.
#
# ### Model application
#
# After training and testing the model on labeled data, we proceeded to apply the model on 83,482 inscriptions which are exclusively in EDCS. In this case, we cannot directly measure the proportion of correctly classified inscriptions. But we can use the data from testing to make an estimate.
#
# |    |   threshold (=/>) |   proportion |     N |
# |----|-------------------|--------------|-------|
# |  0 |              0.3  |         0.99 | 82791 |
# |  1 |              0.35 |         0.98 | 81618 |
# |  2 |              0.4  |         0.97 | 81048 |
# |  3 |              0.45 |         0.95 | 79585 |
# |  4 |              0.5  |         0.95 | 78929 |
# |  5 |              0.55 |         0.94 | 78289 |
# |  6 |              0.6  |         0.93 | 77384 |
# |  7 |              0.65 |         0.92 | 76863 |
# |  8 |              0.7  |         0.73 | 61115 |
# |  9 |              0.75 |         0.71 | 59070 |
# | 10 |              0.8  |         0.61 | 50587 |
# | 11 |              0.85 |         0.56 | 46450 |
# | 12 |              0.9  |         0.49 | 40601 |
# | 13 |              0.95 |         0.43 | 36118 |
#
#
# As a result of applying the model, we enriched the whole EDHCS dataset by 2 new attributes:
# * `type_of_inscription_auto`, containing either the predicted label or - where available - the label from `type_of_inscription_clean`
# * `type_of_inscription_auto_prob`, expressing the probability on the scale from 0 to 1 (1 is used for datapoints where the `type_of_inscription_clean` was used)
#
# When we look at the dataset as whole, we see that from the 137,305 inscriptions, 127,773 (93 %) are classified in `type_of_inscription_auto` with probability equal to- or higher than 0.55. Using the 0.55 threshold, this proportion of the dataset can be used for further comparisons.
