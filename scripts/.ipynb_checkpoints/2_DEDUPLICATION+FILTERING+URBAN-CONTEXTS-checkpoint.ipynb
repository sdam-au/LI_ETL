# %% [markdown]
# # Requirements

# %%
import sddk
import pandas as pd
pd.options.display.max_columns = 1000 # to see all columns
import json
import re
import geopandas as gpd
import warnings
from shapely.geometry import Point
from functools import partial
from shapely.ops import transform
import pyproj
warnings.filterwarnings('ignore')
import numpy as np
from scipy.spatial import cKDTree
import matplotlib.pyplot as plt
import geoplot as gplt

# %%
from importlib import reload # for testing purposes
reload(sddk)
# Out:
# <module 'sddk' from '/home/kasev/social_diversity/socdiv_venv/lib/python3.6/site-packages/sddk/__init__.py'>

# %%
sddk.test_package()
# Out:
# here we are right now - May 11, 13:00

# %% [markdown]
# # Import datasets

# %%
# read edh dataset
publicfolder = "b6b6afdb969d378b70929e86e58ad975"
EDH = sddk.read_file("EDH_text_cleaned_2021-01-21.json", "df", publicfolder)
EDH.head(5)
# Out:
# reading file located in a public folder
#   responsible_individual    type_of_inscription letter_size not_after  \
# 0                Feraudi                epitaph    3.2-2 cm      0130
# 1                Feraudi                epitaph        4 cm      0200
# 2                Feraudi  honorific inscription    4.5-3 cm      0170
# 3                   Gräf     votive inscription      2.5 cm      0200
# 4                Feraudi                epitaph         NaN      0200
#
#                                           literature         work_status  \
# 0  AE 1983, 0192.; M. Annecchino, Puteoli 4/5, 19...         provisional
# 1  AE 1983, 0080. (A); A. Ferrua, RAL 36, 1981, 1...            no image
# 2  AE 1983, 0518. (B); J. González, ZPE 52, 1983,...         provisional
# 3  AE 1983, 0533. (B); A.U. Stylow, Gerión 1, 198...  checked with photo
# 4  AE 1983, 0078. (B); A. Ferrua, RAL 36, 1981, 1...            no image
#
# ...

# %%
# read edcs dataset
publicfolder = "1f5f56d09903fe259c0906add8b3a55e"
EDCS = sddk.read_file("EDCS_text_cleaned_2021-03-01.json", "df", publicfolder)
EDCS.head(5)
# Out:
# reading file located in a public folder
#          EDCS-ID                                        publication province  \
# 0  EDCS-31400030                                      CIL 03, 12297   Achaia
# 1  EDCS-24700151  CIL 01, 02650 (p 1097) = IG-05-01, 00741 = ILL...   Achaia
# 2  EDCS-24900077  CIL 01, 00746 (p 944) = D 00867 = ILLRP 00374 ...   Achaia
# 3  EDCS-03700724  ZPE-108-159 = Thesprotia 00001 = AE 1993, 0140...   Achaia
# 4  EDCS-55701593                                    AE 2009, 01286a   Achaia
#
#   province_list                          place                     place_list  \
# 0        Achaia                              ?                              ?
# 1        Achaia                         Afesou                         Afesou
# 2        Achaia  Agia Triada / Merbaka / Midea  [Agia Triada, Merbaka, Midea]
# 3        Achaia     Agios Athanasios / Photike    [Agios Athanasios, Photike]
# ...

# %%
# length of the original dataset
print(len(EDH))
print(len(EDCS))
# Out:
# 81476
# 500618

# %% [markdown]
# # Get EDH-ID from EDCS "Links" column

# %%
def get_edh_id(links):
    try:
        if "edh/inschrift/" in links:
            edh_id = links.rpartition("edh/inschrift/")[2].split()[0]
        else:
            edh_id = None
    except:
        edh_id = None
    return edh_id
EDCS["EDH-ID"] = EDCS["Links"].apply(get_edh_id)

# %%
edh_ids = list(set([el for el in EDCS["EDH-ID"].tolist() if el != None]))
print(edh_ids[:10])
# Out:
# ['HD043107', 'HD068070', 'HD028626', 'HD050054', 'HD042511', 'HD034872', 'HD033488', 'HD026808', 'HD013453', 'HD059560']

# %%
# percents covered: 
len(edh_ids) / len(EDH) * 100
# Out:
# 90.2314792086013

# %%
# inscriptions which are not explicitly refered to in EDCS
EDH.rename(columns={"id":"EDH-ID"}, inplace=True)
EDH_unique = EDH[~EDH["EDH-ID"].isin(edh_ids)]
len(EDH_unique)
# Out:
# 8450

# %% [markdown]
# what about these?
#
# # Get EDH-ID from trismegistos API
#
# EDH standardly includes references to trismegistos. The trismegistos URI api enables queries for EDCS-ID. We will use this extract EDCS-IDs of additional inscriptions in EDCS which are in EDH

# %%
def get_edcs(trismegistos_uri):
    try:
        url = "https://www.trismegistos.org/dataservices/texrelations/{}".format(trismegistos_uri.rpartition("/")[2])
        resp = requests.get(url)
        edcs_ids = resp.json()[3]["EDCS"]
        return edcs_ids
    except: 
        return None

# %%
# %%time
# takes time, so use it carefully, or use data from the previous run below
EDH_unique["edcs_ids"] = EDH_unique["trismegistos_uri"].apply(get_edcs)

# %%
edcs_to_edh_dict = {}
for edh_id, edcs_ids in zip(EDH_unique["id"], EDH_unique["edcs_ids"]):
    try:
        for edcs_id in edcs_ids:
            edcs_to_edh_dict["EDCS-" + edcs_id] = edh_id
    except:
        pass

# %%
# save for future usage
with open("../data/edcs_to_edh_dict.json", "w") as f:
    json.dump(edcs_to_edh_dict, f)

# %%
# upload the previously identified pairs
with open("../data/edcs_to_edh_dict.json", "r") as f:
    edcs_to_edh_dict = json.load(f)

# %%
len(EDCS[EDCS["EDH-ID"].notnull()])
# Out:
# 74304

# %%
def get_edh_id_trismegistos(row):
    edh_id = row["EDH-ID"]
    if row["EDH-ID"] == None:
        if row["EDCS-ID"] in edcs_to_edh_dict.keys():
            edh_id = edcs_to_edh_dict[row["EDCS-ID"]]  
    return edh_id

# %%
EDCS["EDH-ID"] = EDCS.apply(lambda row: get_edh_id_trismegistos(row), axis=1)

# %%
EDCS[EDCS["EDH-ID"].notnull()].head(10)
# Out:
#           EDCS-ID                                        publication province  \
# 1   EDCS-24700151  CIL 01, 02650 (p 1097) = IG-05-01, 00741 = ILL...   Achaia
# 2   EDCS-24900077  CIL 01, 00746 (p 944) = D 00867 = ILLRP 00374 ...   Achaia
# 3   EDCS-03700724  ZPE-108-159 = Thesprotia 00001 = AE 1993, 0140...   Achaia
# 9   EDCS-66200107                                     AE 2008, 01264   Achaia
# 10  EDCS-13800065  CIL 01, 02955 = ILLRP 00370 (p 327) = ILGR 000...   Achaia
# 11  EDCS-66200108                   SEG-49, 00495a = AE 2008, 01265a   Achaia
# 12  EDCS-66200109                   SEG-49, 00495b = AE 2008, 01265b   Achaia
# 18  EDCS-03300852                                     AE 1995, 01409   Achaia
# 19  EDCS-66200178                                     AE 2009, 01314   Achaia
# 20  EDCS-28500283  CIL 03, 07251 = D 00214 = NDIEC-07, p 81 = AE ...   Achaia
#
#    province_list                           place  \
# 1         Achaia                          Afesou
# ...

# %%
len(EDCS[EDCS["EDH-ID"].notnull()])
# Out:
# 78325

# %%
# actual length of EDCS
len(EDCS)
# Out:
# 500618

# %% [markdown]
# # Merge unfiltered versions of the two datasets

# %%
# rename and create some columns to make the dataset more similar
EDCS.rename(columns={"start_yr" : "not_before", "end_yr_1" : "not_after"}, inplace=True)
EDCS["coordinates"] = EDCS.apply(lambda row: [row["Longitude"], row["Latitude"]], axis=1)

# %%
EDCS["language_EDCS"] = EDCS["language"]
EDCS["language_latin"] = EDCS["language"].isnull()
def none_to_latin(language, language_latin):
    if language_latin == True:
        return "Latin"
    elif language == "GR":
        return "Greek"
    else: 
        return language
EDCS["language"] = EDCS.apply(lambda row: none_to_latin(row["language"], row["language_latin"]), axis=1)
EDCS.drop("language_latin", axis=1, inplace=True)

# %%
EDCS["clean_text_interpretive_word_EDCS"] = EDCS["clean_text_interpretive_word"]

# %%
EDHCS = pd.merge(EDCS, EDH, on="EDH-ID", how="outer")
len(EDHCS)
# Out:
# 505652

# %%
len(EDHCS.columns)
# Out:
# 106

# %%
def choose_by_edh_id(row, col):
    if row["EDH-ID"] == None:
        value = row[col.rpartition("_y")[0] + "_x"] # use edcs value
    else:
        value = row[col]
    return value


for col in EDHCS.columns:
    if re.search("_y$", col):
        EDHCS[col.rpartition("_y")[0]] = EDHCS.apply(lambda row: choose_by_edh_id(row, col), axis=1)
        EDHCS.drop([col, col.rpartition("_y")[0] + "_x"], axis=1, inplace=True)
        #EDHCS.rename(columns={col : col.rpartition("_y")[0]}, inplace=True)
len(EDHCS.columns)
# Out:
# 101

# %%
EDHCS[EDHCS["EDH-ID"].notnull()].head(5)
# Out:
#               EDCS-ID                                        publication  \
# 422293  EDCS-24700151  CIL 01, 02650 (p 1097) = IG-05-01, 00741 = ILL...
# 422294  EDCS-24900077  CIL 01, 00746 (p 944) = D 00867 = ILLRP 00374 ...
# 422295  EDCS-03700724  ZPE-108-159 = Thesprotia 00001 = AE 1993, 0140...
# 422296  EDCS-66200107                                     AE 2008, 01264
# 422297  EDCS-13800065  CIL 01, 02955 = ILLRP 00370 (p 327) = ILGR 000...
#
#        province province_list                           place  \
# 422293   Achaia        Achaia                          Afesou
# 422294   Achaia        Achaia   Agia Triada / Merbaka / Midea
# 422295   Achaia        Achaia      Agios Athanasios / Photike
# 422296   Achaia        Achaia  Aigio / Egio / Aiyion / Aegeum
# 422297   Achaia        Achaia  Aigio / Egio / Aiyion / Aegeum
#
#                            place_list end_yr_list notes_dating  \
# 422293                         Afesou          {}
# ...

# %%
EDHCS.to_json("../data/large_data/EDHCS_unfiltered.json")

# %%
conf = sddk.configure("SDAM_root", "648597@au.dk")
# Out:
# sciencedata.dk username (format '123456@au.dk'): 648597@au.dk
# sciencedata.dk password: ········
# connection with shared folder established with you as its owner
# endpoint variable has been configured to: https://sciencedata.dk/files/SDAM_root/

# %%
sddk.write_file("SDAM_data/EDHCS/EDHCS_unfiltered.json", EDHCS, conf)
# Out:
# A file with the same name ("EDHCS_unfiltered.json") already exists in this location.
# Press Enter to overwrite it or choose different path and filename:
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/EDHCS/EDHCS_unfiltered.json"

# %% [markdown]
# # FIlter by language

# %%
EDHCS = pd.read_json("../data/large_data/EDHCS_unfiltered.json")

# %%
# focus on latin inscriptions only
EDHCS = EDHCS[EDHCS["language"].notnull()]
EDHCS = EDHCS[EDHCS["language"].str.contains("Latin")]
print(len(EDHCS))
# Out:
# 482908

# %% [markdown]
# # Filter by dating

# %%
print("not_before or not_after: {0}".format(len(EDHCS[(EDHCS["not_before"].notnull()) | (EDHCS["not_after"].notnull())])))
# Out:
# not_before or not_after: 158761

# %%
# having at least some form of date
EDHCS = EDHCS[(EDHCS["not_before"].notnull()) | (EDHCS["not_after"].notnull())]
len(EDHCS)
# originally we had 98972
# Out:
# 158761

# %%
# this date being numeric
def to_int(date_str):
    try: return int(date_str)
    except: return None
    
EDHCS["not_before"] = EDHCS["not_before"].apply(to_int)
EDHCS["not_after"] = EDHCS["not_after"].apply(to_int)

# %%
# these dates within the desired range
EDHCS = (EDHCS[(EDHCS["not_before"].between(-50, 350) | (EDHCS["not_after"].between(-50, 350)))])
len(EDHCS)
# Out:
# 145694

# %% [markdown]
# # Create geodataframes

# %%
# EDH as geodataframe
EDHCS= EDHCS[EDHCS["coordinates"].apply(lambda x: isinstance(x, list))]
EDHCSg = gpd.GeoDataFrame(EDHCS, geometry=gpd.points_from_xy(EDHCS["coordinates"].apply(lambda x: x[0]), EDHCS["coordinates"].apply(lambda x: x[1])), crs={"init": "epsg:3857"})
len(EDHCSg)
# Out:
# 144780

# %% [markdown]
# # Inscriptions within the provinces

# %%
pleiades_regions = gpd.read_file('../data/pleiades_regions.geojson', driver='GeoJSON')
# merge the regions into one multipolygon
RE_merged = pleiades_regions.unary_union

# %%
# takes time, apply carefully
EDHCSg = EDHCSg[EDHCSg.within(RE_merged)]

# %%
len(EDHCSg)
# Out:
# 137305

# %%
plt.rcParams['figure.dpi'] = 300

# %%
fig, [ax1, ax2] = plt.subplots(2, 1, figsize=[5.2, 7], tight_layout=True)

plt.rcParams['axes.titley'] = 1.0 
plt.rcParams['axes.titlepad'] = -14

pleiades_regions.plot(ax=ax1, color="lightgray")
gplt.kdeplot(EDHCSg[EDHCSg["EDH-ID"].notnull()], cmap='Reds', shade=True, ax=ax1) # , clip=EDHg.geometry,
EDHCSg[EDHCSg["EDH-ID"].notnull()].plot(ax=ax1, color="darkred", markersize=0.3)
ax1.set_axis_off()
ax1.set_xlim(-10, 41)
ax1.set_ylim(23, 55.5)
ax1.set_title("EDH (N={0})".format(len(EDHCSg[EDHCSg["EDH-ID"].notnull()])))

pleiades_regions.plot(ax=ax2, color="lightgray")
gplt.kdeplot(EDHCSg[EDHCSg["EDH-ID"].isnull()], cmap='Greens', shade=True, ax=ax2) # , clip=EDHg.geometry,
EDHCSg[EDHCSg["EDH-ID"].isnull()].plot(ax=ax2, alpha=0.4, color="darkgreen", markersize=0.3)
ax2.set_axis_off()
ax2.set_xlim(-10, 41)
ax2.set_ylim(23, 55.5)
ax2.set_title("EDCS (N={0})".format(len(EDHCSg[EDHCSg["EDH-ID"].isnull()])))
# Out:
# Text(0.5, 1.0, 'EDCS (N=83482)')

# %%
fig.savefig("../figures/EDH-EDCS_spatial_distributions.eps", format="eps", dpi=300)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
len(EDHCSg)
# Out:
# 137305

# %% [markdown]
# # Urban contexts

# %%
cities_pop = gpd.read_file("../data/roman_cities_pop.geojson")

# %%
cities_pop.sort_values("pop_est", ascending=False, inplace=True)
cities_pop.head(5)
# Out:
#           Primary Key        Ancient Toponym Modern Toponym  \
# 991    Hanson2016_992                   Roma           Rome
# 109    Hanson2016_110  Alexandria (Aegyptus)     Alexandria
# 179    Hanson2016_180           Lepcis Magna          Lebda
# 308    Hanson2016_309                 Rhodus         Rhodes
# 1323  Hanson2016_1324      Antiochia (Syria)        Antakya
#
#                   Province Country Barrington Atlas Rank  \
# 991   Italia (VII Etruria)   Italy                     1
# 109               Aegyptus   Egypt                     1
# 179   Africa Proconsularis   Libya                     1
# 308                   Asia  Greece                     3
# 1323                 Syria  Turkey                     1
#
#      Barrington Atlas Reference  Start Date  End Date  \
# 991                       43 B2        -700       NaN
# 109                       74 B2        -322       NaN
# 179                       35 G2         -30       NaN
# ...

# %%
len(cities_pop)
# Out:
# 1388

# %%
# total urban population
cities_pop["pop_est"].sum()
# Out:
# 10159670.0

# %%
cities_pop.columns
# Out:
# Index(['Primary Key', 'Ancient Toponym', 'Modern Toponym', 'Province',
#        'Country', 'Barrington Atlas Rank', 'Barrington Atlas Reference',
#        'Start Date', 'End Date', 'Select Bibliography', 'Area',
#        'Estimate Basis', 'num_of_structures', 'ID', 'level_0', 'Unnamed: 0_y',
#        'index', 'pop_sample', 'pop_est', 'pop_diff', 'geometry'],
#       dtype='object')

# %%
def get_city_type(pop_est):
    if pop_est >= 30000:
        return "big"
    else:
        if pop_est > 1000:
            return "middle"
        else: 
            return "minor"
cities_pop["city_type"] = cities_pop["pop_est"].apply(get_city_type)

# %%
# create two groups of cities
cities_big = cities_pop[cities_pop["city_type"] == "big"]
cities_middle = cities_pop[cities_pop["city_type"] =="middle"]
cities_minor = cities_pop[cities_pop["city_type"] == "minor"]
print("big cities (n={2}) - pop {0}, middle cities (n={3}) {1}".format(cities_big["pop_est"].sum(), cities_middle["pop_est"].sum(), len(cities_big), len(cities_middle)))
# Out:
# big cities (n=68) - pop 4641352.0, middle cities (n=690) 4942985.0

# %%
# by default, buffer is calculated in degrees
# we need to reproject it to calculate buffer in meters

def buffer_in_meters(pt_latlng, city_type): #(lng, lat, area_ha, coef):
    proj_meters = pyproj.Proj(init='epsg:3035')
    proj_latlng = pyproj.Proj(init='epsg:4326')
    project_to_meters = partial(pyproj.transform, proj_latlng, proj_meters)
    project_to_latlng = partial(pyproj.transform, proj_meters, proj_latlng)
    
    pt_meters = transform(project_to_meters, pt_latlng)
    if city_type == "minor":
        buffer_latlng == pt_latlng
    else:
        if city_type == "big":
            radius = 37000
        else:
            radius = 18500 
        buffer_meters = pt_meters.buffer(radius)
        buffer_latlng = transform(project_to_latlng, buffer_meters)
    return buffer_latlng

# %%
# %%time
cities_big["geometry"] = cities_big.apply(lambda row: buffer_in_meters(row["geometry"], row["city_type"]), axis=1)
# Out:
# CPU times: user 27.3 s, sys: 521 ms, total: 27.8 s
# Wall time: 27.9 s

# %%
# %%time
cities_middle["geometry"] = cities_middle.apply(lambda row: buffer_in_meters(row["geometry"], row["city_type"]), axis=1)
# Out:
# CPU times: user 4min 42s, sys: 5.21 s, total: 4min 47s
# Wall time: 4min 47s

# %%
fig, ax = plt.subplots(figsize=[5.2, 5])
pleiades_regions.plot(ax=ax, color="lightgray")
cities_minor.plot(ax=ax, color="darkgrey", markersize=0.5)
cities_middle.plot(ax=ax, color="darkgreen")
cities_big.plot(ax=ax, color="darkred")
ax.set_axis_off()
ax.set_xlim(-10, 41)
ax.set_ylim(23, 55.5)
# Out:
# (23.0, 55.5)

# %%
### some inspiration from here
# https://gis.stackexchange.com/questions/349637/given-list-of-points-lat-long-how-to-find-all-points-within-radius-of-a-give

# %%
cities_big_multipolygon = cities_big["geometry"].unary_union
cities_middle_multipolygon = cities_middle["geometry"].unary_union

# %%
# %%time
# for each inscription, decide whether it is in the multipolygon or not 
edhcs_big_cities_series = EDHCSg.within(cities_big_multipolygon)
edhcs_middle_cities_series = EDHCSg.within(cities_middle_multipolygon)

# working df with the same length as EDH
in_cities_df = pd.DataFrame([edhcs_big_cities_series, edhcs_middle_cities_series]).T
in_cities_df.columns = ["in_big", "in_middle"]
in_cities_df.head()
# Out:
# CPU times: user 8min 40s, sys: 3.63 ms, total: 8min 40s
# Wall time: 8min 40s
#      in_big  in_middle
# 575    True       True
# 715   False      False
# 717   False      False
# 720   False      False
# 724   False      False

# %%
# working df 
def get_big_middle_rest(row):
    value = "rest"
    if row["in_middle"]:
        value = "middle"
    if row["in_big"]:
        value = "big"
    return value
EDHCSg["urban_context"] = in_cities_df.apply(lambda row: get_big_middle_rest(row), axis=1)

# %%
EDHCSg.head(5)
# Out:
#            EDCS-ID                                     publication  province  \
# 575  EDCS-71300269                                  AE 2014, 01203    Achaia
# 715  EDCS-21200140  CIL 03, 00079 = CIL 03, 14147,6 = IDakke 00028  Aegyptus
# 717  EDCS-21200142   CIL 03, 00081 = CIL 03, 13584 = IDakke 00064a  Aegyptus
# 720  EDCS-52100002                                    IDakke 00064  Aegyptus
# 724  EDCS-44500113                                    IDakke 00100  Aegyptus
#
#     province_list                                              place  \
# 575        Achaia         Mavrommati / Mavromati / Messini / Messene
# 715      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 717      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 720      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 724      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
#
#                                             place_list end_yr_list  \
# ...

# %%
print("EDHCS inscriptions in big cities: ", len(EDHCSg[EDHCSg["urban_context"]=="big"]))
print("EDHCS inscriptionslen in middle cities: ", len(EDHCSg[EDHCSg["urban_context"]=="middle"]))
print("EDHCS inscriptions - rest: ", len(EDHCSg[EDHCSg["urban_context"]=="rest"]))
# Out:
# EDHCS inscriptions in big cities:  48898
# EDHCS inscriptionslen in middle cities:  56291
# EDHCS inscriptions - rest:  32116

# %%
print("EDH inscriptions in big cities: ", len(EDHCSg[(EDHCSg["EDH-ID"].notnull()) & (EDHCSg["urban_context"]=="big")]))
print("EDH inscriptionslen in middle cities: ", len(EDHCSg[(EDHCSg["EDH-ID"].notnull()) & (EDHCSg["urban_context"]=="middle")]))
print("EDH inscriptions - rest: ", len(EDHCSg[(EDHCSg["EDH-ID"].notnull()) & (EDHCSg["urban_context"]=="rest")]))
# Out:
# EDH inscriptions in big cities:  4218
# EDH inscriptionslen in middle cities:  25943
# EDH inscriptions - rest:  23662

# %%
print("EDCS inscriptions in big cities: ", len(EDHCSg[(EDHCSg["EDH-ID"].isnull()) & (EDHCSg["urban_context"]=="big")]))
print("EDCS inscriptionslen in middle cities: ", len(EDHCSg[(EDHCSg["EDH-ID"].isnull()) & (EDHCSg["urban_context"]=="middle")]))
print("EDCS inscriptions - rest: ", len(EDHCSg[(EDHCSg["EDH-ID"].isnull()) & (EDHCSg["urban_context"]=="rest")]))
# Out:
# EDCS inscriptions in big cities:  44680
# EDCS inscriptionslen in middle cities:  30348
# EDCS inscriptions - rest:  8454

# %%
#sddk.write_file("SDAM_data/social_diversity/EDH_filtered.json", pd.DataFrame(EDHCSg[EDHCSg["EDH-ID"].notnull()].drop("geometry", axis=1)), conf)
#sddk.write_file("SDAM_data/social_diversity/EDCS_filtered.json", pd.DataFrame(EDHCSg[EDHCSg["EDH-ID"].isnull()].drop("geometry", axis=1)), conf)

# %%
rome_polygon = cities_big.loc[cities_big["Modern Toponym"]=="Rome"]["geometry"].tolist()[0]

# %%
# %%time
EDHCSg["within_rome"] = EDHCSg.within(rome_polygon)

print(len(EDHCSg[(EDHCSg["EDH-ID"].notnull()) & (EDHCSg["within_rome"]==True)]))
print(len(EDHCSg[(EDHCSg["EDH-ID"].isnull()) & (EDHCSg["within_rome"]==True)]))
# Out:
# 2738
# 39824
# CPU times: user 746 ms, sys: 4.75 ms, total: 751 ms
# Wall time: 745 ms

# %%
EDHCSg_rome = EDHCSg[EDHCSg["within_rome"]==True]
EDHCSg_rome["province"].unique().tolist()
# Out:
# ['Etruria / Regio VII',
#  'Latium et Campania / Regio I',
#  'Roma',
#  'Samnium / Regio IV',
#  'Aegyptus',
#  'Aemilia / Regio VIII',
#  'Gallia Narbonensis',
#  'Picenum / Regio V',
#  'Provincia incerta',
#  'Umbria / Regio VI',
#  None]

# %%
len(EDHCSg_rome[EDHCSg_rome["province"]=="Roma"])
# Out:
# 37250

# %%
fig, ax = plt.subplots(figsize=[5.2, 5.2], tight_layout=True)

#pleiades_regions.plot(ax=ax1, color="lightgray")
#gplt.kdeplot(EDHg, cmap='Reds', shade=True, ax=ax1) # , clip=EDHg.geometry,
#EDHg.plot(ax=ax1, color="darkred", markersize=0.3)
#ax1.set_axis_off()
#ax1.set_xlim(-10, 41)
#ax1.set_ylim(23, 55.5)
#ax1.set_title("EDH (N={0})".format(len(EDHg)))


ax.set_axis_off()
cities_big[cities_big.intersects(rome_polygon)].plot(ax=ax, color="lightblue", edgecolor="black", alpha=0.5)
cities_middle[cities_middle.intersects(rome_polygon)].plot(ax=ax, color="lightgray", edgecolor="black", alpha=0.5)

cities_big.loc[cities_big["Modern Toponym"]=="Rome"].plot(ax=ax, color="lightblue", edgecolor="black", alpha=0.5)
# for anotations: 
# cities_rome = cities_pop[(cities_pop["Ancient Toponym"].isin(nearest_cities["city"].unique().tolist())) & (cities_pop["pop_est"] > 1000)]
#for x, y, label in zip(cities_rome.geometry.x, cities_rome.geometry.y, cities_rome["Ancient Toponym"]):
#    ax.annotate(label, xy=(x, y), xytext=(3, 3), textcoords="offset points")
#gplt.kdeplot(EDCSg_rome, Shade=True, ax=ax)

gplt.kdeplot(EDHCSg_rome, Shade=True, ax=ax)
EDHCSg_rome.plot(color="black", markersize=0.5, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Nearest cities

# %%
def ckdnearest(inscriptions, cities):
    cities = cities[['Ancient Toponym', "ID", "pop_est", 'geometry', "city_type"]]
    cities.rename(columns={"Ancient Toponym" : "nearest_city", "city_type": "nearest_city_type", "pop_est" : "city_pop_est", "ID" : "city_id_hanson"}, inplace=True)
    nA = np.array(list(inscriptions.geometry.apply(lambda x: (x.x, x.y))))
    nB = np.array(list(cities.geometry.apply(lambda x: (x.x, x.y))))
    btree = cKDTree(nB)
    dist, idx = btree.query(nA, k=1)
    gdB_nearest = cities.iloc[idx].rename(columns={"geometry": "city_geometry"}).reset_index(drop=True)
    gdB_nearest["city_geometry"] = [[geom.x, geom.y] for geom in gdB_nearest["city_geometry"]]
    gdf = pd.concat(
        [
            inscriptions.reset_index(drop=True),
            gdB_nearest,
            pd.Series(dist, name='nearest_city_dist')
        ], 
        axis=1)
    return gdf

#ckdnearest(gpd1, gpd2)

# %%
# nearest cities in the Rome neighborhood
nearest_cities = ckdnearest(EDHCSg_rome, cities_pop)
nearest_cities.groupby("nearest_city").size()
# Out:
# nearest_city
# Alsium                 13
# Ardea                   7
# Aricia                335
# Baccanae                7
# Bovillae               30
# Caere                 150
# Capena                 96
# Castrimoenium         135
# Cures                  14
# Fidenae               114
# Fregenae               27
# Gabii                  52
# Labicum                12
# Lanuvium              191
# Lavinium               86
# Lucus Feroniae         70
# Nepet                   5
# Nomentum              133
# Ostia                1797
# Portus                579
# Praeneste             344
# Roma                37769
# Sutrium                25
# Tibur                 246
# Trebula Suffenas        4
# Tusculum              118
# Veii                   49
# Velitrae              141
# Vitellia               13
# dtype: int64

# %%
try:
    #EDHg.drop(['nearest_city',
    #   'city_id_hanson', 'city_pop_est', 'city_geometry', 'nearest_city_type',
    #   'nearest_city_dist'], axis=1, inplace=True)
    EDHCSg.drop(['nearest_city',
       'city_id_hanson', 'city_pop_est', 'city_geometry', 'nearest_city_type',
       'nearest_city_dist'], axis=1, inplace=True)
except: pass

# %%
# %%time
EDHCSg = ckdnearest(EDHCSg, cities_pop)
# Out:
# CPU times: user 4.29 s, sys: 75.6 ms, total: 4.37 s
# Wall time: 4.37 s

# %%
EDHCSg.head(5)
# Out:
#          EDCS-ID                                     publication  province  \
# 0  EDCS-71300269                                  AE 2014, 01203    Achaia
# 1  EDCS-21200140  CIL 03, 00079 = CIL 03, 14147,6 = IDakke 00028  Aegyptus
# 2  EDCS-21200142   CIL 03, 00081 = CIL 03, 13584 = IDakke 00064a  Aegyptus
# 3  EDCS-52100002                                    IDakke 00064  Aegyptus
# 4  EDCS-44500113                                    IDakke 00100  Aegyptus
#
#   province_list                                              place  \
# 0        Achaia         Mavrommati / Mavromati / Messini / Messene
# 1      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 2      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 3      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
# 4      Aegyptus  Ad-Dakka / El-Dakka / Dakke / Pselqet / Pselki...
#
#                                           place_list end_yr_list notes_dating  \
# ...

# %%
print(len(EDHCSg[EDHCSg["nearest_city_type"]=="big"]))
print(len(EDHCSg[EDHCSg["nearest_city_type"]=="middle"]))
print(len(EDHCSg[EDHCSg["nearest_city_type"]=="minor"]))
# Out:
# 41997
# 73197
# 22111

# %%
EDHCSg.shape
# Out:
# (137305, 110)

# %% [markdown]
# # Saving for future usage

# %%
with open("EDHCSg.geojson", "w") as file: 
    json.dump(sddk.gdf_to_geojson(EDHCSg), file)

# %%
conf = sddk.configure("SDAM_root", "648597@au.dk")
# Out:
# sciencedata.dk username (format '123456@au.dk'): 648597@au.dk
# sciencedata.dk password: ········
# connection with shared folder established with you as its owner
# endpoint variable has been configured to: https://sciencedata.dk/files/SDAM_root/

# %%
sddk.write_file("SDAM_data/EDHCS/EDHCSg.geojson", EDHCSg, conf)
# Out:
# Your <class 'geopandas.geodataframe.GeoDataFrame'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/EDHCS/EDHCSg.geojson"

# %%
EDHCSg_minimal = EDHCSg[["EDH-ID", "EDCS-ID", "geometry", "not_before", "not_after", "clean_text_interpretive_word", "type_of_inscription_clean", "inscr_type"]]
sddk.write_file("SDAM_data/EDHCS/EDHCSg_minimal.geojson", EDHCSg_minimal, conf)
# Out:
# Your <class 'geopandas.geodataframe.GeoDataFrame'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/EDHCS/EDHCSg_minimal.geojson"

# %%
# test reading back
EDHCSg_minimal_test = sddk.read_file("SDAM_data/EDHCS/EDHCSg_minimal.geojson", "gdf", conf)
EDHCSg_minimal_test.head(5)
# Out:
#   EDH-ID        EDCS-ID  not_before  not_after  \
# 0   None  EDCS-71300269        69.0       96.0
# 1   None  EDCS-21200140       109.0      109.0
# 2   None  EDCS-21200142       109.0      109.0
# 3   None  EDCS-52100002       109.0      109.0
# 4   None  EDCS-44500113       103.0      117.0
#
#                         clean_text_interpretive_word  \
# 0                                      De Rasticanis
# 1  Deo Magno Mercurio adoravit vexillu legionis I...
# 2                                   Anno XII Traiani
# 3                                     Anno XX Traani
# 4  Pro salute Imperatoris Nervae Traiani Caesaris...
#
#   type_of_inscription_clean                                inscr_type  \
# 0                      None                      tituli fabricationis
# 1                      None  ['tituli fabricationis', 'tituli sacri']
# 2                      None                                        {}
# 3                      None                       tituli possessionis
# ...
