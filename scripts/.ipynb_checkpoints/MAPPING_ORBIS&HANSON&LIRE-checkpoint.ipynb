# %%
import sddk
import pandas as pd
pd.options.display.max_columns = 1000 # to see all columns
import json
import re
import geopandas as gpd
import warnings
from shapely.geometry import Point
from functools import partial
from shapely.ops import transform
import pyproj
warnings.filterwarnings('ignore')
import numpy as np
from scipy.spatial import cKDTree
import matplotlib.pyplot as plt
import geoplot as gplt

# %%
# read LIRE dataset from zenodo
# !!! use carefully - takes time 
LIRE = gpd.read_file("https://zenodo.org/record/5074774/files/LIREg.geojson?download=1", driver="geoJSON")
LIRE.head(5)
# Out:
#          EDCS-ID                                        publication province  \
# 0  EDCS-03700724  ZPE-108-159 = Thesprotia 00001 = AE 1993, 0140...   Achaia
# 1  EDCS-03300852                                     AE 1995, 01409   Achaia
# 2  EDCS-28500283  CIL 03, 07251 = D 00214 = NDIEC-07, p 81 = AE ...   Achaia
# 3  EDCS-09400671  CIMRM-02, 02350 = IG-12, 00274 = Andros 00124 ...   Achaia
# 4  EDCS-24600769                    AE 1995, 01407 = AE 2001, 01812   Achaia
#
#   province_list                                       place  \
# 0        Achaia                  Agios Athanasios / Photike
# 1        Achaia                                Alea / Tegea
# 2        Achaia                                Alea / Tegea
# 3        Achaia                                      Andros
# 4        Achaia  Archea Olimpia / Archaia Olympia / Olympia
#
#                                          place_list end_yr_list  \
# 0                   ['Agios Athanasios', 'Photike']         313
# 1                                 ['Alea', 'Tegea']         276
# 2                                 ['Alea', 'Tegea']          50
# 3                                            Andros         209
# 4  ['Archea Olimpia', 'Archaia Olympia', 'Olympia']          96
#
#                              notes_dating  \
# 0
# 1  to 276;   b:  276 to 282         \n\n
# 2
# 3
# 4
#
#                                          status_list        inscr_type  \
# 0  ['Augusti/Augustae', 'litterae erasae', 'ordo ...  tituli honorarii
# 1           ['Augusti/Augustae', 'miliaria', 'viri']          miliaria
# 2              ['Augusti/Augustae', 'leges', 'viri']             leges
# 3                ['litterae erasae', 'tituli sacri']      tituli sacri
# 4                                                { }               { }
#
#                                      status_notation    inscr_process  \
# 0  ['Augusti/Augustae', 'ordo equester', 'tria no...  litterae erasae
# 1                       ['Augusti/Augustae', 'viri']              { }
# 2                       ['Augusti/Augustae', 'viri']              { }
# 3                                                { }  litterae erasae
# 4                                                { }              { }
#
#   notes_references notes_comments  \
# 0
# 1
# 2
# 3
# 4
#
#                                          inscription  \
# 0  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 1  to 276;   b:  276 to 282         \n\n \n \nImp...
# 2  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 3  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 4                             Octa(vius) Sa(lutaris)
#
#                           inscription_stripped_final  \
# 0  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 1  Imp(eratori) / Floriano / P(io) F(elici) Aug(u...
# 2  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 3  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 4                             Octa(vius) Sa(lutaris)
#
#                                                Links  dating from dating to  \
# 0  http://db.edcs.eu/epigr/partner.php?s_language...        309.0       313
# 1  http://db.edcs.eu/epigr/partner.php?s_language...          NaN       276
# 2  http://db.edcs.eu/epigr/partner.php?s_language...         49.0        50
# 3  http://db.edcs.eu/epigr/partner.php?s_language...        198.0       209
# 4  http://db.edcs.eu/epigr/partner.php?s_language...         81.0        96
#
#                                               status   Latitude  Longitude  \
# 0  Augusti/Augustae; litterae erasae; ordo equest...  39.451218  20.766767
# 1                   Augusti/Augustae; miliaria; viri  37.454501  22.420877
# 2                      Augusti/Augustae; leges; viri  37.454501  22.420877
# 3                      litterae erasae; tituli sacri  37.837612  24.937637
# 4                                               None  37.643870  21.625513
#
#                                                photo Material Comment  \
# 0  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None    None
# 1                                               None    lapis    None
# 2                                               None     None    None
# 3  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None    None
# 4                                               None     None    None
#
#      EDH-ID language_EDCS                  clean_text_interpretive_word_EDCS  \
# 0  HD052964          None  Fortissimo et Piissimo Caesari domino nostro G...
# 1  HD051000          None  Imperatori Floriano Pio Felici Augusto patri p...
# 2  HD021396          None  Tiberius Claudius Caesar Augustus Germanicus p...
# 3  HD011892          None  Pro salute Imperatoris Caesaris Luci Septimi S...
# 4  HD050999          None                                 Octavius Salutaris
#
#   responsible_individual       type_of_inscription letter_size  \
# 0                  Cowey     honorific inscription    3-5.3 cm
# 1                  Cowey         mile-/leaguestone    3.3-6 cm
# 2                  Cowey  public legal inscription        None
# 3                  Cowey        votive inscription  5.5-5.7 cm
# 4                  Cowey  owner/artist inscription        None
#
#                                           literature         work_status  \
# 0  AE 1993, 1406.; V. Papadopoulou, AD 43 B, 1988...  checked with photo
# 1  AE 1995, 1409.; M. Iozzer - M. Pangano, ASAA 6...  checked with photo
# 2  CIL 03, 07251.; ILS 0214.; AE 1941, 0119.; MAI...  checked with photo
# 3  AE 1911, 0056. (B); T. Sauciuc, MDAI(R) 25, 19...  checked with photo
# 4  AE 1995, 1407.; U. Sinn u. a., Nikephoros 8, 1...  checked with photo
#
#     height                                    diplomatic_text  \
# 0    99 cm  FORTISSIMO ET PIIS / SIMO CAESARI D N / GAL VA...
# 1  (44) cm  [ ] / AN[ ] FLORIANO / P F AVG / P P / M P III...
# 2   160 cm  T[ ] CLAVDIVS CAESAR AVG / G[ ]ANICVS PONTIF M...
# 3    48 cm  PRO SALVTE IMP CAESARI / L SEPTIMI SEVERI ET M...
# 4     None                                           OCTA SAL
#
#                                               people  depth material  \
# 0  [{'name': 'Gal. Val. [[Maximiano]]', 'nomen': ...  67 cm     None
# 1  [{'person_id': '1', 'nomen': 'Annius+', 'name'...   None     None
# 2  [{'gender': 'male', 'cognomen': 'Caesar August...  17 cm     None
# 3  [{'gender': 'male', 'praenomen': 'L.', 'name':...   None     None
# 4  [{'person_id': '1', 'nomen': 'Octavius*', 'nam...   None     None
#
#           type_of_monument province_label   width  \
# 0              statue base         Epirus   67 cm
# 1        mile-/leaguestone         Achaia   24 cm
# 2                   tabula         Achaia   58 cm
# 3                     None         Achaia  126 cm
# 4  instrumentum domesticum         Achaia    None
#
#                                        transcription country  \
# 0  Fortissimo et piis/simo Caesari d(omino) n(ost...  Greece
# 1  [Imp(eratori) Caes(ari) M(arco)] / An[nio] Flo...  Greece
# 2  T[i(berius)] Claudius Caesar Aug(ustus) / G[er...  Greece
# 3  Pro salute Imp(eratorum) Caesari(s) / L(uci) S...  Greece
# 4                             Octa(vius) Sal(utaris)  Greece
#
#                                                  uri findspot_ancient  \
# 0  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Photike
# 1  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 2  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 3  https://edh-www.adw.uni-heidelberg.de/edh/insc...      Palaeopolis
# 4  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Olympia
#
#   last_update  modern_region findspot_modern  \
# 0  2014-09-16        Ípeiros      Paramythía
# 1  2011-05-24   Pelopónissos            Alea
# 2  2011-05-10   Pelopónissos            Alea
# 3  2017-05-30   Nótio Aigaío     Palaiópolis
# 4  2012-04-16  Stereá Elláda         Olympia
#
#                                    edh_geography_uri  \
# 0  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 1  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 2  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 3  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 4  https://edh-www.adw.uni-heidelberg.de/edh/geog...
#
#                                           commentary  \
# 0                                               None
# 1   Die erste Inschrift ist auf 276, die zweite a...
# 2                                               None
# 3   Auf dem Foto sind die Buchstaben oft kaum erk...
# 4       (B): Sa(lutaris) fehlerhaft für Sal(utaris).
#
#                            trismegistos_uri external_image_uris fotos idno_tm  \
# 0  https://www.trismegistos.org/text/121715                 { }   { }  121715
# 1  https://www.trismegistos.org/text/177273                 { }   { }  177273
# 2  https://www.trismegistos.org/text/177131                 { }   { }  177131
# 3  https://www.trismegistos.org/text/177087                 { }   { }  177087
# 4  https://www.trismegistos.org/text/177272                 { }   { }  177272
#
#                                      placenames_refs  \
# 0  ['http://www.trismegistos.org/place/000655', '...
# 1  ['http://www.trismegistos.org/place/000078', '...
# 2  ['http://www.trismegistos.org/place/000078', '...
# 3                                                 []
# 4  ['http://www.trismegistos.org/place/000078', '...
#
#                                         text_edition  \
# 0                  Fortissimo et piissimo Caesari...
# 1  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 2                  Tiberius Claudius Caesar Augus...
# 3                  Pro salute Imperatorum Caesari...
# 4                                 Octavius Salutaris
#
#                                  origdate_text layout_execution  \
# 0  309 AD – 313 AD                                           21
# 1           276 AD                                           21
# 2    49 AD – 50 AD                                           21
# 3  198 AD – 209 AD                                           21
# 4    81 AD – 96 AD                                           21
#
#   layout_execution_text  support_objecttype  support_objecttype_text  \
# 0            unbestimmt                57.0             Statuenbasis
# 1            unbestimmt                89.0      Meilen-/Leugenstein
# 2            unbestimmt               257.0                    Tafel
# 3            unbestimmt                 2.0               unbestimmt
# 4            unbestimmt               140.0  Instrumentum domesticum
#
#   support_material support_material_text  support_decoration keywords_term  \
# 0              138            unbestimmt              1000.0            69
# 1              138            unbestimmt              1000.0           102
# 2              138            unbestimmt              1000.0
# 3              138            unbestimmt              1000.0            80
# 4              138            unbestimmt              1000.0           311
#
#                  keywords_term_text type_of_inscription_clean  \
# 0                    Ehreninschrift     honorific inscription
# 1               Meilen-/Leugenstein         mile-/leaguestone
# 2  Rechtliche Verfügung, öffentlich  public legal inscription
# 3                     Weihinschrift        votive inscription
# 4     Besitzer-/Herstellerinschrift  owner/artist inscription
#
#   type_of_inscription_certainty  height_cm  width_cm  depth_cm material_clean  \
# 0                       Certain       99.0      67.0      67.0           NULL
# 1                       Certain       44.0      24.0       NaN           NULL
# 2                       Certain      160.0      58.0      17.0           NULL
# 3                       Certain       48.0     126.0       NaN           NULL
# 4                       Certain        NaN       NaN       NaN           NULL
#
#     type_of_monument_clean type_of_monument_certainty province_label_clean  \
# 0              statue base                    Certain               Epirus
# 1        mile-/leaguestone                    Certain               Achaia
# 2                   tabula                    Certain               Achaia
# 3                     NULL                       NULL               Achaia
# 4  instrumentum domesticum                    Certain               Achaia
#
#   province_label_certainty country_clean country_certainty  \
# 0                  Certain        Greece           Certain
# 1                  Certain        Greece           Certain
# 2                  Certain        Greece           Certain
# 3                  Certain        Greece           Certain
# 4                  Certain        Greece           Certain
#
#   findspot_ancient_clean findspot_ancient_certainty modern_region_clean  \
# 0                Photike                    Certain             Ípeiros
# 1                  Tegea                    Certain        Pelopónissos
# 2                  Tegea                    Certain        Pelopónissos
# 3            Palaeopolis                    Certain        Nótio Aigaío
# 4                Olympia                    Certain       Stereá Elláda
#
#   modern_region_certainty findspot_modern_clean findspot_modern_certainty  \
# 0                 Certain            Paramythía                   Certain
# 1                 Certain                  Alea                   Certain
# 2                 Certain                  Alea                   Certain
# 3                 Certain           Palaiópolis                   Certain
# 4                 Certain               Olympia                   Certain
#
#                           findspot_clean findspot_certainty  \
# 0                       Agios Athanasios            Certain
# 1                           Stringu, bei            Certain
# 2                                   NULL               NULL
# 3  to Elleniko Mauer, sekundär verwendet            Certain
# 4                      Haus der Athleten            Certain
#
#   origdate_text_clean                            clean_text_conservative  \
# 0     309 AD – 313 AD  Fortissimo et piissimo Caesari d n Gal Val P F...
# 1              276 AD  An Floriano P F Aug p p m p III Imp Caes M Aur...
# 2       49 AD – 50 AD  T Claudius Caesar Aug Ganicus pontif max trib ...
# 3     198 AD – 209 AD  Pro salute Imp Caesari L Septimi Severi et M A...
# 4       81 AD – 96 AD                                           Octa Sal
#
#                     clean_text_interpretive_sentence  \
# 0  Fortissimo et piissimo Caesari domino nostro G...
# 1  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 2  Tiberius Claudius Caesar Augustus Germanicus p...
# 3  Pro salute Imperatorum Caesaris Luci Septimi S...
# 4                                 Octavius Salutaris
#
#                                 findspot year_of_find  \
# 0                       Agios Athanasios         None
# 1                           Stringu, bei         None
# 2                                   None         None
# 3  to Elleniko Mauer, sekundär verwendet         None
# 4                      Haus der Athleten         None
#
#                present_location                religion       geography  \
# 0                 Fragma Kalama                    None  data available
# 1                   Tegea, Mus.                    None            None
# 2                          None                    None            None
# 3  to Elleniko Mauer, vermauert  names of pagan deities            None
# 4                          None                    None            None
#
#   social_economic_legal_history        military  not_after language  \
# 0                          None            None      313.0    Latin
# 1                data available            None        NaN    Latin
# 2                          None            None       50.0    Latin
# 3                          None  data available      209.0    Latin
# 4                          None            None       96.0    Latin
#
#    not_before         coordinates  \
# 0       309.0  [20.7668, 39.4512]
# 1       276.0  [22.4171, 37.4319]
# 2        49.0  [22.4171, 37.4319]
# 3       198.0  [24.8323, 37.8188]
# 4        81.0  [21.6271, 37.6479]
#
#                         clean_text_interpretive_word urban_context  \
# 0  Fortissimo et piissimo Caesari domino nostro G...          rest
# 1  Imperatori Caesari Marco Annio Floriano Pio Fe...           big
# 2  Tiberius Claudius Caesar Augustus Germanicus p...           big
# 3  Pro salute Imperatorum Caesaris Luci Septimi S...          rest
# 4                                 Octavius Salutaris           big
#
#    within_rome nearest_city city_id_hanson  city_pop_est  \
# 0        False       Dodona             31        1000.0
# 1        False        Tegea             97       46362.0
# 2        False        Tegea             97       46362.0
# 3        False       Ioulis             47        1000.0
# 4        False         Elis             35        1000.0
#
#             city_geometry nearest_city_type  nearest_city_dist  \
# 0  [20.787767, 39.546432]             minor           0.097513
# 1  [22.417226, 37.427653]               big           0.004249
# 2  [22.417226, 37.427653]               big           0.004249
# 3   [24.34625, 37.633122]             minor           0.520308
# 4  [21.435443, 37.827452]             minor           0.262624
#
#    type_of_inscription_auto  type_of_inscription_auto_prob  \
# 0     honorific inscription                            1.0
# 1         mile-/leaguestone                            1.0
# 2  public legal inscription                            1.0
# 3        votive inscription                            1.0
# 4  owner/artist inscription                            1.0
#
#                     geometry
# 0  POINT (20.76680 39.45120)
# 1  POINT (22.41710 37.43190)
# 2  POINT (22.41710 37.43190)
# 3  POINT (24.83230 37.81880)
# 4  POINT (21.62710 37.64790)

# %% [markdown]
# # Import Orbis Sites

# %%
# read orbis nodes (directly from Meeks)

url = "https://raw.githubusercontent.com/emeeks/orbis_v2/master/sites_extended.csv"
orbis_nodes = pd.read_csv(url)
orbis_nodes_meeks = gpd.GeoDataFrame(orbis_nodes, geometry=gpd.points_from_xy(orbis_nodes["x"], orbis_nodes["y"])) #, crs={"init": "epsg:3857"})
orbis_nodes_meeks.head(5)
# Out:
#       id          label  rank       x       y  cost  target       province  \
# 0  50001      Abodiacum    60  10.909  47.909     0       0         Raetia
# 1  50002  Ad fl. Tigrim    60  42.191  37.341     0       0        Armenia
# 2  50003  Ad Publicanos    60   6.374  45.671     0       0    Narbonensis
# 3  50004  Ad Tricesimum    60  13.215  46.157     0       0         Italia
# 4  50005        Ad Aras    60  -0.977  38.736     0       0  Tarraconensis
#
#     modern                   geometry
# 0  Germany  POINT (10.90900 47.90900)
# 1   Turkey  POINT (42.19100 37.34100)
# 2   France   POINT (6.37400 45.67100)
# 3    Italy  POINT (13.21500 46.15700)
# 4    Spain  POINT (-0.97700 38.73600)

# %%
#orbis_hanson_gpd.drop(["cost", "target"], axis=1, inplace=True)

# %%
len(orbis_nodes_meeks)
# Out:
# 670

# %%
# filter out crossroads 
#orbis_nodes_g = orbis_nodes_g[orbis_nodes_g["label"] != "x"]
#len(orbis_nodes_g)

# %%
orbis_nodes_g.plot()
# Out:
# <AxesSubplot:>

# %%
orbis_nodes_meeks_ids = orbis_nodes_g["id"].tolist()

# %%
url = "https://storage.googleapis.com/plos-corpus-prod/10.1371/journal.pone.0208744/1/pone.0208744.s006.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=wombat-sa%40plos-prod.iam.gserviceaccount.com%2F20210910%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210910T135503Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&X-Goog-Signature=..."
orbis_nodes_fousek = pd.read_csv(url, skiprows=5)
orbis_nodes_fousek.head()
# Out:
#    objectid            label  XCOORD  YCOORD                          PLPATH
# 0     50002    Ad fl. Tigrim  37.325  42.196     /places/874296/ad-fl-tigrim
# 1     50209  Iulia Concordia  45.757  12.844  /places/393441/iulia-concordia
# 2     50327             Roma  41.892  12.486             /places/423025/roma
# 3     50319       Praetorium  31.500  15.500       /places/364003/praetorium
# 4     50294         Patavium  45.410  11.877         /places/393473/patavium

# %%
len(orbis_nodes_fousek)
# Out:
# 648

# %%
# but with valid coordinates
len(orbis_nodes_fousek[orbis_nodes_fousek["XCOORD"] !=0])
# Out:
# 573

# %%
# nodes only in fousek
orbis_nodes_fousek[~orbis_nodes_fousek["objectid"].isin(orbis_nodes_meeks_ids)]
# Out:
#      objectid          label  XCOORD  YCOORD  \
# 357     50317         Portus  41.780  12.258
# 399     50522        Aufidus  41.360  16.210
# 502     50572        Rheneia  37.420  25.210
# 504     50457  Kriou Metopon   0.000   0.000
# 622     50786          Kerea  25.750  36.750
# 624     50789      Lebinthos  26.459  37.005
# 625     50790          Leros  23.625  37.875
# 627     50792        Mykonos  25.370  37.440
# 637     51177     Noviomagus   0.000   0.000
# 638     51176           Isca   0.000   0.000
# 640     51175          Venta   0.000   0.000
# 641     51173      Moridunum   0.000   0.000
# 642     51172          Ratae   0.000   0.000
# 644     51171       Cironium   0.000   0.000
# 646     51170     Durovernum   0.000   0.000
#
#                                      PLPATH
# 357                   /places/423012/portus
# 399                                     NaN
# 502                                     NaN
# 504                                     NaN
# 622  http://pleiades.stoa.org/places/599708
# 624  http://pleiades.stoa.org/places/599755
# 625  http://pleiades.stoa.org/places/580012
# 627  http://pleiades.stoa.org/places/599808
# 637                                     NaN
# 638                                     NaN
# 640                                     NaN
# 641                                     NaN
# 642                                     NaN
# 644                                     NaN
# 646                                     NaN

# %% [markdown]
# # import simplified orbis edges based on Fousek et al.

# %%
url = "https://storage.googleapis.com/plos-corpus-prod/10.1371/journal.pone.0208744/1/pone.0208744.s007.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=wombat-sa%40plos-prod.iam.gserviceaccount.com%2F20210910%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210910T134347Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=host&X-Goog-Signature=..."
orbis_edges_fousek = pd.read_csv(url, skiprows=3)
orbis_edges_fousek.head()
# Out:
#     from     to      cost
# 0  50176  50250  1.161604
# 1  50176  50183  1.545437
# 2  50176  50031  3.694511
# 3  50177  50173  0.931266
# 4  50177  50109  0.957881

# %%
# unique nodes in edges
orbis_edgenodes = list(set(orbis_edges["from"].tolist() + orbis_edges["from"].tolist()))
len(orbis_edgenodes)
# Out:
# 648

# %%
len([id for id in orbis_nodes_meeks_ids if id in orbis_edgenodes])
# Out:
# 633

# %%
def check_if_meeks(row):
    if (row["from"] in orbis_nodes_meeks_ids) and (row["to"] in orbis_nodes_meeks_ids):
        return True
    else:
        return False
orbis_edges_fousek["meeks?"] = orbis_edges_fousek.apply(lambda row: check_if_meeks(row), axis=1)

# %%
orbis_edges_fousek_filtered = orbis_edges_fousek[orbis_edges_fousek["meeks?"]]

# %%
import networkx as nx

# %%
G = nx.convert_matrix.from_pandas_edgelist(orbis_edges_fousek, "from", "to", edge_attr="cost")
nx.is_connected(G)

# %%
len(G.nodes)
# Out:
# 648

# %%
G2 = nx.convert_matrix.from_pandas_edgelist(orbis_edges_fousek_filtered, "from", "to", edge_attr="cost")
nx.is_connected(G2)
# Out:
# True

# %%
len(G2.nodes)
# Out:
# 633

# %%
nx.draw_kamada_kawai(G, with_labels=False, node_size=5, node_color="darkblue", node_shape="o", alpha=0.5, linewidths=1)

# %%
nx.draw_kamada_kawai(G2, with_labels=False, node_size=5, node_color="darkblue", node_shape="o", alpha=0.5, linewidths=1)

# %% [markdown]
# # import roman cities according to hanson

# %%
# import roman cities according to hanson

roman_cities_df = pd.DataFrame(requests.get("https://sciencedata.dk//shared/e62cf51531dd1003d0453cfa62cbdab3?download").json())
roman_cities = gpd.GeoDataFrame(roman_cities_df, geometry=gpd.points_from_xy(roman_cities_df["Longitude (X)"], roman_cities_df["Latitude (Y)"]))
roman_cities.head(5)
# Out:
#     Primary Key Ancient Toponym Modern Toponym Province Country  \
# 0  Hanson2016_1            Abae       Kalapodi   Achaea  Greece
# 1  Hanson2016_2        Acharnae       Acharnes   Achaea  Greece
# 2  Hanson2016_3       Acraephia      Akraifnio   Achaea  Greece
# 3  Hanson2016_4          Aegina         Aigina   Achaea  Greece
# 4  Hanson2016_5          Aegira        Aigeira   Achaea  Greece
#
#   Barrington Atlas Rank Barrington Atlas Reference  Start Date  End Date  \
# 0                4 or 5                      55 D3        -600       NaN
# 1                     3                      59 B2        -600       NaN
# 2                     3                      55 E4        -600       NaN
# 3                     2                      59 A3        -600       NaN
# 4                     3                      58 C1        -600       NaN
#
#    Longitude (X)  Latitude (Y)  \
# 0      22.933333     38.583333
# 1      23.734088     38.083473
# 2      23.219702     38.452606
# 3      23.428500     37.750074
# 4      22.355720     38.147951
#
#                                  Select Bibliography  Area  Estimate Basis  \
# 0  BNP; Hansen 2006; Hansen and Nielsen 2004; PEC...  16.0           Walls
# 1                        BNP; DGRG; PECS; Sear 2006.   NaN            None
# 2  BNP; DGRG; Hansen and Nielsen 2004; PECS; Sear...   NaN            None
# 3  BNP; DGRG; Hansen 2006; Hansen and Nielsen 200...  52.0  Inhabited area
# 4                     DGRG; Hansen and Nielsen 2004.   NaN            None
#
#               Civic Status                                          Structure  \
# 0  [Rights and privileges]  [Acropolis, Agora, Temple of Apollo, Theatre, ...
# 1                     None  [Sanctuary of Apollo Argyieus, Sanctuary of He...
# 2                     None  [Acropolis, Agora, Fountain, Temple of Apollo ...
# 3  [Rights and privileges]  [Shrine of Aeacus, Stadium, Temple of Aphrodit...
# 4                     None  [Acropolis, Agora, Gymnasium, Temple of Aphrod...
#
#    num_of_structures ID  pop_sample  pop_est  pop_diff  \
# 0                  5  1         NaN   1700.0       NaN
# 1                  3  2         NaN   1000.0       NaN
# 2                  7  3         NaN   1000.0       NaN
# 3                  8  4         NaN   8209.0       NaN
# 4                  8  5         NaN   1000.0       NaN
#
#                     geometry
# 0  POINT (22.93333 38.58333)
# 1  POINT (23.73409 38.08347)
# 2  POINT (23.21970 38.45261)
# 3  POINT (23.42850 37.75007)
# 4  POINT (22.35572 38.14795)

# %%
roman_cities.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Mapping Hanson on Orbis

# %%
def ckdnearest(orbis_nodes, cities):
    cities = cities[['Ancient Toponym', "ID", "pop_est", 'geometry']]
    cities.rename(columns={"Ancient Toponym" : "hanson_label", "ID" : "hanson_ID"}, inplace=True)
    nA = np.array(list(orbis_nodes.geometry.apply(lambda x: (x.x, x.y))))
    nB = np.array(list(cities.geometry.apply(lambda x: (x.x, x.y))))
    btree = cKDTree(nB)
    dist, idx = btree.query(nA, k=1)
    gdB_nearest = cities.iloc[idx].rename(columns={"geometry": "hanson_geo"}).reset_index(drop=True)
    gdB_nearest["hanson_geo"] = [[geom.x, geom.y] for geom in gdB_nearest["hanson_geo"]]
    gdf = pd.concat(
        [
            orbis_nodes.reset_index(drop=True),
            gdB_nearest,
            pd.Series(dist, name='dist')
        ], 
        axis=1)
    return gdf

# %%
orbis_hanson_gpd = ckdnearest(orbis_nodes_g, roman_cities)

# %%
orbis_hanson_gpd.sort_values("dist", inplace=True, ascending=True)
orbis_hanson_gpd.head(5)
# Out:
#         id                      label  rank       x       y  cost  target  \
# 465  50474              Portus Magnus    70  -0.266  35.808     0       0
# 411  50418                     Vienna    90   4.878  45.524     0       0
# 126  50131                    Corduba   100  -4.780  37.884     0       0
# 167  50172                   Faventia    70  11.883  44.285     0       0
# 120  50125  Ulpia Traiana Tricensimae    80   6.445  51.668     0       0
#
#                     province   modern                   geometry  \
# 465  Mauretania Caesariensis  Algeria  POINT (-0.26600 35.80800)
# 411              Narbonensis   France   POINT (4.87800 45.52400)
# 126                  Baetica    Spain  POINT (-4.78000 37.88400)
# 167                   Italia    Italy  POINT (11.88300 44.28500)
# 120        Germania Inferior  Germany   POINT (6.44500 51.66800)
#
#               hanson_label hanson_ID  pop_est              hanson_geo  \
# 465          Portus Magnus      1182   1000.0  [-0.266018, 35.807917]
# 411                 Vienna       658  15332.0   [4.878056, 45.524167]
# 126                Corduba       336  19404.0    [-4.78025, 37.88376]
# 167               Faventia      1014   5399.0  [11.882989, 44.285348]
# 120  Colonia Ulpia Traiana       661  14596.0   [6.444591, 51.668014]
#
#          dist
# 465  0.000085
# 411  0.000176
# 126  0.000347
# 167  0.000348
# 120  0.000409

# %%
orbis_hanson_gpd[orbis_hanson_gpd["dist"] < 0.1].tail(10)
# Out:
#         id          label  rank       x       y  cost  target    province  \
# 209  50214     Kallipolis    60  26.680  40.414     0       0     Thracia
# 493  50524   Lacinium Pr.    60  17.200  39.030     0       0      Italia
# 632  50801          Thera    70  25.433  36.417     0       0     Graecia
# 351  50357       Sinuessa    80  13.830  41.161     0       0      Italia
# 534  50590        Sigeion    70  26.200  40.010     0       0        Asia
# 370  50376          Tabia    80  34.535  39.858     0       0  Cappadocia
# 539  50598  Trogilion Pr.    60  27.020  37.670     0       0        Asia
# 521  50557    Sounion Pr.    60  24.030  37.650     0       0     Graecia
# 311  50316     Porolissum    80  23.194  47.168     0       0       Dacia
# 528  50569     Hephaistia    70  25.235  39.932     0       0     Thracia
#
#       modern                   geometry hanson_label hanson_ID  pop_est  \
# 209   Turkey  POINT (26.68000 40.41400)    Lampsacus       289   1000.0
# 493    Italy  POINT (17.20000 39.03000)       Croton       855   1000.0
# 632   Greece  POINT (25.43300 36.41700)        Thera       102   1000.0
# 351    Italy  POINT (13.83000 41.16100)     Sinuessa       799   4113.0
# 534   Turkey  POINT (26.20000 40.01000)        Ilium       288   3086.0
# 370   Turkey  POINT (34.53500 39.85800)       Tavium       425   1000.0
# 539   Greece  POINT (27.02000 37.67000)        Samos       311  30829.0
# 521   Greece  POINT (24.03000 37.65000)     Thoricus       105   1000.0
# 311  Romania  POINT (23.19400 47.16800)   Porolissum       497   2601.0
# 528   Greece  POINT (25.23500 39.93200)   Hephaestia        44   4291.0
#
#                  hanson_geo      dist
# 209  [26.699162, 40.346685]  0.069989
# 493  [17.146875, 39.079077]  0.072324
# 632  [25.474522, 36.352514]  0.076698
# 351  [13.894556, 41.115167]  0.079172
# 534  [26.257773, 39.953869]  0.080551
# 370  [34.456374, 39.878991]  0.081380
# 539   [26.94006, 37.691522]  0.082786
# 521  [24.053491, 37.737524]  0.090622
# 311  [23.126667, 47.230278]  0.091718
# 528   [25.324204, 39.95907]  0.093221

# %%
len(orbis_hanson_gpd[orbis_hanson_gpd["dist"] < 0.06])
# Out:
# 412

# %%
len(orbis_hanson_gpd[orbis_hanson_gpd["dist"] < 0.06]["hanson_label"].unique().tolist())
# Out:
# 412

# %%
for k, row in orbis_hanson_gpd.iterrows():
    if row["dist"] >= 0.06:
        row["hanson_city"] = None
        row["hanson_city_id"] = None 
        row["city_pop_est"] = 1000
        row["city_geometry"] = None

# %%
def dist_filter(row, col, threshold=0.06):
    if row["dist"] < threshold:
        return row[col]
    else:
        if col == "pop_est":
            return 1000
        else:
            return None 

for col in ["hanson_label", "hanson_ID", "hanson_geo", "pop_est", "dist"]:
    orbis_hanson_gpd[col] = orbis_hanson_gpd.apply(lambda row: dist_filter(row, col), axis=1)

# %%
orbis_hanson_gpd.tail(5)
# Out:
#         id        label  rank       x       y  cost  target          province  \
# 558  50623  Kalos Limen    80  32.703  45.521     0       0  Outside_Blacksea
# 589  50682        Ammon    80  25.544  29.205     0       0          Aegyptus
# 580  50651   Dioscurias    90  41.003  42.993     0       0  Outside_Blacksea
# 581  50652       Phasis    80  41.667  42.150     0       0  Outside_Blacksea
# 579  50650       Tanais    80  39.258  47.268     0       0  Outside_Blacksea
#
#       modern                   geometry hanson_label hanson_ID  pop_est  \
# 558  Ukraine  POINT (32.70300 45.52100)         None      None   1000.0
# 589    Egypt  POINT (25.54400 29.20500)         None      None   1000.0
# 580  Georgia  POINT (41.00300 42.99300)         None      None   1000.0
# 581  Georgia  POINT (41.66700 42.15000)         None      None   1000.0
# 579   Russia  POINT (39.25800 47.26800)         None      None   1000.0
#
#     hanson_geo  dist
# 558       None   NaN
# 589       None   NaN
# 580       None   NaN
# 581       None   NaN
# 579       None   NaN

# %%
len(orbis_hanson_gpd[orbis_hanson_gpd["hanson_label"].notnull()])
# Out:
# 412

# %%
orbis_hanson_gpd["pop_est"].sum()
# Out:
# 6282830.0

# %%
# an alternative approach would be to do something like this:
# i.e., to iterate over cities one by one, from the biggests to smaller ones:

# for city_geo in roman_cities.sort_values["geometry"].tolist()š:

#def min_dist(city_geo, orbis_nodes_gpd):
#    orbis_nodes_g['dist'] = orbis_nodes_g.apply(lambda row:  city_geo.distance(row["geometry"]),axis=1)
#    orbis_nodes_g.sort_values("dist")
#    return orbis_nodes_g

# %% [markdown]
# # Map inscriptions on orbis sites

# %%
def ckdnearest(inscriptions, sites_gdf):
    sites_gdf = sites_gdf[["id", "geometry"]] 
    sites_gdf.rename(columns={"id" : "orbis_id"}, inplace=True)
    nA = np.array(list(inscriptions.geometry.apply(lambda x: (x.x, x.y))))
    nB = np.array(list(sites_gdf.geometry.apply(lambda x: (x.x, x.y))))
    btree = cKDTree(nB)
    dist, idx = btree.query(nA, k=1)
    gdB_nearest = sites_gdf.iloc[idx].rename(columns={"geometry": "city_geometry"}).reset_index(drop=True)
    gdB_nearest["city_geometry"] = [[geom.x, geom.y] for geom in gdB_nearest["city_geometry"]]
    gdf = pd.concat(
        [
            inscriptions.reset_index(drop=True),
            gdB_nearest,
            pd.Series(dist, name='orbis_site_dist')
        ], 
        axis=1)
    return gdf

#ckdnearest(gpd1, gpd2)

# %%
LIRE = ckdnearest(LIRE, orbis_hanson_gpd)
LIRE.head(5)
# Out:
#          EDCS-ID                                        publication province  \
# 0  EDCS-03700724  ZPE-108-159 = Thesprotia 00001 = AE 1993, 0140...   Achaia
# 1  EDCS-03300852                                     AE 1995, 01409   Achaia
# 2  EDCS-28500283  CIL 03, 07251 = D 00214 = NDIEC-07, p 81 = AE ...   Achaia
# 3  EDCS-09400671  CIMRM-02, 02350 = IG-12, 00274 = Andros 00124 ...   Achaia
# 4  EDCS-24600769                    AE 1995, 01407 = AE 2001, 01812   Achaia
#
#   province_list                                       place  \
# 0        Achaia                  Agios Athanasios / Photike
# 1        Achaia                                Alea / Tegea
# 2        Achaia                                Alea / Tegea
# 3        Achaia                                      Andros
# 4        Achaia  Archea Olimpia / Archaia Olympia / Olympia
#
#                                          place_list end_yr_list  \
# 0                   ['Agios Athanasios', 'Photike']         313
# 1                                 ['Alea', 'Tegea']         276
# 2                                 ['Alea', 'Tegea']          50
# 3                                            Andros         209
# 4  ['Archea Olimpia', 'Archaia Olympia', 'Olympia']          96
#
#                              notes_dating  \
# 0
# 1  to 276;   b:  276 to 282         \n\n
# 2
# 3
# 4
#
#                                          status_list        inscr_type  \
# 0  ['Augusti/Augustae', 'litterae erasae', 'ordo ...  tituli honorarii
# 1           ['Augusti/Augustae', 'miliaria', 'viri']          miliaria
# 2              ['Augusti/Augustae', 'leges', 'viri']             leges
# 3                ['litterae erasae', 'tituli sacri']      tituli sacri
# 4                                                { }               { }
#
#                                      status_notation    inscr_process  \
# 0  ['Augusti/Augustae', 'ordo equester', 'tria no...  litterae erasae
# 1                       ['Augusti/Augustae', 'viri']              { }
# 2                       ['Augusti/Augustae', 'viri']              { }
# 3                                                { }  litterae erasae
# 4                                                { }              { }
#
#   notes_references notes_comments  \
# 0
# 1
# 2
# 3
# 4
#
#                                          inscription  \
# 0  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 1  to 276;   b:  276 to 282         \n\n \n \nImp...
# 2  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 3  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 4                             Octa(vius) Sa(lutaris)
#
#                           inscription_stripped_final  \
# 0  Fortissimo et Piis/simo Caesari d(omino) n(ost...
# 1  Imp(eratori) / Floriano / P(io) F(elici) Aug(u...
# 2  T[(iberius)] Claudius Caesar Aug(ustus) / G[er...
# 3  Pro salute Imp(eratoris) Caesari(s) / L(uci) S...
# 4                             Octa(vius) Sa(lutaris)
#
#                                                Links  dating from dating to  \
# 0  http://db.edcs.eu/epigr/partner.php?s_language...        309.0       313
# 1  http://db.edcs.eu/epigr/partner.php?s_language...          NaN       276
# 2  http://db.edcs.eu/epigr/partner.php?s_language...         49.0        50
# 3  http://db.edcs.eu/epigr/partner.php?s_language...        198.0       209
# 4  http://db.edcs.eu/epigr/partner.php?s_language...         81.0        96
#
#                                               status   Latitude  Longitude  \
# 0  Augusti/Augustae; litterae erasae; ordo equest...  39.451218  20.766767
# 1                   Augusti/Augustae; miliaria; viri  37.454501  22.420877
# 2                      Augusti/Augustae; leges; viri  37.454501  22.420877
# 3                      litterae erasae; tituli sacri  37.837612  24.937637
# 4                                               None  37.643870  21.625513
#
#                                                photo Material Comment  \
# 0  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None    None
# 1                                               None    lapis    None
# 2                                               None     None    None
# 3  http://db.edcs.eu/epigr/bilder.php?bilder.php?...     None    None
# 4                                               None     None    None
#
#      EDH-ID language_EDCS                  clean_text_interpretive_word_EDCS  \
# 0  HD052964          None  Fortissimo et Piissimo Caesari domino nostro G...
# 1  HD051000          None  Imperatori Floriano Pio Felici Augusto patri p...
# 2  HD021396          None  Tiberius Claudius Caesar Augustus Germanicus p...
# 3  HD011892          None  Pro salute Imperatoris Caesaris Luci Septimi S...
# 4  HD050999          None                                 Octavius Salutaris
#
#   responsible_individual       type_of_inscription letter_size  \
# 0                  Cowey     honorific inscription    3-5.3 cm
# 1                  Cowey         mile-/leaguestone    3.3-6 cm
# 2                  Cowey  public legal inscription        None
# 3                  Cowey        votive inscription  5.5-5.7 cm
# 4                  Cowey  owner/artist inscription        None
#
#                                           literature         work_status  \
# 0  AE 1993, 1406.; V. Papadopoulou, AD 43 B, 1988...  checked with photo
# 1  AE 1995, 1409.; M. Iozzer - M. Pangano, ASAA 6...  checked with photo
# 2  CIL 03, 07251.; ILS 0214.; AE 1941, 0119.; MAI...  checked with photo
# 3  AE 1911, 0056. (B); T. Sauciuc, MDAI(R) 25, 19...  checked with photo
# 4  AE 1995, 1407.; U. Sinn u. a., Nikephoros 8, 1...  checked with photo
#
#     height                                    diplomatic_text  \
# 0    99 cm  FORTISSIMO ET PIIS / SIMO CAESARI D N / GAL VA...
# 1  (44) cm  [ ] / AN[ ] FLORIANO / P F AVG / P P / M P III...
# 2   160 cm  T[ ] CLAVDIVS CAESAR AVG / G[ ]ANICVS PONTIF M...
# 3    48 cm  PRO SALVTE IMP CAESARI / L SEPTIMI SEVERI ET M...
# 4     None                                           OCTA SAL
#
#                                               people  depth material  \
# 0  [{'name': 'Gal. Val. [[Maximiano]]', 'nomen': ...  67 cm     None
# 1  [{'person_id': '1', 'nomen': 'Annius+', 'name'...   None     None
# 2  [{'gender': 'male', 'cognomen': 'Caesar August...  17 cm     None
# 3  [{'gender': 'male', 'praenomen': 'L.', 'name':...   None     None
# 4  [{'person_id': '1', 'nomen': 'Octavius*', 'nam...   None     None
#
#           type_of_monument province_label   width  \
# 0              statue base         Epirus   67 cm
# 1        mile-/leaguestone         Achaia   24 cm
# 2                   tabula         Achaia   58 cm
# 3                     None         Achaia  126 cm
# 4  instrumentum domesticum         Achaia    None
#
#                                        transcription country  \
# 0  Fortissimo et piis/simo Caesari d(omino) n(ost...  Greece
# 1  [Imp(eratori) Caes(ari) M(arco)] / An[nio] Flo...  Greece
# 2  T[i(berius)] Claudius Caesar Aug(ustus) / G[er...  Greece
# 3  Pro salute Imp(eratorum) Caesari(s) / L(uci) S...  Greece
# 4                             Octa(vius) Sal(utaris)  Greece
#
#                                                  uri findspot_ancient  \
# 0  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Photike
# 1  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 2  https://edh-www.adw.uni-heidelberg.de/edh/insc...            Tegea
# 3  https://edh-www.adw.uni-heidelberg.de/edh/insc...      Palaeopolis
# 4  https://edh-www.adw.uni-heidelberg.de/edh/insc...          Olympia
#
#   last_update  modern_region findspot_modern  \
# 0  2014-09-16        Ípeiros      Paramythía
# 1  2011-05-24   Pelopónissos            Alea
# 2  2011-05-10   Pelopónissos            Alea
# 3  2017-05-30   Nótio Aigaío     Palaiópolis
# 4  2012-04-16  Stereá Elláda         Olympia
#
#                                    edh_geography_uri  \
# 0  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 1  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 2  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 3  https://edh-www.adw.uni-heidelberg.de/edh/geog...
# 4  https://edh-www.adw.uni-heidelberg.de/edh/geog...
#
#                                           commentary  \
# 0                                               None
# 1   Die erste Inschrift ist auf 276, die zweite a...
# 2                                               None
# 3   Auf dem Foto sind die Buchstaben oft kaum erk...
# 4       (B): Sa(lutaris) fehlerhaft für Sal(utaris).
#
#                            trismegistos_uri external_image_uris fotos idno_tm  \
# 0  https://www.trismegistos.org/text/121715                 { }   { }  121715
# 1  https://www.trismegistos.org/text/177273                 { }   { }  177273
# 2  https://www.trismegistos.org/text/177131                 { }   { }  177131
# 3  https://www.trismegistos.org/text/177087                 { }   { }  177087
# 4  https://www.trismegistos.org/text/177272                 { }   { }  177272
#
#                                      placenames_refs  \
# 0  ['http://www.trismegistos.org/place/000655', '...
# 1  ['http://www.trismegistos.org/place/000078', '...
# 2  ['http://www.trismegistos.org/place/000078', '...
# 3                                                 []
# 4  ['http://www.trismegistos.org/place/000078', '...
#
#                                         text_edition  \
# 0                  Fortissimo et piissimo Caesari...
# 1  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 2                  Tiberius Claudius Caesar Augus...
# 3                  Pro salute Imperatorum Caesari...
# 4                                 Octavius Salutaris
#
#                                  origdate_text layout_execution  \
# 0  309 AD – 313 AD                                           21
# 1           276 AD                                           21
# 2    49 AD – 50 AD                                           21
# 3  198 AD – 209 AD                                           21
# 4    81 AD – 96 AD                                           21
#
#   layout_execution_text  support_objecttype  support_objecttype_text  \
# 0            unbestimmt                57.0             Statuenbasis
# 1            unbestimmt                89.0      Meilen-/Leugenstein
# 2            unbestimmt               257.0                    Tafel
# 3            unbestimmt                 2.0               unbestimmt
# 4            unbestimmt               140.0  Instrumentum domesticum
#
#   support_material support_material_text  support_decoration keywords_term  \
# 0              138            unbestimmt              1000.0            69
# 1              138            unbestimmt              1000.0           102
# 2              138            unbestimmt              1000.0
# 3              138            unbestimmt              1000.0            80
# 4              138            unbestimmt              1000.0           311
#
#                  keywords_term_text type_of_inscription_clean  \
# 0                    Ehreninschrift     honorific inscription
# 1               Meilen-/Leugenstein         mile-/leaguestone
# 2  Rechtliche Verfügung, öffentlich  public legal inscription
# 3                     Weihinschrift        votive inscription
# 4     Besitzer-/Herstellerinschrift  owner/artist inscription
#
#   type_of_inscription_certainty  height_cm  width_cm  depth_cm material_clean  \
# 0                       Certain       99.0      67.0      67.0           NULL
# 1                       Certain       44.0      24.0       NaN           NULL
# 2                       Certain      160.0      58.0      17.0           NULL
# 3                       Certain       48.0     126.0       NaN           NULL
# 4                       Certain        NaN       NaN       NaN           NULL
#
#     type_of_monument_clean type_of_monument_certainty province_label_clean  \
# 0              statue base                    Certain               Epirus
# 1        mile-/leaguestone                    Certain               Achaia
# 2                   tabula                    Certain               Achaia
# 3                     NULL                       NULL               Achaia
# 4  instrumentum domesticum                    Certain               Achaia
#
#   province_label_certainty country_clean country_certainty  \
# 0                  Certain        Greece           Certain
# 1                  Certain        Greece           Certain
# 2                  Certain        Greece           Certain
# 3                  Certain        Greece           Certain
# 4                  Certain        Greece           Certain
#
#   findspot_ancient_clean findspot_ancient_certainty modern_region_clean  \
# 0                Photike                    Certain             Ípeiros
# 1                  Tegea                    Certain        Pelopónissos
# 2                  Tegea                    Certain        Pelopónissos
# 3            Palaeopolis                    Certain        Nótio Aigaío
# 4                Olympia                    Certain       Stereá Elláda
#
#   modern_region_certainty findspot_modern_clean findspot_modern_certainty  \
# 0                 Certain            Paramythía                   Certain
# 1                 Certain                  Alea                   Certain
# 2                 Certain                  Alea                   Certain
# 3                 Certain           Palaiópolis                   Certain
# 4                 Certain               Olympia                   Certain
#
#                           findspot_clean findspot_certainty  \
# 0                       Agios Athanasios            Certain
# 1                           Stringu, bei            Certain
# 2                                   NULL               NULL
# 3  to Elleniko Mauer, sekundär verwendet            Certain
# 4                      Haus der Athleten            Certain
#
#   origdate_text_clean                            clean_text_conservative  \
# 0     309 AD – 313 AD  Fortissimo et piissimo Caesari d n Gal Val P F...
# 1              276 AD  An Floriano P F Aug p p m p III Imp Caes M Aur...
# 2       49 AD – 50 AD  T Claudius Caesar Aug Ganicus pontif max trib ...
# 3     198 AD – 209 AD  Pro salute Imp Caesari L Septimi Severi et M A...
# 4       81 AD – 96 AD                                           Octa Sal
#
#                     clean_text_interpretive_sentence  \
# 0  Fortissimo et piissimo Caesari domino nostro G...
# 1  Imperatori Caesari Marco Annio Floriano Pio Fe...
# 2  Tiberius Claudius Caesar Augustus Germanicus p...
# 3  Pro salute Imperatorum Caesaris Luci Septimi S...
# 4                                 Octavius Salutaris
#
#                                 findspot year_of_find  \
# 0                       Agios Athanasios         None
# 1                           Stringu, bei         None
# 2                                   None         None
# 3  to Elleniko Mauer, sekundär verwendet         None
# 4                      Haus der Athleten         None
#
#                present_location                religion       geography  \
# 0                 Fragma Kalama                    None  data available
# 1                   Tegea, Mus.                    None            None
# 2                          None                    None            None
# 3  to Elleniko Mauer, vermauert  names of pagan deities            None
# 4                          None                    None            None
#
#   social_economic_legal_history        military  not_after language  \
# 0                          None            None      313.0    Latin
# 1                data available            None        NaN    Latin
# 2                          None            None       50.0    Latin
# 3                          None  data available      209.0    Latin
# 4                          None            None       96.0    Latin
#
#    not_before         coordinates  \
# 0       309.0  [20.7668, 39.4512]
# 1       276.0  [22.4171, 37.4319]
# 2        49.0  [22.4171, 37.4319]
# 3       198.0  [24.8323, 37.8188]
# 4        81.0  [21.6271, 37.6479]
#
#                         clean_text_interpretive_word urban_context  \
# 0  Fortissimo et piissimo Caesari domino nostro G...          rest
# 1  Imperatori Caesari Marco Annio Floriano Pio Fe...           big
# 2  Tiberius Claudius Caesar Augustus Germanicus p...           big
# 3  Pro salute Imperatorum Caesaris Luci Septimi S...          rest
# 4                                 Octavius Salutaris           big
#
#    within_rome nearest_city city_id_hanson  city_pop_est  \
# 0        False       Dodona             31        1000.0
# 1        False        Tegea             97       46362.0
# 2        False        Tegea             97       46362.0
# 3        False       Ioulis             47        1000.0
# 4        False         Elis             35        1000.0
#
#             city_geometry nearest_city_type  nearest_city_dist  \
# 0  [20.787767, 39.546432]             minor           0.097513
# 1  [22.417226, 37.427653]               big           0.004249
# 2  [22.417226, 37.427653]               big           0.004249
# 3   [24.34625, 37.633122]             minor           0.520308
# 4  [21.435443, 37.827452]             minor           0.262624
#
#    type_of_inscription_auto  type_of_inscription_auto_prob  \
# 0     honorific inscription                            1.0
# 1         mile-/leaguestone                            1.0
# 2  public legal inscription                            1.0
# 3        votive inscription                            1.0
# 4  owner/artist inscription                            1.0
#
#                     geometry  orbis_id                 city_geometry  \
# 0  POINT (20.76680 39.45120)     50273              [20.735, 39.007]
# 1  POINT (22.41710 37.43190)     50549              [22.886, 37.912]
# 2  POINT (22.41710 37.43190)     50549              [22.886, 37.912]
# 3  POINT (24.83230 37.81880)     50778  [24.933000000000003, 37.833]
# 4  POINT (21.62710 37.64790)     50542                [21.45, 37.61]
#
#    orbis_site_dist
# 0         0.445337
# 1         0.671091
# 2         0.671091
# 3         0.101696
# 4         0.181110

# %%
# testing overlap between two intervals
# len 0 = no overlap
# len 1 = overlap

from interval import interval
not_before, not_after = 0, 300
period_start, period_end = 101, 200
len(interval[period_start, period_end] & interval[not_before, not_after])
# Out:
# 1

# %%
def temporal_overlap(period_start, period_end, inscr_start, inscr_end):
    if np.isnan(inscr_start):
        inscr_start = inscr_end
    if np.isnan(inscr_end):
        inscr_end = inscr_start
    if len(interval[period_start, period_end] & interval[inscr_start, inscr_end]) > 0:
        return True
    else:
        return False

# %%
LIRE_period1 = LIRE[LIRE.apply(lambda row: temporal_overlap(1, 100, row["not_before"], row["not_after"]), axis=1)] 
LIRE_period2 = LIRE[LIRE.apply(lambda row: temporal_overlap(101, 200, row["not_before"], row["not_after"]), axis=1)] 
LIRE_period3 = LIRE[LIRE.apply(lambda row: temporal_overlap(201, 300, row["not_before"], row["not_after"]), axis=1)]

# %%
for per in [LIRE_period1, LIRE_period2, LIRE_period3]:
    print(len(per))
# Out:
# 56000
# 67838
# 43973

# %%
def get_inscr_ids(orbis_id, source, LIRE_period):
    LIRE_subset = LIRE_period[LIRE_period["orbis_id"]==orbis_id]
    if source == "EDCS":
        ids = LIRE_subset[LIRE_subset["EDCS-ID"].notnull() & LIRE_subset["EDH-ID"].isnull()]["EDCS-ID"].tolist()
    else:
        ids = LIRE_subset[LIRE_subset["EDH-ID"].notnull()]["EDH-ID"].tolist()
    return ids

# %%
get_inscr_ids(50474, "EDH", LIRE_period3)
# Out:
# ['HD033385',
#  'HD000463',
#  'HD052542',
#  'HD033325',
#  'HD033415',
#  'HD033388',
#  'HD030633']

# %%
orbis_hanson_gpd.head(5)
# Out:
#         id                      label  rank       x       y  cost  target  \
# 465  50474              Portus Magnus    70  -0.266  35.808     0       0
# 411  50418                     Vienna    90   4.878  45.524     0       0
# 126  50131                    Corduba   100  -4.780  37.884     0       0
# 167  50172                   Faventia    70  11.883  44.285     0       0
# 120  50125  Ulpia Traiana Tricensimae    80   6.445  51.668     0       0
#
#                     province   modern                   geometry  \
# 465  Mauretania Caesariensis  Algeria  POINT (-0.26600 35.80800)
# 411              Narbonensis   France   POINT (4.87800 45.52400)
# 126                  Baetica    Spain  POINT (-4.78000 37.88400)
# 167                   Italia    Italy  POINT (11.88300 44.28500)
# 120        Germania Inferior  Germany   POINT (6.44500 51.66800)
#
#               hanson_label hanson_ID  pop_est              hanson_geo  \
# 465          Portus Magnus      1182   1000.0  [-0.266018, 35.807917]
# 411                 Vienna       658  15332.0   [4.878056, 45.524167]
# 126                Corduba       336  19404.0    [-4.78025, 37.88376]
# 167               Faventia      1014   5399.0  [11.882989, 44.285348]
# 120  Colonia Ulpia Traiana       661  14596.0   [6.444591, 51.668014]
#
#          dist
# 465  0.000085
# 411  0.000176
# 126  0.000347
# 167  0.000348
# 120  0.000409

# %%
orbis_hanson_gpd["EDH_all"] = orbis_hanson_gpd["id"].apply(lambda x: get_inscr_ids(x, "EDH", LIRE))
orbis_hanson_gpd["EDCS_all"] = orbis_hanson_gpd["id"].apply(lambda x: get_inscr_ids(x, "EDCS", LIRE))

# %%
orbis_hanson_gpd["LIRE_total_N"] = orbis_hanson_gpd.apply(lambda row: len(row["EDH_all"])+len(row["EDCS_all"]), axis=1)

# %%
orbis_hanson_gpd.sort_values("pop_est", ascending=False).head(5)
# Out:
#         id         label  rank       x       y  cost  target  province  \
# 321  50327          Roma   100  12.485  41.891     0       0    Italia
# 16   50017    Alexandria   100  29.910  31.200     0       0  Aegyptus
# 225  50230  Lepcis Magna   100  14.292  32.637     0       0    Africa
# 550  50613        Rhodos    80  28.230  36.440     0       0      Asia
# 22   50024     Antiochia   100  36.169  36.208     0       0     Syria
#
#      modern                   geometry           hanson_label hanson_ID  \
# 321   Italy  POINT (12.48500 41.89100)                   Roma       992
# 16    Egypt  POINT (29.91000 31.20000)  Alexandria (Aegyptus)       110
# 225   Libya  POINT (14.29200 32.63700)           Lepcis Magna       180
# 550  Greece  POINT (28.23000 36.44000)                 Rhodus       309
# 22   Turkey  POINT (36.16900 36.20800)      Antiochia (Syria)      1324
#
#       pop_est              hanson_geo      dist  \
# 321  923313.0  [12.485098, 41.892777]  0.001780
# 16   410502.0  [29.903728, 31.195024]  0.008006
# 225  153722.0    [14.29306, 32.63833]  0.001701
# 550  130398.0  [28.227007, 36.443235]  0.004407
# 22   124930.0  [36.169629, 36.210172]  0.002261
#
#                                                EDH_all  \
# 321  [HD016234, HD007300, HD006780, HD016689, HD002...
# 16   [HD025477, HD017883, HD032199, HD045448, HD019...
# 225  [HD021906, HD045234, HD045235, HD018125, HD021...
# 550                                                 []
# 22                                          [HD061603]
#
#                                               EDCS_all  LIRE_total_N
# 321  [EDCS-22700240, EDCS-22700241, EDCS-22700242, ...         38647
# 16   [EDCS-71300297, EDCS-58200213, EDCS-20800415, ...            37
# 225  [EDCS-51500074, EDCS-51500075, EDCS-51500076, ...           319
# 550                                    [EDCS-70200274]             1
# 22                                                  []             1

# %%
# %%time
orbis_hanson_gpd["EDH_per1"] = orbis_hanson_gpd["id"].apply(lambda x: get_inscr_ids(x, "EDH", LIRE_period1))
orbis_hanson_gpd["EDCS_per1"] = orbis_hanson_gpd["id"].apply(lambda x: get_inscr_ids(x, "EDCS", LIRE_period1))

orbis_hanson_gpd["EDH_per2"] = orbis_hanson_gpd["id"].apply(lambda x: get_inscr_ids(x, "EDH", LIRE_period2))
orbis_hanson_gpd["EDCS_per2"] = orbis_hanson_gpd["id"].apply(lambda x: get_inscr_ids(x, "EDCS", LIRE_period2))

orbis_hanson_gpd["EDH_per3"] = orbis_hanson_gpd["id"].apply(lambda x: get_inscr_ids(x, "EDH", LIRE_period3))
orbis_hanson_gpd["EDCS_per3"] = orbis_hanson_gpd["id"].apply(lambda x: get_inscr_ids(x, "EDCS", LIRE_period3))
# Out:
# CPU times: user 9min 1s, sys: 4.11 s, total: 9min 5s
# Wall time: 9min 5s

# %%
orbis_hanson_gpd["LIRE_per1_N"] = orbis_hanson_gpd.apply(lambda row: len(row["EDH_per1"])+len(row["EDCS_per1"]), axis=1)
orbis_hanson_gpd["LIRE_per2_N"] = orbis_hanson_gpd.apply(lambda row: len(row["EDH_per2"])+len(row["EDCS_per2"]), axis=1)
orbis_hanson_gpd["LIRE_per3_N"] = orbis_hanson_gpd.apply(lambda row: len(row["EDH_per3"])+len(row["EDCS_per3"]), axis=1)

# %%
orbis_hanson_gpd.head(5)
# Out:
#         id                      label  rank       x       y  cost  target  \
# 465  50474              Portus Magnus    70  -0.266  35.808     0       0
# 411  50418                     Vienna    90   4.878  45.524     0       0
# 126  50131                    Corduba   100  -4.780  37.884     0       0
# 167  50172                   Faventia    70  11.883  44.285     0       0
# 120  50125  Ulpia Traiana Tricensimae    80   6.445  51.668     0       0
#
#                     province   modern                   geometry  \
# 465  Mauretania Caesariensis  Algeria  POINT (-0.26600 35.80800)
# 411              Narbonensis   France   POINT (4.87800 45.52400)
# 126                  Baetica    Spain  POINT (-4.78000 37.88400)
# 167                   Italia    Italy  POINT (11.88300 44.28500)
# 120        Germania Inferior  Germany   POINT (6.44500 51.66800)
#
#               hanson_label hanson_ID  pop_est              hanson_geo  \
# 465          Portus Magnus      1182   1000.0  [-0.266018, 35.807917]
# 411                 Vienna       658  15332.0   [4.878056, 45.524167]
# 126                Corduba       336  19404.0    [-4.78025, 37.88376]
# 167               Faventia      1014   5399.0  [11.882989, 44.285348]
# 120  Colonia Ulpia Traiana       661  14596.0   [6.444591, 51.668014]
#
#          dist                                            EDH_all  \
# 465  0.000085  [HD047307, HD033385, HD000463, HD052542, HD033...
# 411  0.000176  [HD052078, HD052079, HD001171, HD001626, HD001...
# 126  0.000347  [HD006608, HD006605, HD006602, HD006599, HD000...
# 167  0.000348  [HD017246, HD016084, HD018809, HD008967, HD032...
# 120  0.000409  [HD031155, HD050305, HD050306, HD050307, HD022...
#
#                                               EDCS_all  LIRE_total_N  \
# 465  [EDCS-75300340, EDCS-25500569, EDCS-25500582, ...            16
# 411  [EDCS-09200591, EDCS-09200592, EDCS-09500338, ...           119
# 126  [EDCS-72600014, EDCS-72600015, EDCS-75900070, ...          1290
# 167  [EDCS-64901116, EDCS-30200030, EDCS-30400520, ...           102
# 120  [EDCS-78300132, EDCS-78300660, EDCS-72700161, ...           424
#
#                                               EDH_per1  \
# 465                                                 []
# 411  [HD001171, HD001626, HD001620, HD001623, HD049...
# 126  [HD006599, HD000035, HD028010, HD013569, HD028...
# 167  [HD018809, HD032458, HD005009, HD003863, HD003...
# 120  [HD050305, HD050306, HD040731, HD040731, HD040...
#
#                                              EDCS_per1  \
# 465                                    [EDCS-25500582]
# 411  [EDCS-09200592, EDCS-09200607, EDCS-09200608, ...
# 126  [EDCS-72600014, EDCS-75900070, EDCS-75900071, ...
# 167  [EDCS-04900283, EDCS-04900288, EDCS-20402028, ...
# 120  [EDCS-78300132, EDCS-78300660, EDCS-72700161, ...
#
#                                               EDH_per2  \
# 465                                                 []
# 411  [HD052078, HD052079, HD001617, HD052073, HD050...
# 126  [HD006608, HD006605, HD006602, HD006599, HD000...
# 167  [HD017246, HD016084, HD018809, HD008967, HD010...
# 120  [HD031155, HD050305, HD050307, HD022736, HD022...
#
#                                              EDCS_per2  \
# 465                                    [EDCS-25500569]
# 411  [EDCS-09200591, EDCS-09200607, EDCS-09200608, ...
# 126  [EDCS-72600015, EDCS-73900025, EDCS-76900064, ...
# 167  [EDCS-30200030, EDCS-30400520, EDCS-31200405, ...
# 120  [EDCS-72700161, EDCS-72700161, EDCS-76400130, ...
#
#                                               EDH_per3  \
# 465  [HD033385, HD000463, HD052542, HD033325, HD033...
# 411                     [HD001617, HD050227, HD053527]
# 126  [HD006602, HD031526, HD030365, HD030401, HD030...
# 167                               [HD018809, HD010890]
# 120  [HD031155, HD040405, HD040405, HD040353, HD040...
#
#                                              EDCS_per3  LIRE_per1_N  \
# 465      [EDCS-25500560, EDCS-26800812, EDCS-26800790]            1
# 411  [EDCS-09200591, EDCS-09500338, EDCS-09200688, ...           53
# 126  [EDCS-05600095, EDCS-05600096, EDCS-21700295, ...          540
# 167  [EDCS-64901116, EDCS-12300341, EDCS-04900290, ...           41
# 120  [EDCS-17000012, EDCS-69300353, EDCS-74100142, ...          181
#
#      LIRE_per2_N  LIRE_per3_N
# 465            1           10
# 411           73           30
# 126          720          309
# 167           54           22
# 120          249          205

# %%
s = sddk.cloudSession("sciencedata.dk", "SDAM_root", "648597@au.dk")
# Out:
# Your ScienceData username (e.g. '123456@au.dk'): 648597@au.dk
# Your ScienceData password: ········
# connection with shared folder established with you as its owner
# endpoint variable has been configured to: https://sciencedata.dk/files/SDAM_root/

# %%
pd.DataFrame(orbis_hanson_gpd).drop(["geometry"], axis=1)
# Out:
#         id                      label  rank       x       y  cost  target  \
# 465  50474              Portus Magnus    70  -0.266  35.808     0       0
# 411  50418                     Vienna    90   4.878  45.524     0       0
# 126  50131                    Corduba   100  -4.780  37.884     0       0
# 167  50172                   Faventia    70  11.883  44.285     0       0
# 120  50125  Ulpia Traiana Tricensimae    80   6.445  51.668     0       0
# ..     ...                        ...   ...     ...     ...   ...     ...
# 558  50623                Kalos Limen    80  32.703  45.521     0       0
# 589  50682                      Ammon    80  25.544  29.205     0       0
# 580  50651                 Dioscurias    90  41.003  42.993     0       0
# 581  50652                     Phasis    80  41.667  42.150     0       0
# 579  50650                     Tanais    80  39.258  47.268     0       0
#
#                     province   modern           hanson_label hanson_ID  \
# 465  Mauretania Caesariensis  Algeria          Portus Magnus      1182
# 411              Narbonensis   France                 Vienna       658
# 126                  Baetica    Spain                Corduba       336
# 167                   Italia    Italy               Faventia      1014
# 120        Germania Inferior  Germany  Colonia Ulpia Traiana       661
# ..                       ...      ...                    ...       ...
# 558         Outside_Blacksea  Ukraine                   None      None
# 589                 Aegyptus    Egypt                   None      None
# 580         Outside_Blacksea  Georgia                   None      None
# 581         Outside_Blacksea  Georgia                   None      None
# 579         Outside_Blacksea   Russia                   None      None
#
#      pop_est              hanson_geo      dist  \
# 465   1000.0  [-0.266018, 35.807917]  0.000085
# 411  15332.0   [4.878056, 45.524167]  0.000176
# 126  19404.0    [-4.78025, 37.88376]  0.000347
# 167   5399.0  [11.882989, 44.285348]  0.000348
# 120  14596.0   [6.444591, 51.668014]  0.000409
# ..       ...                     ...       ...
# 558   1000.0                    None       NaN
# 589   1000.0                    None       NaN
# 580   1000.0                    None       NaN
# 581   1000.0                    None       NaN
# 579   1000.0                    None       NaN
#
#                                                EDH_all  \
# 465  [HD047307, HD033385, HD000463, HD052542, HD033...
# 411  [HD052078, HD052079, HD001171, HD001626, HD001...
# 126  [HD006608, HD006605, HD006602, HD006599, HD000...
# 167  [HD017246, HD016084, HD018809, HD008967, HD032...
# 120  [HD031155, HD050305, HD050306, HD050307, HD022...
# ..                                                 ...
# 558                                                 []
# 589                                                 []
# 580                                                 []
# 581                                                 []
# 579                                                 []
#
#                                               EDCS_all  LIRE_total_N  \
# 465  [EDCS-75300340, EDCS-25500569, EDCS-25500582, ...            16
# 411  [EDCS-09200591, EDCS-09200592, EDCS-09500338, ...           119
# 126  [EDCS-72600014, EDCS-72600015, EDCS-75900070, ...          1290
# 167  [EDCS-64901116, EDCS-30200030, EDCS-30400520, ...           102
# 120  [EDCS-78300132, EDCS-78300660, EDCS-72700161, ...           424
# ..                                                 ...           ...
# 558                                                 []             0
# 589                                                 []             0
# 580                                                 []             0
# 581                                                 []             0
# 579                                                 []             0
#
#                                               EDH_per1  \
# 465                                                 []
# 411  [HD001171, HD001626, HD001620, HD001623, HD049...
# 126  [HD006599, HD000035, HD028010, HD013569, HD028...
# 167  [HD018809, HD032458, HD005009, HD003863, HD003...
# 120  [HD050305, HD050306, HD040731, HD040731, HD040...
# ..                                                 ...
# 558                                                 []
# 589                                                 []
# 580                                                 []
# 581                                                 []
# 579                                                 []
#
#                                              EDCS_per1  \
# 465                                    [EDCS-25500582]
# 411  [EDCS-09200592, EDCS-09200607, EDCS-09200608, ...
# 126  [EDCS-72600014, EDCS-75900070, EDCS-75900071, ...
# 167  [EDCS-04900283, EDCS-04900288, EDCS-20402028, ...
# 120  [EDCS-78300132, EDCS-78300660, EDCS-72700161, ...
# ..                                                 ...
# 558                                                 []
# 589                                                 []
# 580                                                 []
# 581                                                 []
# 579                                                 []
#
#                                               EDH_per2  \
# 465                                                 []
# 411  [HD052078, HD052079, HD001617, HD052073, HD050...
# 126  [HD006608, HD006605, HD006602, HD006599, HD000...
# 167  [HD017246, HD016084, HD018809, HD008967, HD010...
# 120  [HD031155, HD050305, HD050307, HD022736, HD022...
# ..                                                 ...
# 558                                                 []
# 589                                                 []
# 580                                                 []
# 581                                                 []
# 579                                                 []
#
#                                              EDCS_per2  \
# 465                                    [EDCS-25500569]
# 411  [EDCS-09200591, EDCS-09200607, EDCS-09200608, ...
# 126  [EDCS-72600015, EDCS-73900025, EDCS-76900064, ...
# 167  [EDCS-30200030, EDCS-30400520, EDCS-31200405, ...
# 120  [EDCS-72700161, EDCS-72700161, EDCS-76400130, ...
# ..                                                 ...
# 558                                                 []
# 589                                                 []
# 580                                                 []
# 581                                                 []
# 579                                                 []
#
#                                               EDH_per3  \
# 465  [HD033385, HD000463, HD052542, HD033325, HD033...
# 411                     [HD001617, HD050227, HD053527]
# 126  [HD006602, HD031526, HD030365, HD030401, HD030...
# 167                               [HD018809, HD010890]
# 120  [HD031155, HD040405, HD040405, HD040353, HD040...
# ..                                                 ...
# 558                                                 []
# 589                                                 []
# 580                                                 []
# 581                                                 []
# 579                                                 []
#
#                                              EDCS_per3  LIRE_per1_N  \
# 465      [EDCS-25500560, EDCS-26800812, EDCS-26800790]            1
# 411  [EDCS-09200591, EDCS-09500338, EDCS-09200688, ...           53
# 126  [EDCS-05600095, EDCS-05600096, EDCS-21700295, ...          540
# 167  [EDCS-64901116, EDCS-12300341, EDCS-04900290, ...           41
# 120  [EDCS-17000012, EDCS-69300353, EDCS-74100142, ...          181
# ..                                                 ...          ...
# 558                                                 []            0
# 589                                                 []            0
# 580                                                 []            0
# 581                                                 []            0
# 579                                                 []            0
#
#      LIRE_per2_N  LIRE_per3_N
# 465            1           10
# 411           73           30
# 126          720          309
# 167           54           22
# 120          249          205
# ..           ...          ...
# 558            0            0
# 589            0            0
# 580            0            0
# 581            0            0
# 579            0            0
#
# [633 rows x 26 columns]

# %%
# save it as json (you have to drop the geometry first)
s.write_file("SDAM_data/urban/orbis_hanson.json", pd.DataFrame(orbis_hanson_gpd).drop(["geometry"], axis=1))
# Out:
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/urban/orbis_hanson.json"

# %%
# save as geojson (be careful in reading back)
s.write_file("SDAM_data/urban/orbis_hanson.geojson", orbis_hanson_gpd)
# Out:
# A file with the same name ("orbis_hanson.geojson") already exists in this location.
# Press Enter to overwrite it or choose different path and filename:
# Your <class 'geopandas.geodataframe.GeoDataFrame'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/urban/orbis_hanson.geojson"

# %%
# save as csv (be careful in reading back)
s.write_file("SDAM_data/urban/orbis_hanson.csv", orbis_hanson_gpd)
# Out:
# A file with the same name ("orbis_hanson.csv") already exists in this location.
# Press Enter to overwrite it or choose different path and filename:
# Your <class 'geopandas.geodataframe.GeoDataFrame'> object has been succefully written as "https://sciencedata.dk/files/SDAM_root/SDAM_data/urban/orbis_hanson.csv"

# %%
# save locally as csv
orbis_hanson_gpd.to_csv("../data/orbis_hanson.csv")
